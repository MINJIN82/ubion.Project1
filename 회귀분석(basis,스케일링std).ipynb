# %%
import pandas as pd
import numpy as np
import scipy.stats

# %%
df = pd.read_excel("../데이터자료/join_data.xlsx",index_col=0)
df_data=df[['DateTime', '종가_ex','1Y_Mid_irs','2Y_Mid_irs','3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs',
 '1Y_Mid_crs','2Y_Mid_crs','3Y_Mid_crs','5Y_Mid_crs','10Y_Mid_crs', '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
df_data
# Out:
#         DateTime   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  \
# 열1
# 0     2012-08-01  1126.5       2.850       2.740       2.740       2.770
# 1     2012-08-02  1131.7       2.820       2.690       2.690       2.720
# 2     2012-08-03  1134.8       2.790       2.660       2.660       2.690
# 3     2012-08-06  1129.0       2.810       2.680       2.680       2.710
# 4     2012-08-07  1128.8       2.820       2.680       2.680       2.720
# ...          ...     ...         ...         ...         ...         ...
# 2455  2022-07-25  1313.7       3.165       3.235       3.205       3.125
# 2456  2022-07-26  1307.6       3.155       3.215       3.175       3.095
# 2457  2022-07-27  1313.3       3.145       3.165       3.115       3.035
# 2458  2022-07-28  1296.1       3.175       3.205       3.165       3.085
# 2459  2022-07-29  1299.1       3.105       3.065       3.025       2.945
#
#       10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  국고10년  통안364일  \
# 열1                                                     ...
# 0           2.910        2.09       1.815        1.81  ...   3.14    2.80
# 1           2.860        2.08       1.845        1.85  ...   3.10    2.77
# 2           2.840        2.07       1.830        1.83  ...   3.03    2.75
# 3           2.850        2.07       1.805        1.80  ...   3.03    2.76
# 4           2.870        2.09       1.820        1.80  ...   3.03    2.75
# ...           ...         ...         ...         ...  ...    ...     ...
# 2455        2.965        2.55       2.730        2.71  ...   3.21    2.98
# 2456        2.935        2.56       2.700        2.68  ...   3.18    2.99
# 2457        2.875        2.57       2.690        2.67  ...   3.12    3.01
# 2458        2.945        2.61       2.730        2.71  ...   3.20    3.03
# 2459        2.825        2.50       2.560        2.56  ...   3.12    3.00
#
#       통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0     2.83    -76.0    -92.5    -93.0   -105.0    -108.0       260  1132.25
# 1     2.78    -74.0    -84.5    -84.0    -96.0     -99.0       250  1134.00
# 2     2.77    -72.0    -83.0    -83.0   -101.0    -112.0       240  1138.00
# 3     2.78    -74.0    -87.5    -88.0   -107.0    -117.0       240  1128.50
# 4     2.77    -73.0    -86.0    -88.0   -115.0    -127.0       250  1129.00
# ...    ...      ...      ...      ...      ...       ...       ...      ...
# 2455  3.09    -61.5    -50.5    -49.5    -61.5     -60.5       -60  1309.85
# 2456  3.09    -59.5    -51.5    -49.5    -60.5     -59.5       -70  1311.00
# 2457  3.08    -57.5    -47.5    -44.5    -55.5     -54.5       -55  1310.50
# 2458  3.11    -56.5    -47.5    -45.5    -57.5     -59.5       -65  1306.00
# 2459  3.00    -60.5    -50.5    -46.5    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 25 columns]

# %%
df_data.iloc[1968]
# Out:
# DateTime       2020-08-03
# 종가_ex              1193.4
# 1Y_Mid_irs          0.735
# 2Y_Mid_irs          0.755
# 3Y_Mid_irs          0.785
# 5Y_Mid_irs          0.835
# 10Y_Mid_irs         0.905
# 1Y_Mid_crs         -0.005
# 2Y_Mid_crs          -0.05
# 3Y_Mid_crs          -0.04
# 5Y_Mid_crs          -0.02
# 10Y_Mid_crs         0.215
# 국고1년                 0.65
# 국고3년                 0.79
# 국고5년                 1.04
# 국고10년                 1.3
# 통안364일               0.59
# 통안2년                 0.72
# 1Y_베이시스             -74.0
# 2Y_베이시스             -80.5
# 3Y_베이시스             -82.5
# 5Y_베이시스             -85.5
# 10Y_베이시스            -69.0
# M1_스왑포인트              -10
# Mid_ndf            1194.4
# Name: 1968, dtype: object

# %%
x = df_data[[ '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
y = df_data["종가_ex"]
x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2024\55722237.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#           국고1년      국고3년      국고5년     국고10년    통안364일      통안2년   1Y_베이시스  \
# 열1
# 0     1.736854  1.418482  1.193353  1.198149  1.685954  1.508426 -0.625745
# 1     1.689516  1.356375  1.137069  1.136882  1.638991  1.430584 -0.537507
# 2     1.657958  1.325322  1.038571  1.029664  1.607682  1.415016 -0.449269
# 3     1.673737  1.340848  1.038571  1.029664  1.623336  1.430584 -0.537507
# 4     1.657958  1.340848  1.038571  1.029664  1.607682  1.415016 -0.493388
# ...        ...       ...       ...       ...       ...       ...       ...
# 2455  1.894644  1.915335  1.305922  1.305367  1.967736  1.913203  0.013980
# 2456  1.910423  1.868755  1.277780  1.259417  1.983390  1.913203  0.102218
# 2457  1.910423  1.822175  1.207424  1.167516  2.014699  1.897634  0.190456
# 2458  1.926203  1.884282  1.249638  1.290050  2.046008  1.944339  0.234575
# 2459  1.863086  1.682435  1.080784  1.167516  1.999045  1.773088  0.058099
#
#        2Y_베이시스   3Y_베이시스   5Y_베이시스  10Y_베이시스  M1_스왑포인트   Mid_ndf
# 열1
# 0    -0.820773 -0.839954 -1.393411 -1.897293  1.997906 -0.056053
# 1    -0.492974 -0.480805 -1.033964 -1.523564  1.907434 -0.024147
# 2    -0.431511 -0.440899 -1.233657 -2.063395  1.816961  0.048782
# 3    -0.615899 -0.640427 -1.473288 -2.271023  1.816961 -0.124423
# 4    -0.554436 -0.640427 -1.792797 -2.686278  1.907434 -0.115307
# ...        ...       ...       ...       ...       ...       ...
# 2455  0.900175  0.895936  0.343919  0.075168 -0.897226  3.181963
# 2456  0.859200  0.895936  0.383857  0.116693 -0.987699  3.202930
# 2457  1.023100  1.095463  0.583550  0.324321 -0.851990  3.193814
# 2458  1.023100  1.055558  0.503673  0.116693 -0.942463  3.111769
# 2459  0.900175  1.015652  0.703366  0.241270 -0.897226  2.924891
#
# [2460 rows x 13 columns]

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.389e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:28   Log-Likelihood:                -6981.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2446   BIC:                         1.407e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고1년           0.0366      0.968      0.038      0.970      -1.861       1.934
# 국고3년           0.5897      0.868      0.679      0.497      -1.113       2.292
# 국고5년          -0.5085      1.039     -0.490      0.624      -2.545       1.528
# 국고10년         -0.4795      0.921     -0.521      0.603      -2.285       1.327
# 통안364일        -0.3577      0.765     -0.467      0.640      -1.859       1.143
# 통안2년           0.5033      0.842      0.598      0.550      -1.148       2.154
# 1Y_베이시스       -0.6559      0.212     -3.094      0.002      -1.072      -0.240
# 2Y_베이시스        0.5173      0.630      0.821      0.412      -0.719       1.753
# 3Y_베이시스       -0.5440      0.552     -0.985      0.324      -1.627       0.539
# 5Y_베이시스        0.7966      0.444      1.792      0.073      -0.075       1.668
# 10Y_베이시스      -0.4774      0.270     -1.769      0.077      -1.007       0.052
# M1_스왑포인트      -1.1461      0.154     -7.429      0.000      -1.449      -0.844
# Mid_ndf       54.8152      0.129    423.573      0.000      54.561      55.069
# ==============================================================================
# Omnibus:                      331.261   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2024.790
# Skew:                           0.473   Prob(JB):                         0.00
# Kurtosis:                       7.343   Cond. No.                         46.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor   Feature
# 0   133.977068      국고1년
# 1   107.872336      국고3년
# 2   154.391806      국고5년
# 3   121.405725     국고10년
# 4    83.840700    통안364일
# 5   101.476515      통안2년
# 6     6.431461   1Y_베이시스
# 7    56.878526   2Y_베이시스
# 8    43.622235   3Y_베이시스
# 9    28.270400   5Y_베이시스
# 10   10.427117  10Y_베이시스
# 11    3.406645  M1_스왑포인트
# 12    2.397021   Mid_ndf

# %%
x_scaled.drop(['국고1년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.673e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:29   Log-Likelihood:                -6981.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2447   BIC:                         1.407e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고3년           0.5920      0.866      0.684      0.494      -1.106       2.290
# 국고5년          -0.4957      0.982     -0.505      0.614      -2.422       1.431
# 국고10년         -0.4929      0.850     -0.580      0.562      -2.160       1.174
# 통안364일        -0.3340      0.436     -0.766      0.444      -1.189       0.521
# 통안2년           0.5125      0.806      0.636      0.525      -1.068       2.093
# 1Y_베이시스       -0.6576      0.207     -3.176      0.002      -1.064      -0.252
# 2Y_베이시스        0.5215      0.620      0.841      0.401      -0.695       1.738
# 3Y_베이시스       -0.5463      0.549     -0.996      0.320      -1.622       0.530
# 5Y_베이시스        0.7956      0.444      1.793      0.073      -0.074       1.666
# 10Y_베이시스      -0.4783      0.269     -1.779      0.075      -1.006       0.049
# M1_스왑포인트      -1.1444      0.147     -7.760      0.000      -1.434      -0.855
# Mid_ndf       54.8142      0.127    431.518      0.000      54.565      55.063
# ==============================================================================
# Omnibus:                      331.234   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2024.435
# Skew:                           0.473   Prob(JB):                         0.00
# Kurtosis:                       7.342   Cond. No.                         39.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor   Feature
# 0   107.354147      국고3년
# 1   138.172736      국고5년
# 2   103.459710     국고10년
# 3    27.245743    통안364일
# 4    93.007858      통안2년
# 5     6.137509   1Y_베이시스
# 6    55.118679   2Y_베이시스
# 7    43.109823   3Y_베이시스
# 8    28.182809   5Y_베이시스
# 9    10.352890  10Y_베이시스
# 10    3.114312  M1_스왑포인트
# 11    2.310430   Mid_ndf

# %%
x_scaled.drop(['국고5년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.008e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:29   Log-Likelihood:                -6982.0
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2448   BIC:                         1.406e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고3년           0.5871      0.866      0.678      0.498      -1.110       2.285
# 국고10년         -0.8534      0.460     -1.853      0.064      -1.756       0.050
# 통안364일        -0.4273      0.395     -1.082      0.279      -1.202       0.347
# 통안2년           0.4542      0.798      0.570      0.569      -1.110       2.018
# 1Y_베이시스       -0.6656      0.206     -3.225      0.001      -1.070      -0.261
# 2Y_베이시스        0.5524      0.617      0.895      0.371      -0.658       1.763
# 3Y_베이시스       -0.5387      0.548     -0.982      0.326      -1.614       0.537
# 5Y_베이시스        0.6917      0.393      1.760      0.078      -0.079       1.462
# 10Y_베이시스      -0.4232      0.246     -1.722      0.085      -0.905       0.059
# M1_스왑포인트      -1.1200      0.139     -8.041      0.000      -1.393      -0.847
# Mid_ndf       54.8217      0.126    434.564      0.000      54.574      55.069
# ==============================================================================
# Omnibus:                      330.434   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2015.934
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.333   Cond. No.                         31.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor   Feature
# 0   107.340932      국고3년
# 1    30.371138     국고10년
# 2    22.342996    통안364일
# 3    91.102721      통안2년
# 4     6.101620   1Y_베이시스
# 5    54.580664   2Y_베이시스
# 6    43.077478   3Y_베이시스
# 7    22.113908   5Y_베이시스
# 8     8.644589  10Y_베이시스
# 9     2.778584  M1_스왑포인트
# 10    2.279466   Mid_ndf

# %%
x_scaled.drop(['국고3년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.410e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:29   Log-Likelihood:                -6982.3
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2449   BIC:                         1.405e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고10년         -0.6524      0.352     -1.851      0.064      -1.344       0.039
# 통안364일        -0.4012      0.393     -1.021      0.307      -1.172       0.369
# 통안2년           0.8404      0.558      1.505      0.132      -0.255       1.935
# 1Y_베이시스       -0.6558      0.206     -3.186      0.001      -1.060      -0.252
# 2Y_베이시스        0.5020      0.613      0.819      0.413      -0.700       1.704
# 3Y_베이시스       -0.4723      0.540     -0.875      0.381      -1.530       0.586
# 5Y_베이시스        0.6538      0.389      1.681      0.093      -0.109       1.416
# 10Y_베이시스      -0.3987      0.243     -1.641      0.101      -0.875       0.078
# M1_스왑포인트      -1.1328      0.138     -8.211      0.000      -1.403      -0.862
# Mid_ndf       54.8478      0.120    456.644      0.000      54.612      55.083
# ==============================================================================
# Omnibus:                      331.299   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2028.910
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         22.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   17.795821     국고10년
# 1   22.130662    통안364일
# 2   44.674320      통안2년
# 3    6.071917   1Y_베이시스
# 4   53.788033   2Y_베이시스
# 5   41.705320   3Y_베이시스
# 6   21.665285   5Y_베이시스
# 7    8.458681  10Y_베이시스
# 8    2.727079  M1_스왑포인트
# 9    2.066782   Mid_ndf

# %%
x_scaled.drop(['통안364일'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.900e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:30   Log-Likelihood:                -6982.8
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2450   BIC:                         1.404e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고10년         -0.4818      0.310     -1.553      0.121      -1.090       0.127
# 통안2년           0.3402      0.268      1.270      0.204      -0.185       0.866
# 1Y_베이시스       -0.6335      0.205     -3.094      0.002      -1.035      -0.232
# 2Y_베이시스        0.3971      0.604      0.657      0.511      -0.787       1.582
# 3Y_베이시스       -0.3603      0.528     -0.682      0.495      -1.396       0.676
# 5Y_베이시스        0.6083      0.386      1.575      0.115      -0.149       1.366
# 10Y_베이시스      -0.3504      0.238     -1.470      0.142      -0.818       0.117
# M1_스왑포인트      -1.1680      0.134     -8.742      0.000      -1.430      -0.906
# Mid_ndf       54.9066      0.105    520.793      0.000      54.700      55.113
# ==============================================================================
# Omnibus:                      329.041   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2026.508
# Skew:                           0.465   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         20.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   13.793215     국고10년
# 1   10.285651      통안2년
# 2    6.003156   1Y_베이시스
# 3   52.276280   2Y_베이시스
# 4   39.979035   3Y_베이시스
# 5   21.380574   5Y_베이시스
# 6    8.138158  10Y_베이시스
# 7    2.557483  M1_스왑포인트
# 8    1.592366   Mid_ndf

# %%
x_scaled.drop(['2Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 5.514e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:30   Log-Likelihood:                -6983.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2451   BIC:                         1.404e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고10년         -0.5098      0.307     -1.659      0.097      -1.112       0.093
# 통안2년           0.3424      0.268      1.278      0.201      -0.183       0.868
# 1Y_베이시스       -0.5479      0.158     -3.468      0.001      -0.858      -0.238
# 3Y_베이시스       -0.0717      0.294     -0.244      0.807      -0.648       0.504
# 5Y_베이시스        0.6634      0.377      1.760      0.079      -0.076       1.403
# 10Y_베이시스      -0.3960      0.228     -1.736      0.083      -0.843       0.051
# M1_스왑포인트      -1.1922      0.128     -9.285      0.000      -1.444      -0.940
# Mid_ndf       54.8867      0.101    543.473      0.000      54.689      55.085
# ==============================================================================
# Omnibus:                      329.290   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2026.625
# Skew:                           0.466   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   13.534215     국고10년
# 1   10.284104      통안2년
# 2    3.577453   1Y_베이시스
# 3   12.363081   3Y_베이시스
# 4   20.372150   5Y_베이시스
# 5    7.451701  10Y_베이시스
# 6    2.362648  M1_스왑포인트
# 7    1.461516   Mid_ndf

# %%
x_scaled.drop(['3Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 6.304e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:31   Log-Likelihood:                -6983.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2452   BIC:                         1.403e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고10년         -0.4847      0.290     -1.674      0.094      -1.053       0.083
# 통안2년           0.3193      0.251      1.274      0.203      -0.172       0.811
# 1Y_베이시스       -0.5646      0.142     -3.965      0.000      -0.844      -0.285
# 5Y_베이시스        0.5921      0.238      2.489      0.013       0.126       1.058
# 10Y_베이시스      -0.3726      0.207     -1.800      0.072      -0.779       0.033
# M1_스왑포인트      -1.1838      0.124     -9.569      0.000      -1.426      -0.941
# Mid_ndf       54.8848      0.101    545.094      0.000      54.687      55.082
# ==============================================================================
# Omnibus:                      329.227   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2025.689
# Skew:                           0.466   Prob(JB):                         0.00
# Kurtosis:                       7.347   Cond. No.                         8.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   12.024835     국고10년
# 1    9.003008      통안2년
# 2    2.906440   1Y_베이시스
# 3    8.109798   5Y_베이시스
# 4    6.142427  10Y_베이시스
# 5    2.194287  M1_스왑포인트
# 6    1.453297   Mid_ndf

# %%
x_scaled.drop(['통안2년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 7.353e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:31   Log-Likelihood:                -6983.8
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2453   BIC:                         1.402e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 국고10년         -0.1498      0.122     -1.232      0.218      -0.388       0.089
# 1Y_베이시스       -0.5123      0.136     -3.757      0.000      -0.780      -0.245
# 5Y_베이시스        0.5838      0.238      2.455      0.014       0.117       1.050
# 10Y_베이시스      -0.4130      0.205     -2.019      0.044      -0.814      -0.012
# M1_스왑포인트      -1.2261      0.119    -10.285      0.000      -1.460      -0.992
# Mid_ndf       54.9048      0.099    551.947      0.000      54.710      55.100
# ==============================================================================
# Omnibus:                      332.458   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2065.872
# Skew:                           0.470   Prob(JB):                         0.00
# Kurtosis:                       7.390   Cond. No.                         6.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0    2.118655     국고10년
# 1    2.664653   1Y_베이시스
# 2    8.103715   5Y_베이시스
# 3    5.998621  10Y_베이시스
# 4    2.036752  M1_스왑포인트
# 5    1.418102   Mid_ndf

# %%
x_scaled.drop(['국고10년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 8.822e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:17:55   Log-Likelihood:                -6984.6
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2454   BIC:                         1.402e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8905      0.084   1.36e+04      0.000    1134.727    1135.054
# 1Y_베이시스       -0.4481      0.126     -3.556      0.000      -0.695      -0.201
# 5Y_베이시스        0.5589      0.237      2.358      0.018       0.094       1.024
# 10Y_베이시스      -0.4071      0.205     -1.990      0.047      -0.808      -0.006
# M1_스왑포인트      -1.3065      0.100    -13.100      0.000      -1.502      -1.111
# Mid_ndf       54.9434      0.094    581.864      0.000      54.758      55.129
# ==============================================================================
# Omnibus:                      341.272   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2152.876
# Skew:                           0.484   Prob(JB):                         0.00
# Kurtosis:                       7.480   Cond. No.                         5.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled


def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0    2.275262   1Y_베이시스
# 1    8.045057   5Y_베이시스
# 2    5.995341  10Y_베이시스
# 3    1.425362  M1_스왑포인트
# 4    1.277551   Mid_ndf

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
x_train = x_scaled[:1968]
x_test = x_scaled[1968:]
y_train = y[:1968]
y_test = y[1968:]

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 14.204683207692884, RMSE :  3.769, MAE: 3.769
# Variance score :  0.996

# %%
x
# Out:
#       1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  10Y_Mid_irs  1Y_Mid_crs  \
# 열1
# 0          2.850       2.740       2.740       2.770        2.910        2.09
# 1          2.820       2.690       2.690       2.720        2.860        2.08
# 2          2.790       2.660       2.660       2.690        2.840        2.07
# 3          2.810       2.680       2.680       2.710        2.850        2.07
# 4          2.820       2.680       2.680       2.720        2.870        2.09
# ...          ...         ...         ...         ...          ...         ...
# 2455       3.165       3.235       3.205       3.125        2.965        2.55
# 2456       3.155       3.215       3.175       3.095        2.935        2.56
# 2457       3.145       3.165       3.115       3.035        2.875        2.57
# 2458       3.175       3.205       3.165       3.085        2.945        2.61
# 2459       3.105       3.065       3.025       2.945        2.825        2.50
#
#       2Y_Mid_crs  3Y_Mid_crs  5Y_Mid_crs  10Y_Mid_crs  1Y_베이시스  M1_스왑포인트  \
# 열1
# 0          1.815        1.81        1.72         1.83    -76.0       260
# 1          1.845        1.85        1.76         1.87    -74.0       250
# 2          1.830        1.83        1.68         1.72    -72.0       240
# 3          1.805        1.80        1.64         1.68    -74.0       240
# 4          1.820        1.80        1.57         1.60    -73.0       250
# ...          ...         ...         ...          ...      ...       ...
# 2455       2.730        2.71        2.51         2.36    -61.5       -60
# 2456       2.700        2.68        2.49         2.34    -59.5       -70
# 2457       2.690        2.67        2.48         2.33    -57.5       -55
# 2458       2.730        2.71        2.51         2.35    -56.5       -65
# 2459       2.560        2.56        2.42         2.26    -60.5       -60
#
#       Mid_ndf
# 열1
# 0     1132.25
# 1     1134.00
# 2     1138.00
# 3     1128.50
# 4     1129.00
# ...       ...
# 2455  1309.85
# 2456  1311.00
# 2457  1310.50
# 2458  1306.00
# 2459  1295.75
#
# [2460 rows x 13 columns]

# %%
x
# Out:
#       1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  10Y_Mid_irs  1Y_Mid_crs  \
# 열1
# 0          2.850       2.740       2.740       2.770        2.910        2.09
# 1          2.820       2.690       2.690       2.720        2.860        2.08
# 2          2.790       2.660       2.660       2.690        2.840        2.07
# 3          2.810       2.680       2.680       2.710        2.850        2.07
# 4          2.820       2.680       2.680       2.720        2.870        2.09
# ...          ...         ...         ...         ...          ...         ...
# 2455       3.165       3.235       3.205       3.125        2.965        2.55
# 2456       3.155       3.215       3.175       3.095        2.935        2.56
# 2457       3.145       3.165       3.115       3.035        2.875        2.57
# 2458       3.175       3.205       3.165       3.085        2.945        2.61
# 2459       3.105       3.065       3.025       2.945        2.825        2.50
#
#       2Y_Mid_crs  3Y_Mid_crs  5Y_Mid_crs  10Y_Mid_crs  1Y_베이시스  M1_스왑포인트  \
# 열1
# 0          1.815        1.81        1.72         1.83    -76.0       260
# 1          1.845        1.85        1.76         1.87    -74.0       250
# 2          1.830        1.83        1.68         1.72    -72.0       240
# 3          1.805        1.80        1.64         1.68    -74.0       240
# 4          1.820        1.80        1.57         1.60    -73.0       250
# ...          ...         ...         ...          ...      ...       ...
# 2455       2.730        2.71        2.51         2.36    -61.5       -60
# 2456       2.700        2.68        2.49         2.34    -59.5       -70
# 2457       2.690        2.67        2.48         2.33    -57.5       -55
# 2458       2.730        2.71        2.51         2.35    -56.5       -65
# 2459       2.560        2.56        2.42         2.26    -60.5       -60
#
#       Mid_ndf
# 열1
# 0     1132.25
# 1     1134.00
# 2     1138.00
# 3     1128.50
# 4     1129.00
# ...       ...
# 2455  1309.85
# 2456  1311.00
# 2457  1310.50
# 2458  1306.00
# 2459  1295.75
#
# [2460 rows x 13 columns]
