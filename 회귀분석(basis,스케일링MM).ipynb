# %%
import pandas as pd
import numpy as np
import scipy.stats

# %%
df = pd.read_excel("../데이터자료/join_data.xlsx",index_col=0)
df_data=df[['DateTime', '종가_ex','1Y_Mid_irs','2Y_Mid_irs','3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs',
 '1Y_Mid_crs','2Y_Mid_crs','3Y_Mid_crs','5Y_Mid_crs','10Y_Mid_crs', '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
df_data
# Out:
#         DateTime   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  \
# 열1
# 0     2012-08-01  1126.5       2.850       2.740       2.740       2.770
# 1     2012-08-02  1131.7       2.820       2.690       2.690       2.720
# 2     2012-08-03  1134.8       2.790       2.660       2.660       2.690
# 3     2012-08-06  1129.0       2.810       2.680       2.680       2.710
# 4     2012-08-07  1128.8       2.820       2.680       2.680       2.720
# ...          ...     ...         ...         ...         ...         ...
# 2455  2022-07-25  1313.7       3.165       3.235       3.205       3.125
# 2456  2022-07-26  1307.6       3.155       3.215       3.175       3.095
# 2457  2022-07-27  1313.3       3.145       3.165       3.115       3.035
# 2458  2022-07-28  1296.1       3.175       3.205       3.165       3.085
# 2459  2022-07-29  1299.1       3.105       3.065       3.025       2.945
#
#       10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  국고10년  통안364일  \
# 열1                                                     ...
# 0           2.910        2.09       1.815        1.81  ...   3.14    2.80
# 1           2.860        2.08       1.845        1.85  ...   3.10    2.77
# 2           2.840        2.07       1.830        1.83  ...   3.03    2.75
# 3           2.850        2.07       1.805        1.80  ...   3.03    2.76
# 4           2.870        2.09       1.820        1.80  ...   3.03    2.75
# ...           ...         ...         ...         ...  ...    ...     ...
# 2455        2.965        2.55       2.730        2.71  ...   3.21    2.98
# 2456        2.935        2.56       2.700        2.68  ...   3.18    2.99
# 2457        2.875        2.57       2.690        2.67  ...   3.12    3.01
# 2458        2.945        2.61       2.730        2.71  ...   3.20    3.03
# 2459        2.825        2.50       2.560        2.56  ...   3.12    3.00
#
#       통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0     2.83    -76.0    -92.5    -93.0   -105.0    -108.0       260  1132.25
# 1     2.78    -74.0    -84.5    -84.0    -96.0     -99.0       250  1134.00
# 2     2.77    -72.0    -83.0    -83.0   -101.0    -112.0       240  1138.00
# 3     2.78    -74.0    -87.5    -88.0   -107.0    -117.0       240  1128.50
# 4     2.77    -73.0    -86.0    -88.0   -115.0    -127.0       250  1129.00
# ...    ...      ...      ...      ...      ...       ...       ...      ...
# 2455  3.09    -61.5    -50.5    -49.5    -61.5     -60.5       -60  1309.85
# 2456  3.09    -59.5    -51.5    -49.5    -60.5     -59.5       -70  1311.00
# 2457  3.08    -57.5    -47.5    -44.5    -55.5     -54.5       -55  1310.50
# 2458  3.11    -56.5    -47.5    -45.5    -57.5     -59.5       -65  1306.00
# 2459  3.00    -60.5    -50.5    -46.5    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 25 columns]

# %%
df_data.iloc[1968]
# Out:
# DateTime       2020-08-03
# 종가_ex              1193.4
# 1Y_Mid_irs          0.735
# 2Y_Mid_irs          0.755
# 3Y_Mid_irs          0.785
# 5Y_Mid_irs          0.835
# 10Y_Mid_irs         0.905
# 1Y_Mid_crs         -0.005
# 2Y_Mid_crs          -0.05
# 3Y_Mid_crs          -0.04
# 5Y_Mid_crs          -0.02
# 10Y_Mid_crs         0.215
# 국고1년                 0.65
# 국고3년                 0.79
# 국고5년                 1.04
# 국고10년                 1.3
# 통안364일               0.59
# 통안2년                 0.72
# 1Y_베이시스             -74.0
# 2Y_베이시스             -80.5
# 3Y_베이시스             -82.5
# 5Y_베이시스             -85.5
# 10Y_베이시스            -69.0
# M1_스왑포인트              -10
# Mid_ndf            1194.4
# Name: 1968, dtype: object

# %%
x = df_data[[ '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
y = df_data["종가_ex"]
x.feature = x.columns 

from sklearn.preprocessing import StandardScaler,MinMaxScaler, MaxAbsScaler

# StandardScaler객체 생성
scaler =  MaxAbsScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30620\2310096774.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#           국고1년      국고3년      국고5년     국고10년    통안364일      통안2년   1Y_베이시스  \
# 열1
# 0     0.936877  0.756684  0.815584  0.828496  0.784314  0.792717 -0.307071
# 1     0.926910  0.745989  0.805195  0.817942  0.775910  0.778711 -0.298990
# 2     0.920266  0.740642  0.787013  0.799472  0.770308  0.775910 -0.290909
# 3     0.923588  0.743316  0.787013  0.799472  0.773109  0.778711 -0.298990
# 4     0.920266  0.743316  0.787013  0.799472  0.770308  0.775910 -0.294949
# ...        ...       ...       ...       ...       ...       ...       ...
# 2455  0.970100  0.842246  0.836364  0.846966  0.834734  0.865546 -0.248485
# 2456  0.973422  0.834225  0.831169  0.839050  0.837535  0.865546 -0.240404
# 2457  0.973422  0.826203  0.818182  0.823219  0.843137  0.862745 -0.232323
# 2458  0.976744  0.836898  0.825974  0.844327  0.848739  0.871148 -0.228283
# 2459  0.963455  0.802139  0.794805  0.823219  0.840336  0.840336 -0.244444
#
#        2Y_베이시스   3Y_베이시스   5Y_베이시스  10Y_베이시스  M1_스왑포인트   Mid_ndf
# 열1
# 0    -0.457921 -0.443914 -0.486111 -0.496552  0.577778  0.858415
# 1    -0.418317 -0.400955 -0.444444 -0.455172  0.555556  0.859742
# 2    -0.410891 -0.396181 -0.467593 -0.514943  0.533333  0.862775
# 3    -0.433168 -0.420048 -0.495370 -0.537931  0.533333  0.855572
# 4    -0.425743 -0.420048 -0.532407 -0.583908  0.555556  0.855951
# ...        ...       ...       ...       ...       ...       ...
# 2455 -0.250000 -0.236277 -0.284722 -0.278161 -0.133333  0.993063
# 2456 -0.254950 -0.236277 -0.280093 -0.273563 -0.155556  0.993935
# 2457 -0.235149 -0.212411 -0.256944 -0.250575 -0.122222  0.993556
# 2458 -0.235149 -0.217184 -0.266204 -0.273563 -0.144444  0.990144
# 2459 -0.250000 -0.221957 -0.243056 -0.259770 -0.133333  0.982373
#
# [2460 rows x 13 columns]

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.389e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:52   Log-Likelihood:                -6981.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2446   BIC:                         1.407e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8647      2.953      0.293      0.770      -4.927       6.656
# 국고1년           0.1737      4.595      0.038      0.970      -8.837       9.185
# 국고3년           3.4244      5.041      0.679      0.497      -6.461      13.310
# 국고5년          -2.7546      5.627     -0.490      0.624     -13.788       8.279
# 국고10년         -2.7833      5.346     -0.521      0.603     -13.267       7.701
# 통안364일        -1.9993      4.277     -0.467      0.640     -10.387       6.388
# 통안2년           2.7971      4.680      0.598      0.550      -6.380      11.974
# 1Y_베이시스       -7.1618      2.315     -3.094      0.002     -11.701      -2.623
# 2Y_베이시스        4.2817      5.218      0.821      0.412      -5.950      14.513
# 3Y_베이시스       -4.5483      4.615     -0.985      0.324     -13.599       4.502
# 5Y_베이시스        6.8718      3.834      1.792      0.073      -0.646      14.390
# 10Y_베이시스      -4.3120      2.438     -1.769      0.077      -9.092       0.468
# M1_스왑포인트      -4.6662      0.628     -7.429      0.000      -5.898      -3.435
# Mid_ndf     1318.2008      3.112    423.573      0.000    1312.098    1324.303
# ==============================================================================
# Omnibus:                      331.261   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2024.790
# Skew:                           0.473   Prob(JB):                         0.00
# Kurtosis:                       7.343   Cond. No.                         204.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#      VIF_Factor   Feature
# 0   1067.937135      국고1년
# 1    929.537722      국고3년
# 2   1759.527045      국고5년
# 3   1515.745334     국고10년
# 4    691.080724    통안364일
# 5    930.164477      통안2년
# 6     53.194185   1Y_베이시스
# 7    555.907415   2Y_베이시스
# 8    402.987054   3Y_베이시스
# 9    237.905170   5Y_베이시스
# 10    71.654085  10Y_베이시스
# 11     3.753484  M1_스왑포인트
# 12    32.496897   Mid_ndf

# %%
x_scaled.drop(['국고1년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.673e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:52   Log-Likelihood:                -6981.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2447   BIC:                         1.407e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8887      2.883      0.308      0.758      -4.765       6.543
# 국고3년           3.4376      5.028      0.684      0.494      -6.422      13.297
# 국고5년          -2.6856      5.322     -0.505      0.614     -13.121       7.750
# 국고10년         -2.8611      4.934     -0.580      0.562     -12.537       6.815
# 통안364일        -1.8664      2.438     -0.766      0.444      -6.647       2.914
# 통안2년           2.8482      4.479      0.636      0.525      -5.936      11.632
# 1Y_베이시스       -7.1805      2.261     -3.176      0.002     -11.614      -2.747
# 2Y_베이시스        4.3164      5.135      0.841      0.401      -5.754      14.386
# 3Y_베이시스       -4.5672      4.587     -0.996      0.320     -13.563       4.428
# 5Y_베이시스        6.8638      3.827      1.793      0.073      -0.641      14.369
# 10Y_베이시스      -4.3198      2.429     -1.779      0.075      -9.082       0.442
# M1_스왑포인트      -4.6592      0.600     -7.760      0.000      -5.837      -3.482
# Mid_ndf     1318.1785      3.055    431.518      0.000    1312.188    1324.169
# ==============================================================================
# Omnibus:                      331.234   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2024.435
# Skew:                           0.473   Prob(JB):                         0.00
# Kurtosis:                       7.342   Cond. No.                         180.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#      VIF_Factor   Feature
# 0    929.481986      국고3년
# 1   1570.429470      국고5년
# 2   1340.938235     국고10년
# 3    183.562762    통안364일
# 4    865.022329      통안2년
# 5     51.278966   1Y_베이시스
# 6    534.700039   2Y_베이시스
# 7    397.502534   3Y_베이시스
# 8    235.126867   5Y_베이시스
# 9     71.637902  10Y_베이시스
# 10     3.478274  M1_스왑포인트
# 11    31.970438   Mid_ndf

# %%
x_scaled.drop(['국고5년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.008e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:52   Log-Likelihood:                -6982.0
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2448   BIC:                         1.406e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8083      2.878      0.281      0.779      -4.836       6.453
# 국고3년           3.4095      5.027      0.678      0.498      -6.448      13.267
# 국고10년         -4.9541      2.673     -1.853      0.064     -10.196       0.288
# 통안364일        -2.3883      2.207     -1.082      0.279      -6.717       1.940
# 통안2년           2.5247      4.433      0.570      0.569      -6.167      11.217
# 1Y_베이시스       -7.2678      2.254     -3.225      0.001     -11.687      -2.848
# 2Y_베이시스        4.5724      5.109      0.895      0.371      -5.447      14.592
# 3Y_베이시스       -4.5038      4.585     -0.982      0.326     -13.494       4.487
# 5Y_베이시스        5.9675      3.390      1.760      0.078      -0.679      12.614
# 10Y_베이시스      -3.8220      2.219     -1.722      0.085      -8.173       0.529
# M1_스왑포인트      -4.5598      0.567     -8.041      0.000      -5.672      -3.448
# Mid_ndf     1318.3569      3.034    434.564      0.000    1312.408    1324.306
# ==============================================================================
# Omnibus:                      330.434   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2015.934
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.333   Cond. No.                         154.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor   Feature
# 0   929.411268      국고3년
# 1   273.591066     국고10년
# 2   138.164208    통안364일
# 3   848.432518      통안2년
# 4    50.930045   1Y_베이시스
# 5   530.028155   2Y_베이시스
# 6   397.138572   3Y_베이시스
# 7   184.308356   5Y_베이시스
# 8    59.566898  10Y_베이시스
# 9     3.087902  M1_스왑포인트
# 10   28.220476   Mid_ndf

# %%
x_scaled.drop(['국고3년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.410e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:53   Log-Likelihood:                -6982.3
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2449   BIC:                         1.405e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1283      2.698      0.048      0.962      -5.162       5.419
# 국고10년         -3.7875      2.046     -1.851      0.064      -7.800       0.225
# 통안364일        -2.2423      2.197     -1.021      0.307      -6.550       2.065
# 통안2년           4.6708      3.104      1.505      0.132      -1.415      10.757
# 1Y_베이시스       -7.1611      2.248     -3.186      0.001     -11.569      -2.753
# 2Y_베이시스        4.1548      5.072      0.819      0.413      -5.790      14.100
# 3Y_베이시스       -3.9489      4.511     -0.875      0.381     -12.794       4.896
# 5Y_베이시스        5.6400      3.355      1.681      0.093      -0.938      12.219
# 10Y_베이시스      -3.6013      2.195     -1.641      0.101      -7.905       0.702
# M1_스왑포인트      -4.6121      0.562     -8.211      0.000      -5.714      -3.511
# Mid_ndf     1318.9854      2.888    456.644      0.000    1313.321    1324.649
# ==============================================================================
# Omnibus:                      331.299   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2028.910
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         143.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0  181.781207     국고10년
# 1  136.896083    통안364일
# 2  305.701010      통안2년
# 3   50.864026   1Y_베이시스
# 4  515.038022   2Y_베이시스
# 5  379.626739   3Y_베이시스
# 6  183.531798   5Y_베이시스
# 7   59.479184  10Y_베이시스
# 8    3.054460  M1_스왑포인트
# 9   26.628793   Mid_ndf

# %%
x_scaled.drop(['통안364일'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.900e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:53   Log-Likelihood:                -6982.8
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2450   BIC:                         1.404e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2557      2.333     -0.538      0.590      -5.830       3.318
# 국고10년         -2.7970      1.801     -1.553      0.121      -6.329       0.735
# 통안2년           1.8910      1.489      1.270      0.204      -1.029       4.811
# 1Y_베이시스       -6.9169      2.235     -3.094      0.002     -11.300      -2.534
# 2Y_베이시스        3.2869      5.000      0.657      0.511      -6.518      13.091
# 3Y_베이시스       -3.0120      4.416     -0.682      0.495     -11.672       5.648
# 5Y_베이시스        5.2474      3.333      1.575      0.115      -1.288      11.783
# 10Y_베이시스      -3.1652      2.153     -1.470      0.142      -7.386       1.056
# M1_스왑포인트      -4.7551      0.544     -8.742      0.000      -5.822      -3.688
# Mid_ndf     1320.3982      2.535    520.793      0.000    1315.426    1325.370
# ==============================================================================
# Omnibus:                      329.041   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2026.508
# Skew:                           0.465   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         136.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0  166.767781     국고10년
# 1   93.011676      통안2년
# 2   50.586621   1Y_베이시스
# 3  472.093656   2Y_베이시스
# 4  343.234875   3Y_베이시스
# 5  183.495542   5Y_베이시스
# 6   59.285727  10Y_베이시스
# 7    2.866197  M1_스왑포인트
# 8   26.332108   Mid_ndf

# %%
x_scaled.drop(['2Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 5.514e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:54   Log-Likelihood:                -6983.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2451   BIC:                         1.404e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8216      2.237     -0.367      0.713      -5.208       3.565
# 국고10년         -2.9592      1.784     -1.659      0.097      -6.458       0.539
# 통안2년           1.9030      1.489      1.278      0.201      -1.017       4.823
# 1Y_베이시스       -5.9829      1.725     -3.468      0.001      -9.366      -2.600
# 3Y_베이시스       -0.5990      2.456     -0.244      0.807      -5.414       4.216
# 5Y_베이시스        5.7232      3.253      1.760      0.079      -0.655      12.102
# 10Y_베이시스      -3.5762      2.060     -1.736      0.083      -7.615       0.463
# M1_스왑포인트      -4.8538      0.523     -9.285      0.000      -5.879      -3.829
# Mid_ndf     1319.9204      2.429    543.473      0.000    1315.158    1324.683
# ==============================================================================
# Omnibus:                      329.290   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2026.625
# Skew:                           0.466   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                         85.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0  166.558708     국고10년
# 1   92.821596      통안2년
# 2   27.598532   1Y_베이시스
# 3  113.882550   3Y_베이시스
# 4  177.642135   5Y_베이시스
# 5   55.836621  10Y_베이시스
# 6    2.658905  M1_스왑포인트
# 7   26.270645   Mid_ndf

# %%
x_scaled.drop(['3Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 6.304e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:54   Log-Likelihood:                -6983.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2452   BIC:                         1.403e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7892      2.233     -0.354      0.724      -5.167       3.589
# 국고10년         -2.8139      1.681     -1.674      0.094      -6.111       0.483
# 통안2년           1.7748      1.393      1.274      0.203      -0.957       4.506
# 1Y_베이시스       -6.1651      1.555     -3.965      0.000      -9.214      -3.116
# 5Y_베이시스        5.1077      2.052      2.489      0.013       1.084       9.131
# 10Y_베이시스      -3.3656      1.870     -1.800      0.072      -7.032       0.301
# M1_스왑포인트      -4.8198      0.504     -9.569      0.000      -5.808      -3.832
# Mid_ndf     1319.8760      2.421    545.094      0.000    1315.128    1324.624
# ==============================================================================
# Omnibus:                      329.227   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2025.689
# Skew:                           0.466   Prob(JB):                         0.00
# Kurtosis:                       7.347   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0  142.546041     국고10년
# 1   79.923530      통안2년
# 2   22.363672   1Y_베이시스
# 3   66.891706   5Y_베이시스
# 4   45.256703  10Y_베이시스
# 5    2.469853  M1_스왑포인트
# 6   26.091965   Mid_ndf

# %%
x_scaled.drop(['통안2년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 7.353e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:54   Log-Likelihood:                -6983.8
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2453   BIC:                         1.402e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.4569      2.170     -0.671      0.502      -5.713       2.799
# 국고10년         -0.8694      0.706     -1.232      0.218      -2.253       0.515
# 1Y_베이시스       -5.5937      1.489     -3.757      0.000      -8.513      -2.674
# 5Y_베이시스        5.0360      2.051      2.455      0.014       1.013       9.059
# 10Y_베이시스      -3.7301      1.848     -2.019      0.044      -7.354      -0.107
# M1_스왑포인트      -4.9918      0.485    -10.285      0.000      -5.944      -4.040
# Mid_ndf     1320.3561      2.392    551.947      0.000    1315.665    1325.047
# ==============================================================================
# Omnibus:                      332.458   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2065.872
# Skew:                           0.470   Prob(JB):                         0.00
# Kurtosis:                       7.390   Cond. No.                         64.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   23.852918     국고10년
# 1   21.121695   1Y_베이시스
# 2   66.807170   5Y_베이시스
# 3   43.227754  10Y_베이시스
# 4    2.281327  M1_스왑포인트
# 5   22.461574   Mid_ndf

# %%
x_scaled.drop(['국고10년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 8.822e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:29:55   Log-Likelihood:                -6984.6
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2454   BIC:                         1.402e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.6471      1.944     -1.362      0.173      -6.458       1.164
# 1Y_베이시스       -4.8926      1.376     -3.556      0.000      -7.591      -2.194
# 5Y_베이시스        4.8211      2.044      2.358      0.018       0.813       8.830
# 10Y_베이시스      -3.6769      1.848     -1.990      0.047      -7.300      -0.054
# M1_스왑포인트      -5.3193      0.406    -13.100      0.000      -6.116      -4.523
# Mid_ndf     1321.2837      2.271    581.864      0.000    1316.831    1325.737
# ==============================================================================
# Omnibus:                      341.272   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2152.876
# Skew:                           0.484   Prob(JB):                         0.00
# Kurtosis:                       7.480   Cond. No.                         55.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled


def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   19.036918   1Y_베이시스
# 1   66.723545   5Y_베이시스
# 2   42.773676  10Y_베이시스
# 3    1.322648  M1_스왑포인트
# 4   11.137416   Mid_ndf

# %%
x_scaled.drop(['5Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.101e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:31:04   Log-Likelihood:                -6987.4
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2455   BIC:                         1.401e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7874      1.884     -2.010      0.045      -7.482      -0.092
# 1Y_베이시스       -2.7260      1.025     -2.659      0.008      -4.737      -0.715
# 10Y_베이시스       0.1215      0.906      0.134      0.893      -1.655       1.898
# M1_스왑포인트      -5.1118      0.397    -12.883      0.000      -5.890      -4.334
# Mid_ndf     1322.6624      2.196    602.228      0.000    1318.356    1326.969
# ==============================================================================
# Omnibus:                      358.775   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2235.021
# Skew:                           0.527   Prob(JB):                         0.00
# Kurtosis:                       7.549   Cond. No.                         47.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['10Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.468e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:31:18   Log-Likelihood:                -6987.4
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2456   BIC:                         1.401e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7592      1.872     -2.008      0.045      -7.430      -0.088
# 1Y_베이시스       -2.6640      0.915     -2.911      0.004      -4.459      -0.869
# M1_스왑포인트      -5.1327      0.365    -14.065      0.000      -5.848      -4.417
# Mid_ndf     1322.6093      2.160    612.379      0.000    1318.374    1326.844
# ==============================================================================
# Omnibus:                      358.535   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2233.325
# Skew:                           0.526   Prob(JB):                         0.00
# Kurtosis:                       7.548   Cond. No.                         46.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
x_train = x_scaled[:1968]
x_test = x_scaled[1968:]
y_train = y[:1968]
y_test = y[1968:]

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 14.298407948084776, RMSE :  3.781, MAE: 3.781
# Variance score :  0.996

# %%
x
# Out:
#       국고1년  국고3년  국고5년  국고10년  통안364일  통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  \
# 열1
# 0     2.82  2.83  3.14   3.14    2.80  2.83    -76.0    -92.5    -93.0
# 1     2.79  2.79  3.10   3.10    2.77  2.78    -74.0    -84.5    -84.0
# 2     2.77  2.77  3.03   3.03    2.75  2.77    -72.0    -83.0    -83.0
# 3     2.78  2.78  3.03   3.03    2.76  2.78    -74.0    -87.5    -88.0
# 4     2.77  2.78  3.03   3.03    2.75  2.77    -73.0    -86.0    -88.0
# ...    ...   ...   ...    ...     ...   ...      ...      ...      ...
# 2455  2.92  3.15  3.22   3.21    2.98  3.09    -61.5    -50.5    -49.5
# 2456  2.93  3.12  3.20   3.18    2.99  3.09    -59.5    -51.5    -49.5
# 2457  2.93  3.09  3.15   3.12    3.01  3.08    -57.5    -47.5    -44.5
# 2458  2.94  3.13  3.18   3.20    3.03  3.11    -56.5    -47.5    -45.5
# 2459  2.90  3.00  3.06   3.12    3.00  3.00    -60.5    -50.5    -46.5
#
#       5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0      -105.0    -108.0       260  1132.25
# 1       -96.0     -99.0       250  1134.00
# 2      -101.0    -112.0       240  1138.00
# 3      -107.0    -117.0       240  1128.50
# 4      -115.0    -127.0       250  1129.00
# ...       ...       ...       ...      ...
# 2455    -61.5     -60.5       -60  1309.85
# 2456    -60.5     -59.5       -70  1311.00
# 2457    -55.5     -54.5       -55  1310.50
# 2458    -57.5     -59.5       -65  1306.00
# 2459    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 13 columns]

# %%
x
# Out:
#       국고1년  국고3년  국고5년  국고10년  통안364일  통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  \
# 열1
# 0     2.82  2.83  3.14   3.14    2.80  2.83    -76.0    -92.5    -93.0
# 1     2.79  2.79  3.10   3.10    2.77  2.78    -74.0    -84.5    -84.0
# 2     2.77  2.77  3.03   3.03    2.75  2.77    -72.0    -83.0    -83.0
# 3     2.78  2.78  3.03   3.03    2.76  2.78    -74.0    -87.5    -88.0
# 4     2.77  2.78  3.03   3.03    2.75  2.77    -73.0    -86.0    -88.0
# ...    ...   ...   ...    ...     ...   ...      ...      ...      ...
# 2455  2.92  3.15  3.22   3.21    2.98  3.09    -61.5    -50.5    -49.5
# 2456  2.93  3.12  3.20   3.18    2.99  3.09    -59.5    -51.5    -49.5
# 2457  2.93  3.09  3.15   3.12    3.01  3.08    -57.5    -47.5    -44.5
# 2458  2.94  3.13  3.18   3.20    3.03  3.11    -56.5    -47.5    -45.5
# 2459  2.90  3.00  3.06   3.12    3.00  3.00    -60.5    -50.5    -46.5
#
#       5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0      -105.0    -108.0       260  1132.25
# 1       -96.0     -99.0       250  1134.00
# 2      -101.0    -112.0       240  1138.00
# 3      -107.0    -117.0       240  1128.50
# 4      -115.0    -127.0       250  1129.00
# ...       ...       ...       ...      ...
# 2455    -61.5     -60.5       -60  1309.85
# 2456    -60.5     -59.5       -70  1311.00
# 2457    -55.5     -54.5       -55  1310.50
# 2458    -57.5     -59.5       -65  1306.00
# 2459    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 13 columns]
