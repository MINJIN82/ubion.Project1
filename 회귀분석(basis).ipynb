# %%
import pandas as pd
import numpy as np
import scipy.stats

# %%
df = pd.read_excel("../데이터자료/join_data.xlsx",index_col=0)
df_data=df[['DateTime', '종가_ex','1Y_Mid_irs','2Y_Mid_irs','3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs',
 '1Y_Mid_crs','2Y_Mid_crs','3Y_Mid_crs','5Y_Mid_crs','10Y_Mid_crs', '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
df_data
# Out:
#         DateTime   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  \
# 열1
# 0     2012-08-01  1126.5       2.850       2.740       2.740       2.770
# 1     2012-08-02  1131.7       2.820       2.690       2.690       2.720
# 2     2012-08-03  1134.8       2.790       2.660       2.660       2.690
# 3     2012-08-06  1129.0       2.810       2.680       2.680       2.710
# 4     2012-08-07  1128.8       2.820       2.680       2.680       2.720
# ...          ...     ...         ...         ...         ...         ...
# 2455  2022-07-25  1313.7       3.165       3.235       3.205       3.125
# 2456  2022-07-26  1307.6       3.155       3.215       3.175       3.095
# 2457  2022-07-27  1313.3       3.145       3.165       3.115       3.035
# 2458  2022-07-28  1296.1       3.175       3.205       3.165       3.085
# 2459  2022-07-29  1299.1       3.105       3.065       3.025       2.945
#
#       10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  국고10년  통안364일  \
# 열1                                                     ...
# 0           2.910        2.09       1.815        1.81  ...   3.14    2.80
# 1           2.860        2.08       1.845        1.85  ...   3.10    2.77
# 2           2.840        2.07       1.830        1.83  ...   3.03    2.75
# 3           2.850        2.07       1.805        1.80  ...   3.03    2.76
# 4           2.870        2.09       1.820        1.80  ...   3.03    2.75
# ...           ...         ...         ...         ...  ...    ...     ...
# 2455        2.965        2.55       2.730        2.71  ...   3.21    2.98
# 2456        2.935        2.56       2.700        2.68  ...   3.18    2.99
# 2457        2.875        2.57       2.690        2.67  ...   3.12    3.01
# 2458        2.945        2.61       2.730        2.71  ...   3.20    3.03
# 2459        2.825        2.50       2.560        2.56  ...   3.12    3.00
#
#       통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0     2.83    -76.0    -92.5    -93.0   -105.0    -108.0       260  1132.25
# 1     2.78    -74.0    -84.5    -84.0    -96.0     -99.0       250  1134.00
# 2     2.77    -72.0    -83.0    -83.0   -101.0    -112.0       240  1138.00
# 3     2.78    -74.0    -87.5    -88.0   -107.0    -117.0       240  1128.50
# 4     2.77    -73.0    -86.0    -88.0   -115.0    -127.0       250  1129.00
# ...    ...      ...      ...      ...      ...       ...       ...      ...
# 2455  3.09    -61.5    -50.5    -49.5    -61.5     -60.5       -60  1309.85
# 2456  3.09    -59.5    -51.5    -49.5    -60.5     -59.5       -70  1311.00
# 2457  3.08    -57.5    -47.5    -44.5    -55.5     -54.5       -55  1310.50
# 2458  3.11    -56.5    -47.5    -45.5    -57.5     -59.5       -65  1306.00
# 2459  3.00    -60.5    -50.5    -46.5    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 25 columns]

# %%
df_data.iloc[1968]
# Out:
# DateTime       2020-08-03
# 종가_ex              1193.4
# 1Y_Mid_irs          0.735
# 2Y_Mid_irs          0.755
# 3Y_Mid_irs          0.785
# 5Y_Mid_irs          0.835
# 10Y_Mid_irs         0.905
# 1Y_Mid_crs         -0.005
# 2Y_Mid_crs          -0.05
# 3Y_Mid_crs          -0.04
# 5Y_Mid_crs          -0.02
# 10Y_Mid_crs         0.215
# 국고1년                 0.65
# 국고3년                 0.79
# 국고5년                 1.04
# 국고10년                 1.3
# 통안364일               0.59
# 통안2년                 0.72
# 1Y_베이시스             -74.0
# 2Y_베이시스             -80.5
# 3Y_베이시스             -82.5
# 5Y_베이시스             -85.5
# 10Y_베이시스            -69.0
# M1_스왑포인트              -10
# Mid_ndf            1194.4
# Name: 1968, dtype: object

# %%
x = df_data[['국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
y = df_data["종가_ex"]

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.389e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:05:36   Log-Likelihood:                -6981.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2446   BIC:                         1.407e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8647      2.953      0.293      0.770      -4.927       6.656
# 국고1년           0.0577      1.527      0.038      0.970      -2.936       3.051
# 국고3년           0.9156      1.348      0.679      0.497      -1.728       3.559
# 국고5년          -0.7155      1.461     -0.490      0.624      -3.581       2.150
# 국고10년         -0.7344      1.411     -0.521      0.603      -3.501       2.032
# 통안364일        -0.5600      1.198     -0.467      0.640      -2.909       1.789
# 통안2년           0.7835      1.311      0.598      0.550      -1.787       3.354
# 1Y_베이시스       -0.0289      0.009     -3.094      0.002      -0.047      -0.011
# 2Y_베이시스        0.0212      0.026      0.821      0.412      -0.029       0.072
# 3Y_베이시스       -0.0217      0.022     -0.985      0.324      -0.065       0.021
# 5Y_베이시스        0.0318      0.018      1.792      0.073      -0.003       0.067
# 10Y_베이시스      -0.0198      0.011     -1.769      0.077      -0.042       0.002
# M1_스왑포인트      -0.0104      0.001     -7.429      0.000      -0.013      -0.008
# Mid_ndf        0.9994      0.002    423.573      0.000       0.995       1.004
# ==============================================================================
# Omnibus:                      331.261   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2024.790
# Skew:                           0.473   Prob(JB):                         0.00
# Kurtosis:                       7.343   Cond. No.                     4.24e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#      VIF_Factor   Feature
# 0   1067.937135      국고1년
# 1    929.537722      국고3년
# 2   1759.527045      국고5년
# 3   1515.745334     국고10년
# 4    691.080724    통안364일
# 5    930.164477      통안2년
# 6     53.194185   1Y_베이시스
# 7    555.907415   2Y_베이시스
# 8    402.987054   3Y_베이시스
# 9    237.905170   5Y_베이시스
# 10    71.654085  10Y_베이시스
# 11     3.753484  M1_스왑포인트
# 12    32.496897   Mid_ndf

# %%
x.drop(['국고5년',"국고1년"], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\201535763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['국고5년',"국고1년"], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.008e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:06:10   Log-Likelihood:                -6982.0
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2448   BIC:                         1.406e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8083      2.878      0.281      0.779      -4.836       6.453
# 국고3년           0.9116      1.344      0.678      0.498      -1.724       3.547
# 국고10년         -1.3071      0.705     -1.853      0.064      -2.690       0.076
# 통안364일        -0.6690      0.618     -1.082      0.279      -1.881       0.543
# 통안2년           0.7072      1.242      0.570      0.569      -1.728       3.142
# 1Y_베이시스       -0.0294      0.009     -3.225      0.001      -0.047      -0.012
# 2Y_베이시스        0.0226      0.025      0.895      0.371      -0.027       0.072
# 3Y_베이시스       -0.0215      0.022     -0.982      0.326      -0.064       0.021
# 5Y_베이시스        0.0276      0.016      1.760      0.078      -0.003       0.058
# 10Y_베이시스      -0.0176      0.010     -1.722      0.085      -0.038       0.002
# M1_스왑포인트      -0.0101      0.001     -8.041      0.000      -0.013      -0.008
# Mid_ndf        0.9995      0.002    434.564      0.000       0.995       1.004
# ==============================================================================
# Omnibus:                      330.434   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2015.934
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.333   Cond. No.                     4.09e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.09e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop(['국고3년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\480503202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['국고3년'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.410e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:06:22   Log-Likelihood:                -6982.3
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2449   BIC:                         1.405e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1283      2.698      0.048      0.962      -5.162       5.419
# 국고10년         -0.9993      0.540     -1.851      0.064      -2.058       0.059
# 통안364일        -0.6281      0.615     -1.021      0.307      -1.835       0.578
# 통안2년           1.3083      0.869      1.505      0.132      -0.396       3.013
# 1Y_베이시스       -0.0289      0.009     -3.186      0.001      -0.047      -0.011
# 2Y_베이시스        0.0206      0.025      0.819      0.413      -0.029       0.070
# 3Y_베이시스       -0.0188      0.022     -0.875      0.381      -0.061       0.023
# 5Y_베이시스        0.0261      0.016      1.681      0.093      -0.004       0.057
# 10Y_베이시스      -0.0166      0.010     -1.641      0.101      -0.036       0.003
# M1_스왑포인트      -0.0102      0.001     -8.211      0.000      -0.013      -0.008
# Mid_ndf        1.0000      0.002    456.644      0.000       0.996       1.004
# ==============================================================================
# Omnibus:                      331.299   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2028.910
# Skew:                           0.472   Prob(JB):                         0.00
# Kurtosis:                       7.348   Cond. No.                     3.81e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.81e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0  181.781207     국고10년
# 1  136.896083    통안364일
# 2  305.701010      통안2년
# 3   50.864026   1Y_베이시스
# 4  515.038022   2Y_베이시스
# 5  379.626739   3Y_베이시스
# 6  183.531798   5Y_베이시스
# 7   59.479184  10Y_베이시스
# 8    3.054460  M1_스왑포인트
# 9   26.628793   Mid_ndf

# %%
x.drop(['통안364일', '통안2년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\2325076357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['통안364일', '통안2년'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 5.511e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:07:06   Log-Likelihood:                -6983.6
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2451   BIC:                         1.404e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8291      2.289     -0.799      0.424      -6.317       2.659
# 국고10년         -0.1880      0.196     -0.961      0.337      -0.572       0.196
# 1Y_베이시스       -0.0272      0.009     -3.021      0.003      -0.045      -0.010
# 2Y_베이시스        0.0167      0.025      0.673      0.501      -0.032       0.065
# 3Y_베이시스       -0.0094      0.021     -0.454      0.650      -0.050       0.031
# 5Y_베이시스        0.0187      0.015      1.264      0.206      -0.010       0.048
# 10Y_베이시스      -0.0143      0.010     -1.444      0.149      -0.034       0.005
# M1_스왑포인트      -0.0108      0.001     -9.002      0.000      -0.013      -0.008
# Mid_ndf        1.0013      0.002    524.495      0.000       0.998       1.005
# ==============================================================================
# Omnibus:                      331.919   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2062.021
# Skew:                           0.469   Prob(JB):                         0.00
# Kurtosis:                       7.386   Cond. No.                     3.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   25.081777     국고10년
# 1   50.428382   1Y_베이시스
# 2  471.128878   2Y_베이시스
# 3  321.532601   3Y_베이시스
# 4  170.963734   5Y_베이시스
# 5   59.248440  10Y_베이시스
# 6    2.797994  M1_스왑포인트
# 7   22.588506   Mid_ndf

# %%
x.drop([ '2Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\4202671566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '2Y_베이시스'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 6.300e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:07:52   Log-Likelihood:                -6983.8
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2452   BIC:                         1.403e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.3884      2.193     -0.633      0.527      -5.688       2.911
# 국고10년         -0.2283      0.186     -1.225      0.221      -0.594       0.137
# 1Y_베이시스       -0.0234      0.007     -3.365      0.001      -0.037      -0.010
# 3Y_베이시스        0.0024      0.011      0.221      0.825      -0.019       0.024
# 5Y_베이시스        0.0209      0.014      1.451      0.147      -0.007       0.049
# 10Y_베이시스      -0.0162      0.009     -1.713      0.087      -0.035       0.002
# M1_스왑포인트      -0.0110      0.001     -9.576      0.000      -0.013      -0.009
# Mid_ndf        1.0010      0.002    547.426      0.000       0.997       1.005
# ==============================================================================
# Omnibus:                      332.208   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2062.671
# Skew:                           0.469   Prob(JB):                         0.00
# Kurtosis:                       7.387   Cond. No.                     3.01e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   24.089036     국고10년
# 1   27.565686   1Y_베이시스
# 2   98.057950   3Y_베이시스
# 3  164.296735   5Y_베이시스
# 4   55.824684  10Y_베이시스
# 5    2.600909  M1_스왑포인트
# 6   22.562709   Mid_ndf

# %%
x.drop(['5Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\1602728941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['5Y_베이시스'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 7.347e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:08:08   Log-Likelihood:                -6984.9
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2453   BIC:                         1.402e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5902      2.189     -0.726      0.468      -5.882       2.702
# 국고10년         -0.2077      0.186     -1.118      0.264      -0.572       0.157
# 1Y_베이시스       -0.0234      0.007     -3.373      0.001      -0.037      -0.010
# 3Y_베이시스        0.0144      0.007      1.992      0.047       0.000       0.029
# 10Y_베이시스      -0.0046      0.005     -0.911      0.362      -0.014       0.005
# M1_스왑포인트      -0.0104      0.001     -9.661      0.000      -0.013      -0.008
# Mid_ndf        1.0012      0.002    549.274      0.000       0.998       1.005
# ==============================================================================
# Omnibus:                      338.168   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2081.559
# Skew:                           0.486   Prob(JB):                         0.00
# Kurtosis:                       7.400   Cond. No.                     3.00e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   24.019275     국고10년
# 1   27.549012   1Y_베이시스
# 2   39.872820   3Y_베이시스
# 3   15.567163  10Y_베이시스
# 4    2.297024  M1_스왑포인트
# 5   22.318956   Mid_ndf

# %%
x.drop([ '국고10년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\3463003749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '국고10년'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 8.815e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:08:51   Log-Likelihood:                -6985.5
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2454   BIC:                         1.402e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.6525      1.972     -1.345      0.179      -6.519       1.214
# 1Y_베이시스       -0.0209      0.007     -3.183      0.001      -0.034      -0.008
# 3Y_베이시스        0.0140      0.007      1.941      0.052      -0.000       0.028
# 10Y_베이시스      -0.0049      0.005     -0.979      0.327      -0.015       0.005
# M1_스왑포인트      -0.0111      0.001    -12.494      0.000      -0.013      -0.009
# Mid_ndf        1.0018      0.002    576.993      0.000       0.998       1.005
# ==============================================================================
# Omnibus:                      345.903   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2159.681
# Skew:                           0.498   Prob(JB):                         0.00
# Kurtosis:                       7.481   Cond. No.                     2.70e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   26.123047   1Y_베이시스
# 1   39.547096   3Y_베이시스
# 2   15.129505  10Y_베이시스
# 3    1.395695  M1_스왑포인트
# 4   11.106226   Mid_ndf

# %%
x.drop(['10Y_베이시스'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\3134370151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['10Y_베이시스'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.102e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:09:16   Log-Likelihood:                -6986.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2455   BIC:                         1.401e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.1446      1.907     -1.649      0.099      -6.884       0.595
# 1Y_베이시스       -0.0196      0.006     -3.048      0.002      -0.032      -0.007
# 3Y_베이시스        0.0100      0.006      1.682      0.093      -0.002       0.022
# M1_스왑포인트      -0.0109      0.001    -12.635      0.000      -0.013      -0.009
# Mid_ndf        1.0023      0.002    605.828      0.000       0.999       1.006
# ==============================================================================
# Omnibus:                      350.957   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2190.709
# Skew:                           0.509   Prob(JB):                         0.00
# Kurtosis:                       7.510   Cond. No.                     2.60e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0   25.396076   1Y_베이시스
# 1   28.590916   3Y_베이시스
# 2    1.352672  M1_스왑포인트
# 3    9.553408   Mid_ndf

# %%
x.drop([ '3Y_베이시스',], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2320\3027057346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '3Y_베이시스',], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.468e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:09:46   Log-Likelihood:                -6987.4
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2456   BIC:                         1.401e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7592      1.872     -2.008      0.045      -7.430      -0.088
# 1Y_베이시스       -0.0108      0.004     -2.911      0.004      -0.018      -0.004
# M1_스왑포인트      -0.0114      0.001    -14.065      0.000      -0.013      -0.010
# Mid_ndf        1.0027      0.002    612.379      0.000       1.000       1.006
# ==============================================================================
# Omnibus:                      358.535   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2233.325
# Skew:                           0.526   Prob(JB):                         0.00
# Kurtosis:                       7.548   Cond. No.                     2.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor   Feature
# 0    8.449698   1Y_베이시스
# 1    1.112315  M1_스왑포인트
# 2    8.526356   Mid_ndf

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
x_train = x[:1968]
x_test = x[1968:]
y_train = y[:1968]
y_test = y[1968:]

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 14.29840794808494, RMSE :  3.781, MAE: 3.781
# Variance score :  0.996

# %%
x
# Out:
#       2Y_Mid_irs  1Y_Mid_crs  M1_스왑포인트  Mid_ndf
# 열1
# 0          2.740        2.09       260  1132.25
# 1          2.690        2.08       250  1134.00
# 2          2.660        2.07       240  1138.00
# 3          2.680        2.07       240  1128.50
# 4          2.680        2.09       250  1129.00
# ...          ...         ...       ...      ...
# 2455       3.235        2.55       -60  1309.85
# 2456       3.215        2.56       -70  1311.00
# 2457       3.165        2.57       -55  1310.50
# 2458       3.205        2.61       -65  1306.00
# 2459       3.065        2.50       -60  1295.75
#
# [2460 rows x 4 columns]
