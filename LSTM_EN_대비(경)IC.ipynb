# %%
import pandas as pd
import numpy as np

# %%
# 파일 불러오기
df = pd.read_excel("../데이터자료/Join_data.xlsx", index_col = 0)    
df = df.set_index("DateTime")

# 대비 계산
df['대비_irs_1Y'] = df['1Y_Mid_irs'] - df['1Y_Mid_irs'].shift(1) 
df['대비_irs_2Y'] = df['2Y_Mid_irs'] - df['2Y_Mid_irs'].shift(1) 
df['대비_irs_3Y'] = df['3Y_Mid_irs'] - df['3Y_Mid_irs'].shift(1) 
df['대비_irs_5Y'] = df['5Y_Mid_irs'] - df['5Y_Mid_irs'].shift(1) 
df['대비_irs_10Y'] = df['10Y_Mid_irs'] - df['10Y_Mid_irs'].shift(1) 

df['대비_crs_1Y'] = df['1Y_Mid_crs'] - df['1Y_Mid_crs'].shift(1)
df['대비_crs_2Y'] = df['2Y_Mid_crs'] - df['2Y_Mid_crs'].shift(1)
df['대비_crs_3Y'] = df['3Y_Mid_crs'] - df['3Y_Mid_crs'].shift(1)
df['대비_crs_5Y'] = df['5Y_Mid_crs'] - df['5Y_Mid_crs'].shift(1)
df['대비_crs_10Y'] = df['10Y_Mid_crs'] - df['10Y_Mid_crs'].shift(1)

df['대비_swapbasis_1Y'] = df['1Y_베이시스']-df['1Y_베이시스'].shift(1)
df['대비_swapbasis_2Y'] = df['2Y_베이시스']-df['2Y_베이시스'].shift(1)
df['대비_swapbasis_3Y'] = df['3Y_베이시스']-df['3Y_베이시스'].shift(1)
df['대비_swapbasis_5Y'] = df['5Y_베이시스']-df['5Y_베이시스'].shift(1)
df['대비_swapbasis_10Y'] = df['10Y_베이시스']-df['10Y_베이시스'].shift(1)

df['대비_국고_1Y'] = df['국고1년']-df['국고1년'].shift(1)
df['대비_국고_3Y'] = df['국고3년']-df['국고3년'].shift(1)
df['대비_국고_5Y'] = df['국고5년']-df['국고5년'].shift(1)
df['대비_국고_10Y'] = df['국고10년']-df['국고10년'].shift(1)

df['대비_통안_1Y'] = df['통안364일']-df['통안364일'].shift(1)
df['대비_통안_2Y'] = df['통안2년']-df['통안2년'].shift(1)

df['대비_ndf'] = df['Mid_ndf']-df['Mid_ndf'].shift(1)
df['스왑포인트_1M'] = df["M1_스왑포인트"]/100 
df['전일종가_ex'] = df['종가_ex'].shift(1)
df['종가_NDF_차이'] = df['전일종가_ex'] - df['Mid_ndf']

# 필요한 칼럼만 추출
df_1 = df[['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y', 
           '대비_swapbasis_1Y', '대비_swapbasis_2Y', '대비_swapbasis_3Y', '대비_swapbasis_5Y', '대비_swapbasis_10Y',
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M', '전일종가_ex', 
           '종가_ex', '종가_NDF_차이' ]] 

# 결측치 제거
df_1 = df_1.dropna()

# %%
x = df_1[[ '대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y',
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '스왑포인트_1M', '전일종가_ex', 
           '종가_NDF_차이'  ]]
y = df_1["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_15748\1797086163.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             대비_irs_1Y  대비_irs_2Y  대비_irs_3Y  대비_irs_5Y  대비_irs_10Y  대비_crs_1Y  \
# DateTime
# 2012-08-02  -0.847862  -1.217081  -0.935854  -1.045679   -1.009126  -0.205655
# 2012-08-03  -0.847862  -0.731532  -0.562378  -0.628002   -0.403231  -0.205655
# 2012-08-06   0.560374   0.482340   0.371312   0.416191    0.202663  -0.003373
# 2012-08-07   0.278727  -0.003209  -0.002164   0.207352    0.404628   0.401191
# 2012-08-08   0.278727   0.482340   0.371312   0.416191    0.606592   0.198909
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-25  -1.129510  -1.945404  -1.309330  -1.881032   -2.220914  -1.621628
# 2022-07-26  -0.284568  -0.488757  -0.562378  -0.628002   -0.605196   0.198909
# 2022-07-27  -0.284568  -1.217081  -1.122592  -1.254517   -1.211091   0.198909
# 2022-07-28   0.842021   0.967889   0.931525   1.042706    1.414452   0.805755
# 2022-07-29  -1.974451  -3.402050  -2.616496  -2.925225   -2.422879  -2.228474
#
#             대비_crs_2Y  대비_crs_3Y  대비_crs_5Y  대비_crs_10Y  대비_국고_1Y  대비_국고_3Y  \
# DateTime
# 2012-08-02   0.707360   0.905480   0.926463    0.826282 -1.698057 -0.646622
# 2012-08-03  -0.364505  -0.463176  -1.872849   -3.115790 -1.132651 -0.323869
# 2012-08-06  -0.602697  -0.691285  -0.939745   -0.833538  0.563566  0.160261
# 2012-08-07   0.350072  -0.006957  -1.639573   -1.663448 -0.567245 -0.001116
# 2012-08-08  -0.007216  -0.006957  -0.473193   -0.833538 -0.567245 -0.323869
# ...               ...        ...        ...         ...       ...       ...
# 2022-07-25  -2.150945  -1.603722  -2.572677   -2.285880 -1.132651 -0.969375
# 2022-07-26  -0.721793  -0.691285  -0.473193   -0.418583  0.563566 -0.485246
# 2022-07-27  -0.245409  -0.235067  -0.239917   -0.211106 -0.001839 -0.485246
# 2022-07-28   0.945552   0.905480   0.693187    0.411327  0.563566  0.644391
# 2022-07-29  -4.056482  -3.428596  -2.106125   -1.870925 -2.263463 -2.099012
#
#             대비_국고_5Y  대비_국고_10Y  대비_통안_1Y  대비_통안_2Y  스왑포인트_1M   전일종가_ex  \
# DateTime
# 2012-08-02 -1.079749  -1.027569 -0.325920 -0.625160  1.909409 -0.149841
# 2012-08-03 -1.890219  -1.798403 -0.217574 -0.125723  1.818881 -0.056232
# 2012-08-06  0.000879   0.000209  0.107465  0.123996  1.818881 -0.000426
# 2012-08-07  0.000879   0.000209 -0.109228 -0.125723  1.909409 -0.104837
# 2012-08-08 -0.539435  -0.513680 -0.109228 -0.125723  1.818881 -0.108437
# ...              ...        ...       ...       ...       ...       ...
# 2022-07-25 -1.890219  -2.312292 -0.109228 -0.625160 -0.896960  3.207485
# 2022-07-26 -0.539435  -0.770625  0.107465 -0.000863 -0.987488  3.220086
# 2022-07-27 -1.349905  -1.541458  0.215812 -0.125723 -0.851696  3.110275
# 2022-07-28  0.811350   2.055766  0.215812  0.373715 -0.942224  3.212885
# 2022-07-29 -3.241004  -2.055348 -0.325920 -1.374316 -0.896960  2.903255
#
#             종가_NDF_차이
# DateTime
# 2012-08-02  -1.648743
# 2012-08-03  -1.366022
# 2012-08-06   1.602547
# 2012-08-07   0.118263
# 2012-08-08  -0.223358
# ...               ...
# 2022-07-25   0.860405
# 2022-07-26   0.754385
# 2022-07-27  -0.564979
# 2022-07-28   1.838148
# 2022-07-29   0.200723
#
# [2459 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
import scipy as sp  
from matplotlib import rc 
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(20,20))

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(data = x_scaled.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap=cmap, center=0)
# Out:
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 50769 (\N{HANGUL SYLLABLE WAB}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50769 (\N{HANGUL SYLLABLE WAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tlsdm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     9.960192   대비_irs_1Y
# 1    19.501070   대비_irs_2Y
# 2     2.662512   대비_irs_3Y
# 3     6.474121   대비_irs_5Y
# 4     5.880995  대비_irs_10Y
# 5     2.663434   대비_crs_1Y
# 6     5.272150   대비_crs_2Y
# 7     3.831861   대비_crs_3Y
# 8     6.698546   대비_crs_5Y
# 9     3.716729  대비_crs_10Y
# 10    1.926839    대비_국고_1Y
# 11    1.254279    대비_국고_3Y
# 12    6.299324    대비_국고_5Y
# 13    5.058509   대비_국고_10Y
# 14    1.025239    대비_통안_1Y
# 15    1.115967    대비_통안_2Y
# 16    1.248050    스왑포인트_1M
# 17    1.192603     전일종가_ex
# 18    1.162388   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.453e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:48   Log-Likelihood:                -6907.2
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2439   BIC:                         1.397e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.0320      0.257      0.125      0.901      -0.471       0.535
# 대비_irs_2Y      0.4368      0.359      1.217      0.224      -0.267       1.141
# 대비_irs_3Y      0.0617      0.133      0.465      0.642      -0.198       0.322
# 대비_irs_5Y     -0.0227      0.207     -0.110      0.913      -0.428       0.383
# 대비_irs_10Y    -0.5280      0.197     -2.678      0.007      -0.915      -0.141
# 대비_crs_1Y     -0.6881      0.133     -5.186      0.000      -0.948      -0.428
# 대비_crs_2Y      0.0527      0.187      0.283      0.778      -0.313       0.419
# 대비_crs_3Y     -0.2957      0.159     -1.858      0.063      -0.608       0.016
# 대비_crs_5Y     -0.3172      0.210     -1.508      0.132      -0.730       0.095
# 대비_crs_10Y     0.1188      0.157      0.758      0.448      -0.189       0.426
# 대비_국고_1Y      -0.0149      0.113     -0.132      0.895      -0.236       0.206
# 대비_국고_3Y      -0.1732      0.091     -1.903      0.057      -0.352       0.005
# 대비_국고_5Y       0.2574      0.204      1.262      0.207      -0.143       0.658
# 대비_국고_10Y     -0.0071      0.183     -0.039      0.969      -0.366       0.351
# 대비_통안_1Y      -0.0048      0.082     -0.058      0.954      -0.166       0.157
# 대비_통안_2Y       0.0294      0.086      0.342      0.732      -0.139       0.198
# 스왑포인트_1M      -1.1729      0.091    -12.914      0.000      -1.351      -0.995
# 전일종가_ex       55.7384      0.089    627.817      0.000      55.564      55.912
# 종가_NDF_차이     -3.9527      0.088    -45.097      0.000      -4.125      -3.781
# ==============================================================================
# Omnibus:                      208.876   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              895.344
# Skew:                           0.305   Prob(JB):                    3.79e-195
# Kurtosis:                       5.892   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.932627   대비_irs_1Y
# 1     2.552008   대비_irs_3Y
# 2     5.807206   대비_irs_5Y
# 3     5.225154  대비_irs_10Y
# 4     2.660685   대비_crs_1Y
# 5     5.260811   대비_crs_2Y
# 6     3.829372   대비_crs_3Y
# 7     6.693347   대비_crs_5Y
# 8     3.716562  대비_crs_10Y
# 9     1.915930    대비_국고_1Y
# 10    1.248234    대비_국고_3Y
# 11    6.212802    대비_국고_5Y
# 12    5.044617   대비_국고_10Y
# 13    1.024881    대비_통안_1Y
# 14    1.115274    대비_통안_2Y
# 15    1.248036    스왑포인트_1M
# 16    1.191889     전일종가_ex
# 17    1.162241   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.589e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:49   Log-Likelihood:                -6908.0
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2440   BIC:                         1.396e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.2748      0.161      1.704      0.088      -0.041       0.591
# 대비_irs_3Y      0.0945      0.130      0.728      0.467      -0.160       0.349
# 대비_irs_5Y      0.0581      0.196      0.296      0.767      -0.326       0.442
# 대비_irs_10Y    -0.4479      0.186     -2.410      0.016      -0.812      -0.083
# 대비_crs_1Y     -0.6933      0.133     -5.228      0.000      -0.953      -0.433
# 대비_crs_2Y      0.0633      0.186      0.339      0.734      -0.302       0.429
# 대비_crs_3Y     -0.3006      0.159     -1.890      0.059      -0.613       0.011
# 대비_crs_5Y     -0.3101      0.210     -1.474      0.141      -0.723       0.102
# 대비_crs_10Y     0.1201      0.157      0.766      0.444      -0.187       0.427
# 대비_국고_1Y      -0.0046      0.113     -0.041      0.967      -0.225       0.216
# 대비_국고_3Y      -0.1655      0.091     -1.822      0.069      -0.344       0.013
# 대비_국고_5Y       0.2865      0.203      1.414      0.158      -0.111       0.684
# 대비_국고_10Y     -0.0188      0.183     -0.103      0.918      -0.377       0.339
# 대비_통안_1Y      -0.0067      0.082     -0.081      0.936      -0.168       0.155
# 대비_통안_2Y       0.0320      0.086      0.373      0.709      -0.136       0.200
# 스왑포인트_1M      -1.1725      0.091    -12.909      0.000      -1.351      -0.994
# 전일종가_ex       55.7357      0.089    627.913      0.000      55.562      55.910
# 종가_NDF_차이     -3.9539      0.088    -45.109      0.000      -4.126      -3.782
# ==============================================================================
# Omnibus:                      211.766   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              913.395
# Skew:                           0.311   Prob(JB):                    4.56e-199
# Kurtosis:                       5.920   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_통안_1Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.931683   대비_irs_1Y
# 1     2.551936   대비_irs_3Y
# 2     5.807205   대비_irs_5Y
# 3     5.224515  대비_irs_10Y
# 4     2.660670   대비_crs_1Y
# 5     5.260766   대비_crs_2Y
# 6     3.829352   대비_crs_3Y
# 7     6.693343   대비_crs_5Y
# 8     3.716561  대비_crs_10Y
# 9     1.904686    대비_국고_1Y
# 10    1.248190    대비_국고_3Y
# 11    6.209501    대비_국고_5Y
# 12    5.044596   대비_국고_10Y
# 13    1.115171    대비_통안_2Y
# 14    1.248023    스왑포인트_1M
# 15    1.191802     전일종가_ex
# 16    1.162241   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.742e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:51   Log-Likelihood:                -6908.0
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2441   BIC:                         1.396e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.2746      0.161      1.704      0.089      -0.041       0.591
# 대비_irs_3Y      0.0946      0.130      0.728      0.466      -0.160       0.349
# 대비_irs_5Y      0.0581      0.196      0.297      0.767      -0.326       0.442
# 대비_irs_10Y    -0.4477      0.186     -2.410      0.016      -0.812      -0.083
# 대비_crs_1Y     -0.6933      0.133     -5.229      0.000      -0.953      -0.433
# 대비_crs_2Y      0.0632      0.186      0.339      0.735      -0.302       0.429
# 대비_crs_3Y     -0.3006      0.159     -1.890      0.059      -0.613       0.011
# 대비_crs_5Y     -0.3101      0.210     -1.474      0.140      -0.722       0.102
# 대비_crs_10Y     0.1201      0.157      0.766      0.443      -0.187       0.427
# 대비_국고_1Y      -0.0053      0.112     -0.047      0.962      -0.225       0.215
# 대비_국고_3Y      -0.1656      0.091     -1.823      0.068      -0.344       0.013
# 대비_국고_5Y       0.2862      0.203      1.413      0.158      -0.111       0.683
# 대비_국고_10Y     -0.0188      0.183     -0.103      0.918      -0.377       0.339
# 대비_통안_2Y       0.0319      0.086      0.372      0.710      -0.136       0.200
# 스왑포인트_1M      -1.1725      0.091    -12.912      0.000      -1.351      -0.994
# 전일종가_ex       55.7357      0.089    628.063      0.000      55.562      55.910
# 종가_NDF_차이     -3.9539      0.088    -45.118      0.000      -4.126      -3.782
# ==============================================================================
# Omnibus:                      211.766   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              913.490
# Skew:                           0.311   Prob(JB):                    4.35e-199
# Kurtosis:                       5.921   Cond. No.                         7.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_3Y', '대비_crs_5Y', '대비_통안_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.609880   대비_irs_1Y
# 1     5.679918   대비_irs_5Y
# 2     5.097396  대비_irs_10Y
# 3     2.658732   대비_crs_1Y
# 4     4.566970   대비_crs_2Y
# 5     3.453762   대비_crs_3Y
# 6     2.434346  대비_crs_10Y
# 7     1.870270    대비_국고_1Y
# 8     1.246588    대비_국고_3Y
# 9     6.160912    대비_국고_5Y
# 10    5.044105   대비_국고_10Y
# 11    1.247990    스왑포인트_1M
# 12    1.191507     전일종가_ex
# 13    1.161683   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 3.330e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:52   Log-Likelihood:                -6909.4
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2444   BIC:                         1.394e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.3199      0.154      2.071      0.038       0.017       0.623
# 대비_irs_5Y      0.0703      0.194      0.363      0.717      -0.310       0.450
# 대비_irs_10Y    -0.4369      0.184     -2.381      0.017      -0.797      -0.077
# 대비_crs_1Y     -0.6937      0.133     -5.234      0.000      -0.954      -0.434
# 대비_crs_2Y     -0.0335      0.174     -0.193      0.847      -0.374       0.307
# 대비_crs_3Y     -0.3754      0.151     -2.485      0.013      -0.672      -0.079
# 대비_crs_10Y    -0.0126      0.127     -0.099      0.921      -0.261       0.236
# 대비_국고_1Y       0.0034      0.111      0.031      0.976      -0.215       0.221
# 대비_국고_3Y      -0.1655      0.091     -1.823      0.068      -0.343       0.012
# 대비_국고_5Y       0.2851      0.202      1.413      0.158      -0.111       0.681
# 대비_국고_10Y     -0.0169      0.183     -0.093      0.926      -0.375       0.341
# 스왑포인트_1M      -1.1723      0.091    -12.910      0.000      -1.350      -0.994
# 전일종가_ex       55.7359      0.089    628.169      0.000      55.562      55.910
# 종가_NDF_차이     -3.9524      0.088    -45.113      0.000      -4.124      -3.781
# ==============================================================================
# Omnibus:                      211.869   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              916.793
# Skew:                           0.310   Prob(JB):                    8.34e-200
# Kurtosis:                       5.927   Cond. No.                         6.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_5Y', '대비_crs_10Y', '대비_국고_1Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 4.244e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:52   Log-Likelihood:                -6909.5
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2447   BIC:                         1.391e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3479      0.133      2.612      0.009       0.087       0.609
# 대비_irs_10Y    -0.4028      0.153     -2.628      0.009      -0.703      -0.102
# 대비_crs_1Y     -0.6954      0.132     -5.253      0.000      -0.955      -0.436
# 대비_crs_2Y     -0.0372      0.166     -0.224      0.823      -0.362       0.288
# 대비_crs_3Y     -0.3786      0.144     -2.630      0.009      -0.661      -0.096
# 대비_국고_3Y      -0.1641      0.090     -1.826      0.068      -0.340       0.012
# 대비_국고_5Y       0.2936      0.191      1.541      0.123      -0.080       0.667
# 대비_국고_10Y     -0.0161      0.182     -0.088      0.930      -0.374       0.341
# 스왑포인트_1M      -1.1718      0.091    -12.916      0.000      -1.350      -0.994
# 전일종가_ex       55.7357      0.088    630.603      0.000      55.562      55.909
# 종가_NDF_차이     -3.9515      0.087    -45.167      0.000      -4.123      -3.780
# ==============================================================================
# Omnibus:                      212.133   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              919.570
# Skew:                           0.310   Prob(JB):                    2.08e-200
# Kurtosis:                       5.931   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_2Y', '대비_국고_10Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.191e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:15:53   Log-Likelihood:                -6909.5
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2449   BIC:                         1.390e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3494      0.131      2.661      0.008       0.092       0.607
# 대비_irs_10Y    -0.4055      0.151     -2.692      0.007      -0.701      -0.110
# 대비_crs_1Y     -0.7104      0.113     -6.261      0.000      -0.933      -0.488
# 대비_crs_3Y     -0.3979      0.116     -3.436      0.001      -0.625      -0.171
# 대비_국고_3Y      -0.1643      0.090     -1.829      0.068      -0.340       0.012
# 대비_국고_5Y       0.2781      0.111      2.506      0.012       0.060       0.496
# 스왑포인트_1M      -1.1721      0.091    -12.925      0.000      -1.350      -0.994
# 전일종가_ex       55.7357      0.088    630.866      0.000      55.562      55.909
# 종가_NDF_차이     -3.9523      0.087    -45.235      0.000      -4.124      -3.781
# ==============================================================================
# Omnibus:                      212.792   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              924.214
# Skew:                           0.311   Prob(JB):                    2.04e-201
# Kurtosis:                       5.938   Cond. No.                         3.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_scaled = pd.concat([x_scaled, y], axis=1)
df_scaled
# Out:
#             대비_irs_1Y  대비_irs_10Y  대비_crs_1Y  대비_crs_3Y  대비_국고_3Y  대비_국고_5Y  \
# DateTime
# 2012-08-02  -0.847862   -1.009126  -0.205655   0.905480 -0.646622 -1.079749
# 2012-08-03  -0.847862   -0.403231  -0.205655  -0.463176 -0.323869 -1.890219
# 2012-08-06   0.560374    0.202663  -0.003373  -0.691285  0.160261  0.000879
# 2012-08-07   0.278727    0.404628   0.401191  -0.006957 -0.001116  0.000879
# 2012-08-08   0.278727    0.606592   0.198909  -0.006957 -0.323869 -0.539435
# ...               ...         ...        ...        ...       ...       ...
# 2022-07-25  -1.129510   -2.220914  -1.621628  -1.603722 -0.969375 -1.890219
# 2022-07-26  -0.284568   -0.605196   0.198909  -0.691285 -0.485246 -0.539435
# 2022-07-27  -0.284568   -1.211091   0.198909  -0.235067 -0.485246 -1.349905
# 2022-07-28   0.842021    1.414452   0.805755   0.905480  0.644391  0.811350
# 2022-07-29  -1.974451   -2.422879  -2.228474  -3.428596 -2.099012 -3.241004
#
#             스왑포인트_1M   전일종가_ex  종가_NDF_차이   종가_ex
# DateTime
# 2012-08-02  1.909409 -0.149841  -1.648743  1131.7
# 2012-08-03  1.818881 -0.056232  -1.366022  1134.8
# 2012-08-06  1.818881 -0.000426   1.602547  1129.0
# 2012-08-07  1.909409 -0.104837   0.118263  1128.8
# 2012-08-08  1.818881 -0.108437  -0.223358  1128.3
# ...              ...       ...        ...     ...
# 2022-07-25 -0.896960  3.207485   0.860405  1313.7
# 2022-07-26 -0.987488  3.220086   0.754385  1307.6
# 2022-07-27 -0.851696  3.110275  -0.564979  1313.3
# 2022-07-28 -0.942224  3.212885   1.838148  1296.1
# 2022-07-29 -0.896960  2.903255   0.200723  1299.1
#
# [2459 rows x 10 columns]

# %%
train = df_scaled[0:1945]
test = df_scaled[1945:]

def make_dataset(data, label, window_size=5):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

feature_cols = ['대비_irs_1Y', '대비_irs_10Y', '대비_crs_1Y', '대비_crs_3Y', '대비_국고_3Y', '대비_국고_5Y', '스왑포인트_1M', '전일종가_ex', '종가_NDF_차이']
label_cols = ['종가_ex']

# %%
from sklearn.model_selection import train_test_split

train_feature = train[feature_cols]
train_label = train[label_cols]
test_feature = test[feature_cols]
test_label = test[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 5)
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((1552, 5, 9), (388, 5, 9))

# %%
train_feature
# Out:
# array([[[-8.47862468e-01, -1.00912576e+00, -2.05654693e-01, ...,
#           1.90940854e+00, -1.49840936e-01, -1.64874272e+00],
#         [-8.47862468e-01, -4.03231428e-01, -2.05654693e-01, ...,
#           1.81888052e+00, -5.62318504e-02, -1.36602186e+00],
#         [ 5.60373809e-01,  2.02662908e-01, -3.37273697e-03, ...,
#           1.81888052e+00, -4.26434230e-04,  1.60254716e+00],
#         [ 2.78726554e-01,  4.04627687e-01,  4.01191175e-01, ...,
#           1.90940854e+00, -1.04836568e-01,  1.18262649e-01],
#         [ 2.78726554e-01,  6.06592466e-01,  1.98909219e-01, ...,
#           1.81888052e+00, -1.08436917e-01, -2.23358389e-01]],
#
#        [[-8.47862468e-01, -4.03231428e-01, -2.05654693e-01, ...,
#           1.81888052e+00, -5.62318504e-02, -1.36602186e+00],
#         [ 5.60373809e-01,  2.02662908e-01, -3.37273697e-03, ...,
#           1.81888052e+00, -4.26434230e-04,  1.60254716e+00],
#         [ 2.78726554e-01,  4.04627687e-01,  4.01191175e-01, ...,
#           1.90940854e+00, -1.04836568e-01,  1.18262649e-01],
#         [ 2.78726554e-01,  6.06592466e-01,  1.98909219e-01, ...,
#           1.81888052e+00, -1.08436917e-01, -2.23358389e-01],
#         [ 1.40531558e+00,  8.08557245e-01,  1.81716487e+00, ...,
#           1.77361651e+00, -1.17437791e-01, -8.71260357e-01]],
#
#        [[ 5.60373809e-01,  2.02662908e-01, -3.37273697e-03, ...,
#           1.81888052e+00, -4.26434230e-04,  1.60254716e+00],
#         [ 2.78726554e-01,  4.04627687e-01,  4.01191175e-01, ...,
#           1.90940854e+00, -1.04836568e-01,  1.18262649e-01],
#         [ 2.78726554e-01,  6.06592466e-01,  1.98909219e-01, ...,
#           1.81888052e+00, -1.08436917e-01, -2.23358389e-01],
#         [ 1.40531558e+00,  8.08557245e-01,  1.81716487e+00, ...,
#           1.77361651e+00, -1.17437791e-01, -8.71260357e-01],
#         [-8.47862468e-01, -1.00912576e+00,  1.98909219e-01, ...,
#           1.81888052e+00, -1.67842683e-01, -9.41940571e-01]],
#
#        ...,
#
#        [[-2.92070151e-03,  2.02662908e-01, -5.09077627e-01, ...,
#          -7.61167960e-01,  1.34610425e+00, -3.29378711e-01],
#         [-2.92070151e-03, -2.01266649e-01,  6.03473131e-01, ...,
#          -8.96959985e-01,  1.45771509e+00,  1.72034751e+00],
#         [-2.92070151e-03, -2.01266649e-01,  1.41260096e+00, ...,
#          -6.70639943e-01,  1.33170286e+00,  3.77423436e-01],
#         [-2.84567957e-01, -4.03231428e-01, -2.05654693e-01, ...,
#          -4.89583909e-01,  1.16248643e+00, -1.48382222e+00],
#         [-2.84567957e-01, -4.03231428e-01,  1.41260096e+00, ...,
#          -4.89583909e-01,  1.25789569e+00,  7.54384581e-01]],
#
#        [[-2.92070151e-03, -2.01266649e-01,  6.03473131e-01, ...,
#          -8.96959985e-01,  1.45771509e+00,  1.72034751e+00],
#         [-2.92070151e-03, -2.01266649e-01,  1.41260096e+00, ...,
#          -6.70639943e-01,  1.33170286e+00,  3.77423436e-01],
#         [-2.84567957e-01, -4.03231428e-01, -2.05654693e-01, ...,
#          -4.89583909e-01,  1.16248643e+00, -1.48382222e+00],
#         [-2.84567957e-01, -4.03231428e-01,  1.41260096e+00, ...,
#          -4.89583909e-01,  1.25789569e+00,  7.54384581e-01],
#         [ 2.78726554e-01,  2.02662908e-01, -6.10218605e-01, ...,
#          -3.53791884e-01,  1.18408853e+00, -6.82779784e-01]],
#
#        [[-2.92070151e-03, -2.01266649e-01,  1.41260096e+00, ...,
#          -6.70639943e-01,  1.33170286e+00,  3.77423436e-01],
#         [-2.84567957e-01, -4.03231428e-01, -2.05654693e-01, ...,
#          -4.89583909e-01,  1.16248643e+00, -1.48382222e+00],
#         [-2.84567957e-01, -4.03231428e-01,  1.41260096e+00, ...,
#          -4.89583909e-01,  1.25789569e+00,  7.54384581e-01],
#         [ 2.78726554e-01,  2.02662908e-01, -6.10218605e-01, ...,
#          -3.53791884e-01,  1.18408853e+00, -6.82779784e-01],
#         [-2.92070151e-03,  6.06592466e-01, -6.10218605e-01, ...,
#          -5.34847918e-01,  1.14808503e+00,  4.75824341e-02]]])

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 5)
test_feature.shape, test_label.shape
# Out:
# ((509, 5, 9), (509, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM

# 모델의 설정
model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )
model.add(Dense(1))

# 모델의 컴파일(모델학습을 위한 학습과정 설정단계)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
early_stop = EarlyStopping(monitor='val_loss', patience=10)
modelpath = './'
checkpoint = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
# filename = os.path.join(file_path=model_path, 'tmp_checkpoint.h5')

# 모델의 실행
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])

# 테스트 정확도 출력                    
# print("\n Test Accuracy: %.4f" % model.evaluate(x_valid, y_valid))
# Out:
# Epoch 1/200
# 93/97 [===========================>..] - ETA: 0s - loss: 1265827.3750 - mae: 1123.9399
# Epoch 1: val_loss improved from inf to 1261981.00000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 12s 88ms/step - loss: 1265239.2500 - mae: 1123.6710 - val_loss: 1261981.0000 - val_mae: 1122.3612
# Epoch 2/200
# 94/97 [============================>.] - ETA: 0s - loss: 1094299.6250 - mae: 1035.2694
# Epoch 2: val_loss improved from 1261981.00000 to 567063.43750, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 88ms/step - loss: 1088173.6250 - mae: 1028.1123 - val_loss: 567063.4375 - val_mae: 699.1015
# Epoch 3/200
# 95/97 [============================>.] - ETA: 0s - loss: 365088.0312 - mae: 473.4753
# Epoch 3: val_loss improved from 567063.43750 to 233501.98438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 86ms/step - loss: 362173.5625 - mae: 471.9400 - val_loss: 233501.9844 - val_mae: 413.6636
# Epoch 4/200
# 96/97 [============================>.] - ETA: 0s - loss: 186083.6719 - mae: 329.9608
# Epoch 4: val_loss improved from 233501.98438 to 130661.67969, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 87ms/step - loss: 185555.8906 - mae: 329.7782 - val_loss: 130661.6797 - val_mae: 283.5010
# Epoch 5/200
# 96/97 [============================>.] - ETA: 0s - loss: 111840.2266 - mae: 246.9231
# Epoch 5: val_loss improved from 130661.67969 to 83737.34375, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 69ms/step - loss: 112048.2031 - mae: 246.9278 - val_loss: 83737.3438 - val_mae: 216.8858
# Epoch 6/200
# 95/97 [============================>.] - ETA: 0s - loss: 71704.0312 - mae: 194.4105
# Epoch 6: val_loss improved from 83737.34375 to 51927.08594, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 87ms/step - loss: 71120.3750 - mae: 193.5435 - val_loss: 51927.0859 - val_mae: 174.1795
# Epoch 7/200
# 94/97 [============================>.] - ETA: 0s - loss: 43965.5117 - mae: 149.3133
# Epoch 7: val_loss improved from 51927.08594 to 33978.39062, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 69ms/step - loss: 43702.9141 - mae: 149.4593 - val_loss: 33978.3906 - val_mae: 143.2916
# Epoch 8/200
# 92/97 [===========================>..] - ETA: 0s - loss: 26587.9082 - mae: 117.4860
# Epoch 8: val_loss improved from 33978.39062 to 19518.95703, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 10s 101ms/step - loss: 26817.3535 - mae: 116.7338 - val_loss: 19518.9570 - val_mae: 103.4855
# Epoch 9/200
# 96/97 [============================>.] - ETA: 0s - loss: 15829.8828 - mae: 88.3228
# Epoch 9: val_loss improved from 19518.95703 to 11716.50293, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 69ms/step - loss: 15793.5215 - mae: 88.4281 - val_loss: 11716.5029 - val_mae: 79.9885
# Epoch 10/200
# 90/97 [==========================>...] - ETA: 0s - loss: 9479.6025 - mae: 69.8713
# Epoch 10: val_loss improved from 11716.50293 to 7958.39355, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 66ms/step - loss: 9911.1729 - mae: 69.5249 - val_loss: 7958.3936 - val_mae: 62.3705
# Epoch 11/200
# 94/97 [============================>.] - ETA: 0s - loss: 6707.4775 - mae: 55.8355
# Epoch 11: val_loss improved from 7958.39355 to 5638.23145, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 68ms/step - loss: 6710.1074 - mae: 55.6660 - val_loss: 5638.2314 - val_mae: 53.0454
# Epoch 12/200
# 97/97 [==============================] - ETA: 0s - loss: 4965.3447 - mae: 46.9807
# Epoch 12: val_loss improved from 5638.23145 to 4477.40967, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 72ms/step - loss: 4965.3447 - mae: 46.9807 - val_loss: 4477.4097 - val_mae: 43.7471
# Epoch 13/200
# 93/97 [===========================>..] - ETA: 0s - loss: 3976.6614 - mae: 41.3837
# Epoch 13: val_loss improved from 4477.40967 to 3699.12793, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 68ms/step - loss: 3930.5830 - mae: 41.2042 - val_loss: 3699.1279 - val_mae: 39.5596
# Epoch 14/200
# 90/97 [==========================>...] - ETA: 0s - loss: 3293.2312 - mae: 37.9317
# Epoch 14: val_loss improved from 3699.12793 to 3329.85889, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 69ms/step - loss: 3252.5906 - mae: 37.4011 - val_loss: 3329.8589 - val_mae: 37.3085
# Epoch 15/200
# 90/97 [==========================>...] - ETA: 0s - loss: 2912.6943 - mae: 35.3777
# Epoch 15: val_loss improved from 3329.85889 to 2899.32764, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 2862.2231 - mae: 35.1929 - val_loss: 2899.3276 - val_mae: 34.1759
# Epoch 16/200
# 97/97 [==============================] - ETA: 0s - loss: 2467.5210 - mae: 32.9550
# Epoch 16: val_loss improved from 2899.32764 to 2595.91016, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 66ms/step - loss: 2467.5210 - mae: 32.9550 - val_loss: 2595.9102 - val_mae: 32.3471
# Epoch 17/200
# 92/97 [===========================>..] - ETA: 0s - loss: 2192.8525 - mae: 30.7736
# Epoch 17: val_loss improved from 2595.91016 to 2364.35938, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 74ms/step - loss: 2169.9827 - mae: 30.5788 - val_loss: 2364.3594 - val_mae: 30.5179
# Epoch 18/200
# 90/97 [==========================>...] - ETA: 0s - loss: 1720.4047 - mae: 28.7389
# Epoch 18: val_loss improved from 2364.35938 to 2254.46338, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 67ms/step - loss: 1971.5029 - mae: 29.3383 - val_loss: 2254.4634 - val_mae: 30.6076
# Epoch 19/200
# 93/97 [===========================>..] - ETA: 0s - loss: 1746.5917 - mae: 27.5221
# Epoch 19: val_loss improved from 2254.46338 to 1973.61682, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 63ms/step - loss: 1732.2700 - mae: 27.5938 - val_loss: 1973.6168 - val_mae: 27.4126
# Epoch 20/200
# 92/97 [===========================>..] - ETA: 0s - loss: 1544.3933 - mae: 26.5821
# Epoch 20: val_loss improved from 1973.61682 to 1918.21460, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 69ms/step - loss: 1561.0721 - mae: 26.5554 - val_loss: 1918.2146 - val_mae: 27.2263
# Epoch 21/200
# 94/97 [============================>.] - ETA: 0s - loss: 1438.3593 - mae: 25.6697
# Epoch 21: val_loss improved from 1918.21460 to 1865.59668, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 1429.2057 - mae: 25.7014 - val_loss: 1865.5967 - val_mae: 27.0299
# Epoch 22/200
# 94/97 [============================>.] - ETA: 0s - loss: 1286.3788 - mae: 24.0593
# Epoch 22: val_loss improved from 1865.59668 to 1714.08862, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 74ms/step - loss: 1266.9368 - mae: 23.9056 - val_loss: 1714.0886 - val_mae: 25.5386
# Epoch 23/200
# 95/97 [============================>.] - ETA: 0s - loss: 1138.9056 - mae: 22.7171
# Epoch 23: val_loss improved from 1714.08862 to 1555.41833, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 64ms/step - loss: 1128.8850 - mae: 22.6732 - val_loss: 1555.4183 - val_mae: 23.3668
# Epoch 24/200
# 88/97 [==========================>...] - ETA: 0s - loss: 1033.5354 - mae: 21.5960
# Epoch 24: val_loss improved from 1555.41833 to 1482.45056, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 67ms/step - loss: 1025.6609 - mae: 21.6101 - val_loss: 1482.4506 - val_mae: 23.1798
# Epoch 25/200
# 95/97 [============================>.] - ETA: 0s - loss: 951.6299 - mae: 21.0126
# Epoch 25: val_loss improved from 1482.45056 to 1361.75037, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 63ms/step - loss: 948.6388 - mae: 21.0511 - val_loss: 1361.7504 - val_mae: 21.4318
# Epoch 26/200
# 94/97 [============================>.] - ETA: 0s - loss: 884.2869 - mae: 20.4047
# Epoch 26: val_loss improved from 1361.75037 to 1276.69775, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 72ms/step - loss: 874.6011 - mae: 20.3626 - val_loss: 1276.6978 - val_mae: 20.8503
# Epoch 27/200
# 90/97 [==========================>...] - ETA: 0s - loss: 784.4367 - mae: 19.1012
# Epoch 27: val_loss improved from 1276.69775 to 1270.82373, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 777.4781 - mae: 19.1201 - val_loss: 1270.8237 - val_mae: 20.7216
# Epoch 28/200
# 97/97 [==============================] - ETA: 0s - loss: 738.1480 - mae: 18.9354
# Epoch 28: val_loss did not improve from 1270.82373
# 97/97 [==============================] - 1s 7ms/step - loss: 738.1480 - mae: 18.9354 - val_loss: 1281.9008 - val_mae: 21.7993
# Epoch 29/200
# 91/97 [===========================>..] - ETA: 0s - loss: 685.9258 - mae: 18.1649
# Epoch 29: val_loss improved from 1270.82373 to 1184.88843, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 666.9270 - mae: 17.9389 - val_loss: 1184.8884 - val_mae: 19.8218
# Epoch 30/200
# 94/97 [============================>.] - ETA: 0s - loss: 631.9512 - mae: 17.5196
# Epoch 30: val_loss improved from 1184.88843 to 1169.21277, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 68ms/step - loss: 624.0903 - mae: 17.4861 - val_loss: 1169.2128 - val_mae: 20.2355
# Epoch 31/200
# 94/97 [============================>.] - ETA: 0s - loss: 610.4407 - mae: 17.3757
# Epoch 31: val_loss improved from 1169.21277 to 1071.70605, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 11s 110ms/step - loss: 598.9166 - mae: 17.2333 - val_loss: 1071.7061 - val_mae: 18.1997
# Epoch 32/200
# 93/97 [===========================>..] - ETA: 0s - loss: 568.5566 - mae: 16.9540
# Epoch 32: val_loss did not improve from 1071.70605
# 97/97 [==============================] - 1s 13ms/step - loss: 570.9714 - mae: 17.0120 - val_loss: 1224.6503 - val_mae: 21.3934
# Epoch 33/200
# 90/97 [==========================>...] - ETA: 0s - loss: 535.3865 - mae: 16.4655
# Epoch 33: val_loss did not improve from 1071.70605
# 97/97 [==============================] - 1s 13ms/step - loss: 522.2159 - mae: 16.3235 - val_loss: 1074.7161 - val_mae: 18.6886
# Epoch 34/200
# 94/97 [============================>.] - ETA: 0s - loss: 479.9203 - mae: 15.5304
# Epoch 34: val_loss improved from 1071.70605 to 998.05475, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 10s 104ms/step - loss: 474.9290 - mae: 15.4666 - val_loss: 998.0547 - val_mae: 17.3056
# Epoch 35/200
# 94/97 [============================>.] - ETA: 0s - loss: 444.6998 - mae: 14.9562
# Epoch 35: val_loss improved from 998.05475 to 945.21454, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 79ms/step - loss: 452.9027 - mae: 15.0644 - val_loss: 945.2145 - val_mae: 16.4919
# Epoch 36/200
# 91/97 [===========================>..] - ETA: 0s - loss: 444.4993 - mae: 15.1138
# Epoch 36: val_loss did not improve from 945.21454
# 97/97 [==============================] - 1s 7ms/step - loss: 435.3004 - mae: 14.9814 - val_loss: 1120.7158 - val_mae: 19.5894
# Epoch 37/200
# 96/97 [============================>.] - ETA: 0s - loss: 414.0565 - mae: 14.8371
# Epoch 37: val_loss did not improve from 945.21454
# 97/97 [==============================] - 1s 7ms/step - loss: 413.8348 - mae: 14.8568 - val_loss: 1060.9666 - val_mae: 18.4396
# Epoch 38/200
# 96/97 [============================>.] - ETA: 0s - loss: 388.4202 - mae: 14.2947
# Epoch 38: val_loss improved from 945.21454 to 935.19836, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 389.8640 - mae: 14.3448 - val_loss: 935.1984 - val_mae: 15.9623
# Epoch 39/200
# 90/97 [==========================>...] - ETA: 0s - loss: 380.3177 - mae: 14.3333
# Epoch 39: val_loss improved from 935.19836 to 922.64587, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 71ms/step - loss: 384.0764 - mae: 14.3627 - val_loss: 922.6459 - val_mae: 15.9619
# Epoch 40/200
# 93/97 [===========================>..] - ETA: 0s - loss: 353.6444 - mae: 13.6739
# Epoch 40: val_loss did not improve from 922.64587
# 97/97 [==============================] - 1s 12ms/step - loss: 350.0844 - mae: 13.6047 - val_loss: 997.8735 - val_mae: 17.2463
# Epoch 41/200
# 95/97 [============================>.] - ETA: 0s - loss: 348.9329 - mae: 13.8440
# Epoch 41: val_loss did not improve from 922.64587
# 97/97 [==============================] - 1s 11ms/step - loss: 347.0165 - mae: 13.8127 - val_loss: 1028.8425 - val_mae: 17.3096
# Epoch 42/200
# 93/97 [===========================>..] - ETA: 0s - loss: 340.4248 - mae: 13.7763
# Epoch 42: val_loss did not improve from 922.64587
# 97/97 [==============================] - 1s 14ms/step - loss: 337.3450 - mae: 13.7612 - val_loss: 968.7870 - val_mae: 16.4815
# Epoch 43/200
# 96/97 [============================>.] - ETA: 0s - loss: 360.5957 - mae: 14.3693
# Epoch 43: val_loss did not improve from 922.64587
# 97/97 [==============================] - 1s 11ms/step - loss: 358.5240 - mae: 14.3357 - val_loss: 955.9070 - val_mae: 16.6878
# Epoch 44/200
# 88/97 [==========================>...] - ETA: 0s - loss: 290.0193 - mae: 12.7458
# Epoch 44: val_loss did not improve from 922.64587
# 97/97 [==============================] - 1s 8ms/step - loss: 297.8361 - mae: 12.8769 - val_loss: 939.2141 - val_mae: 14.9689
# Epoch 45/200
# 93/97 [===========================>..] - ETA: 0s - loss: 290.0650 - mae: 12.6986
# Epoch 45: val_loss improved from 922.64587 to 904.87494, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 76ms/step - loss: 291.2342 - mae: 12.7618 - val_loss: 904.8749 - val_mae: 14.6702
# Epoch 46/200
# 93/97 [===========================>..] - ETA: 0s - loss: 276.5152 - mae: 12.5246
# Epoch 46: val_loss improved from 904.87494 to 881.14551, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 9s 95ms/step - loss: 276.3520 - mae: 12.5569 - val_loss: 881.1455 - val_mae: 13.8011
# Epoch 47/200
# 89/97 [==========================>...] - ETA: 0s - loss: 293.9211 - mae: 13.0098
# Epoch 47: val_loss did not improve from 881.14551
# 97/97 [==============================] - 1s 8ms/step - loss: 288.9763 - mae: 12.9137 - val_loss: 968.8213 - val_mae: 16.0739
# Epoch 48/200
# 90/97 [==========================>...] - ETA: 0s - loss: 263.8542 - mae: 12.2136
# Epoch 48: val_loss did not improve from 881.14551
# 97/97 [==============================] - 1s 7ms/step - loss: 263.3543 - mae: 12.2415 - val_loss: 888.1973 - val_mae: 14.1347
# Epoch 49/200
# 91/97 [===========================>..] - ETA: 0s - loss: 260.9503 - mae: 12.0716
# Epoch 49: val_loss did not improve from 881.14551
# 97/97 [==============================] - 1s 8ms/step - loss: 257.6406 - mae: 12.0638 - val_loss: 927.7755 - val_mae: 15.2889
# Epoch 50/200
# 95/97 [============================>.] - ETA: 0s - loss: 269.1242 - mae: 12.4520
# Epoch 50: val_loss did not improve from 881.14551
# 97/97 [==============================] - 1s 7ms/step - loss: 266.1924 - mae: 12.3429 - val_loss: 921.7741 - val_mae: 14.3978
# Epoch 51/200
# 91/97 [===========================>..] - ETA: 0s - loss: 252.2136 - mae: 12.1875
# Epoch 51: val_loss did not improve from 881.14551
# 97/97 [==============================] - 1s 8ms/step - loss: 252.3678 - mae: 12.1621 - val_loss: 888.4012 - val_mae: 13.7835
# Epoch 52/200
# 92/97 [===========================>..] - ETA: 0s - loss: 238.3385 - mae: 11.7887
# Epoch 52: val_loss improved from 881.14551 to 876.89069, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 86ms/step - loss: 236.9232 - mae: 11.7321 - val_loss: 876.8907 - val_mae: 13.3263
# Epoch 53/200
# 95/97 [============================>.] - ETA: 0s - loss: 230.7656 - mae: 11.5311
# Epoch 53: val_loss did not improve from 876.89069
# 97/97 [==============================] - 1s 10ms/step - loss: 235.2401 - mae: 11.6036 - val_loss: 962.3468 - val_mae: 15.5968
# Epoch 54/200
# 92/97 [===========================>..] - ETA: 0s - loss: 248.7489 - mae: 12.1448
# Epoch 54: val_loss improved from 876.89069 to 867.33411, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 75ms/step - loss: 245.6132 - mae: 12.0501 - val_loss: 867.3341 - val_mae: 13.9925
# Epoch 55/200
# 96/97 [============================>.] - ETA: 0s - loss: 223.8981 - mae: 11.4998
# Epoch 55: val_loss improved from 867.33411 to 857.17157, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 74ms/step - loss: 225.6762 - mae: 11.5264 - val_loss: 857.1716 - val_mae: 13.3033
# Epoch 56/200
# 88/97 [==========================>...] - ETA: 0s - loss: 216.9185 - mae: 11.4283
# Epoch 56: val_loss did not improve from 857.17157
# 97/97 [==============================] - 1s 7ms/step - loss: 221.9968 - mae: 11.4783 - val_loss: 895.0535 - val_mae: 13.5656
# Epoch 57/200
# 96/97 [============================>.] - ETA: 0s - loss: 218.4382 - mae: 11.3461
# Epoch 57: val_loss did not improve from 857.17157
# 97/97 [==============================] - 1s 12ms/step - loss: 218.4619 - mae: 11.3433 - val_loss: 917.9937 - val_mae: 14.6368
# Epoch 58/200
# 93/97 [===========================>..] - ETA: 0s - loss: 219.6686 - mae: 11.3850
# Epoch 58: val_loss did not improve from 857.17157
# 97/97 [==============================] - 1s 10ms/step - loss: 219.0159 - mae: 11.3496 - val_loss: 868.6572 - val_mae: 13.3227
# Epoch 59/200
# 96/97 [============================>.] - ETA: 0s - loss: 192.5035 - mae: 10.7165
# Epoch 59: val_loss improved from 857.17157 to 785.51843, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 8s 80ms/step - loss: 191.6366 - mae: 10.6912 - val_loss: 785.5184 - val_mae: 12.6435
# Epoch 60/200
# 97/97 [==============================] - ETA: 0s - loss: 201.7132 - mae: 10.8285
# Epoch 60: val_loss did not improve from 785.51843
# 97/97 [==============================] - 1s 12ms/step - loss: 201.7132 - mae: 10.8285 - val_loss: 839.0434 - val_mae: 12.9731
# Epoch 61/200
# 96/97 [============================>.] - ETA: 0s - loss: 229.1819 - mae: 11.1626
# Epoch 61: val_loss did not improve from 785.51843
# 97/97 [==============================] - 1s 11ms/step - loss: 227.8496 - mae: 11.1252 - val_loss: 801.4755 - val_mae: 13.0971
# Epoch 62/200
# 94/97 [============================>.] - ETA: 0s - loss: 203.5322 - mae: 10.9445
# Epoch 62: val_loss did not improve from 785.51843
# 97/97 [==============================] - 1s 13ms/step - loss: 215.3561 - mae: 11.2144 - val_loss: 866.7895 - val_mae: 14.4630
# Epoch 63/200
# 93/97 [===========================>..] - ETA: 0s - loss: 235.7918 - mae: 11.9350
# Epoch 63: val_loss did not improve from 785.51843
# 97/97 [==============================] - 1s 11ms/step - loss: 234.7125 - mae: 11.8822 - val_loss: 827.3893 - val_mae: 12.5220
# Epoch 64/200
# 95/97 [============================>.] - ETA: 0s - loss: 187.4147 - mae: 10.4618
# Epoch 64: val_loss improved from 785.51843 to 742.16498, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 66ms/step - loss: 187.2322 - mae: 10.4633 - val_loss: 742.1650 - val_mae: 12.1782
# Epoch 65/200
# 89/97 [==========================>...] - ETA: 0s - loss: 185.3853 - mae: 10.6914
# Epoch 65: val_loss did not improve from 742.16498
# 97/97 [==============================] - 1s 7ms/step - loss: 186.8180 - mae: 10.6742 - val_loss: 770.3888 - val_mae: 13.2090
# Epoch 66/200
# 93/97 [===========================>..] - ETA: 0s - loss: 179.6181 - mae: 10.2887
# Epoch 66: val_loss did not improve from 742.16498
# 97/97 [==============================] - 1s 10ms/step - loss: 180.1357 - mae: 10.2941 - val_loss: 787.9375 - val_mae: 13.1389
# Epoch 67/200
# 96/97 [============================>.] - ETA: 0s - loss: 208.6090 - mae: 11.1708
# Epoch 67: val_loss improved from 742.16498 to 728.43427, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 67ms/step - loss: 207.9796 - mae: 11.1560 - val_loss: 728.4343 - val_mae: 12.4123
# Epoch 68/200
# 89/97 [==========================>...] - ETA: 0s - loss: 200.9005 - mae: 11.0806
# Epoch 68: val_loss did not improve from 728.43427
# 97/97 [==============================] - 1s 8ms/step - loss: 196.0618 - mae: 10.9508 - val_loss: 810.3489 - val_mae: 13.2962
# Epoch 69/200
# 95/97 [============================>.] - ETA: 0s - loss: 183.9909 - mae: 10.5217
# Epoch 69: val_loss did not improve from 728.43427
# 97/97 [==============================] - 1s 11ms/step - loss: 184.5876 - mae: 10.5519 - val_loss: 777.6885 - val_mae: 13.0168
# Epoch 70/200
# 95/97 [============================>.] - ETA: 0s - loss: 186.7432 - mae: 10.6797
# Epoch 70: val_loss did not improve from 728.43427
# 97/97 [==============================] - 1s 12ms/step - loss: 185.1823 - mae: 10.6348 - val_loss: 733.0298 - val_mae: 12.1464
# Epoch 71/200
# 94/97 [============================>.] - ETA: 0s - loss: 183.9899 - mae: 10.5067
# Epoch 71: val_loss improved from 728.43427 to 700.85352, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 66ms/step - loss: 185.1296 - mae: 10.5347 - val_loss: 700.8535 - val_mae: 12.1404
# Epoch 72/200
# 91/97 [===========================>..] - ETA: 0s - loss: 171.1724 - mae: 10.1421
# Epoch 72: val_loss did not improve from 700.85352
# 97/97 [==============================] - 1s 9ms/step - loss: 169.6596 - mae: 10.1118 - val_loss: 718.4293 - val_mae: 11.6731
# Epoch 73/200
# 93/97 [===========================>..] - ETA: 0s - loss: 162.4315 - mae: 9.8125
# Epoch 73: val_loss did not improve from 700.85352
# 97/97 [==============================] - 1s 9ms/step - loss: 160.8579 - mae: 9.7578 - val_loss: 788.6956 - val_mae: 13.5524
# Epoch 74/200
# 96/97 [============================>.] - ETA: 0s - loss: 173.8198 - mae: 10.2084
# Epoch 74: val_loss did not improve from 700.85352
# 97/97 [==============================] - 1s 8ms/step - loss: 174.7859 - mae: 10.2316 - val_loss: 704.2724 - val_mae: 11.7997
# Epoch 75/200
# 97/97 [==============================] - ETA: 0s - loss: 165.2074 - mae: 9.8939
# Epoch 75: val_loss did not improve from 700.85352
# 97/97 [==============================] - 1s 8ms/step - loss: 165.2074 - mae: 9.8939 - val_loss: 713.1164 - val_mae: 11.7223
# Epoch 76/200
# 91/97 [===========================>..] - ETA: 0s - loss: 175.5743 - mae: 10.2267
# Epoch 76: val_loss did not improve from 700.85352
# 97/97 [==============================] - 1s 10ms/step - loss: 177.4396 - mae: 10.2998 - val_loss: 790.1829 - val_mae: 12.9126
# Epoch 77/200
# 93/97 [===========================>..] - ETA: 0s - loss: 190.0986 - mae: 10.6042
# Epoch 77: val_loss improved from 700.85352 to 682.06750, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 65ms/step - loss: 186.9412 - mae: 10.5215 - val_loss: 682.0675 - val_mae: 11.8740
# Epoch 78/200
# 97/97 [==============================] - ETA: 0s - loss: 170.8664 - mae: 9.7609
# Epoch 78: val_loss did not improve from 682.06750
# 97/97 [==============================] - 1s 11ms/step - loss: 170.8664 - mae: 9.7609 - val_loss: 831.0536 - val_mae: 11.8428
# Epoch 79/200
# 89/97 [==========================>...] - ETA: 0s - loss: 191.4196 - mae: 10.5212
# Epoch 79: val_loss improved from 682.06750 to 675.28033, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 75ms/step - loss: 190.8487 - mae: 10.5400 - val_loss: 675.2803 - val_mae: 12.9745
# Epoch 80/200
# 93/97 [===========================>..] - ETA: 0s - loss: 191.1914 - mae: 10.5193
# Epoch 80: val_loss did not improve from 675.28033
# 97/97 [==============================] - 1s 7ms/step - loss: 195.5052 - mae: 10.5778 - val_loss: 800.8346 - val_mae: 14.2574
# Epoch 81/200
# 96/97 [============================>.] - ETA: 0s - loss: 173.1744 - mae: 10.0774
# Epoch 81: val_loss improved from 675.28033 to 616.00287, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 6s 61ms/step - loss: 173.2415 - mae: 10.0854 - val_loss: 616.0029 - val_mae: 11.0009
# Epoch 82/200
# 91/97 [===========================>..] - ETA: 0s - loss: 177.5744 - mae: 10.2898
# Epoch 82: val_loss did not improve from 616.00287
# 97/97 [==============================] - 1s 8ms/step - loss: 173.8165 - mae: 10.1719 - val_loss: 707.3006 - val_mae: 11.8792
# Epoch 83/200
# 97/97 [==============================] - ETA: 0s - loss: 153.9235 - mae: 9.4298
# Epoch 83: val_loss did not improve from 616.00287
# 97/97 [==============================] - 1s 10ms/step - loss: 153.9235 - mae: 9.4298 - val_loss: 638.6591 - val_mae: 11.1555
# Epoch 84/200
# 91/97 [===========================>..] - ETA: 0s - loss: 181.9958 - mae: 10.2890
# Epoch 84: val_loss did not improve from 616.00287
# 97/97 [==============================] - 1s 11ms/step - loss: 179.9861 - mae: 10.2533 - val_loss: 731.3832 - val_mae: 11.8460
# Epoch 85/200
# 94/97 [============================>.] - ETA: 0s - loss: 174.7899 - mae: 10.2219
# Epoch 85: val_loss improved from 616.00287 to 604.60992, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 97/97 [==============================] - 7s 68ms/step - loss: 174.7608 - mae: 10.2199 - val_loss: 604.6099 - val_mae: 11.5738
# Epoch 86/200
# 93/97 [===========================>..] - ETA: 0s - loss: 153.7784 - mae: 9.4491
# Epoch 86: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 11ms/step - loss: 151.2376 - mae: 9.3918 - val_loss: 712.9653 - val_mae: 11.4394
# Epoch 87/200
# 97/97 [==============================] - ETA: 0s - loss: 192.8858 - mae: 10.5086
# Epoch 87: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 9ms/step - loss: 192.8858 - mae: 10.5086 - val_loss: 657.5208 - val_mae: 12.1396
# Epoch 88/200
# 94/97 [============================>.] - ETA: 0s - loss: 172.5569 - mae: 9.8063
# Epoch 88: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 11ms/step - loss: 172.1624 - mae: 9.8080 - val_loss: 781.6383 - val_mae: 12.7023
# Epoch 89/200
# 92/97 [===========================>..] - ETA: 0s - loss: 187.0273 - mae: 10.0954
# Epoch 89: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 7ms/step - loss: 187.3140 - mae: 10.1298 - val_loss: 630.1183 - val_mae: 11.6679
# Epoch 90/200
# 97/97 [==============================] - ETA: 0s - loss: 171.3551 - mae: 9.9149
# Epoch 90: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 8ms/step - loss: 171.3551 - mae: 9.9149 - val_loss: 792.3437 - val_mae: 13.3905
# Epoch 91/200
# 92/97 [===========================>..] - ETA: 0s - loss: 179.2123 - mae: 10.0715
# Epoch 91: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 8ms/step - loss: 182.9092 - mae: 10.1575 - val_loss: 687.0980 - val_mae: 14.2586
# Epoch 92/200
# 87/97 [=========================>....] - ETA: 0s - loss: 172.7803 - mae: 9.8515
# Epoch 92: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 7ms/step - loss: 168.5589 - mae: 9.7587 - val_loss: 732.3624 - val_mae: 11.3163
# Epoch 93/200
# 92/97 [===========================>..] - ETA: 0s - loss: 156.5152 - mae: 9.4795
# Epoch 93: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 6ms/step - loss: 155.5130 - mae: 9.4403 - val_loss: 615.8469 - val_mae: 11.0987
# Epoch 94/200
# 95/97 [============================>.] - ETA: 0s - loss: 162.2211 - mae: 9.8222
# Epoch 94: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 7ms/step - loss: 162.2766 - mae: 9.8196 - val_loss: 700.9221 - val_mae: 12.5680
# Epoch 95/200
# 94/97 [============================>.] - ETA: 0s - loss: 145.4948 - mae: 9.2292
# Epoch 95: val_loss did not improve from 604.60992
# 97/97 [==============================] - 1s 7ms/step - loss: 146.7038 - mae: 9.2862 - val_loss: 664.4204 - val_mae: 11.7078

# %%
pred = model.predict(test_feature)

import matplotlib.pyplot as plt 

plt.figure(figsize=(16, 10))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.grid()
plt.show()
# Out:
# 16/16 [==============================] - 1s 4ms/step
