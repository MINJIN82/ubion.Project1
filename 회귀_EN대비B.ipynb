# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# 파일 불러오기
all = pd.read_excel("../데이터자료/Join_data.xlsx", index_col = 0)    

# 컬럼 추출
all2 = all[['DateTime', '종가_ex', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스', '10Y_베이시스',
        '국고1년', '국고3년', '국고5년','국고10년', '통안364일', '통안2년', 'Mid_ndf',
        'M1_스왑포인트']]            # [[]] 대괄호 2개 사용 -> 데이터 프레임형태로 나옴

all2 = all2.set_index("DateTime")

all2['대비_베이시스1년'] = all2['1Y_베이시스']-all2['1Y_베이시스'].shift(1)
all2['대비_베이시스2년'] = all2['2Y_베이시스']-all2['2Y_베이시스'].shift(1)
all2['대비_베이시스3년'] = all2['3Y_베이시스']-all2['3Y_베이시스'].shift(1)
all2['대비_베이시스5년'] =all2['5Y_베이시스']-all2['5Y_베이시스'].shift(1)
all2['대비_베이시스10년'] = all2['10Y_베이시스']-all2['10Y_베이시스'].shift(1)
all2['대비_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)
all2['대비_국고1년'] = all2['국고1년']-all2['국고1년'].shift(1)
all2['대비_국고3년'] = all2['국고3년']-all2['국고3년'].shift(1)
all2['대비_국고5년'] = all2['국고5년']-all2['국고5년'].shift(1)
all2['대비_국고10년'] = all2['국고10년']-all2['국고10년'].shift(1)
all2['대비_통안1년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_통안2년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['전일종가_ex'] = all2['종가_ex'].shift(1)
all2["종가_NDF차이"] = all2["전일종가_ex"] -all2["Mid_ndf"]
all2['스왑포인트_1월물'] = all2["M1_스왑포인트"]/100 


all2 = all2.dropna()

# 필요 칼럼만 남기기
df = all2.copy()
df = all2[["종가_ex", 
             "대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "종가_NDF차이", "스왑포인트_1월물", "전일종가_ex"]]

# DateTime을 인덱스로 바꿔주기
df.head()
# Out:
#              종가_ex  대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년  \
# DateTime
# 2012-08-02  1131.7        2.0        8.0        9.0        9.0         9.0
# 2012-08-03  1134.8        2.0        1.5        1.0       -5.0       -13.0
# 2012-08-06  1129.0       -2.0       -4.5       -5.0       -6.0        -5.0
# 2012-08-07  1128.8        1.0        1.5        0.0       -8.0       -10.0
# 2012-08-08  1128.3        0.0       -2.0       -2.0       -4.0        -7.0
#
#             대비_국고1년  대비_국고3년  대비_국고5년  대비_국고10년  대비_통안1년  대비_통안2년  종가_NDF차이  \
# DateTime
# 2012-08-02    -0.03    -0.04    -0.04     -0.04    -0.03    -0.03     -7.50
# 2012-08-03    -0.02    -0.02    -0.07     -0.07    -0.02    -0.02     -6.30
# 2012-08-06     0.01     0.01     0.00      0.00     0.01     0.01      6.30
# 2012-08-07    -0.01     0.00     0.00      0.00    -0.01    -0.01      0.00
# 2012-08-08    -0.01    -0.02    -0.02     -0.02    -0.01    -0.01     -1.45
#
#             스왑포인트_1월물  전일종가_ex
# DateTime
# 2012-08-02        2.5   1126.5
# 2012-08-03        2.4   1131.7
# 2012-08-06        2.4   1134.8
# 2012-08-07        2.5   1129.0
# 2012-08-08        2.4   1128.8

# %%
x = df[["대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "종가_NDF차이", "스왑포인트_1월물", "전일종가_ex"]]
y = df["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
#             대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년   대비_국고1년  \
# DateTime
# 2012-08-02   0.348741   1.544080   1.437744   1.627899    1.488363 -1.698057
# 2012-08-03   0.348741   0.286831   0.157058  -0.910410   -2.158344 -1.132651
# 2012-08-06  -0.350946  -0.873707  -0.803456  -1.091718   -0.832269  0.563566
# 2012-08-07   0.173819   0.286831  -0.003027  -1.454333   -1.661066 -0.567245
# 2012-08-08  -0.001103  -0.390150  -0.323199  -0.729102   -1.163788 -0.567245
# ...               ...        ...        ...        ...         ...       ...
# 2022-07-25  -0.700790  -0.196727  -0.003027  -0.366487   -0.003472 -1.132651
# 2022-07-26   0.348741  -0.196727  -0.003027   0.177437    0.162288  0.563566
# 2022-07-27   0.348741   0.770388   0.797401   0.902668    0.825326 -0.001839
# 2022-07-28   0.173819  -0.003304  -0.163113  -0.366487   -0.832269  0.563566
# 2022-07-29  -0.700790  -0.583573  -0.163113   0.902668    0.493807 -2.263463
#
#              대비_국고3년   대비_국고5년  대비_국고10년   대비_통안1년   대비_통안2년  종가_NDF차이  \
# DateTime
# 2012-08-02 -0.646622 -1.079749 -1.027569 -0.325920 -0.325920 -1.648743
# 2012-08-03 -0.323869 -1.890219 -1.798403 -0.217574 -0.217574 -1.366022
# 2012-08-06  0.160261  0.000879  0.000209  0.107465  0.107465  1.602547
# 2012-08-07 -0.001116  0.000879  0.000209 -0.109228 -0.109228  0.118263
# 2012-08-08 -0.323869 -0.539435 -0.513680 -0.109228 -0.109228 -0.223358
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -0.969375 -1.890219 -2.312292 -0.109228 -0.109228  0.860405
# 2022-07-26 -0.485246 -0.539435 -0.770625  0.107465  0.107465  0.754385
# 2022-07-27 -0.485246 -1.349905 -1.541458  0.215812  0.215812 -0.564979
# 2022-07-28  0.644391  0.811350  2.055766  0.215812  0.215812  1.838148
# 2022-07-29 -2.099012 -3.241004 -2.055348 -0.325920 -0.325920  0.200723
#
#             스왑포인트_1월물   전일종가_ex
# DateTime
# 2012-08-02   1.909409 -0.149841
# 2012-08-03   1.818881 -0.056232
# 2012-08-06   1.818881 -0.000426
# 2012-08-07   1.909409 -0.104837
# 2012-08-08   1.818881 -0.108437
# ...               ...       ...
# 2022-07-25  -0.896960  3.207485
# 2022-07-26  -0.987488  3.220086
# 2022-07-27  -0.851696  3.110275
# 2022-07-28  -0.942224  3.212885
# 2022-07-29  -0.896960  2.903255
#
# [2459 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.169118   대비_베이시스1년
# 1     5.911212   대비_베이시스2년
# 2     2.407016   대비_베이시스3년
# 3     4.772389   대비_베이시스5년
# 4     3.267758  대비_베이시스10년
# 5     1.798109     대비_국고1년
# 6     1.244446     대비_국고3년
# 7     5.796262     대비_국고5년
# 8     4.886390    대비_국고10년
# 9          inf     대비_통안1년
# 10         inf     대비_통안2년
# 11    1.149918    종가_NDF차이
# 12    1.246741   스왑포인트_1월물
# 13    1.189172     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 3.512e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6935.7
# No. Observations:                2459   AIC:                         1.390e+04
# Df Residuals:                    2445   BIC:                         1.398e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8201      0.146     -5.608      0.000      -1.107      -0.533
# 대비_베이시스2년      0.0640      0.200      0.320      0.749      -0.328       0.456
# 대비_베이시스3년     -0.1490      0.127     -1.169      0.242      -0.399       0.101
# 대비_베이시스5년     -0.1570      0.179     -0.875      0.382      -0.509       0.195
# 대비_베이시스10년     0.2523      0.148      1.699      0.089      -0.039       0.543
# 대비_국고1년       -0.0900      0.110     -0.817      0.414      -0.306       0.126
# 대비_국고3년       -0.1914      0.092     -2.088      0.037      -0.371      -0.012
# 대비_국고5년       -0.0101      0.198     -0.051      0.959      -0.398       0.378
# 대비_국고10년      -0.0328      0.182     -0.181      0.857      -0.389       0.323
# 대비_통안1년       -0.0042      0.042     -0.101      0.920      -0.086       0.077
# 대비_통안2년       -0.0042      0.042     -0.101      0.920      -0.086       0.077
# 종가_NDF차이      -4.0162      0.088    -45.595      0.000      -4.189      -3.843
# 스왑포인트_1월물     -1.1898      0.092    -12.973      0.000      -1.370      -1.010
# 전일종가_ex       55.7340      0.090    622.204      0.000      55.558      55.910
# ==============================================================================
# Omnibus:                      243.685   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1185.056
# Skew:                           0.348   Prob(JB):                    4.66e-258
# Kurtosis:                       6.329   Cond. No.                     3.97e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.75e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_scaled.drop(['대비_베이시스5년','대비_통안1년', '대비_통안2년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 4.152e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6936.1
# No. Observations:                2459   AIC:                         1.390e+04
# Df Residuals:                    2447   BIC:                         1.397e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8243      0.146     -5.642      0.000      -1.111      -0.538
# 대비_베이시스2년     -0.0032      0.184     -0.017      0.986      -0.365       0.358
# 대비_베이시스3년     -0.1668      0.126     -1.327      0.185      -0.413       0.080
# 대비_베이시스10년     0.1896      0.130      1.458      0.145      -0.065       0.445
# 대비_국고1년       -0.0902      0.110     -0.822      0.411      -0.305       0.125
# 대비_국고3년       -0.1916      0.092     -2.092      0.037      -0.371      -0.012
# 대비_국고5년       -0.0078      0.198     -0.040      0.968      -0.395       0.380
# 대비_국고10년      -0.0317      0.182     -0.175      0.861      -0.388       0.324
# 종가_NDF차이      -4.0137      0.088    -45.602      0.000      -4.186      -3.841
# 스왑포인트_1월물     -1.1892      0.092    -12.969      0.000      -1.369      -1.009
# 전일종가_ex       55.7342      0.090    622.392      0.000      55.559      55.910
# ==============================================================================
# Omnibus:                      243.633   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1183.197
# Skew:                           0.348   Prob(JB):                    1.18e-257
# Kurtosis:                       6.326   Cond. No.                         5.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고1년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 4.568e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6936.4
# No. Observations:                2459   AIC:                         1.389e+04
# Df Residuals:                    2448   BIC:                         1.396e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8253      0.146     -5.649      0.000      -1.112      -0.539
# 대비_베이시스2년      0.0018      0.184      0.010      0.992      -0.359       0.363
# 대비_베이시스3년     -0.1639      0.126     -1.304      0.192      -0.410       0.083
# 대비_베이시스10년     0.1859      0.130      1.430      0.153      -0.069       0.441
# 대비_국고3년       -0.2024      0.091     -2.232      0.026      -0.380      -0.025
# 대비_국고5년       -0.0608      0.187     -0.325      0.745      -0.427       0.306
# 대비_국고10년      -0.0320      0.182     -0.176      0.860      -0.388       0.324
# 종가_NDF차이      -4.0132      0.088    -45.601      0.000      -4.186      -3.841
# 스왑포인트_1월물     -1.1901      0.092    -12.981      0.000      -1.370      -1.010
# 전일종가_ex       55.7279      0.089    624.686      0.000      55.553      55.903
# ==============================================================================
# Omnibus:                      249.352   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1223.359
# Skew:                           0.359   Prob(JB):                    2.24e-266
# Kurtosis:                       6.380   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_베이시스2년', '대비_베이시스3년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.710e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6937.4
# No. Observations:                2459   AIC:                         1.389e+04
# Df Residuals:                    2450   BIC:                         1.395e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8892      0.107     -8.330      0.000      -1.099      -0.680
# 대비_베이시스10년     0.1239      0.109      1.139      0.255      -0.090       0.337
# 대비_국고3년       -0.1984      0.091     -2.190      0.029      -0.376      -0.021
# 대비_국고5년       -0.0488      0.186     -0.262      0.794      -0.414       0.317
# 대비_국고10년      -0.0354      0.181     -0.195      0.846      -0.391       0.320
# 종가_NDF차이      -4.0131      0.088    -45.611      0.000      -4.186      -3.841
# 스왑포인트_1월물     -1.1903      0.092    -12.984      0.000      -1.370      -1.010
# 전일종가_ex       55.7275      0.089    624.695      0.000      55.553      55.902
# ==============================================================================
# Omnibus:                      250.440   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1227.804
# Skew:                           0.362   Prob(JB):                    2.43e-267
# Kurtosis:                       6.385   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고10년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 6.529e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6937.4
# No. Observations:                2459   AIC:                         1.389e+04
# Df Residuals:                    2451   BIC:                         1.394e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8903      0.107     -8.352      0.000      -1.099      -0.681
# 대비_베이시스10년     0.1255      0.108      1.157      0.247      -0.087       0.338
# 대비_국고3년       -0.1980      0.091     -2.188      0.029      -0.376      -0.021
# 대비_국고5년       -0.0802      0.094     -0.857      0.391      -0.264       0.103
# 종가_NDF차이      -4.0136      0.088    -45.644      0.000      -4.186      -3.841
# 스왑포인트_1월물     -1.1902      0.092    -12.986      0.000      -1.370      -1.011
# 전일종가_ex       55.7276      0.089    624.823      0.000      55.553      55.903
# ==============================================================================
# Omnibus:                      250.759   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1231.080
# Skew:                           0.362   Prob(JB):                    4.73e-268
# Kurtosis:                       6.390   Cond. No.                         2.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_베이시스10년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 7.616e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:46   Log-Likelihood:                -6938.1
# No. Observations:                2459   AIC:                         1.389e+04
# Df Residuals:                    2452   BIC:                         1.393e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8133      0.083     -9.764      0.000      -0.977      -0.650
# 대비_국고3년       -0.1967      0.091     -2.173      0.030      -0.374      -0.019
# 대비_국고5년       -0.1034      0.091     -1.132      0.258      -0.283       0.076
# 종가_NDF차이      -4.0161      0.088    -45.683      0.000      -4.188      -3.844
# 스왑포인트_1월물     -1.1922      0.092    -13.008      0.000      -1.372      -1.012
# 전일종가_ex       55.7264      0.089    624.808      0.000      55.552      55.901
# ==============================================================================
# Omnibus:                      251.487   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1235.400
# Skew:                           0.364   Prob(JB):                    5.45e-269
# Kurtosis:                       6.395   Cond. No.                         1.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고5년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 9.138e+04
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:36:47   Log-Likelihood:                -6938.7
# No. Observations:                2459   AIC:                         1.389e+04
# Df Residuals:                    2453   BIC:                         1.392e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.082   1.38e+04      0.000    1134.733    1135.055
# 대비_베이시스1년     -0.8065      0.083     -9.707      0.000      -0.969      -0.644
# 대비_국고3년       -0.2395      0.082     -2.911      0.004      -0.401      -0.078
# 종가_NDF차이      -4.0053      0.087    -45.826      0.000      -4.177      -3.834
# 스왑포인트_1월물     -1.1906      0.092    -12.992      0.000      -1.370      -1.011
# 전일종가_ex       55.7243      0.089    624.890      0.000      55.549      55.899
# ==============================================================================
# Omnibus:                      256.145   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1278.652
# Skew:                           0.369   Prob(JB):                    2.21e-278
# Kurtosis:                       6.455   Cond. No.                         1.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 16.445761551483617, RMSE :  4.055, MAE: 4.055
# Variance score :  0.995

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (4.0804814324288134,
#  array([3.442893  , 4.85461876, 4.24224002, 4.13609955, 3.72655584]),
#  array([-11.85351221, -23.56732328, -17.9966004 , -17.10731947,
#         -13.88721839]))
