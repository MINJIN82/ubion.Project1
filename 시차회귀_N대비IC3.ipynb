# %%
import pandas as pd
import numpy as np

df = pd.read_excel("./xlsx/시차상관분석5Data.xlsx",index_col=0)
df = df.set_index("DateTime")

# 대비 계산
df['대비_irs_1Y'] = df['1Y_Mid_irs'] - df['1Y_Mid_irs'].shift(1) 
df['대비_irs_2Y'] = df['2Y_Mid_irs'] - df['2Y_Mid_irs'].shift(1) 
df['대비_irs_3Y'] = df['3Y_Mid_irs'] - df['3Y_Mid_irs'].shift(1) 
df['대비_irs_5Y'] = df['5Y_Mid_irs'] - df['5Y_Mid_irs'].shift(1) 
df['대비_irs_10Y'] = df['10Y_Mid_irs'] - df['10Y_Mid_irs'].shift(1) 

df['대비_crs_1Y'] = df['1Y_Mid_crs'] - df['1Y_Mid_crs'].shift(1)
df['대비_crs_2Y'] = df['2Y_Mid_crs'] - df['2Y_Mid_crs'].shift(1)
df['대비_crs_3Y'] = df['3Y_Mid_crs'] - df['3Y_Mid_crs'].shift(1)
df['대비_crs_5Y'] = df['5Y_Mid_crs'] - df['5Y_Mid_crs'].shift(1)
df['대비_crs_10Y'] = df['10Y_Mid_crs'] - df['10Y_Mid_crs'].shift(1)

df['대비_swapbasis_1Y'] = df['1Y_베이시스']-df['1Y_베이시스'].shift(1)
df['대비_swapbasis_2Y'] = df['2Y_베이시스']-df['2Y_베이시스'].shift(1)
df['대비_swapbasis_3Y'] = df['3Y_베이시스']-df['3Y_베이시스'].shift(1)
df['대비_swapbasis_5Y'] = df['5Y_베이시스']-df['5Y_베이시스'].shift(1)
df['대비_swapbasis_10Y'] = df['10Y_베이시스']-df['10Y_베이시스'].shift(1)

df['대비_국고_1Y'] = df['국고1년']-df['국고1년'].shift(1)
df['대비_국고_3Y'] = df['국고3년']-df['국고3년'].shift(1)
df['대비_국고_5Y'] = df['국고5년']-df['국고5년'].shift(1)
df['대비_국고_10Y'] = df['국고10년']-df['국고10년'].shift(1)

df['대비_통안_1Y'] = df['통안364일']-df['통안364일'].shift(1)
df['대비_통안_2Y'] = df['통안2년']-df['통안2년'].shift(1)

df['대비_ndf'] = df['Mid_ndf']-df['Mid_ndf'].shift(1)
df['스왑포인트_1M'] = df["M1_스왑포인트"]/100 
df['전일종가_ex'] = df['종가_ex'].shift(1)
df['종가_NDF_차이'] = df['전일종가_ex'] - df['Mid_ndf']

# 필요한 칼럼만 추출
df_1 = df[['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y', 
           '대비_swapbasis_1Y', '대비_swapbasis_2Y', '대비_swapbasis_3Y', '대비_swapbasis_5Y', '대비_swapbasis_10Y',
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M', '전일종가_ex', 
           '종가_ex', '종가_NDF_차이' ]]

# %%
# 결측치 제거
df_1 = df_1.dropna()

# %%
df_1.isna().sum()
# Out:
# 대비_irs_1Y           0
# 대비_irs_2Y           0
# 대비_irs_3Y           0
# 대비_irs_5Y           0
# 대비_irs_10Y          0
# 대비_crs_1Y           0
# 대비_crs_2Y           0
# 대비_crs_3Y           0
# 대비_crs_5Y           0
# 대비_crs_10Y          0
# 대비_swapbasis_1Y     0
# 대비_swapbasis_2Y     0
# 대비_swapbasis_3Y     0
# 대비_swapbasis_5Y     0
# 대비_swapbasis_10Y    0
# 대비_국고_1Y            0
# 대비_국고_3Y            0
# 대비_국고_5Y            0
# 대비_국고_10Y           0
# 대비_통안_1Y            0
# 대비_통안_2Y            0
# 대비_ndf              0
# 스왑포인트_1M            0
# 전일종가_ex             0
# 종가_ex               0
# 종가_NDF_차이           0
# dtype: int64

# %%
x = df_1[['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
       '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y',
       '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M',
       '전일종가_ex']]
y = df_1[['종가_ex']]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\hyeok\AppData\Local\Temp\ipykernel_16552\4135598070.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             대비_irs_1Y  대비_irs_2Y  대비_irs_3Y  대비_irs_5Y  대비_irs_10Y  대비_crs_1Y  \
# DateTime
# 2012-08-03  -0.848159  -0.732099  -0.562745  -0.628439   -0.403644  -0.205698
# 2012-08-06   0.559997   0.481892   0.370922   0.415773    0.202253  -0.003456
# 2012-08-07   0.278366  -0.003704  -0.002545   0.206931    0.404219   0.401029
# 2012-08-08   0.278366   0.481892   0.370922   0.415773    0.606184   0.198787
# 2012-08-09   1.404890   1.453085   1.117855   1.042301    0.808150   1.816727
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-25  -1.129790  -1.946090  -1.309678  -1.881494   -2.221333  -1.621396
# 2022-07-26  -0.284897  -0.489301  -0.562745  -0.628439   -0.605609   0.198787
# 2022-07-27  -0.284897  -1.217695  -1.122944  -1.254966   -1.211506   0.198787
# 2022-07-28   0.841628   0.967489   0.931121   1.042301    1.414046   0.805515
# 2022-07-29  -1.974684  -3.402879  -2.616811  -2.925706   -2.423299  -2.228124
#
#             대비_crs_2Y  대비_crs_3Y  대비_crs_5Y  대비_crs_10Y  대비_국고_1Y  대비_국고_3Y  \
# DateTime
# 2012-08-03  -0.364180  -0.462791  -1.872418   -3.115253 -1.133777 -0.324094
# 2012-08-06  -0.602348  -0.690892  -0.939341   -0.833148  0.563092  0.159979
# 2012-08-07   0.350324  -0.006589  -1.639149   -1.663004 -0.568154 -0.001379
# 2012-08-08  -0.006928  -0.006589  -0.472802   -0.833148 -0.568154 -0.324094
# 2012-08-09   0.945744   0.905815   0.926814    0.826565  2.825583  0.966767
# ...               ...        ...        ...         ...       ...       ...
# 2022-07-25  -2.150439  -1.603295  -2.572226   -2.285397 -1.133777 -0.969524
# 2022-07-26  -0.721432  -0.690892  -0.472802   -0.418220  0.563092 -0.485451
# 2022-07-27  -0.245096  -0.234690  -0.239533   -0.210756 -0.002531 -0.485451
# 2022-07-28   0.945744   0.905815   0.693544    0.411636  0.563092  0.644052
# 2022-07-29  -4.055782  -3.428103  -2.105687   -1.870468 -2.265023 -2.099027
#
#             대비_국고_5Y  대비_국고_10Y  대비_통안_1Y  대비_통안_2Y    대비_ndf  스왑포인트_1M  \
# DateTime
# 2012-08-03 -1.890723  -1.798842 -0.217667 -0.125961  0.184967  1.820638
# 2012-08-06  0.000440  -0.000209  0.107313  0.123726 -0.449739  1.820638
# 2012-08-07  0.000440  -0.000209 -0.109340 -0.125961  0.020414  1.911215
# 2012-08-08 -0.539892  -0.514104 -0.109340 -0.125961  0.055675  1.820638
# 2012-08-09  1.351270   1.284529  0.432293  0.747946  0.102691  1.775350
# ...              ...        ...       ...       ...       ...       ...
# 2022-07-25 -1.890723  -2.312737 -0.109340 -0.625337  0.154407 -0.896666
# 2022-07-26 -0.539892  -0.771052  0.107313 -0.001117  0.050974 -0.987243
# 2022-07-27 -1.350390  -1.541894  0.215640 -0.125961 -0.026602 -0.851378
# 2022-07-28  0.810938   2.055371  0.215640  0.373414 -0.214663 -0.941955
# 2022-07-29 -3.241553  -2.055789 -0.325994 -1.374400 -0.485001 -0.896666
#
#              전일종가_ex
# DateTime
# 2012-08-03 -0.056282
# 2012-08-06 -0.000487
# 2012-08-07 -0.104877
# 2012-08-08 -0.108476
# 2012-08-09 -0.117475
# ...              ...
# 2022-07-25  3.206786
# 2022-07-26  3.219385
# 2022-07-27  3.109596
# 2022-07-28  3.212186
# 2022-07-29  2.902617
#
# [2458 rows x 19 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     9.980783   대비_irs_1Y
# 1    19.538899   대비_irs_2Y
# 2     2.661480   대비_irs_3Y
# 3     6.466968   대비_irs_5Y
# 4     5.880441  대비_irs_10Y
# 5     2.654083   대비_crs_1Y
# 6     5.264862   대비_crs_2Y
# 7     3.829734   대비_crs_3Y
# 8     6.698777   대비_crs_5Y
# 9     3.716959  대비_crs_10Y
# 10    1.924856    대비_국고_1Y
# 11    1.253335    대비_국고_3Y
# 12    6.253819    대비_국고_5Y
# 13    5.051575   대비_국고_10Y
# 14    1.025226    대비_통안_1Y
# 15    1.115518    대비_통안_2Y
# 16    1.007478      대비_ndf
# 17    1.169313    스왑포인트_1M
# 18    1.182009     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.345e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:13:11   Log-Likelihood:                -7638.0
# No. Observations:                2458   AIC:                         1.532e+04
# Df Residuals:                    2438   BIC:                         1.543e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.1729      0.346      0.499      0.618      -0.506       0.852
# 대비_irs_2Y      0.5208      0.484      1.075      0.282      -0.429       1.471
# 대비_irs_3Y      0.0106      0.179      0.059      0.953      -0.340       0.361
# 대비_irs_5Y     -0.2656      0.279     -0.953      0.341      -0.812       0.281
# 대비_irs_10Y    -0.5144      0.266     -1.936      0.053      -1.036       0.007
# 대비_crs_1Y     -1.0747      0.179     -6.020      0.000      -1.425      -0.725
# 대비_crs_2Y     -0.2511      0.251     -0.998      0.318      -0.744       0.242
# 대비_crs_3Y     -0.4304      0.214     -2.007      0.045      -0.851      -0.010
# 대비_crs_5Y     -0.1727      0.284     -0.609      0.543      -0.729       0.383
# 대비_crs_10Y     0.1801      0.211      0.852      0.394      -0.234       0.594
# 대비_국고_1Y       0.1026      0.152      0.675      0.500      -0.196       0.401
# 대비_국고_3Y      -0.2715      0.123     -2.213      0.027      -0.512      -0.031
# 대비_국고_5Y       1.0100      0.274      3.685      0.000       0.473       1.547
# 대비_국고_10Y     -0.2579      0.246     -1.047      0.295      -0.741       0.225
# 대비_통안_1Y      -0.0050      0.111     -0.045      0.964      -0.223       0.213
# 대비_통안_2Y       0.0902      0.116      0.779      0.436      -0.137       0.317
# 대비_ndf         0.5267      0.110      4.788      0.000       0.311       0.742
# 스왑포인트_1M      -0.1473      0.119     -1.243      0.214      -0.380       0.085
# 전일종가_ex       55.3589      0.119    464.633      0.000      55.125      55.593
# ==============================================================================
# Omnibus:                       39.184   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.922
# Skew:                          -0.021   Prob(JB):                     8.87e-17
# Kurtosis:                       3.849   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.929971   대비_irs_1Y
# 1     2.551013   대비_irs_3Y
# 2     5.801410   대비_irs_5Y
# 3     5.222980  대비_irs_10Y
# 4     2.651180   대비_crs_1Y
# 5     5.253418   대비_crs_2Y
# 6     3.827291   대비_crs_3Y
# 7     6.693081   대비_crs_5Y
# 8     3.716832  대비_crs_10Y
# 9     1.913966    대비_국고_1Y
# 10    1.247318    대비_국고_3Y
# 11    6.167543    대비_국고_5Y
# 12    5.037641   대비_국고_10Y
# 13    1.024858    대비_통안_1Y
# 14    1.114823    대비_통안_2Y
# 15    1.005213      대비_ndf
# 16    1.169251    스왑포인트_1M
# 17    1.181228     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.419e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:13:13   Log-Likelihood:                -7638.5
# No. Observations:                2458   AIC:                         1.532e+04
# Df Residuals:                    2439   BIC:                         1.543e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.4627      0.217      2.130      0.033       0.037       0.889
# 대비_irs_3Y      0.0498      0.175      0.284      0.776      -0.293       0.393
# 대비_irs_5Y     -0.1695      0.264     -0.642      0.521      -0.687       0.348
# 대비_irs_10Y    -0.4189      0.250     -1.672      0.095      -0.910       0.072
# 대비_crs_1Y     -1.0811      0.178     -6.058      0.000      -1.431      -0.731
# 대비_crs_2Y     -0.2385      0.251     -0.949      0.343      -0.731       0.254
# 대비_crs_3Y     -0.4363      0.214     -2.035      0.042      -0.857      -0.016
# 대비_crs_5Y     -0.1638      0.284     -0.578      0.563      -0.720       0.392
# 대비_crs_10Y     0.1814      0.211      0.859      0.391      -0.233       0.596
# 대비_국고_1Y       0.1149      0.152      0.758      0.449      -0.182       0.412
# 대비_국고_3Y      -0.2624      0.122     -2.144      0.032      -0.502      -0.022
# 대비_국고_5Y       1.0446      0.272      3.838      0.000       0.511       1.578
# 대비_국고_10Y     -0.2718      0.246     -1.105      0.269      -0.754       0.211
# 대비_통안_1Y      -0.0073      0.111     -0.066      0.948      -0.225       0.210
# 대비_통안_2Y       0.0933      0.116      0.806      0.420      -0.134       0.320
# 대비_ndf         0.5323      0.110      4.845      0.000       0.317       0.748
# 스왑포인트_1M      -0.1463      0.119     -1.235      0.217      -0.379       0.086
# 전일종가_ex       55.3556      0.119    464.744      0.000      55.122      55.589
# ==============================================================================
# Omnibus:                       38.776   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.932
# Skew:                          -0.018   Prob(JB):                     1.46e-16
# Kurtosis:                       3.843   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_3Y', '대비_통안_1Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.618478   대비_irs_1Y
# 1     5.680739   대비_irs_5Y
# 2     5.105414  대비_irs_10Y
# 3     2.649574   대비_crs_1Y
# 4     5.251940   대비_crs_2Y
# 5     3.826311   대비_crs_3Y
# 6     6.690214   대비_crs_5Y
# 7     3.716124  대비_crs_10Y
# 8     1.899133    대비_국고_1Y
# 9     1.246658    대비_국고_3Y
# 10    6.161645    대비_국고_5Y
# 11    5.037584   대비_국고_10Y
# 12    1.114592    대비_통안_2Y
# 13    1.005192      대비_ndf
# 14    1.169235    스왑포인트_1M
# 15    1.180980     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.598e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:14:08   Log-Likelihood:                -7638.6
# No. Observations:                2458   AIC:                         1.531e+04
# Df Residuals:                    2441   BIC:                         1.541e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.4799      0.208      2.303      0.021       0.071       0.889
# 대비_irs_5Y     -0.1586      0.261     -0.608      0.544      -0.671       0.353
# 대비_irs_10Y    -0.4080      0.248     -1.648      0.099      -0.893       0.077
# 대비_crs_1Y     -1.0823      0.178     -6.070      0.000      -1.432      -0.733
# 대비_crs_2Y     -0.2373      0.251     -0.945      0.345      -0.730       0.255
# 대비_crs_3Y     -0.4372      0.214     -2.040      0.041      -0.857      -0.017
# 대비_crs_5Y     -0.1621      0.283     -0.572      0.567      -0.718       0.393
# 대비_crs_10Y     0.1822      0.211      0.863      0.388      -0.232       0.596
# 대비_국고_1Y       0.1160      0.151      0.769      0.442      -0.180       0.412
# 대비_국고_3Y      -0.2617      0.122     -2.139      0.033      -0.502      -0.022
# 대비_국고_5Y       1.0458      0.272      3.846      0.000       0.513       1.579
# 대비_국고_10Y     -0.2720      0.246     -1.106      0.269      -0.754       0.210
# 대비_통안_2Y       0.0936      0.116      0.809      0.418      -0.133       0.320
# 대비_ndf         0.5324      0.110      4.847      0.000       0.317       0.748
# 스왑포인트_1M      -0.1463      0.118     -1.235      0.217      -0.379       0.086
# 전일종가_ex       55.3552      0.119    464.971      0.000      55.122      55.589
# ==============================================================================
# Omnibus:                       38.749   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.857
# Skew:                          -0.019   Prob(JB):                     1.51e-16
# Kurtosis:                       3.843   Cond. No.                         7.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_5Y', '대비_crs_5Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     2.809287   대비_irs_1Y
# 1     3.636571  대비_irs_10Y
# 2     2.646237   대비_crs_1Y
# 3     4.562565   대비_crs_2Y
# 4     3.452997   대비_crs_3Y
# 5     2.424762  대비_crs_10Y
# 6     1.898870    대비_국고_1Y
# 7     1.245319    대비_국고_3Y
# 8     6.102503    대비_국고_5Y
# 9     5.036301   대비_국고_10Y
# 10    1.114395    대비_통안_2Y
# 11    1.004766      대비_ndf
# 12    1.169211    스왑포인트_1M
# 13    1.180542     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.827e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:16:17   Log-Likelihood:                -7638.9
# No. Observations:                2458   AIC:                         1.531e+04
# Df Residuals:                    2443   BIC:                         1.540e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.4241      0.184      2.310      0.021       0.064       0.784
# 대비_irs_10Y    -0.4948      0.209     -2.369      0.018      -0.904      -0.085
# 대비_crs_1Y     -1.0775      0.178     -6.048      0.000      -1.427      -0.728
# 대비_crs_2Y     -0.2899      0.234     -1.239      0.215      -0.749       0.169
# 대비_crs_3Y     -0.4763      0.204     -2.340      0.019      -0.875      -0.077
# 대비_crs_10Y     0.1050      0.171      0.616      0.538      -0.229       0.439
# 대비_국고_1Y       0.1148      0.151      0.761      0.447      -0.181       0.411
# 대비_국고_3Y      -0.2650      0.122     -2.168      0.030      -0.505      -0.025
# 대비_국고_5Y       1.0246      0.271      3.787      0.000       0.494       1.555
# 대비_국고_10Y     -0.2726      0.246     -1.109      0.267      -0.755       0.209
# 대비_통안_2Y       0.0923      0.116      0.798      0.425      -0.134       0.319
# 대비_ndf         0.5332      0.110      4.857      0.000       0.318       0.748
# 스왑포인트_1M      -0.1467      0.118     -1.239      0.215      -0.379       0.085
# 전일종가_ex       55.3571      0.119    465.195      0.000      55.124      55.590
# ==============================================================================
# Omnibus:                       38.627   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.520
# Skew:                          -0.019   Prob(JB):                     1.79e-16
# Kurtosis:                       3.841   Cond. No.                         6.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_2Y', '대비_crs_10Y', '대비_국고_1Y'], axis=1, inplace=True)
feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.327e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:17:17   Log-Likelihood:                -7640.0
# No. Observations:                2458   AIC:                         1.530e+04
# Df Residuals:                    2446   BIC:                         1.537e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.4424      0.180      2.459      0.014       0.090       0.795
# 대비_irs_10Y    -0.5073      0.207     -2.453      0.014      -0.913      -0.102
# 대비_crs_1Y     -1.1760      0.152     -7.715      0.000      -1.475      -0.877
# 대비_crs_3Y     -0.5639      0.156     -3.611      0.000      -0.870      -0.258
# 대비_국고_3Y      -0.2552      0.121     -2.106      0.035      -0.493      -0.018
# 대비_국고_5Y       1.0769      0.257      4.186      0.000       0.572       1.581
# 대비_국고_10Y     -0.2603      0.246     -1.060      0.289      -0.742       0.221
# 대비_통안_2Y       0.1032      0.115      0.900      0.368      -0.122       0.328
# 대비_ndf         0.5354      0.110      4.879      0.000       0.320       0.751
# 스왑포인트_1M      -0.1472      0.118     -1.243      0.214      -0.379       0.085
# 전일종가_ex       55.3621      0.119    466.745      0.000      55.129      55.595
# ==============================================================================
# Omnibus:                       39.164   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.962
# Skew:                          -0.018   Prob(JB):                     8.70e-17
# Kurtosis:                       3.849   Cond. No.                         5.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고_10Y', '대비_통안_2Y', '스왑포인트_1M'], axis=1, inplace=True)
feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 3.198e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:18:26   Log-Likelihood:                -7641.7
# No. Observations:                2458   AIC:                         1.530e+04
# Df Residuals:                    2449   BIC:                         1.535e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8952      0.110   1.04e+04      0.000    1134.680    1135.110
# 대비_irs_1Y      0.4835      0.177      2.732      0.006       0.137       0.831
# 대비_irs_10Y    -0.5570      0.203     -2.743      0.006      -0.955      -0.159
# 대비_crs_1Y     -1.1722      0.152     -7.691      0.000      -1.471      -0.873
# 대비_crs_3Y     -0.5660      0.156     -3.625      0.000      -0.872      -0.260
# 대비_국고_3Y      -0.2504      0.121     -2.067      0.039      -0.488      -0.013
# 대비_국고_5Y       0.8852      0.149      5.958      0.000       0.594       1.177
# 대비_ndf         0.5367      0.110      4.890      0.000       0.321       0.752
# 전일종가_ex       55.4169      0.110    504.864      0.000      55.202      55.632
# ==============================================================================
# Omnibus:                       39.450   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.475
# Skew:                          -0.026   Prob(JB):                     6.73e-17
# Kurtosis:                       3.851   Cond. No.                         3.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 31.360419441085945, RMSE :  5.600, MAE: 5.600
# Variance score :  0.989

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (8.12468449043211,
#  array([ 4.15409136,  7.03417065,  5.67967498, 18.61779063,  5.13769484]),
#  array([ -17.256475  ,  -49.47955669,  -32.25870784, -346.6221278 ,
#          -26.39590832]))
