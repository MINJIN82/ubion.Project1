# %%
import pandas as pd
import numpy as np
import scipy.stats

# %%
df = pd.read_excel("../데이터자료/join_data.xlsx",index_col=0)
df_data=df[['DateTime', '종가_ex','1Y_Mid_irs','2Y_Mid_irs','3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs',
 '1Y_Mid_crs','2Y_Mid_crs','3Y_Mid_crs','5Y_Mid_crs','10Y_Mid_crs', '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스','M1_스왑포인트', 'Mid_ndf']]
df_data
# Out:
#         DateTime   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  5Y_Mid_irs  \
# 열1
# 0     2012-08-01  1126.5       2.850       2.740       2.740       2.770
# 1     2012-08-02  1131.7       2.820       2.690       2.690       2.720
# 2     2012-08-03  1134.8       2.790       2.660       2.660       2.690
# 3     2012-08-06  1129.0       2.810       2.680       2.680       2.710
# 4     2012-08-07  1128.8       2.820       2.680       2.680       2.720
# ...          ...     ...         ...         ...         ...         ...
# 2455  2022-07-25  1313.7       3.165       3.235       3.205       3.125
# 2456  2022-07-26  1307.6       3.155       3.215       3.175       3.095
# 2457  2022-07-27  1313.3       3.145       3.165       3.115       3.035
# 2458  2022-07-28  1296.1       3.175       3.205       3.165       3.085
# 2459  2022-07-29  1299.1       3.105       3.065       3.025       2.945
#
#       10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  국고10년  통안364일  \
# 열1                                                     ...
# 0           2.910        2.09       1.815        1.81  ...   3.14    2.80
# 1           2.860        2.08       1.845        1.85  ...   3.10    2.77
# 2           2.840        2.07       1.830        1.83  ...   3.03    2.75
# 3           2.850        2.07       1.805        1.80  ...   3.03    2.76
# 4           2.870        2.09       1.820        1.80  ...   3.03    2.75
# ...           ...         ...         ...         ...  ...    ...     ...
# 2455        2.965        2.55       2.730        2.71  ...   3.21    2.98
# 2456        2.935        2.56       2.700        2.68  ...   3.18    2.99
# 2457        2.875        2.57       2.690        2.67  ...   3.12    3.01
# 2458        2.945        2.61       2.730        2.71  ...   3.20    3.03
# 2459        2.825        2.50       2.560        2.56  ...   3.12    3.00
#
#       통안2년  1Y_베이시스  2Y_베이시스  3Y_베이시스  5Y_베이시스  10Y_베이시스  M1_스왑포인트  Mid_ndf
# 열1
# 0     2.83    -76.0    -92.5    -93.0   -105.0    -108.0       260  1132.25
# 1     2.78    -74.0    -84.5    -84.0    -96.0     -99.0       250  1134.00
# 2     2.77    -72.0    -83.0    -83.0   -101.0    -112.0       240  1138.00
# 3     2.78    -74.0    -87.5    -88.0   -107.0    -117.0       240  1128.50
# 4     2.77    -73.0    -86.0    -88.0   -115.0    -127.0       250  1129.00
# ...    ...      ...      ...      ...      ...       ...       ...      ...
# 2455  3.09    -61.5    -50.5    -49.5    -61.5     -60.5       -60  1309.85
# 2456  3.09    -59.5    -51.5    -49.5    -60.5     -59.5       -70  1311.00
# 2457  3.08    -57.5    -47.5    -44.5    -55.5     -54.5       -55  1310.50
# 2458  3.11    -56.5    -47.5    -45.5    -57.5     -59.5       -65  1306.00
# 2459  3.00    -60.5    -50.5    -46.5    -52.5     -56.5       -60  1295.75
#
# [2460 rows x 25 columns]

# %%
df_data.iloc[1968]
# Out:
# DateTime       2020-08-03
# 종가_ex              1193.4
# 1Y_Mid_irs          0.735
# 2Y_Mid_irs          0.755
# 3Y_Mid_irs          0.785
# 5Y_Mid_irs          0.835
# 10Y_Mid_irs         0.905
# 1Y_Mid_crs         -0.005
# 2Y_Mid_crs          -0.05
# 3Y_Mid_crs          -0.04
# 5Y_Mid_crs          -0.02
# 10Y_Mid_crs         0.215
# 국고1년                 0.65
# 국고3년                 0.79
# 국고5년                 1.04
# 국고10년                 1.3
# 통안364일               0.59
# 통안2년                 0.72
# 1Y_베이시스             -74.0
# 2Y_베이시스             -80.5
# 3Y_베이시스             -82.5
# 5Y_베이시스             -85.5
# 10Y_베이시스            -69.0
# M1_스왑포인트              -10
# Mid_ndf            1194.4
# Name: 1968, dtype: object

# %%
x = df_data[['1Y_Mid_irs','2Y_Mid_irs','3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs',
 '1Y_Mid_crs','2Y_Mid_crs','3Y_Mid_crs','5Y_Mid_crs','10Y_Mid_crs', '국고1년','국고3년','국고5년','국고10년','통안364일','통안2년', 
 'M1_스왑포인트', 'Mid_ndf']]
y = df_data["종가_ex"]

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 2.450e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:16   Log-Likelihood:                -6978.3
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2441   BIC:                         1.411e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           5.0604      3.425      1.478      0.140      -1.655      11.776
# 1Y_Mid_irs      2.4908      2.879      0.865      0.387      -3.154       8.136
# 2Y_Mid_irs     -2.9995      5.434     -0.552      0.581     -13.656       7.657
# 3Y_Mid_irs      2.2000      3.446      0.638      0.523      -4.557       8.957
# 5Y_Mid_irs      4.9040      4.820      1.017      0.309      -4.548      14.356
# 10Y_Mid_irs    -3.5922      2.708     -1.326      0.185      -8.903       1.719
# 1Y_Mid_crs     -3.2747      1.008     -3.249      0.001      -5.251      -1.298
# 2Y_Mid_crs      2.4004      3.148      0.763      0.446      -3.772       8.572
# 3Y_Mid_crs     -2.6541      2.754     -0.964      0.335      -8.055       2.747
# 5Y_Mid_crs      4.2424      1.963      2.161      0.031       0.393       8.092
# 10Y_Mid_crs    -3.1439      1.265     -2.486      0.013      -5.624      -0.664
# 국고1년            1.1291      1.989      0.568      0.570      -2.772       5.030
# 국고3년           -1.1267      1.806     -0.624      0.533      -4.668       2.415
# 국고5년            0.5857      1.728      0.339      0.735      -2.803       3.974
# 국고10년          -1.1373      1.979     -0.575      0.565      -5.017       2.743
# 통안364일         -0.2371      1.222     -0.194      0.846      -2.633       2.159
# 통안2년           -0.2056      1.418     -0.145      0.885      -2.986       2.575
# M1_스왑포인트       -0.0090      0.002     -5.682      0.000      -0.012      -0.006
# Mid_ndf         0.9961      0.003    351.351      0.000       0.990       1.002
# ==============================================================================
# Omnibus:                      318.875   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1894.064
# Skew:                           0.455   Prob(JB):                         0.00
# Kurtosis:                       7.201   Cond. No.                     9.47e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1881.558
# Skew:                           0.453   Prob(JB):                         0.00
# Kurtosis:                       7.187   Cond. No.                     7.72e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop(['국고1년', '국고3년', '국고5년', '국고10년', '통안364일', '통안2년'], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30648\830561042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['국고1년', '국고3년', '국고5년', '국고10년', '통안364일', '통안2년'], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.903e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:17   Log-Likelihood:                -6982.0
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2450   BIC:                         1.404e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           4.9098      3.269      1.502      0.133      -1.500      11.320
# 2Y_Mid_irs      4.5257      2.361      1.917      0.055      -0.104       9.155
# 3Y_Mid_irs     -0.4315      3.172     -0.136      0.892      -6.651       5.788
# 5Y_Mid_irs     -2.0194      3.510     -0.575      0.565      -8.903       4.864
# 10Y_Mid_irs    -0.4388      1.789     -0.245      0.806      -3.947       3.069
# 1Y_Mid_crs     -2.2775      0.581     -3.921      0.000      -3.417      -1.138
# 5Y_Mid_crs      2.8619      1.001      2.859      0.004       0.899       4.825
# 10Y_Mid_crs    -2.7457      1.010     -2.719      0.007      -4.726      -0.766
# M1_스왑포인트       -0.0092      0.001     -7.111      0.000      -0.012      -0.007
# Mid_ndf         0.9960      0.003    371.058      0.000       0.991       1.001
# ==============================================================================
# Omnibus:                      332.142   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1992.497
# Skew:                           0.481   Prob(JB):                         0.00
# Kurtosis:                       7.303   Cond. No.                     6.39e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop([ '3Y_Mid_irs', '5Y_Mid_irs', '10Y_Mid_irs',], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30648\2852196762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '3Y_Mid_irs', '5Y_Mid_irs', '10Y_Mid_irs',], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 7.353e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:17   Log-Likelihood:                -6983.9
# No. Observations:                2460   AIC:                         1.398e+04
# Df Residuals:                    2453   BIC:                         1.402e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           3.0528      2.833      1.078      0.281      -2.503       8.608
# 2Y_Mid_irs      1.7088      0.476      3.587      0.000       0.775       2.643
# 1Y_Mid_crs     -1.6412      0.451     -3.641      0.000      -2.525      -0.757
# 5Y_Mid_crs      2.6576      0.974      2.728      0.006       0.748       4.568
# 10Y_Mid_crs    -3.0715      0.989     -3.105      0.002      -5.011      -1.132
# M1_스왑포인트       -0.0106      0.001    -10.909      0.000      -0.012      -0.009
# Mid_ndf         0.9972      0.002    415.490      0.000       0.993       1.002
# ==============================================================================
# Omnibus:                      338.607   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2062.871
# Skew:                           0.490   Prob(JB):                         0.00
# Kurtosis:                       7.378   Cond. No.                     4.12e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop([ '10Y_Mid_crs',], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30648\3427273283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '10Y_Mid_crs',], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 8.792e+04
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:17   Log-Likelihood:                -6988.7
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2454   BIC:                         1.402e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2680      1.974     -1.655      0.098      -7.139       0.603
# 2Y_Mid_irs     0.8233      0.382      2.153      0.031       0.074       1.573
# 1Y_Mid_crs    -0.7253      0.342     -2.124      0.034      -1.395      -0.056
# 5Y_Mid_crs    -0.1916      0.328     -0.585      0.559      -0.834       0.451
# M1_스왑포인트      -0.0112      0.001    -11.807      0.000      -0.013      -0.009
# Mid_ndf        1.0025      0.002    590.665      0.000       0.999       1.006
# ==============================================================================
# Omnibus:                      362.049   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2245.151
# Skew:                           0.535   Prob(JB):                         0.00
# Kurtosis:                       7.556   Cond. No.                     2.68e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.68e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop([ '5Y_Mid_crs',], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30648\122212482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '5Y_Mid_crs',], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.099e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:17   Log-Likelihood:                -6988.9
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2455   BIC:                         1.402e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4112      1.959     -1.742      0.082      -7.252       0.429
# 2Y_Mid_irs     0.6880      0.304      2.261      0.024       0.091       1.285
# 1Y_Mid_crs    -0.7637      0.335     -2.279      0.023      -1.421      -0.107
# M1_스왑포인트      -0.0112      0.001    -11.826      0.000      -0.013      -0.009
# Mid_ndf        1.0027      0.002    599.834      0.000       0.999       1.006
# ==============================================================================
# Omnibus:                      362.788   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2256.198
# Skew:                           0.536   Prob(JB):                         0.00
# Kurtosis:                       7.568   Cond. No.                     2.66e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x.drop([ '1Y_Mid_crs',], axis=1, inplace=True)

import statsmodels.api as sm

feature_add = sm.add_constant(x, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30648\3509276033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop([ '1Y_Mid_crs',], axis=1, inplace=True)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 1.463e+05
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):               0.00
# Time:                        14:55:33   Log-Likelihood:                -6991.5
# No. Observations:                2460   AIC:                         1.399e+04
# Df Residuals:                    2456   BIC:                         1.401e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7630      1.954     -1.926      0.054      -7.595       0.069
# 2Y_Mid_irs     0.0897      0.154      0.582      0.560      -0.212       0.392
# M1_스왑포인트      -0.0117      0.001    -12.575      0.000      -0.013      -0.010
# Mid_ndf        1.0032      0.002    605.459      0.000       1.000       1.006
# ==============================================================================
# Omnibus:                      367.244   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2290.911
# Skew:                           0.544   Prob(JB):                         0.00
# Kurtosis:                       7.601   Cond. No.                     2.65e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor     Feature
# 0   12.094299  2Y_Mid_irs
# 1    1.639531    M1_스왑포인트
# 2   10.282872     Mid_ndf

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
x_train = x[:1968]
x_test = x[1968:]
y_train = y[:1968]
y_test = y[1968:]

from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 14.765099515815681, RMSE :  3.843, MAE: 3.843
# Variance score :  0.996

# %%
x
# Out:
#       2Y_Mid_irs  1Y_Mid_crs  M1_스왑포인트  Mid_ndf
# 열1
# 0          2.740        2.09       260  1132.25
# 1          2.690        2.08       250  1134.00
# 2          2.660        2.07       240  1138.00
# 3          2.680        2.07       240  1128.50
# 4          2.680        2.09       250  1129.00
# ...          ...         ...       ...      ...
# 2455       3.235        2.55       -60  1309.85
# 2456       3.215        2.56       -70  1311.00
# 2457       3.165        2.57       -55  1310.50
# 2458       3.205        2.61       -65  1306.00
# 2459       3.065        2.50       -60  1295.75
#
# [2460 rows x 4 columns]
