# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../데이터자료/시차상관분석4Data.xlsx",index_col=0)

df = df.set_index("DateTime")
df
# Out:
#             Unnamed: 0   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  \
# DateTime
# 2012-08-02           1  1131.7       2.820       2.690       2.690
# 2012-08-03           2  1134.8       2.790       2.660       2.660
# 2012-08-06           3  1129.0       2.810       2.680       2.680
# 2012-08-07           4  1128.8       2.820       2.680       2.680
# 2012-08-08           5  1128.3       2.830       2.700       2.700
# ...                ...     ...         ...         ...         ...
# 2022-07-25        2455  1313.7       3.165       3.235       3.205
# 2022-07-26        2456  1307.6       3.155       3.215       3.175
# 2022-07-27        2457  1313.3       3.145       3.165       3.115
# 2022-07-28        2458  1296.1       3.175       3.205       3.165
# 2022-07-29        2459  1299.1       3.105       3.065       3.025
#
#             5Y_Mid_irs  10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  \
# DateTime                                                                 ...
# 2012-08-02       2.720        2.860        2.08       1.845        1.85  ...
# 2012-08-03       2.690        2.840        2.07       1.830        1.83  ...
# 2012-08-06       2.710        2.850        2.07       1.805        1.80  ...
# 2012-08-07       2.720        2.870        2.09       1.820        1.80  ...
# 2012-08-08       2.740        2.900        2.10       1.820        1.80  ...
# ...                ...          ...         ...         ...         ...  ...
# 2022-07-25       3.125        2.965        2.55       2.730        2.71  ...
# 2022-07-26       3.095        2.935        2.56       2.700        2.68  ...
# 2022-07-27       3.035        2.875        2.57       2.690        2.67  ...
# 2022-07-28       3.085        2.945        2.61       2.730        2.71  ...
# 2022-07-29       2.945        2.825        2.50       2.560        2.56  ...
#
#             국고10년대비  통안1년대비  통안2년대비  전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  \
# DateTime
# 2012-08-02    -0.21   -0.03    0.02          2.0          8.0          9.0
# 2012-08-03    -0.03   -0.03    0.00          2.0          1.5          1.0
# 2012-08-06    -0.03   -0.01    0.02         -2.0         -4.5         -5.0
# 2012-08-07    -0.04   -0.01   -0.01          1.0          1.5          0.0
# 2012-08-08    -0.04   -0.06   -0.03          0.0         -2.0         -2.0
# ...             ...     ...     ...          ...          ...          ...
# 2022-07-25    -0.11    0.05    0.00         -4.0         -1.0          0.0
# 2022-07-26    -0.08    0.01   -0.05          2.0         -1.0          0.0
# 2022-07-27     0.01   -0.01   -0.02          2.0          4.0          5.0
# 2022-07-28     0.06    0.00    0.00          1.0          0.0         -1.0
# 2022-07-29     0.02    0.12    0.01         -4.0         -3.0         -1.0
#
#             전일비_5Y_베이시스  전일비_10Y_베이시스  전날 종가_ex  종가_NDF차이
# DateTime
# 2012-08-02          9.0           9.0    1126.5     -7.50
# 2012-08-03         -5.0         -13.0    1131.7     -6.30
# 2012-08-06         -6.0          -5.0    1134.8      6.30
# 2012-08-07         -8.0         -10.0    1129.0      0.00
# 2012-08-08         -4.0          -7.0    1128.8     -1.45
# ...                 ...           ...       ...       ...
# 2022-07-25         -2.0           0.0    1313.0      3.15
# 2022-07-26          1.0           1.0    1313.7      2.70
# 2022-07-27          5.0           5.0    1307.6     -2.90
# 2022-07-28         -2.0          -5.0    1313.3      7.30
# 2022-07-29          5.0           3.0    1296.1      0.35
#
# [2459 rows x 51 columns]

# %%
df.columns
df["전일비_ndf"] = df["Mid_ndf"]-df["Mid_ndf"].shift(1)
df = df.dropna()

# %%
x = df[['전일비_1Y_베이시스', '전일비_2Y_베이시스', '전일비_3Y_베이시스', '전일비_5Y_베이시스','전일비_10Y_베이시스', 
             '국고1년대비',  '국고3년대비',  '국고5년대비',  '국고10년대비', '통안1년대비', '통안2년대비',
            '전일비_ndf', 'M1_스왑포인트', '전날 종가_ex']]
y = df['종가_ex']

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_32156\2325144293.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  전일비_5Y_베이시스  전일비_10Y_베이시스  \
# DateTime
# 2012-08-03     0.348821     0.287540     0.157678    -0.910053     -2.158273
# 2012-08-06    -0.350742    -0.873325    -0.803045    -1.091422     -0.831869
# 2012-08-07     0.173930     0.287540    -0.002443    -1.454160     -1.660871
# 2012-08-08    -0.000961    -0.389631    -0.322684    -0.728685     -1.163470
# 2012-08-09     0.698602    -0.389631    -0.322684    -0.184578     -0.002867
# ...                 ...          ...          ...          ...           ...
# 2022-07-25    -0.700523    -0.196154    -0.002443    -0.365947     -0.002867
# 2022-07-26     0.348821    -0.196154    -0.002443     0.178159      0.162934
# 2022-07-27     0.348821     0.771234     0.798160     0.903634      0.826135
# 2022-07-28     0.173930    -0.002676    -0.162563    -0.365947     -0.831869
# 2022-07-29    -0.700523    -0.583109    -0.162563     0.903634      0.494535
#
#               국고1년대비    국고3년대비    국고5년대비   국고10년대비    통안1년대비    통안2년대비  \
# DateTime
# 2012-08-03  0.052388  0.003875  0.035065 -0.773688 -0.325506  0.014920
# 2012-08-06  0.052388 -0.160361  2.466717 -0.773688 -0.108855  0.267835
# 2012-08-07 -0.563730 -0.160361 -0.505303 -1.031269 -0.108855 -0.111538
# 2012-08-08 -0.563730 -0.324597  0.035065 -1.031269 -0.650484 -0.364454
# 2012-08-09 -0.563730  0.003875 -2.666772  0.771801  0.107797  0.014920
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -1.179847  1.974707 -0.235119 -2.834339  0.541100  0.014920
# 2022-07-26  0.668505  0.825055 -1.315854 -2.061595  0.107797 -0.617370
# 2022-07-27  0.052388  0.660819 -1.586037  0.256638 -0.108855 -0.237996
# 2022-07-28  1.284622  1.153527  0.035065  1.544546 -0.000529  0.014920
# 2022-07-29  0.668505 -0.653069  0.305248  0.514220  1.299382  0.141378
#
#              전일비_ndf  M1_스왑포인트  전날 종가_ex
# DateTime
# 2012-08-03  0.184967  1.820638 -0.056282
# 2012-08-06 -0.449739  1.820638 -0.000487
# 2012-08-07  0.020414  1.911215 -0.104877
# 2012-08-08  0.055675  1.820638 -0.108476
# 2012-08-09  0.102691  1.775350 -0.117475
# ...              ...       ...       ...
# 2022-07-25  0.154407 -0.896666  3.206786
# 2022-07-26  0.050974 -0.987243  3.219385
# 2022-07-27 -0.026602 -0.851378  3.109596
# 2022-07-28 -0.214663 -0.941955  3.212186
# 2022-07-29 -0.485001 -0.896666  2.902617
#
# [2458 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     3.109965   전일비_1Y_베이시스
# 1     5.877062   전일비_2Y_베이시스
# 2     2.398917   전일비_3Y_베이시스
# 3     4.751751   전일비_5Y_베이시스
# 4     3.227889  전일비_10Y_베이시스
# 5     1.006382        국고1년대비
# 6     1.002834        국고3년대비
# 7     1.005077        국고5년대비
# 8     1.006160       국고10년대비
# 9     1.003549        통안1년대비
# 10    1.000587        통안2년대비
# 11    1.002616       전일비_ndf
# 12    1.169490      M1_스왑포인트
# 13    1.173649      전날 종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.803e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:19   Log-Likelihood:                -7655.1
# No. Observations:                2458   AIC:                         1.534e+04
# Df Residuals:                    2443   BIC:                         1.543e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8952      0.110   1.03e+04      0.000    1134.679    1135.111
# 전일비_1Y_베이시스     -1.2588      0.194     -6.475      0.000      -1.640      -0.878
# 전일비_2Y_베이시스     -0.2282      0.267     -0.854      0.393      -0.752       0.296
# 전일비_3Y_베이시스     -0.1611      0.171     -0.944      0.345      -0.496       0.174
# 전일비_5Y_베이시스      0.0852      0.240      0.355      0.723      -0.386       0.556
# 전일비_10Y_베이시스     0.2788      0.198      1.408      0.159      -0.110       0.667
# 국고1년대비          -0.2246      0.111     -2.031      0.042      -0.441      -0.008
# 국고3년대비          -0.4147      0.110     -3.757      0.000      -0.631      -0.198
# 국고5년대비          -0.3643      0.111     -3.297      0.001      -0.581      -0.148
# 국고10년대비         -0.2888      0.111     -2.611      0.009      -0.506      -0.072
# 통안1년대비          -0.2401      0.110     -2.174      0.030      -0.457      -0.024
# 통안2년대비          -0.3702      0.110     -3.357      0.001      -0.586      -0.154
# 전일비_ndf          0.5752      0.110      5.211      0.000       0.359       0.792
# M1_스왑포인트        -0.1523      0.119     -1.278      0.201      -0.386       0.081
# 전날 종가_ex        55.3838      0.119    463.723      0.000      55.150      55.618
# ==============================================================================
# Omnibus:                       56.245   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.590
# Skew:                          -0.012   Prob(JB):                     8.83e-28
# Kurtosis:                       4.103   Cond. No.                         5.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_5Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.943e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:21   Log-Likelihood:                -7655.2
# No. Observations:                2458   AIC:                         1.534e+04
# Df Residuals:                    2444   BIC:                         1.542e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8952      0.110   1.03e+04      0.000    1134.679    1135.111
# 전일비_1Y_베이시스     -1.2571      0.194     -6.469      0.000      -1.638      -0.876
# 전일비_2Y_베이시스     -0.1916      0.246     -0.777      0.437      -0.675       0.292
# 전일비_3Y_베이시스     -0.1512      0.168     -0.898      0.369      -0.482       0.179
# 전일비_10Y_베이시스     0.3133      0.173      1.816      0.069      -0.025       0.652
# 국고1년대비          -0.2244      0.111     -2.029      0.043      -0.441      -0.008
# 국고3년대비          -0.4148      0.110     -3.758      0.000      -0.631      -0.198
# 국고5년대비          -0.3650      0.110     -3.304      0.001      -0.582      -0.148
# 국고10년대비         -0.2890      0.111     -2.614      0.009      -0.506      -0.072
# 통안1년대비          -0.2401      0.110     -2.174      0.030      -0.457      -0.024
# 통안2년대비          -0.3699      0.110     -3.355      0.001      -0.586      -0.154
# 전일비_ndf          0.5749      0.110      5.209      0.000       0.359       0.791
# M1_스왑포인트        -0.1524      0.119     -1.278      0.201      -0.386       0.081
# 전날 종가_ex        55.3835      0.119    463.815      0.000      55.149      55.618
# ==============================================================================
# Omnibus:                       56.437   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.211
# Skew:                          -0.012   Prob(JB):                     6.47e-28
# Kurtosis:                       4.105   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_2Y_베이시스', '전일비_3Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.296e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:22   Log-Likelihood:                -7656.3
# No. Observations:                2458   AIC:                         1.534e+04
# Df Residuals:                    2446   BIC:                         1.541e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8952      0.110   1.03e+04      0.000    1134.679    1135.111
# 전일비_1Y_베이시스     -1.4256      0.142    -10.033      0.000      -1.704      -1.147
# 전일비_10Y_베이시스     0.1760      0.142      1.241      0.215      -0.102       0.454
# 국고1년대비          -0.2247      0.111     -2.033      0.042      -0.442      -0.008
# 국고3년대비          -0.4127      0.110     -3.740      0.000      -0.629      -0.196
# 국고5년대비          -0.3644      0.110     -3.298      0.001      -0.581      -0.148
# 국고10년대비         -0.2852      0.111     -2.581      0.010      -0.502      -0.068
# 통안1년대비          -0.2385      0.110     -2.160      0.031      -0.455      -0.022
# 통안2년대비          -0.3696      0.110     -3.352      0.001      -0.586      -0.153
# 전일비_ndf          0.5792      0.110      5.250      0.000       0.363       0.795
# M1_스왑포인트        -0.1526      0.119     -1.280      0.201      -0.386       0.081
# 전날 종가_ex        55.3830      0.119    463.797      0.000      55.149      55.617
# ==============================================================================
# Omnibus:                       54.427   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.783
# Skew:                          -0.004   Prob(JB):                     1.61e-26
# Kurtosis:                       4.077   Cond. No.                         2.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['M1_스왑포인트'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.525e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:22   Log-Likelihood:                -7657.1
# No. Observations:                2458   AIC:                         1.534e+04
# Df Residuals:                    2447   BIC:                         1.540e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8952      0.110   1.03e+04      0.000    1134.679    1135.111
# 전일비_1Y_베이시스     -1.4267      0.142    -10.040      0.000      -1.705      -1.148
# 전일비_10Y_베이시스     0.1791      0.142      1.263      0.207      -0.099       0.457
# 국고1년대비          -0.2212      0.111     -2.001      0.045      -0.438      -0.004
# 국고3년대비          -0.4133      0.110     -3.745      0.000      -0.630      -0.197
# 국고5년대비          -0.3637      0.111     -3.292      0.001      -0.580      -0.147
# 국고10년대비         -0.2865      0.111     -2.592      0.010      -0.503      -0.070
# 통안1년대비          -0.2391      0.110     -2.165      0.030      -0.456      -0.023
# 통안2년대비          -0.3683      0.110     -3.340      0.001      -0.585      -0.152
# 전일비_ndf          0.5794      0.110      5.252      0.000       0.363       0.796
# 전날 종가_ex        55.4408      0.111    501.461      0.000      55.224      55.658
# ==============================================================================
# Omnibus:                       54.137   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.836
# Skew:                          -0.006   Prob(JB):                     2.58e-26
# Kurtosis:                       4.073   Cond. No.                         2.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_10Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.804e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:22   Log-Likelihood:                -7657.9
# No. Observations:                2458   AIC:                         1.534e+04
# Df Residuals:                    2448   BIC:                         1.539e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8952      0.110   1.03e+04      0.000    1134.679    1135.111
# 전일비_1Y_베이시스    -1.3142      0.111    -11.869      0.000      -1.531      -1.097
# 국고1년대비         -0.2225      0.111     -2.012      0.044      -0.439      -0.006
# 국고3년대비         -0.4139      0.110     -3.750      0.000      -0.630      -0.198
# 국고5년대비         -0.3627      0.111     -3.282      0.001      -0.579      -0.146
# 국고10년대비        -0.2829      0.110     -2.561      0.011      -0.500      -0.066
# 통안1년대비         -0.2377      0.110     -2.152      0.031      -0.454      -0.021
# 통안2년대비         -0.3675      0.110     -3.332      0.001      -0.584      -0.151
# 전일비_ndf         0.5791      0.110      5.249      0.000       0.363       0.796
# 전날 종가_ex       55.4390      0.111    501.425      0.000      55.222      55.656
# ==============================================================================
# Omnibus:                       57.158   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.707
# Skew:                          -0.006   Prob(JB):                     1.86e-28
# Kurtosis:                       4.117   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['국고1년대비','국고3년대비','국고5년대비'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 4.162e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:22   Log-Likelihood:                -7672.4
# No. Observations:                2458   AIC:                         1.536e+04
# Df Residuals:                    2451   BIC:                         1.540e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8952      0.111   1.02e+04      0.000    1134.678    1135.113
# 전일비_1Y_베이시스    -1.2923      0.111    -11.630      0.000      -1.510      -1.074
# 국고10년대비        -0.2889      0.111     -2.601      0.009      -0.507      -0.071
# 통안1년대비         -0.2446      0.111     -2.206      0.027      -0.462      -0.027
# 통안2년대비         -0.3713      0.111     -3.349      0.001      -0.589      -0.154
# 전일비_ndf         0.5834      0.111      5.259      0.000       0.366       0.801
# 전날 종가_ex       55.4025      0.111    499.520      0.000      55.185      55.620
# ==============================================================================
# Omnibus:                       54.607   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              119.295
# Skew:                          -0.009   Prob(JB):                     1.25e-26
# Kurtosis:                       4.079   Cond. No.                         1.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['통안1년대비','통안2년대비'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 6.206e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:31:25   Log-Likelihood:                -7680.5
# No. Observations:                2458   AIC:                         1.537e+04
# Df Residuals:                    2453   BIC:                         1.540e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8952      0.111   1.02e+04      0.000    1134.677    1135.113
# 전일비_1Y_베이시스    -1.2971      0.111    -11.641      0.000      -1.516      -1.079
# 국고10년대비        -0.2944      0.111     -2.644      0.008      -0.513      -0.076
# 전일비_ndf         0.5873      0.111      5.280      0.000       0.369       0.805
# 전날 종가_ex       55.3976      0.111    498.104      0.000      55.180      55.616
# ==============================================================================
# Omnibus:                       53.054   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.269
# Skew:                          -0.013   Prob(JB):                     1.54e-25
# Kurtosis:                       4.056   Cond. No.                         1.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=10)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 26.900955614506284, RMSE :  5.187, MAE: 5.187
# Variance score :  0.991

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (8.241325384075989,
#  array([ 4.52636359,  6.76840089,  5.64639955, 19.22510227,  5.04036063]),
#  array([ -20.48796734,  -45.81125057,  -31.88182784, -369.60455733,
#          -25.40523524]))
