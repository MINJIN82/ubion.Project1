# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# 파일 불러오기
df = pd.read_excel("./xlsx/Join_data_3.xlsx", index_col = 0)    
df = df.set_index("DateTime")


# 대비 계산
df['대비_swapbasis_1Y'] = df['1Y_베이시스']-df['1Y_베이시스'].shift(1)
df['대비_swapbasis_2Y'] = df['2Y_베이시스']-df['2Y_베이시스'].shift(1)
df['대비_swapbasis_3Y'] = df['3Y_베이시스']-df['3Y_베이시스'].shift(1)
df['대비_swapbasis_5Y'] = df['5Y_베이시스']-df['5Y_베이시스'].shift(1)
df['대비_swapbasis_10Y'] = df['10Y_베이시스']-df['10Y_베이시스'].shift(1)

df['대비_국고_1Y'] = df['국고1년']-df['국고1년'].shift(1)
df['대비_국고_3Y'] = df['국고3년']-df['국고3년'].shift(1)
df['대비_국고_5Y'] = df['국고5년']-df['국고5년'].shift(1)
df['대비_국고_10Y'] = df['국고10년']-df['국고10년'].shift(1)

df['대비_통안_1Y'] = df['통안364일']-df['통안364일'].shift(1)
df['대비_통안_2Y'] = df['통안2년']-df['통안2년'].shift(1)

df['스왑포인트_1M'] = df['M1_스왑포인트']/100 
df['전일종가_ex'] = df['종가_ex'].shift(1)
df['종가_NDF_차이'] = df['전일종가_ex'] - df['Mid_ndf']

df.rename({ '1Y_전일비_irs' : '대비_irs_1Y', '2Y_전일비_irs' :'대비_irs_2Y','3Y_전일비_irs':'대비_irs_3Y', '5Y_전일비_irs' : '대비_irs_5Y', '10Y_전일비_irs' : '대비_irs_10Y',
           '1Y_전일비_crs' :'대비_crs_1Y', '2Y_전일비_crs' :'대비_crs_2Y','3Y_전일비_crs' : '대비_crs_3Y', '5Y_전일비_crs' :'대비_crs_5Y', '10Y_전일비_crs' : '대비_crs_10Y','전일비_ndf' :'대비_ndf'}, axis=1, inplace=True)

# 필요한 칼럼만 추출
df_1 = df[['대비_irs_1Y','대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y', 
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M', '전일종가_ex', 
           '종가_ex' ]]      


# 결측치 제거
df_1 = df_1.dropna()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns   
# import scipy as sp  
# from matplotlib import rc 
# rc('font', family='AppleGothic')
# plt.rcParams['axes.unicode_minus'] = False

# plt.figure(figsize=(20,20))

# cmap = sns.diverging_palette(220, 10, as_cmap=True)
# sns.heatmap(data = df.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap=cmap, center=0)

# %%
df_1.columns
# Out:
# Index(['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
#        '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y',
#        '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', '대비_통안_1Y', '대비_통안_2Y',
#        '대비_ndf', '스왑포인트_1M', '전일종가_ex', '종가_ex'],
#       dtype='object')

# %%
x = df_1[['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
        '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y',
        '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
        '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M',
        '전일종가_ex']]
y = df_1["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
#             대비_irs_1Y  대비_irs_2Y  대비_irs_3Y  대비_irs_5Y  대비_irs_10Y  대비_crs_1Y  \
# DateTime
# 2012-08-02  -0.847862  -1.216879  -0.935732  -1.045679   -1.009126  -0.205336
# 2012-08-03  -0.847862  -0.731372  -0.562274  -0.628002   -0.403231  -0.205336
# 2012-08-06   0.560374   0.482398   0.371369   0.416191    0.202663  -0.003044
# 2012-08-07   0.278727  -0.003110  -0.002088   0.207352    0.404628   0.401540
# 2012-08-08   0.278727   0.482398   0.371369   0.416191    0.606592   0.199248
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-25  -1.129510  -1.945141  -1.309189  -1.881032   -2.220914  -1.621379
# 2022-07-26  -0.284568  -0.488618  -0.562274  -0.628002   -0.605196   0.199248
# 2022-07-27  -0.284568  -1.216879  -1.122460  -1.254517   -1.211091   0.199248
# 2022-07-28   0.842021   0.967906   0.931555   1.042706    1.414452   0.806124
# 2022-07-29  -1.974451  -3.401665  -2.616289  -2.925225   -2.422879  -2.228254
#
#             대비_crs_2Y  대비_crs_3Y  대비_crs_5Y  대비_crs_10Y  대비_국고_1Y  대비_국고_3Y  \
# DateTime
# 2012-08-02   0.707523   0.905683   0.926547    0.826527 -1.698057 -0.646622
# 2012-08-03  -0.364368  -0.463000  -1.872732   -3.115507 -1.132651 -0.323869
# 2012-08-06  -0.602566  -0.691113  -0.939639   -0.833277  0.563566  0.160261
# 2012-08-07   0.350226  -0.006772  -1.639459   -1.663179 -0.567245 -0.001116
# 2012-08-08  -0.007071  -0.006772  -0.473092   -0.833277 -0.567245 -0.323869
# ...               ...        ...        ...         ...       ...       ...
# 2022-07-25  -2.150854  -1.603569  -2.572552   -2.285605 -1.132651 -0.969375
# 2022-07-26  -0.721665  -0.691113  -0.473092   -0.418326  0.563566 -0.485246
# 2022-07-27  -0.245269  -0.234886  -0.239819   -0.210850 -0.001839 -0.485246
# 2022-07-28   0.945721   0.905683   0.693274    0.411576  0.563566  0.644391
# 2022-07-29  -4.056438  -3.428479  -2.106005   -1.870654 -2.263463 -2.099012
#
#             대비_국고_5Y  대비_국고_10Y  대비_통안_1Y  대비_통안_2Y    대비_ndf  스왑포인트_1M  \
# DateTime
# 2012-08-02 -1.079749  -1.027569 -0.325920 -0.625160  0.294493  1.909409
# 2012-08-03 -1.890219  -1.798403 -0.217574 -0.125723  0.687227  1.818881
# 2012-08-06  0.000879   0.000209  0.107465  0.123996 -1.669177  1.818881
# 2012-08-07  0.000879   0.000209 -0.109228 -0.125723  0.076307  1.909409
# 2012-08-08 -0.539435  -0.513680 -0.109228 -0.125723  0.207219  1.818881
# ...              ...        ...       ...       ...       ...       ...
# 2022-07-25 -1.890219  -2.312292 -0.109228 -0.625160  0.573770 -0.896960
# 2022-07-26 -0.539435  -0.770625  0.107465 -0.000863  0.189764 -0.987488
# 2022-07-27 -1.349905  -1.541458  0.215812 -0.125723 -0.098241 -0.851696
# 2022-07-28  0.811350   2.055766  0.215812  0.373715 -0.796435 -0.942224
# 2022-07-29 -3.241004  -2.055348 -0.325920 -1.374316 -1.800088 -0.896960
#
#              전일종가_ex
# DateTime
# 2012-08-02 -0.149841
# 2012-08-03 -0.056232
# 2012-08-06 -0.000426
# 2012-08-07 -0.104837
# 2012-08-08 -0.108437
# ...              ...
# 2022-07-25  3.207485
# 2022-07-26  3.220086
# 2022-07-27  3.110275
# 2022-07-28  3.212885
# 2022-07-29  2.903255
#
# [2459 rows x 19 columns]

# %%
# 히트맵 그리기
import matplotlib.pyplot as plt
import seaborn as sns   
import scipy as sp 
from matplotlib import rc 
rc('font', family='AppleGothic')
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(20,20))

cmap = sns.diverging_palette(210, 10, as_cmap=True)

res= sns.heatmap(data = x_scaled.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap=cmap, center=0, annot_kws = {'size' : 13})

res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 17)
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 17)
# Out:
# [Text(0, 0.5, '대비_irs_1Y'),
#  Text(0, 1.5, '대비_irs_2Y'),
#  Text(0, 2.5, '대비_irs_3Y'),
#  Text(0, 3.5, '대비_irs_5Y'),
#  Text(0, 4.5, '대비_irs_10Y'),
#  Text(0, 5.5, '대비_crs_1Y'),
#  Text(0, 6.5, '대비_crs_2Y'),
#  Text(0, 7.5, '대비_crs_3Y'),
#  Text(0, 8.5, '대비_crs_5Y'),
#  Text(0, 9.5, '대비_crs_10Y'),
#  Text(0, 10.5, '대비_국고_1Y'),
#  Text(0, 11.5, '대비_국고_3Y'),
#  Text(0, 12.5, '대비_국고_5Y'),
#  Text(0, 13.5, '대비_국고_10Y'),
#  Text(0, 14.5, '대비_통안_1Y'),
#  Text(0, 15.5, '대비_통안_2Y'),
#  Text(0, 16.5, '대비_ndf'),
#  Text(0, 17.5, '스왑포인트_1M'),
#  Text(0, 18.5, '전일종가_ex')]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     9.964149   대비_irs_1Y
# 1    19.507769   대비_irs_2Y
# 2     2.664108   대비_irs_3Y
# 3     6.468432   대비_irs_5Y
# 4     5.883580  대비_irs_10Y
# 5     2.651537   대비_crs_1Y
# 6     5.272451   대비_crs_2Y
# 7     3.830892   대비_crs_3Y
# 8     6.708564   대비_crs_5Y
# 9     3.722040  대비_crs_10Y
# 10    1.927034    대비_국고_1Y
# 11    1.253542    대비_국고_3Y
# 12    6.299576    대비_국고_5Y
# 13    5.056958   대비_국고_10Y
# 14    1.025512    대비_통안_1Y
# 15    1.115948    대비_통안_2Y
# 16    1.043675      대비_ndf
# 17    1.169209    스왑포인트_1M
# 18    1.182174     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.638e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:33   Log-Likelihood:                -7400.7
# No. Observations:                2459   AIC:                         1.484e+04
# Df Residuals:                    2439   BIC:                         1.496e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.1610      0.314      0.513      0.608      -0.454       0.776
# 대비_irs_2Y      0.4541      0.439      1.035      0.301      -0.407       1.315
# 대비_irs_3Y      0.0966      0.162      0.595      0.552      -0.221       0.415
# 대비_irs_5Y     -0.3067      0.253     -1.214      0.225      -0.802       0.189
# 대비_irs_10Y    -0.4535      0.241     -1.882      0.060      -0.926       0.019
# 대비_crs_1Y     -1.0267      0.162     -6.345      0.000      -1.344      -0.709
# 대비_crs_2Y     -0.0391      0.228     -0.171      0.864      -0.486       0.408
# 대비_crs_3Y     -0.3785      0.194     -1.946      0.052      -0.760       0.003
# 대비_crs_5Y      0.0693      0.257      0.269      0.788      -0.435       0.574
# 대비_crs_10Y     0.0142      0.192      0.074      0.941      -0.362       0.390
# 대비_국고_1Y       0.1678      0.138      1.217      0.224      -0.103       0.438
# 대비_국고_3Y      -0.2649      0.111     -2.382      0.017      -0.483      -0.047
# 대비_국고_5Y       0.5415      0.249      2.171      0.030       0.052       1.031
# 대비_국고_10Y     -0.1296      0.223     -0.580      0.562      -0.568       0.309
# 대비_통안_1Y      -0.0413      0.101     -0.410      0.682      -0.239       0.156
# 대비_통안_2Y       0.0531      0.105      0.506      0.613      -0.153       0.259
# 대비_ndf         2.3912      0.102     23.556      0.000       2.192       2.590
# 스왑포인트_1M      -0.1110      0.107     -1.033      0.302      -0.322       0.100
# 전일종가_ex       55.3084      0.108    511.945      0.000      55.097      55.520
# ==============================================================================
# Omnibus:                       49.903   Durbin-Watson:                   2.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.849
# Skew:                           0.046   Prob(JB):                     4.64e-23
# Kurtosis:                       3.998   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.931366   대비_irs_1Y
# 1     2.553341   대비_irs_3Y
# 2     5.804019   대비_irs_5Y
# 3     5.226907  대비_irs_10Y
# 4     2.648706   대비_crs_1Y
# 5     5.260997   대비_crs_2Y
# 6     3.828392   대비_crs_3Y
# 7     6.703122   대비_crs_5Y
# 8     3.721897  대비_crs_10Y
# 9     1.915916    대비_국고_1Y
# 10    1.247534    대비_국고_3Y
# 11    6.213288    대비_국고_5Y
# 12    5.043142   대비_국고_10Y
# 13    1.025145    대비_통안_1Y
# 14    1.115259    대비_통안_2Y
# 15    1.043438      대비_ndf
# 16    1.169155    스왑포인트_1M
# 17    1.181377     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.729e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:39   Log-Likelihood:                -7401.2
# No. Observations:                2459   AIC:                         1.484e+04
# Df Residuals:                    2440   BIC:                         1.495e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4135      0.197      2.099      0.036       0.027       0.800
# 대비_irs_3Y      0.1308      0.159      0.824      0.410      -0.181       0.442
# 대비_irs_5Y     -0.2229      0.239     -0.931      0.352      -0.692       0.246
# 대비_irs_10Y    -0.3702      0.227     -1.630      0.103      -0.816       0.075
# 대비_crs_1Y     -1.0322      0.162     -6.383      0.000      -1.349      -0.715
# 대비_crs_2Y     -0.0281      0.228     -0.123      0.902      -0.475       0.419
# 대비_crs_3Y     -0.3837      0.194     -1.973      0.049      -0.765      -0.002
# 대비_crs_5Y      0.0769      0.257      0.299      0.765      -0.428       0.581
# 대비_crs_10Y     0.0154      0.192      0.081      0.936      -0.360       0.391
# 대비_국고_1Y       0.1787      0.138      1.299      0.194      -0.091       0.448
# 대비_국고_3Y      -0.2570      0.111     -2.315      0.021      -0.475      -0.039
# 대비_국고_5Y       0.5717      0.248      2.308      0.021       0.086       1.057
# 대비_국고_10Y     -0.1416      0.223     -0.635      0.526      -0.579       0.296
# 대비_통안_1Y      -0.0432      0.101     -0.430      0.667      -0.241       0.154
# 대비_통안_2Y       0.0558      0.105      0.532      0.595      -0.150       0.262
# 대비_ndf         2.3928      0.102     23.574      0.000       2.194       2.592
# 스왑포인트_1M      -0.1102      0.107     -1.026      0.305      -0.321       0.100
# 전일종가_ex       55.3055      0.108    512.084      0.000      55.094      55.517
# ==============================================================================
# Omnibus:                       50.378   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.924
# Skew:                           0.050   Prob(JB):                     2.71e-23
# Kurtosis:                       4.002   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_통안_1Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.930436   대비_irs_1Y
# 1     2.553279   대비_irs_3Y
# 2     5.804019   대비_irs_5Y
# 3     5.226284  대비_irs_10Y
# 4     2.648687   대비_crs_1Y
# 5     5.260930   대비_crs_2Y
# 6     3.828374   대비_crs_3Y
# 7     6.703122   대비_crs_5Y
# 8     3.721893  대비_crs_10Y
# 9     1.904571    대비_국고_1Y
# 10    1.247489    대비_국고_3Y
# 11    6.210367    대비_국고_5Y
# 12    5.043111   대비_국고_10Y
# 13    1.115161    대비_통안_2Y
# 14    1.043169      대비_ndf
# 15    1.169140    스왑포인트_1M
# 16    1.181296     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.831e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:42   Log-Likelihood:                -7401.3
# No. Observations:                2459   AIC:                         1.484e+04
# Df Residuals:                    2441   BIC:                         1.494e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4122      0.197      2.093      0.036       0.026       0.798
# 대비_irs_3Y      0.1311      0.159      0.826      0.409      -0.180       0.442
# 대비_irs_5Y     -0.2230      0.239     -0.932      0.352      -0.692       0.246
# 대비_irs_10Y    -0.3691      0.227     -1.625      0.104      -0.814       0.076
# 대비_crs_1Y     -1.0323      0.162     -6.385      0.000      -1.349      -0.715
# 대비_crs_2Y     -0.0284      0.228     -0.125      0.901      -0.475       0.418
# 대비_crs_3Y     -0.3835      0.194     -1.973      0.049      -0.765      -0.002
# 대비_crs_5Y      0.0769      0.257      0.299      0.765      -0.428       0.581
# 대비_crs_10Y     0.0155      0.192      0.081      0.935      -0.360       0.391
# 대비_국고_1Y       0.1741      0.137      1.270      0.204      -0.095       0.443
# 대비_국고_3Y      -0.2573      0.111     -2.318      0.021      -0.475      -0.040
# 대비_국고_5Y       0.5694      0.248      2.300      0.022       0.084       1.055
# 대비_국고_10Y     -0.1419      0.223     -0.636      0.525      -0.579       0.296
# 대비_통안_2Y       0.0554      0.105      0.528      0.598      -0.150       0.261
# 대비_ndf         2.3921      0.101     23.574      0.000       2.193       2.591
# 스왑포인트_1M      -0.1104      0.107     -1.027      0.304      -0.321       0.100
# 전일종가_ex       55.3052      0.108    512.183      0.000      55.093      55.517
# ==============================================================================
# Omnibus:                       50.272   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.643
# Skew:                           0.050   Prob(JB):                     3.12e-23
# Kurtosis:                       4.001   Cond. No.                         7.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_3Y', '대비_crs_5Y', '대비_통안_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.608611   대비_irs_1Y
# 1     5.676229   대비_irs_5Y
# 2     5.099788  대비_irs_10Y
# 3     2.646713   대비_crs_1Y
# 4     4.577107   대비_crs_2Y
# 5     3.455338   대비_crs_3Y
# 6     2.433840  대비_crs_10Y
# 7     1.869923    대비_국고_1Y
# 8     1.245917    대비_국고_3Y
# 9     6.159149    대비_국고_5Y
# 10    5.042444   대비_국고_10Y
# 11    1.040456      대비_ndf
# 12    1.169134    스왑포인트_1M
# 13    1.181006     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 2.225e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:47   Log-Likelihood:                -7401.9
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2444   BIC:                         1.492e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4580      0.189      2.428      0.015       0.088       0.828
# 대비_irs_5Y     -0.1905      0.237     -0.805      0.421      -0.654       0.273
# 대비_irs_10Y    -0.3436      0.224     -1.532      0.126      -0.783       0.096
# 대비_crs_1Y     -1.0359      0.162     -6.412      0.000      -1.353      -0.719
# 대비_crs_2Y      0.0001      0.212      0.001      1.000      -0.417       0.417
# 대비_crs_3Y     -0.3675      0.185     -1.991      0.047      -0.730      -0.006
# 대비_crs_10Y     0.0535      0.155      0.345      0.730      -0.250       0.357
# 대비_국고_1Y       0.1885      0.136      1.388      0.165      -0.078       0.455
# 대비_국고_3Y      -0.2533      0.111     -2.285      0.022      -0.471      -0.036
# 대비_국고_5Y       0.5876      0.246      2.384      0.017       0.104       1.071
# 대비_국고_10Y     -0.1435      0.223     -0.644      0.520      -0.581       0.294
# 대비_ndf         2.3897      0.101     23.591      0.000       2.191       2.588
# 스왑포인트_1M      -0.1102      0.107     -1.026      0.305      -0.321       0.100
# 전일종가_ex       55.3035      0.108    512.433      0.000      55.092      55.515
# ==============================================================================
# Omnibus:                       50.347   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.155
# Skew:                           0.046   Prob(JB):                     2.42e-23
# Kurtosis:                       4.004   Cond. No.                         6.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_5Y', '대비_crs_10Y', '대비_국고_1Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 2.833e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:49   Log-Likelihood:                -7403.2
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2447   BIC:                         1.490e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4295      0.163      2.638      0.008       0.110       0.749
# 대비_irs_10Y    -0.4694      0.187     -2.505      0.012      -0.837      -0.102
# 대비_crs_1Y     -1.0285      0.161     -6.371      0.000      -1.345      -0.712
# 대비_crs_2Y      0.0236      0.203      0.116      0.907      -0.374       0.422
# 대비_crs_3Y     -0.3515      0.176     -1.997      0.046      -0.697      -0.006
# 대비_국고_3Y      -0.2361      0.110     -2.149      0.032      -0.451      -0.021
# 대비_국고_5Y       0.6784      0.233      2.916      0.004       0.222       1.135
# 대비_국고_10Y     -0.1354      0.223     -0.608      0.544      -0.572       0.302
# 대비_ndf         2.3869      0.101     23.575      0.000       2.188       2.585
# 스왑포인트_1M      -0.1091      0.107     -1.017      0.309      -0.320       0.101
# 전일종가_ex       55.3153      0.108    514.221      0.000      55.104      55.526
# ==============================================================================
# Omnibus:                       47.482   Durbin-Watson:                   2.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.481
# Skew:                           0.033   Prob(JB):                     1.12e-21
# Kurtosis:                       3.968   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_2Y', '대비_국고_10Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 3.465e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:00:52   Log-Likelihood:                -7403.4
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2449   BIC:                         1.488e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4464      0.160      2.782      0.005       0.132       0.761
# 대비_irs_10Y    -0.4901      0.184     -2.661      0.008      -0.851      -0.129
# 대비_crs_1Y     -1.0170      0.138     -7.355      0.000      -1.288      -0.746
# 대비_crs_3Y     -0.3402      0.142     -2.399      0.017      -0.618      -0.062
# 대비_국고_3Y      -0.2354      0.110     -2.144      0.032      -0.451      -0.020
# 대비_국고_5Y       0.5651      0.135      4.173      0.000       0.300       0.831
# 대비_ndf         2.3878      0.101     23.639      0.000       2.190       2.586
# 스왑포인트_1M      -0.1086      0.107     -1.012      0.312      -0.319       0.102
# 전일종가_ex       55.3147      0.108    514.407      0.000      55.104      55.526
# ==============================================================================
# Omnibus:                       47.622   Durbin-Watson:                   2.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.025
# Skew:                           0.031   Prob(JB):                     8.54e-22
# Kurtosis:                       3.971   Cond. No.                         3.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['스왑포인트_1M'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 3.898e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:01:01   Log-Likelihood:                -7403.9
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2450   BIC:                         1.488e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.4456      0.160      2.777      0.006       0.131       0.760
# 대비_irs_10Y    -0.4901      0.184     -2.662      0.008      -0.851      -0.129
# 대비_crs_1Y     -1.0171      0.138     -7.356      0.000      -1.288      -0.746
# 대비_crs_3Y     -0.3399      0.142     -2.396      0.017      -0.618      -0.062
# 대비_국고_3Y      -0.2357      0.110     -2.147      0.032      -0.451      -0.020
# 대비_국고_5Y       0.5638      0.135      4.164      0.000       0.298       0.829
# 대비_ndf         2.3891      0.101     23.653      0.000       2.191       2.587
# 전일종가_ex       55.3559      0.100    556.193      0.000      55.161      55.551
# ==============================================================================
# Omnibus:                       47.349   Durbin-Watson:                   2.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.265
# Skew:                           0.030   Prob(JB):                     1.25e-21
# Kurtosis:                       3.967   Cond. No.                         3.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_10Y',  '대비_crs_3Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 5.173e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:01:04   Log-Likelihood:                -7410.4
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2452   BIC:                         1.488e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_irs_1Y      0.1138      0.106      1.068      0.285      -0.095       0.323
# 대비_crs_1Y     -1.2371      0.102    -12.155      0.000      -1.437      -1.038
# 대비_국고_3Y      -0.2266      0.110     -2.061      0.039      -0.442      -0.011
# 대비_국고_5Y       0.3294      0.115      2.854      0.004       0.103       0.556
# 대비_ndf         2.4105      0.101     23.874      0.000       2.213       2.609
# 전일종가_ex       55.3679      0.100    555.444      0.000      55.172      55.563
# ==============================================================================
# Omnibus:                       51.841   Durbin-Watson:                   2.647
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.044
# Skew:                           0.042   Prob(JB):                     2.10e-24
# Kurtosis:                       4.028   Cond. No.                         1.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_1Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 6.208e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:01:04   Log-Likelihood:                -7411.0
# No. Observations:                2459   AIC:                         1.483e+04
# Df Residuals:                    2453   BIC:                         1.487e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.099   1.14e+04      0.000    1134.699    1135.089
# 대비_crs_1Y     -1.2282      0.101    -12.108      0.000      -1.427      -1.029
# 대비_국고_3Y      -0.2186      0.110     -1.993      0.046      -0.434      -0.004
# 대비_국고_5Y       0.3637      0.111      3.281      0.001       0.146       0.581
# 대비_ndf         2.4095      0.101     23.865      0.000       2.211       2.607
# 전일종가_ex       55.3709      0.100    555.681      0.000      55.176      55.566
# ==============================================================================
# Omnibus:                       52.019   Durbin-Watson:                   2.648
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.709
# Skew:                           0.040   Prob(JB):                     1.50e-24
# Kurtosis:                       4.032   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_scaled = pd.concat([x_scaled, y], axis=1)
df_scaled
# Out:
#             대비_crs_1Y  대비_국고_3Y  대비_국고_5Y    대비_ndf   전일종가_ex   종가_ex
# DateTime
# 2012-08-02  -0.205336 -0.646622 -1.079749  0.294493 -0.149841  1131.7
# 2012-08-03  -0.205336 -0.323869 -1.890219  0.687227 -0.056232  1134.8
# 2012-08-06  -0.003044  0.160261  0.000879 -1.669177 -0.000426  1129.0
# 2012-08-07   0.401540 -0.001116  0.000879  0.076307 -0.104837  1128.8
# 2012-08-08   0.199248 -0.323869 -0.539435  0.207219 -0.108437  1128.3
# ...               ...       ...       ...       ...       ...     ...
# 2022-07-25  -1.621379 -0.969375 -1.890219  0.573770  3.207485  1313.7
# 2022-07-26   0.199248 -0.485246 -0.539435  0.189764  3.220086  1307.6
# 2022-07-27   0.199248 -0.485246 -1.349905 -0.098241  3.110275  1313.3
# 2022-07-28   0.806124  0.644391  0.811350 -0.796435  3.212885  1296.1
# 2022-07-29  -2.228254 -2.099012 -3.241004 -1.800088  2.903255  1299.1
#
# [2459 rows x 6 columns]

# %%
train = df_scaled[0:1945]
test = df_scaled[1945:]

def make_dataset(data, label, window_size=1):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

label_cols = ['종가_ex']
feature_cols = ['대비_crs_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_ndf', '전일종가_ex']

# %%
from sklearn.model_selection import train_test_split

train_feature = train[feature_cols]
train_label = train[label_cols]
test_feature = test[feature_cols]
test_label = test[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 1)
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((1555, 1, 5), (389, 1, 5))

# %%
x_train
# Out:
# array([[[-0.00304384, -0.16249229, -0.26927797,  0.94904921,
#          -0.18584443]],
#
#        [[-0.00304384, -0.16249229,  0.54119268,  0.44285887,
#           1.17148731]],
#
#        [[ 0.199248  ,  0.16026097,  0.54119268,  1.1235976 ,
#          -1.23894664]],
#
#        ...,
#
#        [[-0.00304384, -0.16249229, -0.80959173, -1.25898795,
#          -0.23444915]],
#
#        [[ 0.60383169, -0.16249229, -0.80959173,  0.99268631,
#          -0.3586612 ]],
#
#        [[ 0.199248  , -0.16249229, -0.26927797,  0.7221363 ,
#           1.36770635]]])

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 1)
test_feature.shape, test_label.shape
# Out:
# ((513, 1, 5), (513, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM

# 모델의 설정
model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )
model.add(Dense(1))

# 모델의 컴파일(모델학습을 위한 학습과정 설정단계)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
early_stop = EarlyStopping(monitor='val_loss', patience=10)
modelpath = './'
checkpoint = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
# filename = os.path.join(file_path=model_path, 'tmp_checkpoint.h5')

# 모델의 실행
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])

# 테스트 정확도 출력                    
# print("\n Test Accuracy: %.4f" % model.evaluate(x_valid, y_valid))
# Out:
# Epoch 1/200
# 94/98 [===========================>..] - ETA: 0s - loss: 1265294.8750 - mae: 1123.6877
# Epoch 1: val_loss improved from inf to 1274701.25000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 13s 99ms/step - loss: 1264724.1250 - mae: 1123.4442 - val_loss: 1274701.2500 - val_mae: 1127.9882
# Epoch 2/200
# 93/98 [===========================>..] - ETA: 0s - loss: 1263469.8750 - mae: 1122.9050
# Epoch 2: val_loss improved from 1274701.25000 to 1273385.00000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 8s 87ms/step - loss: 1263791.8750 - mae: 1123.0294 - val_loss: 1273385.0000 - val_mae: 1127.4048
# Epoch 3/200
# 86/98 [=========================>....] - ETA: 0s - loss: 1261727.8750 - mae: 1122.1071
# Epoch 3: val_loss improved from 1273385.00000 to 1270658.75000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 7s 76ms/step - loss: 1261846.3750 - mae: 1122.1631 - val_loss: 1270658.7500 - val_mae: 1126.1938
# Epoch 4/200
# 89/98 [==========================>...] - ETA: 0s - loss: 1259342.5000 - mae: 1121.0463
# Epoch 4: val_loss improved from 1270658.75000 to 1266062.37500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 7s 70ms/step - loss: 1258202.5000 - mae: 1120.5337 - val_loss: 1266062.3750 - val_mae: 1124.1447
# Epoch 5/200
# 92/98 [===========================>..] - ETA: 0s - loss: 1253058.5000 - mae: 1118.2302
# Epoch 5: val_loss improved from 1266062.37500 to 1259476.50000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 8s 82ms/step - loss: 1252547.3750 - mae: 1117.9952 - val_loss: 1259476.5000 - val_mae: 1121.1957
# Epoch 6/200
# 85/98 [=========================>....] - ETA: 0s - loss: 1246007.6250 - mae: 1115.0659
# Epoch 6: val_loss improved from 1259476.50000 to 1250993.00000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 8s 84ms/step - loss: 1244908.0000 - mae: 1114.5486 - val_loss: 1250993.0000 - val_mae: 1117.3793
# Epoch 7/200
# 85/98 [=========================>....] - ETA: 0s - loss: 1237053.2500 - mae: 1110.9866
# Epoch 7: val_loss improved from 1250993.00000 to 1240819.62500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 7s 75ms/step - loss: 1235400.6250 - mae: 1110.2377 - val_loss: 1240819.6250 - val_mae: 1112.7786
# Epoch 8/200
# 87/98 [=========================>....] - ETA: 0s - loss: 1224918.6250 - mae: 1105.4504
# Epoch 8: val_loss improved from 1240819.62500 to 1229157.37500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 7s 72ms/step - loss: 1224250.2500 - mae: 1105.1517 - val_loss: 1229157.3750 - val_mae: 1107.4733
# Epoch 9/200
# 96/98 [============================>.] - ETA: 0s - loss: 1211407.3750 - mae: 1099.2542
# Epoch 9: val_loss improved from 1229157.37500 to 1216142.12500, saving model to .\
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hyeok\Desktop\PBL\py\프로젝트1\LSTM_N대비IC.ipynb 셀 24 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=18'>19</a> checkpoint = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=19'>20</a> # filename = os.path.join(file_path=model_path, 'tmp_checkpoint.h5')
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=20'>21</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=21'>22</a> # 모델의 실행
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=22'>23</a> history = model.fit(x_train, y_train,
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=23'>24</a>                     epochs=200,
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=24'>25</a>                     batch_size=16,
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=25'>26</a>                     validation_data=(x_valid, y_valid),
#      <a href='vscode-notebook-cell:/c%3A/Users/hyeok/Desktop/PBL/py/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/LSTM_N%EB%8C%80%EB%B9%84IC.ipynb#X32sZmlsZQ%3D%3D?line=26'>27</a>                     callbacks=[early_stop, checkpoint])
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\engine\training.py:1460, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1457   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1458   epoch_logs.update(val_logs)
# -> 1460 callbacks.on_epoch_end(epoch, epoch_logs)
#    1461 training_logs = epoch_logs
#    1462 if self.stop_training:
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     414 logs = self._process_logs(logs)
#     415 for callback in self.callbacks:
# --> 416   callback.on_epoch_end(epoch, logs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\callbacks.py:1389, in ModelCheckpoint.on_epoch_end(self, epoch, logs)
#    1387 # pylint: disable=protected-access
#    1388 if self.save_freq == 'epoch':
# -> 1389   self._save_model(epoch=epoch, batch=None, logs=logs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\callbacks.py:1444, in ModelCheckpoint._save_model(self, epoch, batch, logs)
#    1441     self.model.save_weights(
#    1442         filepath, overwrite=True, options=self._options)
#    1443   else:
# -> 1444     self.model.save(filepath, overwrite=True, options=self._options)
#    1445 else:
#    1446   if self.verbose > 0:
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\engine\training.py:2435, in Model.save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2393 """Saves the model to Tensorflow SavedModel or a single HDF5 file.
#    2394
#    2395 Please see `tf.keras.models.save_model` or the
#    (...)
#    2432 ```
#    2433 """
#    2434 # pylint: enable=line-too-long
# -> 2435 save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2436                 signatures, options, save_traces)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\save.py:153, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     151 else:
#     152   with generic_utils.SharedObjectSavingScope():
# --> 153     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#     154                           signatures, options, save_traces)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save.py:93, in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      91 with backend.deprecated_internal_learning_phase_scope(0):
#      92   with utils.keras_option_scope(save_traces):
# ---> 93     saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      94         model, filepath, signatures, options)
#      96   # Save all metadata to a separate file in the SavedModel directory.
#      97   metadata = generate_keras_metadata(saved_nodes, node_paths)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\saved_model\save.py:1325, in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1321 saved_model = saved_model_pb2.SavedModel()
#    1322 meta_graph_def = saved_model.meta_graphs.add()
#    1324 _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1325     _build_meta_graph(obj, signatures, options, meta_graph_def))
#    1326 saved_model.saved_model_schema_version = (
#    1327     constants.SAVED_MODEL_SCHEMA_VERSION)
#    1329 # Write the checkpoint, copy assets into the assets directory, and write out
#    1330 # the SavedModel proto itself.
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\saved_model\save.py:1491, in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1466 """Creates a MetaGraph under a save context.
#    1467
#    1468 Args:
#    (...)
#    1487   asset_info: `_AssetInfo` tuple containing external assets in the `obj`.
#    1488 """
#    1490 with save_context.save_context(options):
# -> 1491   return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\saved_model\save.py:1433, in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1431 augmented_graph_view = _AugmentedGraphView(obj)
#    1432 if signatures is None:
# -> 1433   signatures = signature_serialization.find_function_to_export(
#    1434       augmented_graph_view)
#    1436 signatures, wrapped_functions = (
#    1437     signature_serialization.canonicalize_signatures(signatures))
#    1438 signature_serialization.validate_augmented_graph_view(augmented_graph_view)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\saved_model\signature_serialization.py:103, in find_function_to_export(saveable_view)
#      99 # TODO(b/205014194): Discuss removing this behaviour. It can lead to WTFs when
#     100 # a user decides to annotate more functions with tf.function and suddenly
#     101 # serving that model way later in the process stops working.
#     102 possible_signatures = []
# --> 103 for name, child in children:
#     104   if not isinstance(child, (def_function.Function, defun.ConcreteFunction)):
#     105     continue
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\saved_model\save.py:143, in _AugmentedGraphView.list_children(self, obj)
#     140 if obj not in self._children_cache:
#     141   children = self._children_cache[obj] = {}
# --> 143   for name, child in super(_AugmentedGraphView, self).list_children(
#     144       obj,
#     145       save_type=base.SaveType.SAVEDMODEL,
#     146       cache=self._serialization_cache):
#     147     if isinstance(child, defun.ConcreteFunction):
#     148       child = self._maybe_uncache_variable_captures(child)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\training\tracking\graph_view.py:203, in ObjectGraphView.list_children(self, obj, save_type, **kwargs)
#     200 # pylint: disable=protected-access
#     201 obj._maybe_initialize_trackable()
#     202 children = [base.TrackableReference(name, ref) for name, ref
# --> 203             in obj._trackable_children(save_type, **kwargs).items()]
#     204 # pylint: enable=protected-access
#     205
#     206 # GraphView objects may define children of the root object that are not
#     207 # actually attached, e.g. a Checkpoint object's save_counter.
#     208 if obj is self.root and self._attached_dependencies:
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\engine\functional.py:409, in Functional._trackable_children(self, save_type, **kwargs)
#     406 def _trackable_children(self, save_type='checkpoint', **kwargs):
#     407   dependencies = self._layer_checkpoint_dependencies
#     408   dependencies.update(
# --> 409       super(Functional, self)._trackable_children(save_type, **kwargs))
#     410   return dependencies
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\engine\training.py:3201, in Model._trackable_children(self, save_type, **kwargs)
#    3198   self.predict_function = None
#    3199   self.train_tf_function = None
# -> 3201 children = super(Model, self)._trackable_children(save_type, **kwargs)
#    3203 if save_type == 'savedmodel':
#    3204   self.train_function = train_function
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\engine\base_layer.py:3174, in Layer._trackable_children(self, save_type, **kwargs)
#    3170   cache = kwargs['cache']
#    3171   # TODO(b/213628533): This must be called before super() to ensure
#    3172   # that any input shape changes are applied before getting the config of
#    3173   # the model.
# -> 3174   children = self._trackable_saved_model_saver.trackable_children(cache)
#    3175 else:
#    3176   children = {}
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\base_serialization.py:59, in SavedModelSaver.trackable_children(self, serialization_cache)
#      56 if not utils.should_save_traces():
#      57   return {}
# ---> 59 children = self.objects_to_serialize(serialization_cache)
#      60 children.update(self.functions_to_serialize(serialization_cache))
#      61 return children
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:68, in LayerSavedModelSaver.objects_to_serialize(self, serialization_cache)
#      67 def objects_to_serialize(self, serialization_cache):
# ---> 68   return (self._get_serialized_attributes(
#      69       serialization_cache).objects_to_serialize)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:88, in LayerSavedModelSaver._get_serialized_attributes(self, serialization_cache)
#      84 if (save_impl.should_skip_serialization(self.obj) or
#      85     self.obj._must_restore_from_config):  # pylint: disable=protected-access
#      86   return serialized_attr
# ---> 88 object_dict, function_dict = self._get_serialized_attributes_internal(
#      89     serialization_cache)
#      91 serialized_attr.set_and_validate_objects(object_dict)
#      92 serialized_attr.set_and_validate_functions(function_dict)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\model_serialization.py:56, in ModelSavedModelSaver._get_serialized_attributes_internal(self, serialization_cache)
#      51   default_signature = save_impl.default_save_signature(self.obj)
#      53 # Other than the default signature function, all other attributes match with
#      54 # the ones serialized by Layer.
#      55 objects, functions = (
# ---> 56     super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57         serialization_cache))
#      58 functions['_default_save_signature'] = default_signature
#      59 return objects, functions
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:98, in LayerSavedModelSaver._get_serialized_attributes_internal(self, serialization_cache)
#      96 """Returns dictionary of serialized attributes."""
#      97 objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# ---> 98 functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#      99 # Attribute validator requires that the default save signature is added to
#     100 # function dict, even if the value is None.
#     101 functions['_default_save_signature'] = None
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:197, in wrap_layer_functions(layer, serialization_cache)
#     195     for fn in fns.values():
#     196       if fn is not None and not isinstance(fn, LayerCall):
# --> 197         fn.get_concrete_function()
#     199 # Restore overwritten functions and losses
#     200 _restore_child_layer_functions(original_fns)
#
# File c:\Users\hyeok\anaconda3\lib\contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:359, in tracing_scope()
#     357 if training is not None:
#     358   with backend.deprecated_internal_learning_phase_scope(training):
# --> 359     fn.get_concrete_function(*args, **kwargs)
#     360 else:
#     361   fn.get_concrete_function(*args, **kwargs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:1239, in Function.get_concrete_function(self, *args, **kwargs)
#    1237 def get_concrete_function(self, *args, **kwargs):
#    1238   # Implements GenericFunction.get_concrete_function.
# -> 1239   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1240   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1241   return concrete
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:1230, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1225   return self._stateless_fn._get_concrete_function_garbage_collected(  # pylint: disable=protected-access
#    1226       *args, **kwargs)
#    1227 elif self._stateful_fn is not None:
#    1228   # In this case we have not created variables on the first call. So we can
#    1229   # run the first trace but we should fail if variables are created.
# -> 1230   concrete = self._stateful_fn._get_concrete_function_garbage_collected(  # pylint: disable=protected-access
#    1231       *args, **kwargs)
#    1232   if self._created_variables:
#    1233     raise ValueError("Creating variables on a non-first call to a function"
#    1234                      " decorated with tf.function.")
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2533, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2531   args, kwargs = None, None
#    2532 with self._lock:
# -> 2533   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2534   seen_names = set()
#    2535   captured = object_identity.ObjectIdentitySet(
#    2536       graph_function.graph.internal_captures)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:572, in layer_call_wrapper.<locals>.wrapper(*args, **kwargs)
#     567 with base_layer_utils.call_context().enter(
#     568     layer, inputs=inputs, build_graph=False, training=training,
#     569     saving=True):
#     570   with autocast_variable.enable_auto_cast_variables(
#     571       layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 572     ret = method(*args, **kwargs)
#     573 _restore_layer_losses(original_losses)
#     574 return ret
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:168, in maybe_add_training_arg.<locals>.wrap_with_training_arg(*args, **kwargs)
#     165   set_training_arg(training, training_arg_index, args, kwargs)
#     166   return wrapped_call(*args, **kwargs)
# --> 168 return control_flow_util.smart_cond(
#     169     training, lambda: replace_training_and_call(True),
#     170     lambda: replace_training_and_call(False))
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\utils\control_flow_util.py:105, in smart_cond(pred, true_fn, false_fn, name)
#     102 if isinstance(pred, tf.Variable):
#     103   return tf.cond(
#     104       pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105 return tf.__internal__.smart_cond.smart_cond(
#     106     pred, true_fn=true_fn, false_fn=false_fn, name=name)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\smart_cond.py:53, in smart_cond(pred, true_fn, false_fn, name)
#      51 if pred_value is not None:
#      52   if pred_value:
# ---> 53     return true_fn()
#      54   else:
#      55     return false_fn()
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:169, in maybe_add_training_arg.<locals>.wrap_with_training_arg.<locals>.<lambda>()
#     165   set_training_arg(training, training_arg_index, args, kwargs)
#     166   return wrapped_call(*args, **kwargs)
#     168 return control_flow_util.smart_cond(
# --> 169     training, lambda: replace_training_and_call(True),
#     170     lambda: replace_training_and_call(False))
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:166, in maybe_add_training_arg.<locals>.wrap_with_training_arg.<locals>.replace_training_and_call(training)
#     164 def replace_training_and_call(training):
#     165   set_training_arg(training, training_arg_index, args, kwargs)
# --> 166   return wrapped_call(*args, **kwargs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:652, in _extract_outputs_from_fn.<locals>.call(inputs, *args, **kwargs)
#     651 def call(inputs, *args, **kwargs):
# --> 652   return call_and_return_conditional_losses(inputs, *args, **kwargs)[0]
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:610, in LayerCall.__call__(self, *args, **kwargs)
#     608 def __call__(self, *args, **kwargs):
#     609   self._maybe_trace(args, kwargs)
# --> 610   return self.wrapped_call(*args, **kwargs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2452, in Function.__call__(self, *args, **kwargs)
#    2449 """Calls a graph function specialized to the inputs."""
#    2450 with self._lock:
#    2451   (graph_function,
# -> 2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:572, in layer_call_wrapper.<locals>.wrapper(*args, **kwargs)
#     567 with base_layer_utils.call_context().enter(
#     568     layer, inputs=inputs, build_graph=False, training=training,
#     569     saving=True):
#     570   with autocast_variable.enable_auto_cast_variables(
#     571       layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 572     ret = method(*args, **kwargs)
#     573 _restore_layer_losses(original_losses)
#     574 return ret
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:168, in maybe_add_training_arg.<locals>.wrap_with_training_arg(*args, **kwargs)
#     165   set_training_arg(training, training_arg_index, args, kwargs)
#     166   return wrapped_call(*args, **kwargs)
# --> 168 return control_flow_util.smart_cond(
#     169     training, lambda: replace_training_and_call(True),
#     170     lambda: replace_training_and_call(False))
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\utils\control_flow_util.py:105, in smart_cond(pred, true_fn, false_fn, name)
#     102 if isinstance(pred, tf.Variable):
#     103   return tf.cond(
#     104       pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105 return tf.__internal__.smart_cond.smart_cond(
#     106     pred, true_fn=true_fn, false_fn=false_fn, name=name)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\smart_cond.py:53, in smart_cond(pred, true_fn, false_fn, name)
#      51 if pred_value is not None:
#      52   if pred_value:
# ---> 53     return true_fn()
#      54   else:
#      55     return false_fn()
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:169, in maybe_add_training_arg.<locals>.wrap_with_training_arg.<locals>.<lambda>()
#     165   set_training_arg(training, training_arg_index, args, kwargs)
#     166   return wrapped_call(*args, **kwargs)
#     168 return control_flow_util.smart_cond(
# --> 169     training, lambda: replace_training_and_call(True),
#     170     lambda: replace_training_and_call(False))
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\utils.py:166, in maybe_add_training_arg.<locals>.wrap_with_training_arg.<locals>.replace_training_and_call(training)
#     164 def replace_training_and_call(training):
#     165   set_training_arg(training, training_arg_index, args, kwargs)
# --> 166   return wrapped_call(*args, **kwargs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\saving\saved_model\save_impl.py:634, in _wrap_call_and_conditional_losses.<locals>.call_and_return_conditional_losses(*args, **kwargs)
#     632 def call_and_return_conditional_losses(*args, **kwargs):
#     633   """Returns layer (call_output, conditional losses) tuple."""
# --> 634   call_output = layer_call(*args, **kwargs)
#     635   if version_utils.is_v1_layer_or_model(layer):
#     636     conditional_losses = layer.get_losses_for(
#     637         _filtered_inputs([args, kwargs]))
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\layers\rnn\lstm.py:574, in LSTM.call(self, inputs, mask, training, initial_state)
#     571   def step(inputs, states):
#     572     return self.cell(inputs, states, **kwargs)
# --> 574   last_output, outputs, states = backend.rnn(
#     575       step,
#     576       inputs,
#     577       initial_state,
#     578       constants=None,
#     579       go_backwards=self.go_backwards,
#     580       mask=mask,
#     581       unroll=self.unroll,
#     582       input_length=row_lengths if row_lengths is not None else timesteps,
#     583       time_major=self.time_major,
#     584       zero_output_for_mask=self.zero_output_for_mask,
#     585       return_all_outputs=self.return_sequences)
#     586   runtime = gru_lstm_utils.runtime(gru_lstm_utils.RUNTIME_UNKNOWN)
#     587 else:
#     588   # Use the new defun approach for backend implementation swap.
#     589   # Note that different implementations need to have same function
#     590   # signature, eg, the tensor parameters need to have same shape and dtypes.
#     591   # Since the cuDNN has an extra set of bias, those bias will be passed to
#     592   # both normal and cuDNN implementations.
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\keras\backend.py:4776, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#    4773     new_states = tf.nest.pack_sequence_as(initial_states, flat_new_state)
#    4774     return (time + 1, output_ta_t) + tuple(new_states)
# -> 4776   final_outputs = tf.compat.v1.while_loop(
#    4777       body=_step,
#    4778       loop_vars=(time, output_ta) + states,
#    4779       **while_loop_kwargs)
#    4780   new_states = final_outputs[2:]
#    4782 output_ta = final_outputs[1]
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2705, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2702 executing_eagerly = context.executing_eagerly()
#    2703 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#    2704     not executing_eagerly):
# -> 2705   return while_v2.while_loop(
#    2706       cond,
#    2707       body,
#    2708       loop_vars,
#    2709       shape_invariants=shape_invariants,
#    2710       parallel_iterations=parallel_iterations,
#    2711       maximum_iterations=maximum_iterations,
#    2712       name=name,
#    2713       return_same_structure=return_same_structure,
#    2714       back_prop=back_prop)
#    2716 with ops.name_scope(name, "while", loop_vars):
#    2717   if not loop_vars:
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\while_v2.py:298, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     294   orig_loop_vars_range = slice(first_loop_var_index,
#     295                                first_loop_var_index + num_flattened_outputs)
#     296   output_shapes[orig_loop_vars_range] = flat_shape_invariants
# --> 298   outputs = _build_while_op(
#     299       flattened_loop_vars,
#     300       cond_graph,
#     301       body_graph,
#     302       output_shapes=output_shapes,
#     303       parallel_iterations=parallel_iterations,
#     304       name=scope,
#     305       num_original_outputs=num_original_outputs,
#     306       stateful_parallelism=stateful_parallelism)
#     307 if not ops.get_default_graph().building_function:
#     308   # In V1 graph mode, return identities for each output of the While op,
#     309   # rather than the output of the While op directly. This makes pruning work
#    (...)
#     313   # lowering, each output identity op will end up with only the appropriate
#     314   # exit op as input.
#     315   outputs = tuple(array_ops.identity(t) for t in outputs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\while_v2.py:499, in _build_while_op(loop_vars, cond_graph, body_graph, output_shapes, parallel_iterations, name, num_original_outputs, stateful_parallelism)
#     497   while_op._body_graph = body_graph
#     498   return tensors
# --> 499 return util.run_as_function_for_tape_gradients(_make_op, loop_vars)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_util_v2.py:376, in run_as_function_for_tape_gradients(make_op, inputs)
#     374   return results
#     375 else:
# --> 376   return make_op(inputs)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\while_v2.py:475, in _build_while_op.<locals>._make_op(inputs)
#     474 def _make_op(inputs):
# --> 475   while_op, tensors = util.get_op_and_outputs(op_fn(
#     476       inputs,
#     477       util.create_new_tf_function(cond_graph),
#     478       util.create_new_tf_function(body_graph),
#     479       output_shapes=output_shapes,
#     480       parallel_iterations=parallel_iterations,
#     481       name=name))
#     482   _copy_handle_data(body_graph.outputs, tensors)
#     483   util.maybe_set_lowering_attr(while_op)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\ops\gen_functional_ops.py:1255, in _while(input, cond, body, output_shapes, parallel_iterations, name)
#    1253   parallel_iterations = 10
#    1254 parallel_iterations = _execute.make_int(parallel_iterations, "parallel_iterations")
# -> 1255 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    1256       "While", input=input, cond=cond, body=body,
#    1257                output_shapes=output_shapes,
#    1258                parallel_iterations=parallel_iterations, name=name)
#    1259 _result = _outputs[:]
#    1260 if not _result:
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:694, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     692   inp = self.capture(inp)
#     693   captured_inputs.append(inp)
# --> 694 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     695     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     696     compute_device)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3754, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3751 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3752 # Session.run call cannot occur between creating and mutating the op.
#    3753 with self._mutation_lock():
# -> 3754   ret = Operation(
#    3755       node_def,
#    3756       self,
#    3757       inputs=inputs,
#    3758       output_types=dtypes,
#    3759       control_inputs=control_inputs,
#    3760       input_types=input_types,
#    3761       original_op=self._default_original_op,
#    3762       op_def=op_def)
#    3763   self._create_op_helper(ret, compute_device=compute_device)
#    3764 return ret
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2129, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2127   if op_def is None:
#    2128     op_def = self._graph._get_op_def(node_def.op)
# -> 2129   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2130                             control_input_ops, op_def)
#    2131   name = compat.as_str(node_def.name)
#    2133 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hyeok\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1960, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1956   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1957                                          serialized)
#    1959 try:
# -> 1960   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1961 except errors.InvalidArgumentError as e:
#    1962   # Convert to ValueError for backwards compatibility.
#    1963   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
pred = model.predict(test_feature)

import matplotlib.pyplot as plt 

plt.figure(figsize=(16, 10))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.grid()
plt.show()
# Out:
# 17/17 [==============================] - 0s 1ms/step

# %%
import pandas as pd
import numpy as np

df_ex = pd.read_excel('./xlsx/df_ex.xlsx')
df_ex= df_ex.set_index("DateTime")


df_ex_data=df_ex[['대비_crs_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_ndf', '전일종가_ex']]
df_ex_target = df_ex["종가"]

# %%
df_ex_data.feature = df_ex_data.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMadf_ex_dataScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(df_ex_data)
data_scaled = scaler.transform(df_ex_data)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
df_ex_data_scaled = pd.DataFrame(data = data_scaled, columns=df_ex_data.feature)

df_ex_data_scaled.index = df_ex_data.index # 인덱스가 달라서 똑같이 설정

# df_ex_data_scaled = df_ex_data_scaled.dropna()
df_ex_data_scaled
# Out:
#             대비_crs_1Y  대비_국고_3Y  대비_국고_5Y    대비_ndf   전일종가_ex
# DateTime
# 2012-08-03  -0.207333 -0.326540 -1.874896  0.184855 -0.076063
# 2012-08-06  -0.004827  0.156825 -0.004534 -0.451826 -0.021997
# 2012-08-07   0.400185 -0.004297 -0.004534  0.019790 -0.123154
# 2012-08-08   0.197679 -0.326540 -0.538923  0.055161 -0.126642
# 2012-08-09   1.817726  0.962434  1.331439  0.102323 -0.135362
# ...               ...       ...       ...       ...       ...
# 2022-08-19   0.197679  1.123555  2.400217  0.564506  3.220249
# 2022-08-22  -0.409839  0.801312  1.064244  0.404157  3.310941
# 2022-08-23  -0.207333  0.156825 -0.806118  0.366427  3.553368
# 2022-08-24   0.197679  0.962434  2.934606 -0.204228  3.652781
# 2022-08-25   1.210208  3.540381  5.339358  0.066951  3.593482
#
# [2475 rows x 5 columns]

# %%
X_train = df_ex_data_scaled[['대비_crs_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_ndf', '전일종가_ex']][:2457]
X_test = df_ex_data_scaled[['대비_crs_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_ndf', '전일종가_ex']][2457:]
y_train =  df_ex_target[:2457]
y_test =  df_ex_target[2457:]

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error


from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)

y_pred = mlr.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 46.32380831917489, RMSE :  6.806, MAE: 6.806
# Variance score :  0.796

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.title(' 환율 예측')
plt.plot(y_test.index, y_test.values, label="test")
plt.plot(y_test.index, y_pred, label="pred")
plt.legend(loc='best')
plt.grid()
plt.show()
