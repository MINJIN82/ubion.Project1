# %%
import pandas as pd
import numpy as np

df = pd.read_excel("./xlsx/시차상관분석4Data.xlsx",index_col=0)

df = df.set_index("DateTime")
df
# Out:
#             Unnamed: 0   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  \
# DateTime
# 2012-08-02           1  1131.7       2.820       2.690       2.690
# 2012-08-03           2  1134.8       2.790       2.660       2.660
# 2012-08-06           3  1129.0       2.810       2.680       2.680
# 2012-08-07           4  1128.8       2.820       2.680       2.680
# 2012-08-08           5  1128.3       2.830       2.700       2.700
# ...                ...     ...         ...         ...         ...
# 2022-07-25        2455  1313.7       3.165       3.235       3.205
# 2022-07-26        2456  1307.6       3.155       3.215       3.175
# 2022-07-27        2457  1313.3       3.145       3.165       3.115
# 2022-07-28        2458  1296.1       3.175       3.205       3.165
# 2022-07-29        2459  1299.1       3.105       3.065       3.025
#
#             5Y_Mid_irs  10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  \
# DateTime                                                                 ...
# 2012-08-02       2.720        2.860        2.08       1.845        1.85  ...
# 2012-08-03       2.690        2.840        2.07       1.830        1.83  ...
# 2012-08-06       2.710        2.850        2.07       1.805        1.80  ...
# 2012-08-07       2.720        2.870        2.09       1.820        1.80  ...
# 2012-08-08       2.740        2.900        2.10       1.820        1.80  ...
# ...                ...          ...         ...         ...         ...  ...
# 2022-07-25       3.125        2.965        2.55       2.730        2.71  ...
# 2022-07-26       3.095        2.935        2.56       2.700        2.68  ...
# 2022-07-27       3.035        2.875        2.57       2.690        2.67  ...
# 2022-07-28       3.085        2.945        2.61       2.730        2.71  ...
# 2022-07-29       2.945        2.825        2.50       2.560        2.56  ...
#
#             국고10년대비  통안1년대비  통안2년대비  전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  \
# DateTime
# 2012-08-02    -0.21   -0.03    0.02          2.0          8.0          9.0
# 2012-08-03    -0.03   -0.03    0.00          2.0          1.5          1.0
# 2012-08-06    -0.03   -0.01    0.02         -2.0         -4.5         -5.0
# 2012-08-07    -0.04   -0.01   -0.01          1.0          1.5          0.0
# 2012-08-08    -0.04   -0.06   -0.03          0.0         -2.0         -2.0
# ...             ...     ...     ...          ...          ...          ...
# 2022-07-25    -0.11    0.05    0.00         -4.0         -1.0          0.0
# 2022-07-26    -0.08    0.01   -0.05          2.0         -1.0          0.0
# 2022-07-27     0.01   -0.01   -0.02          2.0          4.0          5.0
# 2022-07-28     0.06    0.00    0.00          1.0          0.0         -1.0
# 2022-07-29     0.02    0.12    0.01         -4.0         -3.0         -1.0
#
#             전일비_5Y_베이시스  전일비_10Y_베이시스  전날 종가_ex  종가_NDF차이
# DateTime
# 2012-08-02          9.0           9.0    1126.5     -7.50
# 2012-08-03         -5.0         -13.0    1131.7     -6.30
# 2012-08-06         -6.0          -5.0    1134.8      6.30
# 2012-08-07         -8.0         -10.0    1129.0      0.00
# 2012-08-08         -4.0          -7.0    1128.8     -1.45
# ...                 ...           ...       ...       ...
# 2022-07-25         -2.0           0.0    1313.0      3.15
# 2022-07-26          1.0           1.0    1313.7      2.70
# 2022-07-27          5.0           5.0    1307.6     -2.90
# 2022-07-28         -2.0          -5.0    1313.3      7.30
# 2022-07-29          5.0           3.0    1296.1      0.35
#
# [2459 rows x 51 columns]

# %%
df["종가_NDF차이"][950:1000]
# Out:
# DateTime
# 2016-06-14      -0.100
# 2016-06-15      -3.900
# 2016-06-16       2.300
# 2016-06-17      -2.100
# 2016-06-20       1.700
# 2016-06-21      -0.750
# 2016-06-22       2.100
# 2016-06-23       2.650
# 2016-06-24       7.700
# 2016-06-27       6.400
# 2016-06-28       1.050
# 2016-06-29       3.800
# 2016-06-30       5.700
# 2016-07-01      -1.200
# 2016-07-04      -6.500
# 2016-07-05      -1.600
# 2016-07-06      -4.350
# 2016-07-07       5.450
# 2016-07-08      -4.500
# 2016-07-11      10.050
# 2016-07-12      -5.500
# 2016-07-13       3.500
# 2016-07-14      -0.100
# 2016-07-15       4.900
# 2016-07-18      -7.100
# 2016-07-19       0.050
# 2016-07-20      -6.750
# 2016-07-21      -2.250
# 2016-07-22      -3.100
# 2016-07-25      -1.350
# 2016-07-26      -6.500
# 2016-07-27      -3.600
# 2016-07-28       2.700
# 2016-07-29      -0.500
# 2016-08-01    1118.955
# 2016-08-02    1106.765
# 2016-08-03    1108.750
# 2016-08-04    1116.350
# 2016-08-05    1112.765
# 2016-08-08    1109.145
# 2016-08-09    1107.045
# 2016-08-10    1104.870
# 2016-08-11    1094.160
# 2016-08-12    1098.260
# 2016-08-16    1102.060
# 2016-08-17    1090.960
# 2016-08-18    1107.055
# 2016-08-19    1105.950
# 2016-08-22    1116.345
# 2016-08-23    1125.245
# Name: 종가_NDF차이, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '종가_ex', '1Y_Mid_irs', '2Y_Mid_irs', '3Y_Mid_irs',
#        '5Y_Mid_irs', '10Y_Mid_irs', '1Y_Mid_crs', '2Y_Mid_crs', '3Y_Mid_crs',
#        '5Y_Mid_crs', '10Y_Mid_crs', '국고1년', '국고3년', '국고5년', '국고10년', '통안364일',
#        '통안2년', 'Mid_ndf', '전일비_ndf', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스',
#        '5Y_베이시스', '10Y_베이시스', 'M1_스왑포인트', '전일대비_종가_ex', '등락률_종가_ex',
#        '전일비_1Y_irs', '전일비_2Y_irs', '전일비_3Y_irs', '전일비_5Y_irs', '전일비_10Y_irs',
#        '전일비_1Y_crs', '전일비_2Y_crs', '전일비_3Y_crs', '전일비_5Y_crs', '전일비_10Y_crs',
#        '국고1년대비', '국고3년대비', '국고5년대비', '국고10년대비', '통안1년대비', '통안2년대비',
#        '전일비_1Y_베이시스', '전일비_2Y_베이시스', '전일비_3Y_베이시스', '전일비_5Y_베이시스',
#        '전일비_10Y_베이시스', '전날 종가_ex', '종가_NDF차이'],
#       dtype='object')

# %%
df['종가_NDF차이'] = df['전날 종가_ex'] -df['Mid_ndf']

# %%
x = df[['전일비_1Y_베이시스', '전일비_2Y_베이시스', '전일비_3Y_베이시스', '전일비_5Y_베이시스','전일비_10Y_베이시스', 
            '국고1년대비', '국고3년대비', '국고5년대비', '국고10년대비', '통안1년대비', '통안2년대비',
            '종가_NDF차이', 'M1_스왑포인트', '전날 종가_ex']]
y = df['종가_ex']

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\hyeok\AppData\Local\Temp\ipykernel_19508\1602819918.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  전일비_5Y_베이시스  전일비_10Y_베이시스  \
# DateTime
# 2012-08-02     0.348741     1.544080     1.437744     1.627899      1.488363
# 2012-08-03     0.348741     0.286831     0.157058    -0.910410     -2.158344
# 2012-08-06    -0.350946    -0.873707    -0.803456    -1.091718     -0.832269
# 2012-08-07     0.173819     0.286831    -0.003027    -1.454333     -1.661066
# 2012-08-08    -0.001103    -0.390150    -0.323199    -0.729102     -1.163788
# ...                 ...          ...          ...          ...           ...
# 2022-07-25    -0.700790    -0.196727    -0.003027    -0.366487     -0.003472
# 2022-07-26     0.348741    -0.196727    -0.003027     0.177437      0.162288
# 2022-07-27     0.348741     0.770388     0.797401     0.902668      0.825326
# 2022-07-28     0.173819    -0.003304    -0.163113    -0.366487     -0.832269
# 2022-07-29    -0.700790    -0.583573    -0.163113     0.902668      0.493807
#
#               국고1년대비    국고3년대비    국고5년대비   국고10년대비    통안1년대비    통안2년대비  \
# DateTime
# 2012-08-02  1.898958 -0.488709 -1.584904 -5.377146 -0.325433  0.267777
# 2012-08-03  0.051587  0.004075  0.035699 -0.767092 -0.325433  0.014814
# 2012-08-06  0.051587 -0.160187  2.466603 -0.767092 -0.108742  0.267777
# 2012-08-07 -0.564203 -0.160187 -0.504502 -1.023207 -0.108742 -0.111668
# 2012-08-08 -0.564203 -0.324448  0.035699 -1.023207 -0.650470 -0.364632
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -1.179994  1.975212 -0.234402 -2.816005  0.541331  0.014814
# 2022-07-26  0.667378  0.825382 -1.314804 -2.047663  0.107949 -0.617595
# 2022-07-27  0.051587  0.661120 -1.584904  0.257364 -0.108742 -0.238150
# 2022-07-28  1.283168  1.153905  0.035699  1.537934 -0.000397  0.014814
# 2022-07-29  0.667378 -0.652971  0.305799  0.513478  1.299750  0.141295
#
#             종가_NDF차이  M1_스왑포인트  전날 종가_ex
# DateTime
# 2012-08-02 -0.495597  1.909409 -0.149841
# 2012-08-03 -0.415698  1.818881 -0.056232
# 2012-08-06  0.423243  1.818881 -0.000426
# 2012-08-07  0.003773  1.909409 -0.104837
# 2012-08-08 -0.092772  1.818881 -0.108437
# ...              ...       ...       ...
# 2022-07-25  0.213508 -0.896960  3.207485
# 2022-07-26  0.183546 -0.987488  3.220086
# 2022-07-27 -0.189317 -0.851696  3.110275
# 2022-07-28  0.489826 -0.942224  3.212885
# 2022-07-29  0.027076 -0.896960  2.903255
#
# [2459 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     3.107495   전일비_1Y_베이시스
# 1     5.877984   전일비_2Y_베이시스
# 2     2.400764   전일비_3Y_베이시스
# 3     4.756365   전일비_5Y_베이시스
# 4     3.229687  전일비_10Y_베이시스
# 5     1.006221        국고1년대비
# 6     1.002852        국고3년대비
# 7     1.005182        국고5년대비
# 8     1.006059       국고10년대비
# 9     1.003521        통안1년대비
# 10    1.000687        통안2년대비
# 11    1.018009      종가_NDF차이
# 12    1.184734      M1_스왑포인트
# 13    1.173312      전날 종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.837e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:05:36   Log-Likelihood:                -7635.4
# No. Observations:                2459   AIC:                         1.530e+04
# Df Residuals:                    2444   BIC:                         1.539e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.109   1.04e+04      0.000    1134.680    1135.108
# 전일비_1Y_베이시스     -1.2439      0.193     -6.462      0.000      -1.621      -0.866
# 전일비_2Y_베이시스     -0.2336      0.265     -0.882      0.378      -0.753       0.286
# 전일비_3Y_베이시스     -0.1521      0.169     -0.899      0.369      -0.484       0.180
# 전일비_5Y_베이시스      0.0757      0.238      0.318      0.751      -0.391       0.543
# 전일비_10Y_베이시스     0.2859      0.196      1.457      0.145      -0.099       0.671
# 국고1년대비          -0.2192      0.110     -2.001      0.046      -0.434      -0.004
# 국고3년대비          -0.4107      0.109     -3.756      0.000      -0.625      -0.196
# 국고5년대비          -0.3675      0.109     -3.357      0.001      -0.582      -0.153
# 국고10년대비         -0.3020      0.110     -2.757      0.006      -0.517      -0.087
# 통안1년대비          -0.2355      0.109     -2.153      0.031      -0.450      -0.021
# 통안2년대비          -0.3601      0.109     -3.296      0.001      -0.574      -0.146
# 종가_NDF차이        -0.9419      0.110     -8.548      0.000      -1.158      -0.726
# M1_스왑포인트        -0.2663      0.119     -2.241      0.025      -0.499      -0.033
# 전날 종가_ex        55.3806      0.118    468.192      0.000      55.149      55.613
# ==============================================================================
# Omnibus:                      129.274   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.738
# Skew:                           0.197   Prob(JB):                     2.13e-88
# Kurtosis:                       4.946   Cond. No.                         5.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_5Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.980e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:05:50   Log-Likelihood:                -7635.4
# No. Observations:                2459   AIC:                         1.530e+04
# Df Residuals:                    2445   BIC:                         1.538e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.109   1.04e+04      0.000    1134.680    1135.108
# 전일비_1Y_베이시스     -1.2424      0.192     -6.457      0.000      -1.620      -0.865
# 전일비_2Y_베이시스     -0.2010      0.244     -0.823      0.410      -0.680       0.278
# 전일비_3Y_베이시스     -0.1433      0.167     -0.859      0.391      -0.471       0.184
# 전일비_10Y_베이시스     0.3166      0.171      1.852      0.064      -0.019       0.652
# 국고1년대비          -0.2190      0.110     -2.000      0.046      -0.434      -0.004
# 국고3년대비          -0.4108      0.109     -3.757      0.000      -0.625      -0.196
# 국고5년대비          -0.3681      0.109     -3.364      0.001      -0.583      -0.154
# 국고10년대비         -0.3023      0.110     -2.760      0.006      -0.517      -0.088
# 통안1년대비          -0.2355      0.109     -2.153      0.031      -0.450      -0.021
# 통안2년대비          -0.3598      0.109     -3.294      0.001      -0.574      -0.146
# 종가_NDF차이        -0.9419      0.110     -8.550      0.000      -1.158      -0.726
# M1_스왑포인트        -0.2664      0.119     -2.241      0.025      -0.499      -0.033
# 전날 종가_ex        55.3804      0.118    468.287      0.000      55.148      55.612
# ==============================================================================
# Omnibus:                      129.441   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              405.083
# Skew:                           0.197   Prob(JB):                     1.09e-88
# Kurtosis:                       4.949   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_2Y_베이시스', '전일비_3Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 2.339e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:05:57   Log-Likelihood:                -7636.5
# No. Observations:                2459   AIC:                         1.530e+04
# Df Residuals:                    2447   BIC:                         1.537e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.109   1.04e+04      0.000    1134.680    1135.108
# 전일비_1Y_베이시스     -1.4129      0.141    -10.039      0.000      -1.689      -1.137
# 전일비_10Y_베이시스     0.1785      0.140      1.270      0.204      -0.097       0.454
# 국고1년대비          -0.2196      0.110     -2.005      0.045      -0.434      -0.005
# 국고3년대비          -0.4087      0.109     -3.739      0.000      -0.623      -0.194
# 국고5년대비          -0.3673      0.109     -3.356      0.001      -0.582      -0.153
# 국고10년대비         -0.2978      0.109     -2.721      0.007      -0.512      -0.083
# 통안1년대비          -0.2338      0.109     -2.138      0.033      -0.448      -0.019
# 통안2년대비          -0.3594      0.109     -3.291      0.001      -0.574      -0.145
# 종가_NDF차이        -0.9443      0.110     -8.573      0.000      -1.160      -0.728
# M1_스왑포인트        -0.2671      0.119     -2.247      0.025      -0.500      -0.034
# 전날 종가_ex        55.3799      0.118    468.268      0.000      55.148      55.612
# ==============================================================================
# Omnibus:                      129.129   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.450
# Skew:                           0.205   Prob(JB):                     8.16e-87
# Kurtosis:                       4.924   Cond. No.                         2.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_10Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 2.573e+04
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:00:40   Log-Likelihood:                -7637.3
# No. Observations:                2459   AIC:                         1.530e+04
# Df Residuals:                    2448   BIC:                         1.536e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8939      0.109   1.04e+04      0.000    1134.680    1135.108
# 전일비_1Y_베이시스    -1.3009      0.110    -11.862      0.000      -1.516      -1.086
# 국고1년대비         -0.2207      0.110     -2.015      0.044      -0.435      -0.006
# 국고3년대비         -0.4094      0.109     -3.745      0.000      -0.624      -0.195
# 국고5년대비         -0.3665      0.109     -3.348      0.001      -0.581      -0.152
# 국고10년대비        -0.2948      0.109     -2.694      0.007      -0.509      -0.080
# 통안1년대비         -0.2325      0.109     -2.125      0.034      -0.447      -0.018
# 통안2년대비         -0.3586      0.109     -3.283      0.001      -0.573      -0.144
# 종가_NDF차이       -0.9443      0.110     -8.572      0.000      -1.160      -0.728
# M1_스왑포인트       -0.2694      0.119     -2.267      0.023      -0.502      -0.036
# 전날 종가_ex       55.3772      0.118    468.260      0.000      55.145      55.609
# ==============================================================================
# Omnibus:                      131.725   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              412.695
# Skew:                           0.205   Prob(JB):                     2.42e-90
# Kurtosis:                       4.965   Cond. No.                         1.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 27.862858766326777, RMSE :  5.279, MAE: 5.279
# Variance score :  0.991

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (9.666147433304229,
#  array([ 4.39314575,  6.61293474,  5.5470977 , 26.81603994,  4.96151903]),
#  array([ -19.29972959,  -43.73090585,  -30.77029291, -719.09999822,
#          -24.61667111]))
