# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# 파일 불러오기
all = pd.read_excel("../엑셀/Join_data.xlsx", index_col = 0)    

# 컬럼 추출
all2 = all[['DateTime', '종가_ex','1Y_전일비_irs', '2Y_전일비_irs', '3Y_전일비_irs',
        '5Y_전일비_irs', '10Y_전일비_irs',  '1Y_전일비_crs', '2Y_전일비_crs','3Y_전일비_crs','5Y_전일비_crs','10Y_전일비_crs',
        '국고1년', '국고3년', '국고5년','국고10년', '통안364일', '통안2년', 'Mid_ndf',
        'M1_스왑포인트']]            # [[]] 대괄호 2개 사용 -> 데이터 프레임형태로 나옴

all2 = all2.set_index("DateTime")

all2['대비_국고1년'] = all2['국고1년']-all2['국고1년'].shift(1)
all2['대비_국고3년'] = all2['국고3년']-all2['국고3년'].shift(1)
all2['대비_국고5년'] = all2['국고5년']-all2['국고5년'].shift(1)
all2['대비_국고10년'] = all2['국고10년']-all2['국고10년'].shift(1)
all2['대비_통안1년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_통안2년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['등락_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)/all2['Mid_ndf']
all2['스왑포인트_1월물'] = all2["M1_스왑포인트"]/100 
all2['전일종가_ex'] = all2['종가_ex'].shift(1)

all2.rename({"1Y_전일비_irs" : "1Y_대비_irs", "2Y_전일비_irs" : "2Y_대비_irs", "3Y_전일비_irs" : "3Y_대비_irs", "5Y_전일비_irs" : "5Y_대비_irs", "10Y_전일비_irs" : "10Y_대비_irs",
            "1Y_전일비_crs" : "1Y_대비_crs", "2Y_전일비_crs" : "2Y_대비_crs", "3Y_전일비_crs" : "3Y_대비_crs", "5Y_전일비_crs" : "5Y_대비_crs", "10Y_전일비_crs" : "10Y_대비_crs"}, axis=1, inplace=True)

all2 = all2.dropna()

# 필요 칼럼만 남기기
df = all2.copy()
df = all2[["종가_ex", 
            '1Y_대비_irs', '2Y_대비_irs', '3Y_대비_irs', '5Y_대비_irs', '10Y_대비_irs', 
            '1Y_대비_crs', '2Y_대비_crs', '3Y_대비_crs', '5Y_대비_crs', '10Y_대비_crs', 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "등락_ndf", "스왑포인트_1월물", "전일종가_ex"]]

# DateTime을 인덱스로 바꿔주기
df.head()
# Out:
#              종가_ex  1Y_대비_irs  2Y_대비_irs  3Y_대비_irs  5Y_대비_irs  10Y_대비_irs  \
# DateTime
# 2012-08-02  1131.7      -0.03      -0.05      -0.05      -0.05       -0.05
# 2012-08-03  1134.8      -0.03      -0.03      -0.03      -0.03       -0.02
# 2012-08-06  1129.0       0.02       0.02       0.02       0.02        0.01
# 2012-08-07  1128.8       0.01       0.00       0.00       0.01        0.02
# 2012-08-08  1128.3       0.01       0.02       0.02       0.02        0.03
#
#             1Y_대비_crs  2Y_대비_crs  3Y_대비_crs  5Y_대비_crs  10Y_대비_crs  대비_국고1년  \
# DateTime
# 2012-08-02      -0.01      0.030       0.04       0.04        0.04    -0.03
# 2012-08-03      -0.01     -0.015      -0.02      -0.08       -0.15    -0.02
# 2012-08-06       0.00     -0.025      -0.03      -0.04       -0.04     0.01
# 2012-08-07       0.02      0.015       0.00      -0.07       -0.08    -0.01
# 2012-08-08       0.01      0.000       0.00      -0.02       -0.04    -0.01
#
#             대비_국고3년  대비_국고5년  대비_국고10년  대비_통안1년  대비_통안2년       등락_ndf  \
# DateTime
# 2012-08-02    -0.04    -0.04     -0.04    -0.03    -0.03  1133.001543
# 2012-08-03    -0.02    -0.07     -0.07    -0.02    -0.02  1137.003515
# 2012-08-06     0.01     0.00      0.00     0.01     0.01  1127.491582
# 2012-08-07     0.00     0.00      0.00    -0.01    -0.01  1128.000443
# 2012-08-08    -0.02    -0.02     -0.02    -0.01    -0.01  1129.251106
#
#             스왑포인트_1월물  전일종가_ex
# DateTime
# 2012-08-02        2.5   1126.5
# 2012-08-03        2.4   1131.7
# 2012-08-06        2.4   1134.8
# 2012-08-07        2.5   1129.0
# 2012-08-08        2.4   1128.8

# %%
x = df[['1Y_대비_irs', '2Y_대비_irs', '3Y_대비_irs', '5Y_대비_irs', '10Y_대비_irs', 
          '1Y_대비_crs', '2Y_대비_crs', '3Y_대비_crs', '5Y_대비_crs', '10Y_대비_crs', 
          "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
           "등락_ndf", "스왑포인트_1월물", "전일종가_ex"]]
y = df[["종가_ex"]]

x.feature = x.columns 
x.feature

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
#             1Y_대비_irs  2Y_대비_irs  3Y_대비_irs  5Y_대비_irs  10Y_대비_irs  1Y_대비_crs  \
# DateTime
# 2012-08-02  -0.847862  -1.216879  -0.935732  -1.045679   -1.009126  -0.205336
# 2012-08-03  -0.847862  -0.731372  -0.562274  -0.628002   -0.403231  -0.205336
# 2012-08-06   0.560374   0.482398   0.371369   0.416191    0.202663  -0.003044
# 2012-08-07   0.278727  -0.003110  -0.002088   0.207352    0.404628   0.401540
# 2012-08-08   0.278727   0.482398   0.371369   0.416191    0.606592   0.199248
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-25  -1.129510  -1.945141  -1.309189  -1.881032   -2.220914  -1.621379
# 2022-07-26  -0.284568  -0.488618  -0.562274  -0.628002   -0.605196   0.199248
# 2022-07-27  -0.284568  -1.216879  -1.122460  -1.254517   -1.211091   0.199248
# 2022-07-28   0.842021   0.967906   0.931555   1.042706    1.414452   0.806124
# 2022-07-29  -1.974451  -3.401665  -2.616289  -2.925225   -2.422879  -2.228254
#
#             2Y_대비_crs  3Y_대비_crs  5Y_대비_crs  10Y_대비_crs   대비_국고1년   대비_국고3년  \
# DateTime
# 2012-08-02   0.707523   0.905683   0.926547    0.826527 -1.698057 -0.646622
# 2012-08-03  -0.364368  -0.463000  -1.872732   -3.115507 -1.132651 -0.323869
# 2012-08-06  -0.602566  -0.691113  -0.939639   -0.833277  0.563566  0.160261
# 2012-08-07   0.350226  -0.006772  -1.639459   -1.663179 -0.567245 -0.001116
# 2012-08-08  -0.007071  -0.006772  -0.473092   -0.833277 -0.567245 -0.323869
# ...               ...        ...        ...         ...       ...       ...
# 2022-07-25  -2.150854  -1.603569  -2.572552   -2.285605 -1.132651 -0.969375
# 2022-07-26  -0.721665  -0.691113  -0.473092   -0.418326  0.563566 -0.485246
# 2022-07-27  -0.245269  -0.234886  -0.239819   -0.210850 -0.001839 -0.485246
# 2022-07-28   0.945721   0.905683   0.693274    0.411576  0.563566  0.644391
# 2022-07-29  -4.056438  -3.428479  -2.106005   -1.870654 -2.263463 -2.099012
#
#              대비_국고5년  대비_국고10년   대비_통안1년   대비_통안2년    등락_ndf  스왑포인트_1월물  \
# DateTime
# 2012-08-02 -1.079749 -1.027569 -0.325920 -0.325920 -0.015466   1.909409
# 2012-08-03 -1.890219 -1.798403 -0.217574 -0.217574  0.054987   1.818881
# 2012-08-06  0.000879  0.000209  0.107465  0.107465 -0.112468   1.818881
# 2012-08-07  0.000879  0.000209 -0.109228 -0.109228 -0.103509   1.909409
# 2012-08-08 -0.539435 -0.513680 -0.109228 -0.109228 -0.081492   1.818881
# ...              ...       ...       ...       ...       ...        ...
# 2022-07-25 -1.890219 -2.312292 -0.109228 -0.109228  3.080332  -0.896960
# 2022-07-26 -0.539435 -0.770625  0.107465  0.107465  3.100548  -0.987488
# 2022-07-27 -1.349905 -1.541458  0.215812  0.215812  3.091724  -0.851696
# 2022-07-28  0.811350  2.055766  0.215812  0.215812  3.012449  -0.942224
# 2022-07-29 -3.241004 -2.055348 -0.325920 -0.325920  2.831922  -0.896960
#
#              전일종가_ex
# DateTime
# 2012-08-02 -0.149841
# 2012-08-03 -0.056232
# 2012-08-06 -0.000426
# 2012-08-07 -0.104837
# 2012-08-08 -0.108437
# ...              ...
# 2022-07-25  3.207485
# 2022-07-26  3.220086
# 2022-07-27  3.110275
# 2022-07-28  3.212885
# 2022-07-29  2.903255
#
# [2459 rows x 19 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     9.993509   1Y_대비_irs
# 1    19.526295   2Y_대비_irs
# 2     2.662449   3Y_대비_irs
# 3     6.468456   5Y_대비_irs
# 4     5.871525  10Y_대비_irs
# 5     2.652922   1Y_대비_crs
# 6     5.263532   2Y_대비_crs
# 7     3.830192   3Y_대비_crs
# 8     6.696202   5Y_대비_crs
# 9     3.716629  10Y_대비_crs
# 10    1.896712     대비_국고1년
# 11    1.253105     대비_국고3년
# 12    6.219779     대비_국고5년
# 13    5.054265    대비_국고10년
# 14         inf     대비_통안1년
# 15         inf     대비_통안2년
# 16   14.601849      등락_ndf
# 17    1.184645   스왑포인트_1월물
# 18   15.149850     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.445e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:01   Log-Likelihood:                -7619.6
# No. Observations:                2459   AIC:                         1.528e+04
# Df Residuals:                    2440   BIC:                         1.539e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.109   1.05e+04      0.000    1134.681    1135.107
# 1Y_대비_irs      0.2636      0.343      0.768      0.443      -0.410       0.937
# 2Y_대비_irs      0.4519      0.480      0.942      0.346      -0.489       1.393
# 3Y_대비_irs      0.0027      0.177      0.015      0.988      -0.345       0.350
# 5Y_대비_irs     -0.2660      0.276     -0.963      0.336      -0.808       0.276
# 10Y_대비_irs    -0.5289      0.263     -2.010      0.045      -1.045      -0.013
# 1Y_대비_crs     -1.0469      0.177     -5.919      0.000      -1.394      -0.700
# 2Y_대비_crs     -0.2506      0.249     -1.006      0.315      -0.739       0.238
# 3Y_대비_crs     -0.4314      0.213     -2.030      0.042      -0.848      -0.015
# 5Y_대비_crs     -0.1728      0.281     -0.615      0.539      -0.724       0.378
# 10Y_대비_crs     0.1728      0.209      0.825      0.409      -0.238       0.583
# 대비_국고1년        0.1011      0.150      0.676      0.499      -0.192       0.394
# 대비_국고3년       -0.2624      0.122     -2.158      0.031      -0.501      -0.024
# 대비_국고5년        1.0184      0.271      3.761      0.000       0.487       1.549
# 대비_국고10년      -0.2424      0.244     -0.993      0.321      -0.721       0.236
# 대비_통안1년       -0.0020      0.055     -0.037      0.971      -0.110       0.106
# 대비_통안2년       -0.0020      0.055     -0.037      0.971      -0.110       0.106
# 등락_ndf         3.4046      0.415      8.205      0.000       2.591       4.218
# 스왑포인트_1월물     -0.2526      0.118     -2.138      0.033      -0.484      -0.021
# 전일종가_ex       52.0254      0.423    123.088      0.000      51.197      52.854
# ==============================================================================
# Omnibus:                      107.274   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              298.570
# Skew:                           0.172   Prob(JB):                     1.47e-65
# Kurtosis:                       4.672   Cond. No.                     3.75e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_scaled.drop(['2Y_대비_irs'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.933639   1Y_대비_irs
# 1     2.552088   3Y_대비_irs
# 2     5.803322   5Y_대비_irs
# 3     5.219861  10Y_대비_irs
# 4     2.650278   1Y_대비_crs
# 5     5.252370   2Y_대비_crs
# 6     3.827642   3Y_대비_crs
# 7     6.690821   5Y_대비_crs
# 8     3.716489  10Y_대비_crs
# 9     1.884864     대비_국고1년
# 10    1.246953     대비_국고3년
# 11    6.129910     대비_국고5년
# 12    5.040503    대비_국고10년
# 13         inf     대비_통안1년
# 14         inf     대비_통안2년
# 15   14.575520      등락_ndf
# 16    1.184642   스왑포인트_1월물
# 17   15.114976     전일종가_ex

# %%
x_scaled.drop(['전일종가_ex'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.926461   1Y_대비_irs
# 1     2.551667   3Y_대비_irs
# 2     5.802423   5Y_대비_irs
# 3     5.219047  10Y_대비_irs
# 4     2.646563   1Y_대비_crs
# 5     5.252248   2Y_대비_crs
# 6     3.827609   3Y_대비_crs
# 7     6.690690   5Y_대비_crs
# 8     3.715509  10Y_대비_crs
# 9     1.884629     대비_국고1년
# 10    1.246925     대비_국고3년
# 11    6.125574     대비_국고5년
# 12    5.039310    대비_국고10년
# 13         inf     대비_통안1년
# 14         inf     대비_통안2년
# 15    1.138804      등락_ndf
# 16    1.129613   스왑포인트_1월물

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     2123.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10050.
# No. Observations:                2459   AIC:                         2.013e+04
# Df Residuals:                    2442   BIC:                         2.023e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.292   3891.230      0.000    1134.322    1135.466
# 1Y_대비_irs      1.6488      0.578      2.853      0.004       0.516       2.782
# 3Y_대비_irs     -0.2378      0.466     -0.510      0.610      -1.151       0.676
# 5Y_대비_irs     -0.5838      0.703     -0.831      0.406      -1.961       0.794
# 10Y_대비_irs    -0.8280      0.666     -1.243      0.214      -2.135       0.479
# 1Y_대비_crs     -0.2369      0.474     -0.499      0.618      -1.167       0.693
# 2Y_대비_crs     -0.0918      0.668     -0.137      0.891      -1.402       1.219
# 3Y_대비_crs     -0.3599      0.571     -0.631      0.528      -1.479       0.759
# 5Y_대비_crs     -0.0122      0.754     -0.016      0.987      -1.492       1.467
# 10Y_대비_crs    -0.2446      0.562     -0.435      0.664      -1.347       0.858
# 대비_국고1년        0.3173      0.400      0.792      0.428      -0.468       1.102
# 대비_국고3년       -0.1835      0.326     -0.563      0.573      -0.822       0.455
# 대비_국고5년        0.1683      0.722      0.233      0.816      -1.247       1.584
# 대비_국고10년       0.2076      0.655      0.317      0.751      -1.076       1.491
# 대비_통안1년        0.0012      0.148      0.008      0.993      -0.288       0.291
# 대비_통안2년        0.0012      0.148      0.008      0.993      -0.288       0.291
# 등락_ndf        52.4554      0.311    168.538      0.000      51.845      53.066
# 스왑포인트_1월물     -3.3904      0.310    -10.937      0.000      -3.998      -2.783
# ==============================================================================
# Omnibus:                     6146.271   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73282042.581
# Skew:                          26.553   Prob(JB):                         0.00
# Kurtosis:                     847.048   Cond. No.                     5.39e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.78e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_scaled.drop(['3Y_대비_irs', '2Y_대비_crs', '대비_통안1년', '대비_통안2년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     2615.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10050.
# No. Observations:                2459   AIC:                         2.013e+04
# Df Residuals:                    2445   BIC:                         2.021e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.291   3893.395      0.000    1134.322    1135.465
# 1Y_대비_irs      1.5631      0.554      2.822      0.005       0.477       2.649
# 5Y_대비_irs     -0.6347      0.695     -0.914      0.361      -1.997       0.728
# 10Y_대비_irs    -0.8773      0.658     -1.333      0.183      -2.168       0.414
# 1Y_대비_crs     -0.2629      0.420     -0.626      0.532      -1.087       0.561
# 3Y_대비_crs     -0.3791      0.546     -0.694      0.488      -1.450       0.692
# 5Y_대비_crs     -0.0600      0.703     -0.085      0.932      -1.438       1.318
# 10Y_대비_crs    -0.2493      0.562     -0.444      0.657      -1.351       0.852
# 대비_국고1년        0.3065      0.398      0.770      0.442      -0.475       1.088
# 대비_국고3년       -0.1873      0.325     -0.576      0.565      -0.825       0.451
# 대비_국고5년        0.1590      0.721      0.220      0.826      -1.255       1.573
# 대비_국고10년       0.2100      0.654      0.321      0.748      -1.073       1.493
# 등락_ndf        52.4565      0.311    168.651      0.000      51.847      53.066
# 스왑포인트_1월물     -3.3911      0.310    -10.946      0.000      -3.999      -2.784
# ==============================================================================
# Omnibus:                     6147.194   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73358542.817
# Skew:                          26.563   Prob(JB):                         0.00
# Kurtosis:                     847.489   Cond. No.                         6.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['5Y_대비_crs', '대비_국고5년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     3093.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10050.
# No. Observations:                2459   AIC:                         2.012e+04
# Df Residuals:                    2447   BIC:                         2.019e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.291   3894.944      0.000    1134.323    1135.465
# 1Y_대비_irs      1.5541      0.551      2.820      0.005       0.474       2.635
# 5Y_대비_irs     -0.6226      0.691     -0.901      0.368      -1.978       0.733
# 10Y_대비_irs    -0.8658      0.655     -1.321      0.187      -2.151       0.419
# 1Y_대비_crs     -0.2725      0.412     -0.661      0.509      -1.081       0.536
# 3Y_대비_crs     -0.3982      0.483     -0.825      0.410      -1.345       0.548
# 10Y_대비_crs    -0.2742      0.434     -0.632      0.527      -1.124       0.576
# 대비_국고1년        0.3332      0.378      0.881      0.378      -0.408       1.074
# 대비_국고3년       -0.1775      0.322     -0.552      0.581      -0.808       0.453
# 대비_국고10년       0.3181      0.429      0.741      0.458      -0.523       1.159
# 등락_ndf        52.4560      0.311    168.737      0.000      51.846      53.066
# 스왑포인트_1월물     -3.3906      0.310    -10.950      0.000      -3.998      -2.783
# ==============================================================================
# Omnibus:                     6146.999   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73342854.120
# Skew:                          26.561   Prob(JB):                         0.00
# Kurtosis:                     847.399   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['5Y_대비_irs', '10Y_대비_crs', '대비_국고3년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     4256.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10051.
# No. Observations:                2459   AIC:                         2.012e+04
# Df Residuals:                    2450   BIC:                         2.017e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.291   3896.011      0.000    1134.323    1135.465
# 1Y_대비_irs      1.3268      0.486      2.728      0.006       0.373       2.280
# 10Y_대비_irs    -1.2213      0.546     -2.237      0.025      -2.292      -0.151
# 1Y_대비_crs     -0.3095      0.405     -0.764      0.445      -1.104       0.485
# 3Y_대비_crs     -0.5800      0.414     -1.401      0.161      -1.392       0.232
# 대비_국고1년        0.2799      0.371      0.755      0.450      -0.447       1.007
# 대비_국고10년       0.2025      0.418      0.484      0.628      -0.618       1.023
# 등락_ndf        52.4654      0.311    168.864      0.000      51.856      53.075
# 스왑포인트_1월물     -3.3904      0.310    -10.953      0.000      -3.997      -2.783
# ==============================================================================
# Omnibus:                     6149.740   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73560391.134
# Skew:                          26.590   Prob(JB):                         0.00
# Kurtosis:                     848.651   Cond. No.                         4.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['1Y_대비_crs', '대비_국고10년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     5677.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10051.
# No. Observations:                2459   AIC:                         2.012e+04
# Df Residuals:                    2452   BIC:                         2.016e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.291   3896.914      0.000    1134.323    1135.465
# 1Y_대비_irs      1.2315      0.459      2.684      0.007       0.332       2.131
# 10Y_대비_irs    -1.0681      0.472     -2.263      0.024      -1.993      -0.143
# 3Y_대비_crs     -0.7829      0.301     -2.605      0.009      -1.372      -0.194
# 대비_국고1년        0.3689      0.323      1.141      0.254      -0.265       1.003
# 등락_ndf        52.4567      0.310    168.952      0.000      51.848      53.066
# 스왑포인트_1월물     -3.3897      0.309    -10.953      0.000      -3.997      -2.783
# ==============================================================================
# Omnibus:                     6146.445   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73295091.843
# Skew:                          26.555   Prob(JB):                         0.00
# Kurtosis:                     847.123   Cond. No.                         3.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고1년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     6811.
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:10:02   Log-Likelihood:                -10052.
# No. Observations:                2459   AIC:                         2.012e+04
# Df Residuals:                    2453   BIC:                         2.015e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.291   3896.675      0.000    1134.323    1135.465
# 1Y_대비_irs      1.2597      0.458      2.750      0.006       0.361       2.158
# 10Y_대비_irs    -0.9506      0.461     -2.064      0.039      -1.854      -0.047
# 3Y_대비_crs     -0.7333      0.297     -2.465      0.014      -1.316      -0.150
# 등락_ndf        52.4834      0.310    169.510      0.000      51.876      53.091
# 스왑포인트_1월물     -3.3845      0.309    -10.937      0.000      -3.991      -2.778
# ==============================================================================
# Omnibus:                     6147.980   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         73419866.766
# Skew:                          26.571   Prob(JB):                         0.00
# Kurtosis:                     847.842   Cond. No.                         2.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=30)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 43.51670182497547, RMSE :  6.597, MAE: 6.597
# Variance score :  0.986
