# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# 파일 불러오기
all = pd.read_excel("./xlsx/corona_data.xlsx", index_col = 0)              # index_col = 0 파일 읽어올 떄 "Unnamed: 0" 컬럼이 추가돼서 해당 컬럼 제거

# 컬럼 추출
all2 = all[['DateTime', '종가_ex', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스', '10Y_베이시스',
        '국고1년', '국고3년', '국고5년','국고10년', '통안364일', '통안2년', 'Mid_ndf',
        'M1_스왑포인트']]            # [[]] 대괄호 2개 사용 -> 데이터 프레임형태로 나옴

all2 = all2.set_index("DateTime")

all2['대비_베이시스1년'] = all2['1Y_베이시스']-all2['1Y_베이시스'].shift(1)
all2['대비_베이시스2년'] = all2['2Y_베이시스']-all2['2Y_베이시스'].shift(1)
all2['대비_베이시스3년'] = all2['3Y_베이시스']-all2['3Y_베이시스'].shift(1)
all2['대비_베이시스5년'] =all2['5Y_베이시스']-all2['5Y_베이시스'].shift(1)
all2['대비_베이시스10년'] = all2['10Y_베이시스']-all2['10Y_베이시스'].shift(1)
all2['대비_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)
all2['대비_국고1년'] = all2['국고1년']-all2['국고1년'].shift(1)
all2['대비_국고3년'] = all2['국고3년']-all2['국고3년'].shift(1)
all2['대비_국고5년'] = all2['국고5년']-all2['국고5년'].shift(1)
all2['대비_국고10년'] = all2['국고10년']-all2['국고10년'].shift(1)
all2['대비_통안1년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_통안2년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)
all2['스왑포인트_1월물'] = all2["M1_스왑포인트"]/100 
all2['전일종가_ex'] = all2['종가_ex'].shift(1)


all2 = all2.dropna()

# 필요 칼럼만 남기기
df = all2.copy()
df = all2[["종가_ex", 
             "대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "대비_ndf", "스왑포인트_1월물", "전일종가_ex"]]

# DateTime을 인덱스로 바꿔주기
df.head()
# Out:
#              종가_ex  대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년  \
# DateTime
# 2012-08-02  1131.7        2.0        8.0        9.0        9.0         9.0
# 2012-08-03  1134.8        2.0        1.5        1.0       -5.0       -13.0
# 2012-08-06  1129.0       -2.0       -4.5       -5.0       -6.0        -5.0
# 2012-08-07  1128.8        1.0        1.5        0.0       -8.0       -10.0
# 2012-08-08  1128.3        0.0       -2.0       -2.0       -4.0        -7.0
#
#             대비_국고1년  대비_국고3년  대비_국고5년  대비_국고10년  대비_통안1년  대비_통안2년  대비_ndf  \
# DateTime
# 2012-08-02    -0.03    -0.04    -0.04     -0.04    -0.03    -0.03    1.75
# 2012-08-03    -0.02    -0.02    -0.07     -0.07    -0.02    -0.02    4.00
# 2012-08-06     0.01     0.01     0.00      0.00     0.01     0.01   -9.50
# 2012-08-07    -0.01     0.00     0.00      0.00    -0.01    -0.01    0.50
# 2012-08-08    -0.01    -0.02    -0.02     -0.02    -0.01    -0.01    1.25
#
#             스왑포인트_1월물  전일종가_ex
# DateTime
# 2012-08-02        2.5   1126.5
# 2012-08-03        2.4   1131.7
# 2012-08-06        2.4   1134.8
# 2012-08-07        2.5   1129.0
# 2012-08-08        2.4   1128.8

# %%
x = df[["대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "대비_ndf", "스왑포인트_1월물", "전일종가_ex"]]
y = df["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
#             대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년   대비_국고1년  \
# DateTime
# 2012-08-02   0.417154   1.635051   1.489425   1.688725    1.558649 -1.701782
# 2012-08-03   0.417154   0.303704   0.162679  -0.944483   -2.260350 -1.135141
# 2012-08-06  -0.419816  -0.925232  -0.832381  -1.132570   -0.871623  0.564780
# 2012-08-07   0.207912   0.303704  -0.003164  -1.508742   -1.739577 -0.568501
# 2012-08-08  -0.001331  -0.413175  -0.334851  -0.756397   -1.218805 -0.568501
# ...               ...        ...        ...        ...         ...       ...
# 2022-07-25  -0.838300  -0.208353  -0.003164  -0.380225   -0.003668 -1.135141
# 2022-07-26   0.417154  -0.208353  -0.003164   0.184034    0.169922  0.564780
# 2022-07-27   0.417154   0.815760   0.826052   0.936380    0.864286 -0.001860
# 2022-07-28   0.207912  -0.003530  -0.169008  -0.380225   -0.871623  0.564780
# 2022-07-29  -0.838300  -0.617998  -0.169008   0.936380    0.517104 -2.268422
#
#              대비_국고3년   대비_국고5년  대비_국고10년   대비_통안1년   대비_통안2년    대비_ndf  \
# DateTime
# 2012-08-02 -0.645960 -1.089152 -1.035349 -0.324588 -0.324588  0.078898
# 2012-08-03 -0.323542 -1.906687 -1.812020 -0.216687 -0.216687  0.184381
# 2012-08-06  0.160084  0.000895  0.000212  0.107015  0.107015 -0.448521
# 2012-08-07 -0.001125  0.000895  0.000212 -0.108786 -0.108786  0.020296
# 2012-08-08 -0.323542 -0.544129 -0.517568 -0.108786 -0.108786  0.055457
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -0.968378 -1.906687 -2.329801 -0.108786 -0.108786  0.153908
# 2022-07-26 -0.484751 -0.544129 -0.776459  0.107015  0.107015  0.050769
# 2022-07-27 -0.484751 -1.361664 -1.553130  0.214916  0.214916 -0.026586
# 2022-07-28  0.643711  0.818430  2.071335  0.214916  0.214916 -0.214113
# 2022-07-29 -2.096841 -3.269246 -2.070910 -0.324588 -0.324588 -0.483683
#
#             스왑포인트_1월물   전일종가_ex
# DateTime
# 2012-08-02   1.933692 -0.136969
# 2012-08-03   1.841127 -0.042667
# 2012-08-06   1.841127  0.013552
# 2012-08-07   1.933692 -0.091631
# 2012-08-08   1.841127 -0.095258
# ...               ...       ...
# 2022-07-25  -0.935804  3.245230
# 2022-07-26  -1.028369  3.257924
# 2022-07-27  -0.889522  3.147300
# 2022-07-28  -0.982087  3.250670
# 2022-07-29  -0.935804  2.938746
#
# [2437 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.651726   대비_베이시스1년
# 1     5.675513   대비_베이시스2년
# 2     2.241866   대비_베이시스3년
# 3     4.467777   대비_베이시스5년
# 4     3.022453  대비_베이시스10년
# 5     1.706698     대비_국고1년
# 6     1.235509     대비_국고3년
# 7     5.692059     대비_국고5년
# 8     4.816813    대비_국고10년
# 9          inf     대비_통안1년
# 10         inf     대비_통안2년
# 11    1.002807      대비_ndf
# 12    1.149808   스왑포인트_1월물
# 13    1.157973     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.933e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        15:53:03   Log-Likelihood:                -7567.3
# No. Observations:                2437   AIC:                         1.516e+04
# Df Residuals:                    2423   BIC:                         1.524e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.908    1134.339
# 대비_베이시스1년     -0.4830      0.210     -2.304      0.021      -0.894      -0.072
# 대비_베이시스2년     -0.2347      0.261     -0.898      0.369      -0.747       0.278
# 대비_베이시스3년     -0.1648      0.164     -1.004      0.316      -0.487       0.157
# 대비_베이시스5년      0.0264      0.232      0.114      0.909      -0.428       0.481
# 대비_베이시스10년     0.1192      0.191      0.625      0.532      -0.255       0.493
# 대비_국고1년       -0.0969      0.143     -0.676      0.499      -0.378       0.184
# 대비_국고3년       -0.3066      0.122     -2.515      0.012      -0.546      -0.068
# 대비_국고5년        0.4776      0.262      1.825      0.068      -0.036       0.991
# 대비_국고10년      -0.1678      0.241     -0.697      0.486      -0.640       0.304
# 대비_통안1년       -0.0040      0.055     -0.072      0.943      -0.113       0.105
# 대비_통안2년       -0.0040      0.055     -0.072      0.943      -0.113       0.105
# 대비_ndf         0.5660      0.110      5.153      0.000       0.351       0.781
# 스왑포인트_1월물     -0.1506      0.118     -1.281      0.200      -0.381       0.080
# 전일종가_ex       54.9286      0.118    465.368      0.000      54.697      55.160
# ==============================================================================
# Omnibus:                       40.669   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.175
# Skew:                           0.019   Prob(JB):                     1.06e-17
# Kurtosis:                       3.877   Cond. No.                     4.58e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.88e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_scaled.drop(['대비_베이시스5년','대비_통안1년', '대비_통안2년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.286e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        15:53:45   Log-Likelihood:                -7567.4
# No. Observations:                2437   AIC:                         1.516e+04
# Df Residuals:                    2425   BIC:                         1.523e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.909    1134.339
# 대비_베이시스1년     -0.4800      0.208     -2.308      0.021      -0.888      -0.072
# 대비_베이시스2년     -0.2249      0.246     -0.914      0.361      -0.708       0.258
# 대비_베이시스3년     -0.1621      0.162     -0.998      0.318      -0.481       0.156
# 대비_베이시스10년     0.1292      0.169      0.765      0.444      -0.202       0.461
# 대비_국고1년       -0.0976      0.143     -0.684      0.494      -0.377       0.182
# 대비_국고3년       -0.3067      0.122     -2.517      0.012      -0.546      -0.068
# 대비_국고5년        0.4765      0.261      1.822      0.069      -0.036       0.989
# 대비_국고10년      -0.1681      0.241     -0.698      0.485      -0.640       0.304
# 대비_ndf         0.5659      0.110      5.154      0.000       0.351       0.781
# 스왑포인트_1월물     -0.1507      0.118     -1.281      0.200      -0.381       0.080
# 전일종가_ex       54.9284      0.118    465.593      0.000      54.697      55.160
# ==============================================================================
# Omnibus:                       40.648   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.123
# Skew:                           0.018   Prob(JB):                     1.09e-17
# Kurtosis:                       3.876   Cond. No.                         5.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고1년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.515e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        15:54:18   Log-Likelihood:                -7567.6
# No. Observations:                2437   AIC:                         1.516e+04
# Df Residuals:                    2426   BIC:                         1.522e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.909    1134.339
# 대비_베이시스1년     -0.4923      0.207     -2.376      0.018      -0.899      -0.086
# 대비_베이시스2년     -0.2176      0.246     -0.885      0.376      -0.700       0.265
# 대비_베이시스3년     -0.1583      0.162     -0.975      0.330      -0.477       0.160
# 대비_베이시스10년     0.1267      0.169      0.750      0.453      -0.204       0.458
# 대비_국고3년       -0.3188      0.121     -2.644      0.008      -0.555      -0.082
# 대비_국고5년        0.4180      0.247      1.692      0.091      -0.066       0.902
# 대비_국고10년      -0.1643      0.241     -0.683      0.495      -0.636       0.307
# 대비_ndf         0.5666      0.110      5.161      0.000       0.351       0.782
# 스왑포인트_1월물     -0.1511      0.118     -1.285      0.199      -0.382       0.079
# 전일종가_ex       54.9218      0.118    467.142      0.000      54.691      55.152
# ==============================================================================
# Omnibus:                       41.218   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.571
# Skew:                           0.022   Prob(JB):                     5.27e-18
# Kurtosis:                       3.884   Cond. No.                         5.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor     Feature
# 0    3.571602   대비_베이시스1년
# 1    5.032750   대비_베이시스2년
# 2    2.193250   대비_베이시스3년
# 3    2.372697  대비_베이시스10년
# 4    1.209312     대비_국고3년
# 5    5.077745     대비_국고5년
# 6    4.813845    대비_국고10년
# 7    1.002669      대비_ndf
# 8    1.149764   스왑포인트_1월물
# 9    1.150102     전일종가_ex

# %%
x_scaled.drop(['대비_베이시스2년', '대비_베이시스3년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 3.143e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        15:58:58   Log-Likelihood:                -7568.8
# No. Observations:                2437   AIC:                         1.516e+04
# Df Residuals:                    2428   BIC:                         1.521e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.909    1134.339
# 대비_베이시스1년     -0.6984      0.144     -4.862      0.000      -0.980      -0.417
# 대비_베이시스10년     0.0042      0.147      0.029      0.977      -0.284       0.293
# 대비_국고3년       -0.3093      0.120     -2.569      0.010      -0.545      -0.073
# 대비_국고5년        0.4455      0.246      1.808      0.071      -0.038       0.929
# 대비_국고10년      -0.1736      0.240     -0.722      0.470      -0.645       0.298
# 대비_ndf         0.5704      0.110      5.198      0.000       0.355       0.786
# 스왑포인트_1월물     -0.1517      0.118     -1.291      0.197      -0.382       0.079
# 전일종가_ex       54.9215      0.118    467.098      0.000      54.691      55.152
# ==============================================================================
# Omnibus:                       40.568   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.679
# Skew:                           0.026   Prob(JB):                     1.36e-17
# Kurtosis:                       3.873   Cond. No.                         4.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_베이시스10년', '대비_국고10년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 4.193e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        15:59:34   Log-Likelihood:                -7569.1
# No. Observations:                2437   AIC:                         1.515e+04
# Df Residuals:                    2430   BIC:                         1.519e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.909    1134.338
# 대비_베이시스1년     -0.6945      0.110     -6.304      0.000      -0.911      -0.478
# 대비_국고3년       -0.3075      0.120     -2.555      0.011      -0.543      -0.072
# 대비_국고5년        0.2897      0.121      2.397      0.017       0.053       0.527
# 대비_ndf         0.5710      0.110      5.205      0.000       0.356       0.786
# 스왑포인트_1월물     -0.1510      0.118     -1.285      0.199      -0.381       0.079
# 전일종가_ex       54.9214      0.118    467.274      0.000      54.691      55.152
# ==============================================================================
# Omnibus:                       40.800   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.327
# Skew:                           0.025   Prob(JB):                     9.80e-18
# Kurtosis:                       3.877   Cond. No.                         1.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['스왑포인트_1월물'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 5.031e+04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:00:30   Log-Likelihood:                -7569.9
# No. Observations:                2437   AIC:                         1.515e+04
# Df Residuals:                    2431   BIC:                         1.519e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.1235      0.110   1.03e+04      0.000    1133.909    1134.338
# 대비_베이시스1년     -0.6968      0.110     -6.324      0.000      -0.913      -0.481
# 대비_국고3년       -0.3078      0.120     -2.558      0.011      -0.544      -0.072
# 대비_국고5년        0.2880      0.121      2.382      0.017       0.051       0.525
# 대비_ndf         0.5711      0.110      5.206      0.000       0.356       0.786
# 전일종가_ex       54.9759      0.110    501.407      0.000      54.761      55.191
# ==============================================================================
# Omnibus:                       40.542   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.793
# Skew:                           0.020   Prob(JB):                     1.28e-17
# Kurtosis:                       3.874   Cond. No.                         1.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 29.671454064663696, RMSE :  5.447, MAE: 5.447
# Variance score :  0.991

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (8.179325736695056,
#  array([ 4.34856439,  6.74620579,  5.68737723, 18.96890554,  5.14557573]),
#  array([ -18.91001222,  -45.51129262,  -32.34625977, -359.81937728,
#          -26.47694963]))
