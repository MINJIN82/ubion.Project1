# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# 파일 불러오기
all = pd.read_excel("../엑셀/Join_data.xlsx", index_col = 0)    

# 컬럼 추출
all2 = all[['DateTime', '종가_ex', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스', '10Y_베이시스',
        '국고1년', '국고3년', '국고5년','국고10년', '통안364일', '통안2년', 'Mid_ndf',
        'M1_스왑포인트']]            # [[]] 대괄호 2개 사용 -> 데이터 프레임형태로 나옴

all2 = all2.set_index("DateTime")

all2['대비_베이시스1년'] = all2['1Y_베이시스']-all2['1Y_베이시스'].shift(1)
all2['대비_베이시스2년'] = all2['2Y_베이시스']-all2['2Y_베이시스'].shift(1)
all2['대비_베이시스3년'] = all2['3Y_베이시스']-all2['3Y_베이시스'].shift(1)
all2['대비_베이시스5년'] =all2['5Y_베이시스']-all2['5Y_베이시스'].shift(1)
all2['대비_베이시스10년'] = all2['10Y_베이시스']-all2['10Y_베이시스'].shift(1)
all2['대비_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)
all2['대비_국고1년'] = all2['국고1년']-all2['국고1년'].shift(1)
all2['대비_국고3년'] = all2['국고3년']-all2['국고3년'].shift(1)
all2['대비_국고5년'] = all2['국고5년']-all2['국고5년'].shift(1)
all2['대비_국고10년'] = all2['국고10년']-all2['국고10년'].shift(1)
all2['대비_통안1년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_통안2년'] = all2['통안364일']-all2['통안364일'].shift(1)
all2['대비_ndf'] = all2['Mid_ndf']-all2['Mid_ndf'].shift(1)
all2['스왑포인트_1월물'] = all2["M1_스왑포인트"]/100 
all2['전일종가_ex'] = all2['종가_ex'].shift(1)


all2 = all2.dropna()

# 필요 칼럼만 남기기
df = all2.copy()
df = all2[["종가_ex", 
             "대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "대비_ndf", "스왑포인트_1월물", "전일종가_ex"]]

# DateTime을 인덱스로 바꿔주기
df.head()
# Out:
#              종가_ex  대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년  \
# DateTime
# 2012-08-02  1131.7        2.0        8.0        9.0        9.0         9.0
# 2012-08-03  1134.8        2.0        1.5        1.0       -5.0       -13.0
# 2012-08-06  1129.0       -2.0       -4.5       -5.0       -6.0        -5.0
# 2012-08-07  1128.8        1.0        1.5        0.0       -8.0       -10.0
# 2012-08-08  1128.3        0.0       -2.0       -2.0       -4.0        -7.0
#
#             대비_국고1년  대비_국고3년  대비_국고5년  대비_국고10년  대비_통안1년  대비_통안2년  대비_ndf  \
# DateTime
# 2012-08-02    -0.03    -0.04    -0.04     -0.04    -0.03    -0.03    1.75
# 2012-08-03    -0.02    -0.02    -0.07     -0.07    -0.02    -0.02    4.00
# 2012-08-06     0.01     0.01     0.00      0.00     0.01     0.01   -9.50
# 2012-08-07    -0.01     0.00     0.00      0.00    -0.01    -0.01    0.50
# 2012-08-08    -0.01    -0.02    -0.02     -0.02    -0.01    -0.01    1.25
#
#             스왑포인트_1월물  전일종가_ex
# DateTime
# 2012-08-02        2.5   1126.5
# 2012-08-03        2.4   1131.7
# 2012-08-06        2.4   1134.8
# 2012-08-07        2.5   1129.0
# 2012-08-08        2.4   1128.8

# %%
x = df[["대비_베이시스1년", "대비_베이시스2년", "대비_베이시스3년", "대비_베이시스5년","대비_베이시스10년", 
            "대비_국고1년", "대비_국고3년", "대비_국고5년", "대비_국고10년", "대비_통안1년", "대비_통안2년",
            "대비_ndf", "스왑포인트_1월물", "전일종가_ex"]]
y = df["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
#             대비_베이시스1년  대비_베이시스2년  대비_베이시스3년  대비_베이시스5년  대비_베이시스10년   대비_국고1년  \
# DateTime
# 2012-08-02   0.348741   1.544080   1.437744   1.627899    1.488363 -1.698057
# 2012-08-03   0.348741   0.286831   0.157058  -0.910410   -2.158344 -1.132651
# 2012-08-06  -0.350946  -0.873707  -0.803456  -1.091718   -0.832269  0.563566
# 2012-08-07   0.173819   0.286831  -0.003027  -1.454333   -1.661066 -0.567245
# 2012-08-08  -0.001103  -0.390150  -0.323199  -0.729102   -1.163788 -0.567245
# ...               ...        ...        ...        ...         ...       ...
# 2022-07-25  -0.700790  -0.196727  -0.003027  -0.366487   -0.003472 -1.132651
# 2022-07-26   0.348741  -0.196727  -0.003027   0.177437    0.162288  0.563566
# 2022-07-27   0.348741   0.770388   0.797401   0.902668    0.825326 -0.001839
# 2022-07-28   0.173819  -0.003304  -0.163113  -0.366487   -0.832269  0.563566
# 2022-07-29  -0.700790  -0.583573  -0.163113   0.902668    0.493807 -2.263463
#
#              대비_국고3년   대비_국고5년  대비_국고10년   대비_통안1년   대비_통안2년    대비_ndf  \
# DateTime
# 2012-08-02 -0.646622 -1.079749 -1.027569 -0.325920 -0.325920  0.079167
# 2012-08-03 -0.323869 -1.890219 -1.798403 -0.217574 -0.217574  0.184972
# 2012-08-06  0.160261  0.000879  0.000209  0.107465  0.107465 -0.449862
# 2012-08-07 -0.001116  0.000879  0.000209 -0.109228 -0.109228  0.020386
# 2012-08-08 -0.323869 -0.539435 -0.513680 -0.109228 -0.109228  0.055654
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -0.969375 -1.890219 -2.312292 -0.109228 -0.109228  0.154406
# 2022-07-26 -0.485246 -0.539435 -0.770625  0.107465  0.107465  0.050952
# 2022-07-27 -0.485246 -1.349905 -1.541458  0.215812  0.215812 -0.026639
# 2022-07-28  0.644391  0.811350  2.055766  0.215812  0.215812 -0.214738
# 2022-07-29 -2.099012 -3.241004 -2.055348 -0.325920 -0.325920 -0.485131
#
#             스왑포인트_1월물   전일종가_ex
# DateTime
# 2012-08-02   1.909409 -0.149841
# 2012-08-03   1.818881 -0.056232
# 2012-08-06   1.818881 -0.000426
# 2012-08-07   1.909409 -0.104837
# 2012-08-08   1.818881 -0.108437
# ...               ...       ...
# 2022-07-25  -0.896960  3.207485
# 2022-07-26  -0.987488  3.220086
# 2022-07-27  -0.851696  3.110275
# 2022-07-28  -0.942224  3.212885
# 2022-07-29  -0.896960  2.903255
#
# [2459 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.152007   대비_베이시스1년
# 1     5.908616   대비_베이시스2년
# 2     2.407018   대비_베이시스3년
# 3     4.767472   대비_베이시스5년
# 4     3.268949  대비_베이시스10년
# 5     1.798312     대비_국고1년
# 6     1.243380     대비_국고3년
# 7     5.768167     대비_국고5년
# 8     4.882755    대비_국고10년
# 9          inf     대비_통안1년
# 10         inf     대비_통안2년
# 11    1.003381      대비_ndf
# 12    1.168849   스왑포인트_1월물
# 13    1.177871     전일종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.910e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:59   Log-Likelihood:                -7679.0
# No. Observations:                2459   AIC:                         1.539e+04
# Df Residuals:                    2445   BIC:                         1.547e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.3109      0.197     -6.644      0.000      -1.698      -0.924
# 대비_베이시스2년     -0.1945      0.270     -0.720      0.472      -0.724       0.335
# 대비_베이시스3년     -0.1365      0.172     -0.792      0.429      -0.475       0.202
# 대비_베이시스5년      0.1189      0.243      0.490      0.624      -0.357       0.595
# 대비_베이시스10년     0.2855      0.201      1.421      0.155      -0.108       0.680
# 대비_국고1년       -0.0454      0.149     -0.305      0.761      -0.338       0.247
# 대비_국고3년       -0.3122      0.124     -2.519      0.012      -0.555      -0.069
# 대비_국고5년        0.6166      0.267      2.310      0.021       0.093       1.140
# 대비_국고10년      -0.2560      0.246     -1.042      0.297      -0.738       0.226
# 대비_통안1년       -0.0052      0.056     -0.092      0.926      -0.115       0.105
# 대비_통안2년       -0.0052      0.056     -0.092      0.926      -0.115       0.105
# 대비_ndf         0.5734      0.111      5.151      0.000       0.355       0.792
# 스왑포인트_1월물     -0.1436      0.120     -1.196      0.232      -0.379       0.092
# 전일종가_ex       55.3313      0.121    458.758      0.000      55.095      55.568
# ==============================================================================
# Omnibus:                       50.795   Durbin-Watson:                   2.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.343
# Skew:                          -0.000   Prob(JB):                     4.91e-24
# Kurtosis:                       4.024   Cond. No.                     4.48e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.27e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_scaled.drop(['대비_베이시스5년','대비_통안1년', '대비_통안2년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.259e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:59   Log-Likelihood:                -7679.1
# No. Observations:                2459   AIC:                         1.538e+04
# Df Residuals:                    2447   BIC:                         1.545e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.3077      0.197     -6.634      0.000      -1.694      -0.921
# 대비_베이시스2년     -0.1439      0.249     -0.577      0.564      -0.633       0.345
# 대비_베이시스3년     -0.1230      0.170     -0.723      0.470      -0.457       0.211
# 대비_베이시스10년     0.3330      0.176      1.893      0.058      -0.012       0.678
# 대비_국고1년       -0.0471      0.148     -0.317      0.751      -0.338       0.244
# 대비_국고3년       -0.3122      0.124     -2.520      0.012      -0.555      -0.069
# 대비_국고5년        0.6142      0.267      2.303      0.021       0.091       1.137
# 대비_국고10년      -0.2569      0.245     -1.046      0.295      -0.738       0.224
# 대비_ndf         0.5730      0.111      5.150      0.000       0.355       0.791
# 스왑포인트_1월물     -0.1437      0.120     -1.196      0.232      -0.379       0.092
# 전일종가_ex       55.3308      0.121    458.948      0.000      55.094      55.567
# ==============================================================================
# Omnibus:                       51.054   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.138
# Skew:                          -0.001   Prob(JB):                     3.30e-24
# Kurtosis:                       4.027   Cond. No.                         5.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고1년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.486e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:59   Log-Likelihood:                -7679.1
# No. Observations:                2459   AIC:                         1.538e+04
# Df Residuals:                    2448   BIC:                         1.544e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.3082      0.197     -6.638      0.000      -1.695      -0.922
# 대비_베이시스2년     -0.1413      0.249     -0.567      0.571      -0.630       0.348
# 대비_베이시스3년     -0.1215      0.170     -0.714      0.475      -0.455       0.212
# 대비_베이시스10년     0.3311      0.176      1.883      0.060      -0.014       0.676
# 대비_국고3년       -0.3178      0.123     -2.593      0.010      -0.558      -0.077
# 대비_국고5년        0.5865      0.252      2.328      0.020       0.093       1.081
# 대비_국고10년      -0.2570      0.245     -1.047      0.295      -0.738       0.224
# 대비_ndf         0.5735      0.111      5.155      0.000       0.355       0.792
# 스왑포인트_1월물     -0.1442      0.120     -1.201      0.230      -0.380       0.091
# 전일종가_ex       55.3275      0.120    460.711      0.000      55.092      55.563
# ==============================================================================
# Omnibus:                       51.084   Durbin-Watson:                   2.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.233
# Skew:                           0.001   Prob(JB):                     3.14e-24
# Kurtosis:                       4.028   Cond. No.                         5.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#    VIF_Factor     Feature
# 0    3.148584   대비_베이시스1년
# 1    5.036947   대비_베이시스2년
# 2    2.343314   대비_베이시스3년
# 3    2.504779  대비_베이시스10년
# 4    1.218046     대비_국고3년
# 5    5.144934     대비_국고5년
# 6    4.882438    대비_국고10년
# 7    1.003170      대비_ndf
# 8    1.168599   스왑포인트_1월물
# 9    1.169013     전일종가_ex

# %%
x_scaled.drop(['대비_베이시스2년', '대비_베이시스3년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 3.108e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:28:59   Log-Likelihood:                -7679.8
# No. Observations:                2459   AIC:                         1.538e+04
# Df Residuals:                    2450   BIC:                         1.543e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.4371      0.143    -10.019      0.000      -1.718      -1.156
# 대비_베이시스10년     0.2299      0.147      1.562      0.118      -0.059       0.519
# 대비_국고3년       -0.3116      0.122     -2.545      0.011      -0.552      -0.071
# 대비_국고5년        0.6056      0.251      2.410      0.016       0.113       1.098
# 대비_국고10년      -0.2640      0.245     -1.076      0.282      -0.745       0.217
# 대비_ndf         0.5762      0.111      5.182      0.000       0.358       0.794
# 스왑포인트_1월물     -0.1447      0.120     -1.206      0.228      -0.380       0.091
# 전일종가_ex       55.3270      0.120    460.780      0.000      55.092      55.562
# ==============================================================================
# Omnibus:                       49.355   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.921
# Skew:                           0.006   Prob(JB):                     4.48e-23
# Kurtosis:                       4.002   Cond. No.                         4.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고10년', '스왑포인트_1월물'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 4.143e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:29:00   Log-Likelihood:                -7681.1
# No. Observations:                2459   AIC:                         1.538e+04
# Df Residuals:                    2452   BIC:                         1.542e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.4462      0.143    -10.096      0.000      -1.727      -1.165
# 대비_베이시스10년     0.2443      0.147      1.665      0.096      -0.043       0.532
# 대비_국고3년       -0.3098      0.122     -2.530      0.011      -0.550      -0.070
# 대비_국고5년        0.3702      0.126      2.942      0.003       0.123       0.617
# 대비_ndf         0.5769      0.111      5.189      0.000       0.359       0.795
# 전일종가_ex       55.3817      0.111    498.437      0.000      55.164      55.600
# ==============================================================================
# Omnibus:                       49.419   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.142
# Skew:                           0.002   Prob(JB):                     4.01e-23
# Kurtosis:                       4.003   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_베이시스10년'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 4.968e+04
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:29:00   Log-Likelihood:                -7682.5
# No. Observations:                2459   AIC:                         1.538e+04
# Df Residuals:                    2453   BIC:                         1.541e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.111   1.02e+04      0.000    1134.676    1135.112
# 대비_베이시스1년     -1.2969      0.112    -11.602      0.000      -1.516      -1.078
# 대비_국고3년       -0.3073      0.122     -2.510      0.012      -0.547      -0.067
# 대비_국고5년        0.3255      0.123      2.647      0.008       0.084       0.567
# 대비_ndf         0.5781      0.111      5.197      0.000       0.360       0.796
# 전일종가_ex       55.3798      0.111    498.265      0.000      55.162      55.598
# ==============================================================================
# Omnibus:                       54.009   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.427
# Skew:                           0.003   Prob(JB):                     3.17e-26
# Kurtosis:                       4.071   Cond. No.                         1.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 29.05852078124814, RMSE :  5.391, MAE: 5.391
# Variance score :  0.991

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y,scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (8.216670227806325,
#  array([ 4.54381437,  6.75748577,  5.67388105, 19.0517729 ,  5.05639705]),
#  array([ -20.64624907,  -45.66361397,  -32.19292613, -362.97005049,
#          -25.56715112]))
