# %%
import pandas as pd
import numpy as np

# %%
# 파일 불러오기
df = pd.read_excel("./xlsx/Join_data3.xlsx", index_col = 0)    
df = df.set_index("DateTime")

# 대비 계산
df['대비_irs_1Y'] = df['1Y_Mid_irs'] - df['1Y_Mid_irs'].shift(1) 
df['대비_irs_2Y'] = df['2Y_Mid_irs'] - df['2Y_Mid_irs'].shift(1) 
df['대비_irs_3Y'] = df['3Y_Mid_irs'] - df['3Y_Mid_irs'].shift(1) 
df['대비_irs_5Y'] = df['5Y_Mid_irs'] - df['5Y_Mid_irs'].shift(1) 
df['대비_irs_10Y'] = df['10Y_Mid_irs'] - df['10Y_Mid_irs'].shift(1) 

df['대비_crs_1Y'] = df['1Y_Mid_crs'] - df['1Y_Mid_crs'].shift(1)
df['대비_crs_2Y'] = df['2Y_Mid_crs'] - df['2Y_Mid_crs'].shift(1)
df['대비_crs_3Y'] = df['3Y_Mid_crs'] - df['3Y_Mid_crs'].shift(1)
df['대비_crs_5Y'] = df['5Y_Mid_crs'] - df['5Y_Mid_crs'].shift(1)
df['대비_crs_10Y'] = df['10Y_Mid_crs'] - df['10Y_Mid_crs'].shift(1)

df['대비_swapbasis_1Y'] = df['1Y_베이시스']-df['1Y_베이시스'].shift(1)
df['대비_swapbasis_2Y'] = df['2Y_베이시스']-df['2Y_베이시스'].shift(1)
df['대비_swapbasis_3Y'] = df['3Y_베이시스']-df['3Y_베이시스'].shift(1)
df['대비_swapbasis_5Y'] = df['5Y_베이시스']-df['5Y_베이시스'].shift(1)
df['대비_swapbasis_10Y'] = df['10Y_베이시스']-df['10Y_베이시스'].shift(1)

df['대비_국고_1Y'] = df['국고1년']-df['국고1년'].shift(1)
df['대비_국고_3Y'] = df['국고3년']-df['국고3년'].shift(1)
df['대비_국고_5Y'] = df['국고5년']-df['국고5년'].shift(1)
df['대비_국고_10Y'] = df['국고10년']-df['국고10년'].shift(1)

df['대비_통안_1Y'] = df['통안364일']-df['통안364일'].shift(1)
df['대비_통안_2Y'] = df['통안2년']-df['통안2년'].shift(1)

df['대비_ndf'] = df['Mid_ndf']-df['Mid_ndf'].shift(1)
df['스왑포인트_1M'] = df["M1_스왑포인트"]/100 
df['전일종가_ex'] = df['종가_ex'].shift(1)
df['종가_NDF_차이'] = df['전일종가_ex'] - df['Mid_ndf']

# 필요한 칼럼만 추출
df_1 = df[['대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y', 
           '대비_swapbasis_1Y', '대비_swapbasis_2Y', '대비_swapbasis_3Y', '대비_swapbasis_5Y', '대비_swapbasis_10Y',
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '대비_ndf', '스왑포인트_1M', '전일종가_ex', 
           '종가_ex', '종가_NDF_차이' ]] 

# 결측치 제거
df_1 = df_1.dropna()

# %%
x = df_1[[ '대비_irs_1Y', '대비_irs_2Y', '대비_irs_3Y', '대비_irs_5Y', '대비_irs_10Y',
           '대비_crs_1Y', '대비_crs_2Y', '대비_crs_3Y', '대비_crs_5Y', '대비_crs_10Y',
           '대비_국고_1Y', '대비_국고_3Y', '대비_국고_5Y', '대비_국고_10Y', 
           '대비_통안_1Y', '대비_통안_2Y', '스왑포인트_1M', '전일종가_ex', 
           '종가_NDF_차이'  ]]
y = df_1["종가_ex"]

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\hyeok\AppData\Local\Temp\ipykernel_42888\1797086163.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             대비_irs_1Y  대비_irs_2Y  대비_irs_3Y  대비_irs_5Y  대비_irs_10Y  대비_crs_1Y  \
# DateTime
# 2012-08-02  -0.847862  -1.217081  -0.935854  -1.045679   -1.009126  -0.205655
# 2012-08-03  -0.847862  -0.731532  -0.562378  -0.628002   -0.403231  -0.205655
# 2012-08-06   0.560374   0.482340   0.371312   0.416191    0.202663  -0.003373
# 2012-08-07   0.278727  -0.003209  -0.002164   0.207352    0.404628   0.401191
# 2012-08-08   0.278727   0.482340   0.371312   0.416191    0.606592   0.198909
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-25  -1.129510  -1.945404  -1.309330  -1.881032   -2.220914  -1.621628
# 2022-07-26  -0.284568  -0.488757  -0.562378  -0.628002   -0.605196   0.198909
# 2022-07-27  -0.284568  -1.217081  -1.122592  -1.254517   -1.211091   0.198909
# 2022-07-28   0.842021   0.967889   0.931525   1.042706    1.414452   0.805755
# 2022-07-29  -1.974451  -3.402050  -2.616496  -2.925225   -2.422879  -2.228474
#
#             대비_crs_2Y  대비_crs_3Y  대비_crs_5Y  대비_crs_10Y  대비_국고_1Y  대비_국고_3Y  \
# DateTime
# 2012-08-02   0.707360   0.905480   0.926463    0.826282 -1.698057 -0.646622
# 2012-08-03  -0.364505  -0.463176  -1.872849   -3.115790 -1.132651 -0.323869
# 2012-08-06  -0.602697  -0.691285  -0.939745   -0.833538  0.563566  0.160261
# 2012-08-07   0.350072  -0.006957  -1.639573   -1.663448 -0.567245 -0.001116
# 2012-08-08  -0.007216  -0.006957  -0.473193   -0.833538 -0.567245 -0.323869
# ...               ...        ...        ...         ...       ...       ...
# 2022-07-25  -2.150945  -1.603722  -2.572677   -2.285880 -1.132651 -0.969375
# 2022-07-26  -0.721793  -0.691285  -0.473193   -0.418583  0.563566 -0.485246
# 2022-07-27  -0.245409  -0.235067  -0.239917   -0.211106 -0.001839 -0.485246
# 2022-07-28   0.945552   0.905480   0.693187    0.411327  0.563566  0.644391
# 2022-07-29  -4.056482  -3.428596  -2.106125   -1.870925 -2.263463 -2.099012
#
#             대비_국고_5Y  대비_국고_10Y  대비_통안_1Y  대비_통안_2Y  스왑포인트_1M   전일종가_ex  \
# DateTime
# 2012-08-02 -1.079749  -1.027569 -0.325920 -0.625160  1.909409 -0.149841
# 2012-08-03 -1.890219  -1.798403 -0.217574 -0.125723  1.818881 -0.056232
# 2012-08-06  0.000879   0.000209  0.107465  0.123996  1.818881 -0.000426
# 2012-08-07  0.000879   0.000209 -0.109228 -0.125723  1.909409 -0.104837
# 2012-08-08 -0.539435  -0.513680 -0.109228 -0.125723  1.818881 -0.108437
# ...              ...        ...       ...       ...       ...       ...
# 2022-07-25 -1.890219  -2.312292 -0.109228 -0.625160 -0.896960  3.207485
# 2022-07-26 -0.539435  -0.770625  0.107465 -0.000863 -0.987488  3.220086
# 2022-07-27 -1.349905  -1.541458  0.215812 -0.125723 -0.851696  3.110275
# 2022-07-28  0.811350   2.055766  0.215812  0.373715 -0.942224  3.212885
# 2022-07-29 -3.241004  -2.055348 -0.325920 -1.374316 -0.896960  2.903255
#
#             종가_NDF_차이
# DateTime
# 2012-08-02  -1.648743
# 2012-08-03  -1.366022
# 2012-08-06   1.602547
# 2012-08-07   0.118263
# 2012-08-08  -0.223358
# ...               ...
# 2022-07-25   0.860405
# 2022-07-26   0.754385
# 2022-07-27  -0.564979
# 2022-07-28   1.838148
# 2022-07-29   0.200723
#
# [2459 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
import scipy as sp  
from matplotlib import rc 
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(20,20))

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(data = x_scaled.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap=cmap, center=0)
# Out:
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 50769 (\N{HANGUL SYLLABLE WAB}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\hyeok\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50769 (\N{HANGUL SYLLABLE WAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\hyeok\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     9.960192   대비_irs_1Y
# 1    19.501070   대비_irs_2Y
# 2     2.662512   대비_irs_3Y
# 3     6.474121   대비_irs_5Y
# 4     5.880995  대비_irs_10Y
# 5     2.663434   대비_crs_1Y
# 6     5.272150   대비_crs_2Y
# 7     3.831861   대비_crs_3Y
# 8     6.698546   대비_crs_5Y
# 9     3.716729  대비_crs_10Y
# 10    1.926839    대비_국고_1Y
# 11    1.254279    대비_국고_3Y
# 12    6.299324    대비_국고_5Y
# 13    5.058509   대비_국고_10Y
# 14    1.025239    대비_통안_1Y
# 15    1.115967    대비_통안_2Y
# 16    1.248050    스왑포인트_1M
# 17    1.192603     전일종가_ex
# 18    1.162388   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.453e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:15:36   Log-Likelihood:                -6907.2
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2439   BIC:                         1.397e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.0320      0.257      0.125      0.901      -0.471       0.535
# 대비_irs_2Y      0.4368      0.359      1.217      0.224      -0.267       1.141
# 대비_irs_3Y      0.0617      0.133      0.465      0.642      -0.198       0.322
# 대비_irs_5Y     -0.0227      0.207     -0.110      0.913      -0.428       0.383
# 대비_irs_10Y    -0.5280      0.197     -2.678      0.007      -0.915      -0.141
# 대비_crs_1Y     -0.6881      0.133     -5.186      0.000      -0.948      -0.428
# 대비_crs_2Y      0.0527      0.187      0.283      0.778      -0.313       0.419
# 대비_crs_3Y     -0.2957      0.159     -1.858      0.063      -0.608       0.016
# 대비_crs_5Y     -0.3172      0.210     -1.508      0.132      -0.730       0.095
# 대비_crs_10Y     0.1188      0.157      0.758      0.448      -0.189       0.426
# 대비_국고_1Y      -0.0149      0.113     -0.132      0.895      -0.236       0.206
# 대비_국고_3Y      -0.1732      0.091     -1.903      0.057      -0.352       0.005
# 대비_국고_5Y       0.2574      0.204      1.262      0.207      -0.143       0.658
# 대비_국고_10Y     -0.0071      0.183     -0.039      0.969      -0.366       0.351
# 대비_통안_1Y      -0.0048      0.082     -0.058      0.954      -0.166       0.157
# 대비_통안_2Y       0.0294      0.086      0.342      0.732      -0.139       0.198
# 스왑포인트_1M      -1.1729      0.091    -12.914      0.000      -1.351      -0.995
# 전일종가_ex       55.7384      0.089    627.817      0.000      55.564      55.912
# 종가_NDF_차이     -3.9527      0.088    -45.097      0.000      -4.125      -3.781
# ==============================================================================
# Omnibus:                      208.876   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              895.344
# Skew:                           0.305   Prob(JB):                    3.79e-195
# Kurtosis:                       5.892   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.932627   대비_irs_1Y
# 1     2.552008   대비_irs_3Y
# 2     5.807206   대비_irs_5Y
# 3     5.225154  대비_irs_10Y
# 4     2.660685   대비_crs_1Y
# 5     5.260811   대비_crs_2Y
# 6     3.829372   대비_crs_3Y
# 7     6.693347   대비_crs_5Y
# 8     3.716562  대비_crs_10Y
# 9     1.915930    대비_국고_1Y
# 10    1.248234    대비_국고_3Y
# 11    6.212802    대비_국고_5Y
# 12    5.044617   대비_국고_10Y
# 13    1.024881    대비_통안_1Y
# 14    1.115274    대비_통안_2Y
# 15    1.248036    스왑포인트_1M
# 16    1.191889     전일종가_ex
# 17    1.162241   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.589e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:15:42   Log-Likelihood:                -6908.0
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2440   BIC:                         1.396e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.2748      0.161      1.704      0.088      -0.041       0.591
# 대비_irs_3Y      0.0945      0.130      0.728      0.467      -0.160       0.349
# 대비_irs_5Y      0.0581      0.196      0.296      0.767      -0.326       0.442
# 대비_irs_10Y    -0.4479      0.186     -2.410      0.016      -0.812      -0.083
# 대비_crs_1Y     -0.6933      0.133     -5.228      0.000      -0.953      -0.433
# 대비_crs_2Y      0.0633      0.186      0.339      0.734      -0.302       0.429
# 대비_crs_3Y     -0.3006      0.159     -1.890      0.059      -0.613       0.011
# 대비_crs_5Y     -0.3101      0.210     -1.474      0.141      -0.723       0.102
# 대비_crs_10Y     0.1201      0.157      0.766      0.444      -0.187       0.427
# 대비_국고_1Y      -0.0046      0.113     -0.041      0.967      -0.225       0.216
# 대비_국고_3Y      -0.1655      0.091     -1.822      0.069      -0.344       0.013
# 대비_국고_5Y       0.2865      0.203      1.414      0.158      -0.111       0.684
# 대비_국고_10Y     -0.0188      0.183     -0.103      0.918      -0.377       0.339
# 대비_통안_1Y      -0.0067      0.082     -0.081      0.936      -0.168       0.155
# 대비_통안_2Y       0.0320      0.086      0.373      0.709      -0.136       0.200
# 스왑포인트_1M      -1.1725      0.091    -12.909      0.000      -1.351      -0.994
# 전일종가_ex       55.7357      0.089    627.913      0.000      55.562      55.910
# 종가_NDF_차이     -3.9539      0.088    -45.109      0.000      -4.126      -3.782
# ==============================================================================
# Omnibus:                      211.766   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              913.395
# Skew:                           0.311   Prob(JB):                    4.56e-199
# Kurtosis:                       5.920   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_통안_1Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     3.931683   대비_irs_1Y
# 1     2.551936   대비_irs_3Y
# 2     5.807205   대비_irs_5Y
# 3     5.224515  대비_irs_10Y
# 4     2.660670   대비_crs_1Y
# 5     5.260766   대비_crs_2Y
# 6     3.829352   대비_crs_3Y
# 7     6.693343   대비_crs_5Y
# 8     3.716561  대비_crs_10Y
# 9     1.904686    대비_국고_1Y
# 10    1.248190    대비_국고_3Y
# 11    6.209501    대비_국고_5Y
# 12    5.044596   대비_국고_10Y
# 13    1.115171    대비_통안_2Y
# 14    1.248023    스왑포인트_1M
# 15    1.191802     전일종가_ex
# 16    1.162241   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.742e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:15:52   Log-Likelihood:                -6908.0
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2441   BIC:                         1.396e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.734    1135.053
# 대비_irs_1Y      0.2746      0.161      1.704      0.089      -0.041       0.591
# 대비_irs_3Y      0.0946      0.130      0.728      0.466      -0.160       0.349
# 대비_irs_5Y      0.0581      0.196      0.297      0.767      -0.326       0.442
# 대비_irs_10Y    -0.4477      0.186     -2.410      0.016      -0.812      -0.083
# 대비_crs_1Y     -0.6933      0.133     -5.229      0.000      -0.953      -0.433
# 대비_crs_2Y      0.0632      0.186      0.339      0.735      -0.302       0.429
# 대비_crs_3Y     -0.3006      0.159     -1.890      0.059      -0.613       0.011
# 대비_crs_5Y     -0.3101      0.210     -1.474      0.140      -0.722       0.102
# 대비_crs_10Y     0.1201      0.157      0.766      0.443      -0.187       0.427
# 대비_국고_1Y      -0.0053      0.112     -0.047      0.962      -0.225       0.215
# 대비_국고_3Y      -0.1656      0.091     -1.823      0.068      -0.344       0.013
# 대비_국고_5Y       0.2862      0.203      1.413      0.158      -0.111       0.683
# 대비_국고_10Y     -0.0188      0.183     -0.103      0.918      -0.377       0.339
# 대비_통안_2Y       0.0319      0.086      0.372      0.710      -0.136       0.200
# 스왑포인트_1M      -1.1725      0.091    -12.912      0.000      -1.351      -0.994
# 전일종가_ex       55.7357      0.089    628.063      0.000      55.562      55.910
# 종가_NDF_차이     -3.9539      0.088    -45.118      0.000      -4.126      -3.782
# ==============================================================================
# Omnibus:                      211.766   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              913.490
# Skew:                           0.311   Prob(JB):                    4.35e-199
# Kurtosis:                       5.921   Cond. No.                         7.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_irs_3Y', '대비_irs_5Y','대비_통안_2Y'], axis=1, inplace=True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor     Feature
# 0     2.809873   대비_irs_1Y
# 1     3.643651  대비_irs_10Y
# 2     2.655681   대비_crs_1Y
# 3     5.258811   대비_crs_2Y
# 4     3.828086   대비_crs_3Y
# 5     6.683120   대비_crs_5Y
# 6     3.712837  대비_crs_10Y
# 7     1.869913    대비_국고_1Y
# 8     1.245958    대비_국고_3Y
# 9     6.114840    대비_국고_5Y
# 10    5.043795   대비_국고_10Y
# 11    1.247862    스왑포인트_1M
# 12    1.191190     전일종가_ex
# 13    1.161078   종가_NDF_차이

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 3.333e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:16:31   Log-Likelihood:                -6908.4
# No. Observations:                2459   AIC:                         1.385e+04
# Df Residuals:                    2444   BIC:                         1.393e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3392      0.136      2.491      0.013       0.072       0.606
# 대비_irs_10Y    -0.3897      0.155     -2.513      0.012      -0.694      -0.086
# 대비_crs_1Y     -0.6974      0.132     -5.267      0.000      -0.957      -0.438
# 대비_crs_2Y      0.0644      0.186      0.345      0.730      -0.301       0.430
# 대비_crs_3Y     -0.3032      0.159     -1.907      0.057      -0.615       0.009
# 대비_crs_5Y     -0.3036      0.210     -1.445      0.148      -0.716       0.108
# 대비_crs_10Y     0.1234      0.157      0.788      0.431      -0.184       0.430
# 대비_국고_1Y       0.0043      0.111      0.039      0.969      -0.214       0.222
# 대비_국고_3Y      -0.1623      0.091     -1.789      0.074      -0.340       0.016
# 대비_국고_5Y       0.3031      0.201      1.508      0.132      -0.091       0.697
# 대비_국고_10Y     -0.0184      0.182     -0.101      0.920      -0.376       0.339
# 스왑포인트_1M      -1.1721      0.091    -12.913      0.000      -1.350      -0.994
# 전일종가_ex       55.7341      0.089    628.484      0.000      55.560      55.908
# 종가_NDF_차이     -3.9531      0.088    -45.151      0.000      -4.125      -3.781
# ==============================================================================
# Omnibus:                      212.515   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              922.903
# Skew:                           0.310   Prob(JB):                    3.93e-201
# Kurtosis:                       5.937   Cond. No.                         6.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_2Y', '대비_국고_1Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 3.892e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:17:07   Log-Likelihood:                -6908.5
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2446   BIC:                         1.392e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3422      0.133      2.565      0.010       0.081       0.604
# 대비_irs_10Y    -0.3921      0.154     -2.549      0.011      -0.694      -0.090
# 대비_crs_1Y     -0.6762      0.118     -5.754      0.000      -0.907      -0.446
# 대비_crs_3Y     -0.2873      0.152     -1.887      0.059      -0.586       0.011
# 대비_crs_5Y     -0.2771      0.196     -1.417      0.157      -0.661       0.107
# 대비_crs_10Y     0.1236      0.156      0.790      0.429      -0.183       0.430
# 대비_국고_3Y      -0.1616      0.090     -1.798      0.072      -0.338       0.015
# 대비_국고_5Y       0.3073      0.191      1.611      0.107      -0.067       0.681
# 대비_국고_10Y     -0.0192      0.182     -0.106      0.916      -0.377       0.338
# 스왑포인트_1M      -1.1716      0.091    -12.914      0.000      -1.349      -0.994
# 전일종가_ex       55.7345      0.088    630.551      0.000      55.561      55.908
# 종가_NDF_차이     -3.9520      0.087    -45.199      0.000      -4.123      -3.781
# ==============================================================================
# Omnibus:                      211.519   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              916.740
# Skew:                           0.308   Prob(JB):                    8.56e-200
# Kurtosis:                       5.927   Cond. No.                         6.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_10Y', '대비_국고_10Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 4.672e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:17:28   Log-Likelihood:                -6908.8
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2448   BIC:                         1.390e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3418      0.131      2.601      0.009       0.084       0.599
# 대비_irs_10Y    -0.3913      0.151     -2.589      0.010      -0.688      -0.095
# 대비_crs_1Y     -0.6744      0.117     -5.742      0.000      -0.905      -0.444
# 대비_crs_3Y     -0.2813      0.152     -1.851      0.064      -0.579       0.017
# 대비_crs_5Y     -0.1788      0.151     -1.184      0.237      -0.475       0.117
# 대비_국고_3Y      -0.1624      0.090     -1.808      0.071      -0.339       0.014
# 대비_국고_5Y       0.2938      0.112      2.628      0.009       0.075       0.513
# 스왑포인트_1M      -1.1728      0.091    -12.933      0.000      -1.351      -0.995
# 전일종가_ex       55.7336      0.088    630.774      0.000      55.560      55.907
# 종가_NDF_차이     -3.9530      0.087    -45.246      0.000      -4.124      -3.782
# ==============================================================================
# Omnibus:                      211.956   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              916.239
# Skew:                           0.310   Prob(JB):                    1.10e-199
# Kurtosis:                       5.925   Cond. No.                         4.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_crs_5Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.191e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:18:13   Log-Likelihood:                -6909.5
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2449   BIC:                         1.390e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3494      0.131      2.661      0.008       0.092       0.607
# 대비_irs_10Y    -0.4055      0.151     -2.692      0.007      -0.701      -0.110
# 대비_crs_1Y     -0.7104      0.113     -6.261      0.000      -0.933      -0.488
# 대비_crs_3Y     -0.3979      0.116     -3.436      0.001      -0.625      -0.171
# 대비_국고_3Y      -0.1643      0.090     -1.829      0.068      -0.340       0.012
# 대비_국고_5Y       0.2781      0.111      2.506      0.012       0.060       0.496
# 스왑포인트_1M      -1.1721      0.091    -12.925      0.000      -1.350      -0.994
# 전일종가_ex       55.7357      0.088    630.866      0.000      55.562      55.909
# 종가_NDF_차이     -3.9523      0.087    -45.235      0.000      -4.124      -3.781
# ==============================================================================
# Omnibus:                      212.792   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              924.214
# Skew:                           0.311   Prob(JB):                    2.04e-201
# Kurtosis:                       5.938   Cond. No.                         3.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['대비_국고_3Y'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.834e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:18:34   Log-Likelihood:                -6911.2
# No. Observations:                2459   AIC:                         1.384e+04
# Df Residuals:                    2450   BIC:                         1.389e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1134.8939      0.081    1.4e+04      0.000    1134.735    1135.053
# 대비_irs_1Y      0.3313      0.131      2.530      0.011       0.075       0.588
# 대비_irs_10Y    -0.3942      0.151     -2.618      0.009      -0.690      -0.099
# 대비_crs_1Y     -0.7120      0.114     -6.272      0.000      -0.935      -0.489
# 대비_crs_3Y     -0.4001      0.116     -3.454      0.001      -0.627      -0.173
# 대비_국고_5Y       0.2091      0.104      2.002      0.045       0.004       0.414
# 스왑포인트_1M      -1.1734      0.091    -12.934      0.000      -1.351      -0.996
# 전일종가_ex       55.7354      0.088    630.562      0.000      55.562      55.909
# 종가_NDF_차이     -3.9557      0.087    -45.263      0.000      -4.127      -3.784
# ==============================================================================
# Omnibus:                      211.730   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              916.319
# Skew:                           0.309   Prob(JB):                    1.06e-199
# Kurtosis:                       5.926   Cond. No.                         3.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.columns
# Out:
# Index(['대비_irs_1Y', '대비_irs_10Y', '대비_crs_1Y', '대비_crs_3Y', '대비_국고_5Y',
#        '스왑포인트_1M', '전일종가_ex', '종가_NDF_차이'],
#       dtype='object')

# %%
df_scaled = pd.concat([x_scaled, y], axis=1)
df_scaled
# Out:
#             대비_irs_1Y  대비_irs_10Y  대비_crs_1Y  대비_crs_3Y  대비_국고_5Y  스왑포인트_1M  \
# DateTime
# 2012-08-02  -0.847862   -1.009126  -0.205655   0.905480 -1.079749  1.909409
# 2012-08-03  -0.847862   -0.403231  -0.205655  -0.463176 -1.890219  1.818881
# 2012-08-06   0.560374    0.202663  -0.003373  -0.691285  0.000879  1.818881
# 2012-08-07   0.278727    0.404628   0.401191  -0.006957  0.000879  1.909409
# 2012-08-08   0.278727    0.606592   0.198909  -0.006957 -0.539435  1.818881
# ...               ...         ...        ...        ...       ...       ...
# 2022-07-25  -1.129510   -2.220914  -1.621628  -1.603722 -1.890219 -0.896960
# 2022-07-26  -0.284568   -0.605196   0.198909  -0.691285 -0.539435 -0.987488
# 2022-07-27  -0.284568   -1.211091   0.198909  -0.235067 -1.349905 -0.851696
# 2022-07-28   0.842021    1.414452   0.805755   0.905480  0.811350 -0.942224
# 2022-07-29  -1.974451   -2.422879  -2.228474  -3.428596 -3.241004 -0.896960
#
#              전일종가_ex  종가_NDF_차이   종가_ex
# DateTime
# 2012-08-02 -0.149841  -1.648743  1131.7
# 2012-08-03 -0.056232  -1.366022  1134.8
# 2012-08-06 -0.000426   1.602547  1129.0
# 2012-08-07 -0.104837   0.118263  1128.8
# 2012-08-08 -0.108437  -0.223358  1128.3
# ...              ...        ...     ...
# 2022-07-25  3.207485   0.860405  1313.7
# 2022-07-26  3.220086   0.754385  1307.6
# 2022-07-27  3.110275  -0.564979  1313.3
# 2022-07-28  3.212885   1.838148  1296.1
# 2022-07-29  2.903255   0.200723  1299.1
#
# [2459 rows x 9 columns]

# %%
train = df_scaled[0:1945]
test = df_scaled[1945:]

def make_dataset(data, label, window_size=1):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

feature_cols = ['대비_irs_1Y', '대비_irs_10Y', '대비_crs_1Y', '대비_crs_3Y', '대비_국고_5Y',
       '스왑포인트_1M', '전일종가_ex', '종가_NDF_차이']
label_cols = ['종가_ex']

# %%
from sklearn.model_selection import train_test_split

train_feature = train[feature_cols]
train_label = train[label_cols]
test_feature = test[feature_cols]
test_label = test[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 1)
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((1555, 1, 8), (389, 1, 8))

# %%
train_feature
# Out:
# array([[[-8.47862468e-01, -1.00912576e+00, -2.05654693e-01, ...,
#           1.90940854e+00, -1.49840936e-01, -1.64874272e+00]],
#
#        [[-8.47862468e-01, -4.03231428e-01, -2.05654693e-01, ...,
#           1.81888052e+00, -5.62318504e-02, -1.36602186e+00]],
#
#        [[ 5.60373809e-01,  2.02662908e-01, -3.37273697e-03, ...,
#           1.81888052e+00, -4.26434230e-04,  1.60254716e+00]],
#
#        ...,
#
#        [[-2.84567957e-01, -4.03231428e-01,  1.41260096e+00, ...,
#          -4.89583909e-01,  1.25789569e+00,  7.54384581e-01]],
#
#        [[ 2.78726554e-01,  2.02662908e-01, -6.10218605e-01, ...,
#          -3.53791884e-01,  1.18408853e+00, -6.82779784e-01]],
#
#        [[-2.92070151e-03,  6.06592466e-01, -6.10218605e-01, ...,
#          -5.34847918e-01,  1.14808503e+00,  4.75824341e-02]]])

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 1)
test_feature.shape, test_label.shape
# Out:
# ((513, 1, 8), (513, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM

# 모델의 설정
model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )
model.add(Dense(1))

# 모델의 컴파일(모델학습을 위한 학습과정 설정단계)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
early_stop = EarlyStopping(monitor='val_loss', patience=10)
modelpath = './'
checkpoint = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
# filename = os.path.join(file_path=model_path, 'tmp_checkpoint.h5')

# 모델의 실행
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])

# 테스트 정확도 출력                    
# print("\n Test Accuracy: %.4f" % model.evaluate(x_valid, y_valid))
# Out:
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 210002.1562 - mae: 400.2354 - val_loss: 220528.8281 - val_mae: 397.2820
# Epoch 61/200
# 98/98 [==============================] - ETA: 0s - loss: 201324.1406 - mae: 389.8841
# Epoch 61: val_loss improved from 220528.82812 to 213091.98438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 43ms/step - loss: 201324.1406 - mae: 389.8841 - val_loss: 213091.9844 - val_mae: 386.7878
# Epoch 62/200
# 92/98 [===========================>..] - ETA: 0s - loss: 195407.0625 - mae: 381.6481
# Epoch 62: val_loss improved from 213091.98438 to 206222.81250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 51ms/step - loss: 192978.0000 - mae: 379.8165 - val_loss: 206222.8125 - val_mae: 376.8496
# Epoch 63/200
# 82/98 [========================>.....] - ETA: 0s - loss: 185394.7031 - mae: 369.9561
# Epoch 63: val_loss improved from 206222.81250 to 199590.12500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 184739.1875 - mae: 369.8442 - val_loss: 199590.1250 - val_mae: 367.0051
# Epoch 64/200
# 84/98 [========================>.....] - ETA: 0s - loss: 171947.8281 - mae: 361.5161
# Epoch 64: val_loss improved from 199590.12500 to 193431.59375, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 46ms/step - loss: 176507.5312 - mae: 360.1619 - val_loss: 193431.5938 - val_mae: 357.6514
# Epoch 65/200
# 81/98 [=======================>......] - ETA: 0s - loss: 164861.9688 - mae: 353.5433
# Epoch 65: val_loss improved from 193431.59375 to 187604.82812, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 46ms/step - loss: 168979.7500 - mae: 350.9359 - val_loss: 187604.8281 - val_mae: 348.4967
# Epoch 66/200
# 87/98 [=========================>....] - ETA: 0s - loss: 162450.8281 - mae: 341.2162
# Epoch 66: val_loss improved from 187604.82812 to 182085.28125, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 162078.0625 - mae: 341.9654 - val_loss: 182085.2812 - val_mae: 339.8370
# Epoch 67/200
# 89/98 [==========================>...] - ETA: 0s - loss: 156751.5938 - mae: 334.0676
# Epoch 67: val_loss improved from 182085.28125 to 176861.18750, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 155510.5312 - mae: 333.3015 - val_loss: 176861.1875 - val_mae: 331.3628
# Epoch 68/200
# 86/98 [=========================>....] - ETA: 0s - loss: 151394.0781 - mae: 326.6415
# Epoch 68: val_loss improved from 176861.18750 to 171963.40625, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 149306.7969 - mae: 324.9405 - val_loss: 171963.4062 - val_mae: 323.2058
# Epoch 69/200
# 78/98 [======================>.......] - ETA: 0s - loss: 144369.8906 - mae: 314.9315
# Epoch 69: val_loss improved from 171963.40625 to 167277.81250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 143268.8438 - mae: 316.7011 - val_loss: 167277.8125 - val_mae: 315.1816
# Epoch 70/200
# 81/98 [=======================>......] - ETA: 0s - loss: 141013.5781 - mae: 311.1585
# Epoch 70: val_loss improved from 167277.81250 to 162897.25000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 137242.7031 - mae: 309.0087 - val_loss: 162897.2500 - val_mae: 307.4930
# Epoch 71/200
# 88/98 [=========================>....] - ETA: 0s - loss: 126109.4688 - mae: 299.9965
# Epoch 71: val_loss improved from 162897.25000 to 158625.15625, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 131074.8438 - mae: 300.8596 - val_loss: 158625.1562 - val_mae: 299.7035
# Epoch 72/200
# 75/98 [=====================>........] - ETA: 0s - loss: 124655.8828 - mae: 290.1429
# Epoch 72: val_loss improved from 158625.15625 to 154749.90625, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 30ms/step - loss: 125495.1328 - mae: 293.6917 - val_loss: 154749.9062 - val_mae: 292.3843
# Epoch 73/200
# 87/98 [=========================>....] - ETA: 0s - loss: 122033.9688 - mae: 287.7980
# Epoch 73: val_loss improved from 154749.90625 to 150981.50000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 120427.5312 - mae: 286.4419 - val_loss: 150981.5000 - val_mae: 284.9765
# Epoch 74/200
# 89/98 [==========================>...] - ETA: 0s - loss: 114826.4844 - mae: 278.5474
# Epoch 74: val_loss improved from 150981.50000 to 147503.75000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 115783.7969 - mae: 279.5898 - val_loss: 147503.7500 - val_mae: 277.7766
# Epoch 75/200
# 88/98 [=========================>....] - ETA: 0s - loss: 109599.8828 - mae: 273.2320
# Epoch 75: val_loss improved from 147503.75000 to 144011.71875, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 46ms/step - loss: 111346.0078 - mae: 272.8711 - val_loss: 144011.7188 - val_mae: 270.8053
# Epoch 76/200
# 80/98 [=======================>......] - ETA: 0s - loss: 112033.6875 - mae: 270.1866
# Epoch 76: val_loss improved from 144011.71875 to 140925.23438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 47ms/step - loss: 107138.9531 - mae: 266.4031 - val_loss: 140925.2344 - val_mae: 264.3481
# Epoch 77/200
# 92/98 [===========================>..] - ETA: 0s - loss: 103137.4219 - mae: 259.8679
# Epoch 77: val_loss improved from 140925.23438 to 137919.01562, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 43ms/step - loss: 103130.7812 - mae: 260.2470 - val_loss: 137919.0156 - val_mae: 257.8396
# Epoch 78/200
# 96/98 [============================>.] - ETA: 0s - loss: 99250.6484 - mae: 253.3257
# Epoch 78: val_loss improved from 137919.01562 to 134963.85938, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 99343.4219 - mae: 253.9143 - val_loss: 134963.8594 - val_mae: 251.6566
# Epoch 79/200
# 97/98 [============================>.] - ETA: 0s - loss: 95773.7188 - mae: 248.2278
# Epoch 79: val_loss improved from 134963.85938 to 132149.95312, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 95658.8125 - mae: 248.0507 - val_loss: 132149.9531 - val_mae: 245.6634
# Epoch 80/200
# 73/98 [=====================>........] - ETA: 0s - loss: 87451.9609 - mae: 239.8838
# Epoch 80: val_loss improved from 132149.95312 to 129438.17969, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 92126.7969 - mae: 242.2631 - val_loss: 129438.1797 - val_mae: 239.8429
# Epoch 81/200
# 97/98 [============================>.] - ETA: 0s - loss: 88555.2812 - mae: 236.8188
# Epoch 81: val_loss improved from 129438.17969 to 126798.46094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 88458.8438 - mae: 236.6674 - val_loss: 126798.4609 - val_mae: 234.4418
# Epoch 82/200
# 73/98 [=====================>........] - ETA: 0s - loss: 83547.2031 - mae: 231.0195
# Epoch 82: val_loss improved from 126798.46094 to 124329.96094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 84820.6328 - mae: 231.1387 - val_loss: 124329.9609 - val_mae: 229.0444
# Epoch 83/200
# 80/98 [=======================>......] - ETA: 0s - loss: 85289.3203 - mae: 230.6685
# Epoch 83: val_loss improved from 124329.96094 to 122046.10156, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 81642.0547 - mae: 225.9346 - val_loss: 122046.1016 - val_mae: 223.9372
# Epoch 84/200
# 76/98 [======================>.......] - ETA: 0s - loss: 80280.6875 - mae: 222.5325
# Epoch 84: val_loss improved from 122046.10156 to 119505.95312, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 78627.2188 - mae: 220.8304 - val_loss: 119505.9531 - val_mae: 218.9625
# Epoch 85/200
# 89/98 [==========================>...] - ETA: 0s - loss: 77484.9766 - mae: 218.3073
# Epoch 85: val_loss improved from 119505.95312 to 117197.50781, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 75758.6875 - mae: 215.9738 - val_loss: 117197.5078 - val_mae: 214.2358
# Epoch 86/200
# 81/98 [=======================>......] - ETA: 0s - loss: 76035.7500 - mae: 214.4152
# Epoch 86: val_loss improved from 117197.50781 to 114998.05469, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 72956.5625 - mae: 211.1812 - val_loss: 114998.0547 - val_mae: 209.7833
# Epoch 87/200
# 92/98 [===========================>..] - ETA: 0s - loss: 71152.1328 - mae: 207.3788
# Epoch 87: val_loss improved from 114998.05469 to 112891.99219, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 70306.8672 - mae: 206.1831 - val_loss: 112891.9922 - val_mae: 205.3580
# Epoch 88/200
# 85/98 [=========================>....] - ETA: 0s - loss: 67939.5391 - mae: 202.3983
# Epoch 88: val_loss improved from 112891.99219 to 110762.73438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 67821.3438 - mae: 201.6273 - val_loss: 110762.7344 - val_mae: 201.1951
# Epoch 89/200
# 84/98 [========================>.....] - ETA: 0s - loss: 60434.0664 - mae: 194.4207
# Epoch 89: val_loss improved from 110762.73438 to 108657.79688, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 65509.9492 - mae: 197.1803 - val_loss: 108657.7969 - val_mae: 197.1334
# Epoch 90/200
# 86/98 [=========================>....] - ETA: 0s - loss: 65066.6328 - mae: 193.3197
# Epoch 90: val_loss improved from 108657.79688 to 106640.14062, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 63227.4688 - mae: 192.9809 - val_loss: 106640.1406 - val_mae: 193.2450
# Epoch 91/200
# 84/98 [========================>.....] - ETA: 0s - loss: 57540.7500 - mae: 186.7664
# Epoch 91: val_loss improved from 106640.14062 to 104721.59375, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 61070.2305 - mae: 188.8595 - val_loss: 104721.5938 - val_mae: 189.2471
# Epoch 92/200
# 94/98 [===========================>..] - ETA: 0s - loss: 58352.0156 - mae: 183.9475
# Epoch 92: val_loss improved from 104721.59375 to 102582.96094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 29ms/step - loss: 59076.8984 - mae: 184.6142 - val_loss: 102582.9609 - val_mae: 185.6211
# Epoch 93/200
# 86/98 [=========================>....] - ETA: 0s - loss: 58209.9023 - mae: 181.4111
# Epoch 93: val_loss improved from 102582.96094 to 100735.66406, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 57023.8086 - mae: 180.6796 - val_loss: 100735.6641 - val_mae: 181.9447
# Epoch 94/200
# 84/98 [========================>.....] - ETA: 0s - loss: 52017.6719 - mae: 177.1336
# Epoch 94: val_loss improved from 100735.66406 to 98906.46094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 55103.2812 - mae: 176.8115 - val_loss: 98906.4609 - val_mae: 178.3584
# Epoch 95/200
# 83/98 [========================>.....] - ETA: 0s - loss: 56236.2109 - mae: 175.5021
# Epoch 95: val_loss improved from 98906.46094 to 96977.26562, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 53229.1055 - mae: 173.0641 - val_loss: 96977.2656 - val_mae: 174.8343
# Epoch 96/200
# 89/98 [==========================>...] - ETA: 0s - loss: 52865.7734 - mae: 169.5481
# Epoch 96: val_loss improved from 96977.26562 to 95149.23438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 51384.0352 - mae: 169.2665 - val_loss: 95149.2344 - val_mae: 171.4264
# Epoch 97/200
# 86/98 [=========================>....] - ETA: 0s - loss: 48519.1680 - mae: 165.1848
# Epoch 97: val_loss improved from 95149.23438 to 93396.78906, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 51ms/step - loss: 49594.2891 - mae: 165.5465 - val_loss: 93396.7891 - val_mae: 168.0170
# Epoch 98/200
# 81/98 [=======================>......] - ETA: 0s - loss: 49931.2656 - mae: 163.2424
# Epoch 98: val_loss improved from 93396.78906 to 91627.06250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 32ms/step - loss: 47904.9102 - mae: 161.8926 - val_loss: 91627.0625 - val_mae: 164.7867
# Epoch 99/200
# 93/98 [===========================>..] - ETA: 0s - loss: 46991.0703 - mae: 158.6849
# Epoch 99: val_loss improved from 91627.06250 to 89896.55469, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 46248.6680 - mae: 158.1831 - val_loss: 89896.5547 - val_mae: 161.6170
# Epoch 100/200
# 86/98 [=========================>....] - ETA: 0s - loss: 43254.3242 - mae: 154.9570
# Epoch 100: val_loss improved from 89896.55469 to 88168.20312, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 45ms/step - loss: 44655.6562 - mae: 154.7230 - val_loss: 88168.2031 - val_mae: 158.4123
# Epoch 101/200
# 91/98 [==========================>...] - ETA: 0s - loss: 42981.1641 - mae: 150.5490
# Epoch 101: val_loss improved from 88168.20312 to 86446.76562, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 43108.3867 - mae: 151.1055 - val_loss: 86446.7656 - val_mae: 155.3264
# Epoch 102/200
# 91/98 [==========================>...] - ETA: 0s - loss: 39259.2227 - mae: 145.5053
# Epoch 102: val_loss improved from 86446.76562 to 84889.19531, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 45ms/step - loss: 41639.4414 - mae: 147.7359 - val_loss: 84889.1953 - val_mae: 152.2301
# Epoch 103/200
# 94/98 [===========================>..] - ETA: 0s - loss: 39972.6445 - mae: 144.3891
# Epoch 103: val_loss improved from 84889.19531 to 82980.93750, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 40156.5625 - mae: 144.7616 - val_loss: 82980.9375 - val_mae: 149.4669
# Epoch 104/200
# 96/98 [============================>.] - ETA: 0s - loss: 39001.4492 - mae: 141.7119
# Epoch 104: val_loss improved from 82980.93750 to 81321.40625, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 38797.3203 - mae: 141.5617 - val_loss: 81321.4062 - val_mae: 146.4955
# Epoch 105/200
# 75/98 [=====================>........] - ETA: 0s - loss: 38095.5820 - mae: 138.4185
# Epoch 105: val_loss improved from 81321.40625 to 79779.60156, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 43ms/step - loss: 37446.9805 - mae: 138.1364 - val_loss: 79779.6016 - val_mae: 143.4871
# Epoch 106/200
# 90/98 [==========================>...] - ETA: 0s - loss: 36652.4375 - mae: 135.1691
# Epoch 106: val_loss improved from 79779.60156 to 78134.73438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 36144.4883 - mae: 135.1331 - val_loss: 78134.7344 - val_mae: 140.5757
# Epoch 107/200
# 95/98 [============================>.] - ETA: 0s - loss: 35255.7734 - mae: 132.3703
# Epoch 107: val_loss improved from 78134.73438 to 76550.02344, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 34851.3125 - mae: 131.8854 - val_loss: 76550.0234 - val_mae: 137.5392
# Epoch 108/200
# 80/98 [=======================>......] - ETA: 0s - loss: 33635.8867 - mae: 130.3945
# Epoch 108: val_loss improved from 76550.02344 to 74919.07812, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 32ms/step - loss: 33589.2539 - mae: 128.7690 - val_loss: 74919.0781 - val_mae: 134.5407
# Epoch 109/200
# 74/98 [=====================>........] - ETA: 0s - loss: 30286.9863 - mae: 123.7504
# Epoch 109: val_loss improved from 74919.07812 to 73420.52344, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 32290.7188 - mae: 125.2769 - val_loss: 73420.5234 - val_mae: 131.4650
# Epoch 110/200
# 92/98 [===========================>..] - ETA: 0s - loss: 31400.1895 - mae: 121.6092
# Epoch 110: val_loss improved from 73420.52344 to 71755.71094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 45ms/step - loss: 31004.5664 - mae: 122.0536 - val_loss: 71755.7109 - val_mae: 128.4542
# Epoch 111/200
# 91/98 [==========================>...] - ETA: 0s - loss: 30712.6680 - mae: 119.8407
# Epoch 111: val_loss improved from 71755.71094 to 70093.06250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 29709.3047 - mae: 118.7947 - val_loss: 70093.0625 - val_mae: 125.1281
# Epoch 112/200
# 90/98 [==========================>...] - ETA: 0s - loss: 28762.0645 - mae: 115.8234
# Epoch 112: val_loss improved from 70093.06250 to 68355.63281, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 28405.4180 - mae: 115.3218 - val_loss: 68355.6328 - val_mae: 121.7696
# Epoch 113/200
# 84/98 [========================>.....] - ETA: 0s - loss: 28773.5625 - mae: 113.1516
# Epoch 113: val_loss improved from 68355.63281 to 66720.75000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 27125.7383 - mae: 111.8117 - val_loss: 66720.7500 - val_mae: 118.2726
# Epoch 114/200
# 77/98 [======================>.......] - ETA: 0s - loss: 26245.3691 - mae: 108.8086
# Epoch 114: val_loss improved from 66720.75000 to 65013.23828, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 25845.2109 - mae: 108.3470 - val_loss: 65013.2383 - val_mae: 114.6430
# Epoch 115/200
# 88/98 [=========================>....] - ETA: 0s - loss: 23326.5469 - mae: 103.9169
# Epoch 115: val_loss improved from 65013.23828 to 63534.76172, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 24593.5391 - mae: 104.6126 - val_loss: 63534.7617 - val_mae: 110.8750
# Epoch 116/200
# 86/98 [=========================>....] - ETA: 0s - loss: 22376.0059 - mae: 100.9903
# Epoch 116: val_loss improved from 63534.76172 to 61862.50000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 23360.0391 - mae: 100.8425 - val_loss: 61862.5000 - val_mae: 107.1377
# Epoch 117/200
# 86/98 [=========================>....] - ETA: 0s - loss: 21525.3730 - mae: 97.8498
# Epoch 117: val_loss improved from 61862.50000 to 60325.58203, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 22086.1152 - mae: 97.0779 - val_loss: 60325.5820 - val_mae: 103.4042
# Epoch 118/200
# 98/98 [==============================] - ETA: 0s - loss: 20733.1992 - mae: 93.1806
# Epoch 118: val_loss improved from 60325.58203 to 58775.88281, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 20733.1992 - mae: 93.1806 - val_loss: 58775.8828 - val_mae: 99.6762
# Epoch 119/200
# 78/98 [======================>.......] - ETA: 0s - loss: 20213.7891 - mae: 91.3443
# Epoch 119: val_loss improved from 58775.88281 to 57293.70312, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 19293.0762 - mae: 89.5925 - val_loss: 57293.7031 - val_mae: 95.9769
# Epoch 120/200
# 95/98 [============================>.] - ETA: 0s - loss: 18232.2656 - mae: 85.7232
# Epoch 120: val_loss improved from 57293.70312 to 55904.35547, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 6s 57ms/step - loss: 18069.2305 - mae: 85.6961 - val_loss: 55904.3555 - val_mae: 92.2563
# Epoch 121/200
# 94/98 [===========================>..] - ETA: 0s - loss: 16508.1348 - mae: 81.8135
# Epoch 121: val_loss improved from 55904.35547 to 54522.80078, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 17031.8398 - mae: 82.1352 - val_loss: 54522.8008 - val_mae: 88.8058
# Epoch 122/200
# 80/98 [=======================>......] - ETA: 0s - loss: 17425.1875 - mae: 79.6577
# Epoch 122: val_loss improved from 54522.80078 to 53266.81641, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 16069.7354 - mae: 78.6796 - val_loss: 53266.8164 - val_mae: 85.4251
# Epoch 123/200
# 75/98 [=====================>........] - ETA: 0s - loss: 14391.5703 - mae: 74.7038
# Epoch 123: val_loss improved from 53266.81641 to 52036.42188, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 15177.9629 - mae: 75.4167 - val_loss: 52036.4219 - val_mae: 82.0289
# Epoch 124/200
# 75/98 [=====================>........] - ETA: 0s - loss: 15697.2852 - mae: 73.2475
# Epoch 124: val_loss improved from 52036.42188 to 50871.45312, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 14296.6709 - mae: 71.9956 - val_loss: 50871.4531 - val_mae: 78.8095
# Epoch 125/200
# 96/98 [============================>.] - ETA: 0s - loss: 13612.7568 - mae: 69.1457
# Epoch 125: val_loss improved from 50871.45312 to 49660.23047, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 52ms/step - loss: 13494.4814 - mae: 68.9174 - val_loss: 49660.2305 - val_mae: 75.7273
# Epoch 126/200
# 80/98 [=======================>......] - ETA: 0s - loss: 13997.9873 - mae: 67.0731
# Epoch 126: val_loss improved from 49660.23047 to 48616.37500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 12743.1777 - mae: 66.0933 - val_loss: 48616.3750 - val_mae: 72.7681
# Epoch 127/200
# 86/98 [=========================>....] - ETA: 0s - loss: 10499.1602 - mae: 62.0552
# Epoch 127: val_loss improved from 48616.37500 to 47695.34766, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 12036.1553 - mae: 63.1750 - val_loss: 47695.3477 - val_mae: 69.9745
# Epoch 128/200
# 96/98 [============================>.] - ETA: 0s - loss: 11458.2178 - mae: 60.9331
# Epoch 128: val_loss improved from 47695.34766 to 46569.25000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 11352.8291 - mae: 60.7275 - val_loss: 46569.2500 - val_mae: 67.3490
# Epoch 129/200
# 81/98 [=======================>......] - ETA: 0s - loss: 10609.3848 - mae: 58.2469
# Epoch 129: val_loss improved from 46569.25000 to 45778.40234, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 10696.1406 - mae: 58.0875 - val_loss: 45778.4023 - val_mae: 64.7135
# Epoch 130/200
# 97/98 [============================>.] - ETA: 0s - loss: 10087.0732 - mae: 55.6041
# Epoch 130: val_loss improved from 45778.40234 to 44869.23438, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 10070.8428 - mae: 55.5668 - val_loss: 44869.2344 - val_mae: 62.3552
# Epoch 131/200
# 83/98 [========================>.....] - ETA: 0s - loss: 10531.5068 - mae: 54.2729
# Epoch 131: val_loss improved from 44869.23438 to 43864.08203, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 9490.1094 - mae: 53.2282 - val_loss: 43864.0820 - val_mae: 60.1243
# Epoch 132/200
# 75/98 [=====================>........] - ETA: 0s - loss: 9766.8428 - mae: 51.0678
# Epoch 132: val_loss improved from 43864.08203 to 43069.08594, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 8940.3320 - mae: 50.8041 - val_loss: 43069.0859 - val_mae: 57.8829
# Epoch 133/200
# 79/98 [=======================>......] - ETA: 0s - loss: 9369.4561 - mae: 48.5694
# Epoch 133: val_loss improved from 43069.08594 to 42273.92188, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 48ms/step - loss: 8467.8975 - mae: 48.5888 - val_loss: 42273.9219 - val_mae: 55.8910
# Epoch 134/200
# 81/98 [=======================>......] - ETA: 0s - loss: 7285.3975 - mae: 46.1014
# Epoch 134: val_loss improved from 42273.92188 to 41530.98047, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 47ms/step - loss: 8037.2573 - mae: 46.4920 - val_loss: 41530.9805 - val_mae: 53.8653
# Epoch 135/200
# 94/98 [===========================>..] - ETA: 0s - loss: 7813.8125 - mae: 44.8870
# Epoch 135: val_loss improved from 41530.98047 to 40756.59766, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 7636.9336 - mae: 44.6196 - val_loss: 40756.5977 - val_mae: 52.1976
# Epoch 136/200
# 91/98 [==========================>...] - ETA: 0s - loss: 7433.2993 - mae: 42.9294
# Epoch 136: val_loss improved from 40756.59766 to 40032.81250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 7270.0688 - mae: 42.9812 - val_loss: 40032.8125 - val_mae: 50.5032
# Epoch 137/200
# 96/98 [============================>.] - ETA: 0s - loss: 6723.5376 - mae: 40.9750
# Epoch 137: val_loss improved from 40032.81250 to 39337.78516, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 6926.9082 - mae: 41.2670 - val_loss: 39337.7852 - val_mae: 49.0492
# Epoch 138/200
# 86/98 [=========================>....] - ETA: 0s - loss: 5817.2886 - mae: 39.4590
# Epoch 138: val_loss improved from 39337.78516 to 38526.06250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 6576.3711 - mae: 39.8088 - val_loss: 38526.0625 - val_mae: 47.6849
# Epoch 139/200
# 90/98 [==========================>...] - ETA: 0s - loss: 6638.6592 - mae: 38.9850
# Epoch 139: val_loss improved from 38526.06250 to 37888.60547, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 6293.0571 - mae: 38.5183 - val_loss: 37888.6055 - val_mae: 46.2943
# Epoch 140/200
# 81/98 [=======================>......] - ETA: 0s - loss: 6775.9092 - mae: 37.9584
# Epoch 140: val_loss improved from 37888.60547 to 37285.14844, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 6003.7671 - mae: 37.0208 - val_loss: 37285.1484 - val_mae: 45.0897
# Epoch 141/200
# 87/98 [=========================>....] - ETA: 0s - loss: 6211.2534 - mae: 36.4497
# Epoch 141: val_loss improved from 37285.14844 to 36670.61328, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 5737.2271 - mae: 35.7519 - val_loss: 36670.6133 - val_mae: 43.7747
# Epoch 142/200
# 91/98 [==========================>...] - ETA: 0s - loss: 5623.2173 - mae: 34.7855
# Epoch 142: val_loss improved from 36670.61328 to 36132.59375, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 5483.0664 - mae: 34.5515 - val_loss: 36132.5938 - val_mae: 42.6962
# Epoch 143/200
# 91/98 [==========================>...] - ETA: 0s - loss: 5399.5840 - mae: 33.5878
# Epoch 143: val_loss improved from 36132.59375 to 35515.24609, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 43ms/step - loss: 5231.2822 - mae: 33.3619 - val_loss: 35515.2461 - val_mae: 41.5239
# Epoch 144/200
# 87/98 [=========================>....] - ETA: 0s - loss: 5233.5400 - mae: 32.3530
# Epoch 144: val_loss improved from 35515.24609 to 34974.32031, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 4995.4141 - mae: 32.2649 - val_loss: 34974.3203 - val_mae: 40.5673
# Epoch 145/200
# 96/98 [============================>.] - ETA: 0s - loss: 4824.1934 - mae: 31.3463
# Epoch 145: val_loss improved from 34974.32031 to 34447.14062, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 4768.2578 - mae: 31.1069 - val_loss: 34447.1406 - val_mae: 39.7080
# Epoch 146/200
# 98/98 [==============================] - ETA: 0s - loss: 4548.5239 - mae: 30.2445
# Epoch 146: val_loss improved from 34447.14062 to 33984.99609, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 4548.5239 - mae: 30.2445 - val_loss: 33984.9961 - val_mae: 38.7157
# Epoch 147/200
# 87/98 [=========================>....] - ETA: 0s - loss: 3960.9648 - mae: 29.2246
# Epoch 147: val_loss improved from 33984.99609 to 33420.62109, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 4333.4731 - mae: 29.4436 - val_loss: 33420.6211 - val_mae: 37.9118
# Epoch 148/200
# 96/98 [============================>.] - ETA: 0s - loss: 4163.3472 - mae: 28.5486
# Epoch 148: val_loss improved from 33420.62109 to 32890.31250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 4124.1191 - mae: 28.4992 - val_loss: 32890.3125 - val_mae: 36.9238
# Epoch 149/200
# 98/98 [==============================] - ETA: 0s - loss: 3947.9827 - mae: 27.6694
# Epoch 149: val_loss improved from 32890.31250 to 32383.22461, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 43ms/step - loss: 3947.9827 - mae: 27.6694 - val_loss: 32383.2246 - val_mae: 36.1388
# Epoch 150/200
# 93/98 [===========================>..] - ETA: 0s - loss: 3903.9546 - mae: 27.1633
# Epoch 150: val_loss improved from 32383.22461 to 31908.74609, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 3773.0237 - mae: 26.9077 - val_loss: 31908.7461 - val_mae: 35.4136
# Epoch 151/200
# 95/98 [============================>.] - ETA: 0s - loss: 3673.5986 - mae: 26.2082
# Epoch 151: val_loss improved from 31908.74609 to 31466.77344, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 56ms/step - loss: 3606.8967 - mae: 26.1125 - val_loss: 31466.7734 - val_mae: 34.6824
# Epoch 152/200
# 88/98 [=========================>....] - ETA: 0s - loss: 3743.9260 - mae: 25.8781
# Epoch 152: val_loss improved from 31466.77344 to 30993.50195, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 3460.2644 - mae: 25.3396 - val_loss: 30993.5020 - val_mae: 34.0500
# Epoch 153/200
# 84/98 [========================>.....] - ETA: 0s - loss: 2640.5676 - mae: 23.3329
# Epoch 153: val_loss improved from 30993.50195 to 30579.08008, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 3314.6948 - mae: 24.5884 - val_loss: 30579.0801 - val_mae: 33.4011
# Epoch 154/200
# 74/98 [=====================>........] - ETA: 0s - loss: 2061.2876 - mae: 22.4225
# Epoch 154: val_loss improved from 30579.08008 to 30118.24414, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 3186.1345 - mae: 23.9993 - val_loss: 30118.2441 - val_mae: 32.8546
# Epoch 155/200
# 83/98 [========================>.....] - ETA: 0s - loss: 3399.4773 - mae: 23.9419
# Epoch 155: val_loss improved from 30118.24414 to 29702.53711, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 33ms/step - loss: 3055.1392 - mae: 23.4331 - val_loss: 29702.5371 - val_mae: 32.2906
# Epoch 156/200
# 82/98 [========================>.....] - ETA: 0s - loss: 2744.3794 - mae: 22.6030
# Epoch 156: val_loss improved from 29702.53711 to 29307.00586, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 2939.1477 - mae: 22.8370 - val_loss: 29307.0059 - val_mae: 31.6750
# Epoch 157/200
# 90/98 [==========================>...] - ETA: 0s - loss: 2960.5200 - mae: 22.4054
# Epoch 157: val_loss improved from 29307.00586 to 28923.14844, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 52ms/step - loss: 2814.7026 - mae: 22.2551 - val_loss: 28923.1484 - val_mae: 31.1276
# Epoch 158/200
# 82/98 [========================>.....] - ETA: 0s - loss: 2561.0886 - mae: 21.4900
# Epoch 158: val_loss improved from 28923.14844 to 28470.21094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 44ms/step - loss: 2705.8064 - mae: 21.6973 - val_loss: 28470.2109 - val_mae: 30.5645
# Epoch 159/200
# 93/98 [===========================>..] - ETA: 0s - loss: 2214.6755 - mae: 20.6902
# Epoch 159: val_loss improved from 28470.21094 to 28177.07422, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 2601.5830 - mae: 21.1161 - val_loss: 28177.0742 - val_mae: 30.0945
# Epoch 160/200
# 87/98 [=========================>....] - ETA: 0s - loss: 2728.3262 - mae: 20.9918
# Epoch 160: val_loss improved from 28177.07422 to 27688.01367, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 2499.6086 - mae: 20.6489 - val_loss: 27688.0137 - val_mae: 29.6538
# Epoch 161/200
# 83/98 [========================>.....] - ETA: 0s - loss: 1949.3695 - mae: 19.3312
# Epoch 161: val_loss improved from 27688.01367 to 27466.39648, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 11s 116ms/step - loss: 2399.6772 - mae: 20.0508 - val_loss: 27466.3965 - val_mae: 29.0827
# Epoch 162/200
# 90/98 [==========================>...] - ETA: 0s - loss: 1903.5460 - mae: 18.7019
# Epoch 162: val_loss improved from 27466.39648 to 26979.26758, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 10s 102ms/step - loss: 2306.7065 - mae: 19.5837 - val_loss: 26979.2676 - val_mae: 28.6270
# Epoch 163/200
# 86/98 [=========================>....] - ETA: 0s - loss: 2368.3367 - mae: 19.4896
# Epoch 163: val_loss improved from 26979.26758 to 26563.85156, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 56ms/step - loss: 2223.1003 - mae: 19.2530 - val_loss: 26563.8516 - val_mae: 28.2019
# Epoch 164/200
# 93/98 [===========================>..] - ETA: 0s - loss: 2203.2317 - mae: 18.8362
# Epoch 164: val_loss improved from 26563.85156 to 26199.13086, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 46ms/step - loss: 2130.7844 - mae: 18.7069 - val_loss: 26199.1309 - val_mae: 27.8144
# Epoch 165/200
# 93/98 [===========================>..] - ETA: 0s - loss: 2069.5190 - mae: 18.0822
# Epoch 165: val_loss improved from 26199.13086 to 25912.75000, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 45ms/step - loss: 2052.6128 - mae: 18.2082 - val_loss: 25912.7500 - val_mae: 27.4653
# Epoch 166/200
# 95/98 [============================>.] - ETA: 0s - loss: 1912.4674 - mae: 17.7679
# Epoch 166: val_loss improved from 25912.75000 to 25498.92969, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 45ms/step - loss: 1973.7352 - mae: 17.9058 - val_loss: 25498.9297 - val_mae: 27.0327
# Epoch 167/200
# 74/98 [=====================>........] - ETA: 0s - loss: 2217.4819 - mae: 17.7299
# Epoch 167: val_loss improved from 25498.92969 to 25163.21094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 5s 48ms/step - loss: 1895.8444 - mae: 17.4795 - val_loss: 25163.2109 - val_mae: 26.7154
# Epoch 168/200
# 73/98 [=====================>........] - ETA: 0s - loss: 2213.1523 - mae: 17.5587
# Epoch 168: val_loss improved from 25163.21094 to 24812.34180, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 1830.7723 - mae: 17.2158 - val_loss: 24812.3418 - val_mae: 26.2998
# Epoch 169/200
# 97/98 [============================>.] - ETA: 0s - loss: 1757.6481 - mae: 16.7620
# Epoch 169: val_loss improved from 24812.34180 to 24473.73242, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 1754.7013 - mae: 16.7524 - val_loss: 24473.7324 - val_mae: 25.9552
# Epoch 170/200
# 95/98 [============================>.] - ETA: 0s - loss: 1719.4283 - mae: 16.4818
# Epoch 170: val_loss improved from 24473.73242 to 24142.08984, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 1689.1044 - mae: 16.4491 - val_loss: 24142.0898 - val_mae: 25.6836
# Epoch 171/200
# 91/98 [==========================>...] - ETA: 0s - loss: 1677.1874 - mae: 16.3725
# Epoch 171: val_loss improved from 24142.08984 to 23818.17188, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 1624.3761 - mae: 16.1514 - val_loss: 23818.1719 - val_mae: 25.2521
# Epoch 172/200
# 91/98 [==========================>...] - ETA: 0s - loss: 1414.3971 - mae: 15.5057
# Epoch 172: val_loss improved from 23818.17188 to 23512.82422, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 32ms/step - loss: 1564.0277 - mae: 15.7753 - val_loss: 23512.8242 - val_mae: 24.9326
# Epoch 173/200
# 78/98 [======================>.......] - ETA: 0s - loss: 1671.7816 - mae: 16.1768
# Epoch 173: val_loss improved from 23512.82422 to 23154.16797, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 1502.5079 - mae: 15.6202 - val_loss: 23154.1680 - val_mae: 24.5636
# Epoch 174/200
# 96/98 [============================>.] - ETA: 0s - loss: 1456.7167 - mae: 15.2352
# Epoch 174: val_loss improved from 23154.16797 to 22842.62500, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 36ms/step - loss: 1444.6766 - mae: 15.2794 - val_loss: 22842.6250 - val_mae: 24.3117
# Epoch 175/200
# 89/98 [==========================>...] - ETA: 0s - loss: 1482.9447 - mae: 15.1707
# Epoch 175: val_loss improved from 22842.62500 to 22543.50977, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 1386.9622 - mae: 14.9663 - val_loss: 22543.5098 - val_mae: 24.0368
# Epoch 176/200
# 93/98 [===========================>..] - ETA: 0s - loss: 1304.5389 - mae: 14.5477
# Epoch 176: val_loss improved from 22543.50977 to 22272.72266, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 41ms/step - loss: 1330.3242 - mae: 14.7130 - val_loss: 22272.7227 - val_mae: 23.7616
# Epoch 177/200
# 83/98 [========================>.....] - ETA: 0s - loss: 1314.4120 - mae: 14.3992
# Epoch 177: val_loss improved from 22272.72266 to 21941.93750, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 1277.0427 - mae: 14.4688 - val_loss: 21941.9375 - val_mae: 23.4944
# Epoch 178/200
# 92/98 [===========================>..] - ETA: 0s - loss: 1218.9122 - mae: 14.2241
# Epoch 178: val_loss improved from 21941.93750 to 21731.40430, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 1227.6730 - mae: 14.2635 - val_loss: 21731.4043 - val_mae: 23.2850
# Epoch 179/200
# 84/98 [========================>.....] - ETA: 0s - loss: 1301.3174 - mae: 14.4433
# Epoch 179: val_loss improved from 21731.40430 to 21347.23242, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 1185.3534 - mae: 14.1561 - val_loss: 21347.2324 - val_mae: 23.0134
# Epoch 180/200
# 91/98 [==========================>...] - ETA: 0s - loss: 1183.1923 - mae: 13.9735
# Epoch 180: val_loss improved from 21347.23242 to 21072.88086, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 39ms/step - loss: 1130.9568 - mae: 13.8864 - val_loss: 21072.8809 - val_mae: 22.7968
# Epoch 181/200
# 90/98 [==========================>...] - ETA: 0s - loss: 1096.6284 - mae: 13.6079
# Epoch 181: val_loss improved from 21072.88086 to 20807.56250, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 46ms/step - loss: 1086.4236 - mae: 13.6244 - val_loss: 20807.5625 - val_mae: 22.5368
# Epoch 182/200
# 96/98 [============================>.] - ETA: 0s - loss: 1049.3038 - mae: 13.4774
# Epoch 182: val_loss improved from 20807.56250 to 20523.35938, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 1041.7047 - mae: 13.4826 - val_loss: 20523.3594 - val_mae: 22.2572
# Epoch 183/200
# 84/98 [========================>.....] - ETA: 0s - loss: 989.6483 - mae: 13.0029
# Epoch 183: val_loss improved from 20523.35938 to 20257.39844, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 999.9978 - mae: 13.2103 - val_loss: 20257.3984 - val_mae: 22.0876
# Epoch 184/200
# 77/98 [======================>.......] - ETA: 0s - loss: 933.9305 - mae: 13.2209
# Epoch 184: val_loss improved from 20257.39844 to 19972.91406, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 958.7665 - mae: 13.0703 - val_loss: 19972.9141 - val_mae: 21.9133
# Epoch 185/200
# 90/98 [==========================>...] - ETA: 0s - loss: 944.6930 - mae: 12.8265
# Epoch 185: val_loss improved from 19972.91406 to 19722.29883, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 38ms/step - loss: 919.4011 - mae: 12.8839 - val_loss: 19722.2988 - val_mae: 21.7503
# Epoch 186/200
# 96/98 [============================>.] - ETA: 0s - loss: 892.8989 - mae: 12.7797
# Epoch 186: val_loss improved from 19722.29883 to 19468.69336, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 883.4036 - mae: 12.7358 - val_loss: 19468.6934 - val_mae: 21.4866
# Epoch 187/200
# 92/98 [===========================>..] - ETA: 0s - loss: 725.8924 - mae: 12.3227
# Epoch 187: val_loss improved from 19468.69336 to 19221.48633, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 31ms/step - loss: 846.8741 - mae: 12.5508 - val_loss: 19221.4863 - val_mae: 21.2377
# Epoch 188/200
# 96/98 [============================>.] - ETA: 0s - loss: 820.1058 - mae: 12.4161
# Epoch 188: val_loss improved from 19221.48633 to 18955.37305, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 36ms/step - loss: 811.9165 - mae: 12.3854 - val_loss: 18955.3730 - val_mae: 21.0689
# Epoch 189/200
# 81/98 [=======================>......] - ETA: 0s - loss: 883.2331 - mae: 12.4610
# Epoch 189: val_loss improved from 18955.37305 to 18712.98633, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 780.4158 - mae: 12.2452 - val_loss: 18712.9863 - val_mae: 20.8831
# Epoch 190/200
# 81/98 [=======================>......] - ETA: 0s - loss: 808.4712 - mae: 12.1922
# Epoch 190: val_loss improved from 18712.98633 to 18476.96484, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 34ms/step - loss: 749.6747 - mae: 12.1491 - val_loss: 18476.9648 - val_mae: 20.6642
# Epoch 191/200
# 76/98 [======================>.......] - ETA: 0s - loss: 692.1172 - mae: 11.9908
# Epoch 191: val_loss improved from 18476.96484 to 18238.29492, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 35ms/step - loss: 715.9311 - mae: 11.9661 - val_loss: 18238.2949 - val_mae: 20.4504
# Epoch 192/200
# 78/98 [======================>.......] - ETA: 0s - loss: 771.1957 - mae: 12.0272
# Epoch 192: val_loss improved from 18238.29492 to 18004.09961, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 29ms/step - loss: 688.5732 - mae: 11.8336 - val_loss: 18004.0996 - val_mae: 20.3039
# Epoch 193/200
# 76/98 [======================>.......] - ETA: 0s - loss: 761.9415 - mae: 11.8152
# Epoch 193: val_loss improved from 18004.09961 to 17756.40039, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 659.8173 - mae: 11.6644 - val_loss: 17756.4004 - val_mae: 20.0613
# Epoch 194/200
# 87/98 [=========================>....] - ETA: 0s - loss: 659.1590 - mae: 11.6015
# Epoch 194: val_loss improved from 17756.40039 to 17546.38477, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 636.6603 - mae: 11.5185 - val_loss: 17546.3848 - val_mae: 19.9058
# Epoch 195/200
# 76/98 [======================>.......] - ETA: 0s - loss: 464.4684 - mae: 11.1055
# Epoch 195: val_loss improved from 17546.38477 to 17336.25195, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 608.6790 - mae: 11.4136 - val_loss: 17336.2520 - val_mae: 19.9521
# Epoch 196/200
# 96/98 [============================>.] - ETA: 0s - loss: 586.3852 - mae: 11.2647
# Epoch 196: val_loss improved from 17336.25195 to 17108.92578, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 585.4070 - mae: 11.3018 - val_loss: 17108.9258 - val_mae: 19.6610
# Epoch 197/200
# 84/98 [========================>.....] - ETA: 0s - loss: 624.8117 - mae: 11.4170
# Epoch 197: val_loss improved from 17108.92578 to 16877.96094, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 3s 29ms/step - loss: 563.7480 - mae: 11.1741 - val_loss: 16877.9609 - val_mae: 19.4336
# Epoch 198/200
# 81/98 [=======================>......] - ETA: 0s - loss: 604.8670 - mae: 11.2145
# Epoch 198: val_loss improved from 16877.96094 to 16671.03516, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 42ms/step - loss: 540.1084 - mae: 11.0146 - val_loss: 16671.0352 - val_mae: 19.4352
# Epoch 199/200
# 97/98 [============================>.] - ETA: 0s - loss: 518.6368 - mae: 10.9473
# Epoch 199: val_loss improved from 16671.03516 to 16453.26172, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 40ms/step - loss: 517.7806 - mae: 10.9387 - val_loss: 16453.2617 - val_mae: 19.2310
# Epoch 200/200
# 76/98 [======================>.......] - ETA: 0s - loss: 558.2114 - mae: 10.9018
# Epoch 200: val_loss improved from 16453.26172 to 16262.43066, saving model to .\
# INFO:tensorflow:Assets written to: .\assets
# 98/98 [==============================] - 4s 37ms/step - loss: 497.6081 - mae: 10.7973 - val_loss: 16262.4307 - val_mae: 19.1754

# %%
pred = model.predict(test_feature)

import matplotlib.pyplot as plt 

plt.figure(figsize=(16, 10))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.grid()
plt.show()
