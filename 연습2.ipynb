# %%
import pandas as pd
import numpy as np
df = pd.read_excel("../데이터자료/join_data.xlsx")
df.columns
# Out:
# Index(['Unnamed: 0', 'DateTime', '종가_ex', '대비_ex', '증감률_ex', '1Y_Mid_irs',
#        '1Y_전일비_irs', '2Y_Mid_irs', '2Y_전일비_irs', '3Y_Mid_irs', '3Y_전일비_irs',
#        '5Y_Mid_irs', '5Y_전일비_irs', '10Y_Mid_irs', '10Y_전일비_irs', '1Y_Mid_crs',
#        '1Y_전일비_crs', '2Y_Mid_crs', '2Y_전일비_crs', '3Y_Mid_crs', '3Y_전일비_crs',
#        '5Y_Mid_crs', '5Y_전일비_crs', '10Y_Mid_crs', '10Y_전일비_crs', '국고1년',
#        '국고3년', '국고5년', '국고10년', '통안364일', '통안2년', 'Bid_ndf', 'Ask_ndf',
#        'Mid_ndf', '전일비_ndf', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스',
#        '10Y_베이시스', 'M1_스왑포인트'],
#       dtype='object')

# %%
index1 = df[df["1Y_Mid_crs"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["통안364일"] == 0].index
df.drop(index2, inplace=True)
index1 = df[df["2Y_Mid_crs"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["통안2년"] == 0].index
df.drop(index2, inplace=True)
index1 = df[df["3Y_Mid_crs"] == 0].index
df.drop(index1, inplace=True)
index1 = df[df["5Y_Mid_crs"] == 0].index
df.drop(index1, inplace=True)
index1 = df[df["10Y_Mid_crs"] == 0].index
df.drop(index1, inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
index1 = df[df["1Y_Mid_irs"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["2Y_Mid_irs"] == 0].index
df.drop(index2, inplace=True)
index1 = df[df["3Y_Mid_irs"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["5Y_Mid_irs"] == 0].index
df.drop(index2, inplace=True)
index2 = df[df["10Y_Mid_irs"] == 0].index
df.drop(index2, inplace=True)
index1 = df[df["국고1년"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["국고3년"] == 0].index
df.drop(index2, inplace=True)
index1 = df[df["국고5년"] == 0].index
df.drop(index1, inplace=True)
index2 = df[df["국고10년"] == 0].index
df.drop(index2, inplace=True)
df.drop(index2, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
index1 = df[df['1Y_베이시스'] == 0].index
df.drop(index1, inplace=True)
index2 = df[df['2Y_베이시스'] == 0].index
df.drop(index2, inplace=True)
index1 = df[df['3Y_베이시스'] == 0].index
df.drop(index1, inplace=True)
index2 = df[df['5Y_베이시스'] == 0].index
df.drop(index2, inplace=True)
index1 = df[df['10Y_베이시스'] == 0].index
df.drop(index1, inplace=True)
index2 = df[df['M1_스왑포인트'] == 0].index
df.drop(index2, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.count
# Out:
# <bound method DataFrame.count of       Unnamed: 0    DateTime   종가_ex  대비_ex  증감률_ex  1Y_Mid_irs  1Y_전일비_irs  \
# 0              0  2012-08-01  1126.5   -4.1   -0.36       2.850       -0.03
# 1              1  2012-08-02  1131.7    5.2    0.46       2.820       -0.03
# 2              2  2012-08-03  1134.8    3.1    0.27       2.790       -0.03
# 3              3  2012-08-06  1129.0   -5.8   -0.51       2.810        0.02
# 4              4  2012-08-07  1128.8   -0.2   -0.02       2.820        0.01
# ...          ...         ...     ...    ...     ...         ...         ...
# 2385        2455  2022-07-25  1313.7    0.7    0.05       3.165       -0.04
# 2386        2456  2022-07-26  1307.6   -6.1   -0.47       3.155       -0.01
# 2387        2457  2022-07-27  1313.3    5.7    0.43       3.145       -0.01
# 2388        2458  2022-07-28  1296.1  -17.2   -1.33       3.175        0.03
# 2389        2459  2022-07-29  1299.1    3.0    0.23       3.105       -0.07
#
# ...

# %%
df['1Y_전일비_irs'] = (df['1Y_Mid_irs']-df['1Y_Mid_irs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['2Y_전일비_irs'] = (df['2Y_Mid_irs']-df['2Y_Mid_irs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['3Y_전일비_irs'] = (df['3Y_Mid_irs']-df['3Y_Mid_irs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['5Y_전일비_irs'] = (df['5Y_Mid_irs']-df['5Y_Mid_irs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['10Y_전일비_irs'] = (df['10Y_Mid_irs']-df['10Y_Mid_irs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['1Y_전일비_crs'] = (df['1Y_Mid_crs']-df['1Y_Mid_crs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['2Y_전일비_crs'] = (df['2Y_Mid_crs']-df['2Y_Mid_crs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['3Y_전일비_irs'] = (df['3Y_Mid_irs']-df['3Y_Mid_crs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['5Y_전일비_irs'] = (df['5Y_Mid_irs']-df['5Y_Mid_crs'].shift(1))/df['1Y_Mid_crs'].shift(1)
df['10Y_전일비_irs'] = (df['10Y_Mid_irs']-df['10Y_Mid_crs'].shift(1))/df['1Y_Mid_crs'].shift(1)

# %%
df['국고1년_전일비'] = (df['국고1년']-df['국고1년'].shift(1))/df['국고1년'].shift(1)
df['국고3년_전일비'] = (df['국고3년']-df['국고3년'].shift(1))/df['국고3년'].shift(1)
df['국고5년_전일비'] = (df['국고5년']-df['국고5년'].shift(1))/df['국고5년'].shift(1)
df['국고10년_전일비'] = (df['국고10년']-df['국고10년'].shift(1))/df['국고10년'].shift(1)
df['통안364일_전일비'] = (df['통안364일']-df['통안364일'].shift(1))/df['통안364일'].shift(1)
df['통안2년_전일비'] = (df['통안2년']-df['통안2년'].shift(1))/df['통안2년'].shift(1)

# %%
df['1Y_베이시스_전일비'] =(df['1Y_베이시스'] - df['1Y_베이시스'].shift(1))/df['1Y_베이시스'].shift(1)
df['2Y_베이시스_전일비'] =(df['2Y_베이시스'] - df['2Y_베이시스'].shift(1))/df['2Y_베이시스'].shift(1)
df['3Y_베이시스_전일비'] =(df['3Y_베이시스'] - df['3Y_베이시스'].shift(1))/df['3Y_베이시스'].shift(1)
df['5Y_베이시스_전일비'] =(df['5Y_베이시스'] - df['5Y_베이시스'].shift(1))/df['5Y_베이시스'].shift(1)
df['10Y_베이시스_전일비'] =(df['10Y_베이시스'] - df['10Y_베이시스'].shift(1))/df['10Y_베이시스'].shift(1)

# %%
df = df.drop(['Unnamed: 0','1Y_Mid_irs','2Y_Mid_irs','국고1년', '국고3년', '국고5년', '국고10년'], axis = 1)
df = df.drop(['3Y_Mid_irs','5Y_Mid_irs','10Y_Mid_irs','1Y_Mid_crs','2Y_Mid_crs'], axis = 1)
df = df.drop(['3Y_Mid_crs','5Y_Mid_crs', '10Y_Mid_crs', 'Bid_ndf', 'Ask_ndf','Mid_ndf',], axis = 1)
df = df.drop(['통안364일', '통안2년' , '1Y_베이시스', '2Y_베이시스', '3Y_베이시스', '5Y_베이시스','10Y_베이시스'], axis = 1)

# %%
df= df.set_index("DateTime")
df =df.dropna()

# %%
df.columns
# Out:
# Index(['종가_ex', '대비_ex', '증감률_ex', '1Y_전일비_irs', '2Y_전일비_irs', '3Y_전일비_irs',
#        '5Y_전일비_irs', '10Y_전일비_irs', '1Y_전일비_crs', '2Y_전일비_crs', '3Y_전일비_crs',
#        '5Y_전일비_crs', '10Y_전일비_crs', '전일비_ndf', 'M1_스왑포인트', '국고1년_전일비',
#        '국고3년_전일비', '국고5년_전일비', '국고10년_전일비', '통안364일_전일비', '통안2년_전일비',
#        '1Y_베이시스_전일비', '2Y_베이시스_전일비', '3Y_베이시스_전일비', '5Y_베이시스_전일비',
#        '10Y_베이시스_전일비'],
#       dtype='object')

# %%
# 히트맵 그리기
import matplotlib.pyplot as plt
import seaborn as sns   
import scipy as sp 
from matplotlib import rc 
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(50,30))

cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(data = df.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap=cmap, center=0)
# Out:
# <AxesSubplot:>

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '2Y_전일비_irs', '3Y_전일비_irs',
       '5Y_전일비_irs', '10Y_전일비_irs', '1Y_전일비_crs', '2Y_전일비_crs', '3Y_전일비_crs',
       '5Y_전일비_crs', '10Y_전일비_crs', '전일비_ndf', '국고1년_전일비', '국고3년_전일비',
       '국고5년_전일비', '국고10년_전일비', '통안364일_전일비', '통안2년_전일비', '1Y_베이시스_전일비',
       '2Y_베이시스_전일비', '3Y_베이시스_전일비', '5Y_베이시스_전일비', '10Y_베이시스_전일비',
       'M1_스왑포인트']]

# %%
import statsmodels.api as sm
feature_add = sm.add_constant(df_Data, has_constant='add')

# sm OLS 적합
model = sm.OLS(df_Target, feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  종가_ex   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     19.10
# Date:                Sun, 21 Aug 2022   Prob (F-statistic):           1.95e-71
# Time:                        14:37:24   Log-Likelihood:                -12799.
# No. Observations:                2389   AIC:                         2.565e+04
# Df Residuals:                    2365   BIC:                         2.579e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '2Y_전일비_irs', '3Y_전일비_irs',
         '1Y_전일비_crs', '2Y_전일비_crs', '3Y_전일비_crs',
        '10Y_전일비_crs', '전일비_ndf', '국고1년_전일비', '국고3년_전일비',
       '국고5년_전일비', '국고10년_전일비', '통안364일_전일비', '통안2년_전일비', '1Y_베이시스_전일비',
        '3Y_베이시스_전일비', '5Y_베이시스_전일비', '10Y_베이시스_전일비',
       'M1_스왑포인트']]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = df_Data
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     3.135997    1Y_전일비_irs
# 1     2.846533    2Y_전일비_irs
# 2     1.087845    3Y_전일비_irs
# 3     4.477497    1Y_전일비_crs
# 4     5.127585    2Y_전일비_crs
# 5     2.504989    3Y_전일비_crs
# 6     2.456300   10Y_전일비_crs
# 7     1.003788       전일비_ndf
# 8     2.605042      국고1년_전일비
# 9     5.437886      국고3년_전일비
# 10    5.584462      국고5년_전일비
# 11    2.837171     국고10년_전일비
# 12    1.420898    통안364일_전일비
# 13    2.902401      통안2년_전일비
# 14    2.312710   1Y_베이시스_전일비
# 15    4.608070   3Y_베이시스_전일비
# 16    3.209856   5Y_베이시스_전일비
# 17    2.294377  10Y_베이시스_전일비
# 18    1.004375      M1_스왑포인트

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '2Y_전일비_irs','1Y_전일비_crs', '2Y_전일비_crs', '3Y_전일비_crs',
       '5Y_전일비_crs', '10Y_전일비_crs', '전일비_ndf', '국고1년_전일비', '국고3년_전일비',
       '국고5년_전일비', '국고10년_전일비', '통안364일_전일비', '통안2년_전일비', '1Y_베이시스_전일비',
       '2Y_베이시스_전일비', '3Y_베이시스_전일비', '5Y_베이시스_전일비', '10Y_베이시스_전일비',
       'M1_스왑포인트']]

# %%
import statsmodels.api as sm
feature_add = sm.add_constant(df_Data, has_constant='add')

# sm OLS 적합
model = sm.OLS(df_Target, feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  종가_ex   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     22.22
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           5.75e-71
# Time:                        20:32:38   Log-Likelihood:                -12807.
# No. Observations:                2389   AIC:                         2.565e+04
# Df Residuals:                    2369   BIC:                         2.577e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = df_Data
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     2.978952    1Y_전일비_irs
# 1     2.825933    2Y_전일비_irs
# 2     4.479459    1Y_전일비_crs
# 3     5.135155    2Y_전일비_crs
# 4     3.673746    3Y_전일비_crs
# 5     6.453433    5Y_전일비_crs
# 6     4.032071   10Y_전일비_crs
# 7     1.004257       전일비_ndf
# 8     2.605696      국고1년_전일비
# 9     5.437403      국고3년_전일비
# 10    5.600131      국고5년_전일비
# 11    2.837455     국고10년_전일비
# 12    1.421001    통안364일_전일비
# 13    2.901329      통안2년_전일비
# 14    2.545929   1Y_베이시스_전일비
# 15   10.448106   2Y_베이시스_전일비
# 16    9.046043   3Y_베이시스_전일비
# 17    3.753506   5Y_베이시스_전일비
# 18    2.415239  10Y_베이시스_전일비
# 19    1.003757      M1_스왑포인트

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '2Y_전일비_irs','1Y_전일비_crs', '2Y_전일비_crs', '3Y_전일비_crs',
        '10Y_전일비_crs', '전일비_ndf', '국고1년_전일비', '국고3년_전일비',
       '국고5년_전일비', '국고10년_전일비', '통안364일_전일비', '통안2년_전일비', '1Y_베이시스_전일비',
       '5Y_베이시스_전일비', '10Y_베이시스_전일비','M1_스왑포인트']]

# %%
import statsmodels.api as sm
feature_add = sm.add_constant(df_Data, has_constant='add')

# sm OLS 적합
model = sm.OLS(df_Target, feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  종가_ex   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     24.27
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.31e-70
# Time:                        20:33:41   Log-Likelihood:                -12811.
# No. Observations:                2389   AIC:                         2.566e+04
# Df Residuals:                    2371   BIC:                         2.576e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = df_Data
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     2.977570    1Y_전일비_irs
# 1     2.821803    2Y_전일비_irs
# 2     4.467304    1Y_전일비_crs
# 3     5.118455    2Y_전일비_crs
# 4     2.480786    3Y_전일비_crs
# 5     2.402597   10Y_전일비_crs
# 6     1.003705       전일비_ndf
# 7     2.603387      국고1년_전일비
# 8     5.422700      국고3년_전일비
# 9     5.564143      국고5년_전일비
# 10    2.835341     국고10년_전일비
# 11    1.420894    통안364일_전일비
# 12    2.895512      통안2년_전일비
# 13    1.654867   1Y_베이시스_전일비
# 14    2.186288   5Y_베이시스_전일비
# 15    2.071554  10Y_베이시스_전일비
# 16    1.002699      M1_스왑포인트

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '1Y_전일비_crs',  
        '10Y_전일비_crs', '전일비_ndf', '국고1년_전일비', 
                '5Y_베이시스_전일비','M1_스왑포인트']]

# %%
import statsmodels.api as sm
feature_add = sm.add_constant(df_Data, has_constant='add')

# sm OLS 적합
model = sm.OLS(df_Target, feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  종가_ex   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     58.78
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           4.73e-78
# Time:                        20:37:42   Log-Likelihood:                -12812.
# No. Observations:                2389   AIC:                         2.564e+04
# Df Residuals:                    2381   BIC:                         2.569e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1141.8127      1.126   1014.210      0.000    1139.605    1144.020
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = df_Data
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor      Feature
# 0     2.446899   1Y_전일비_irs
# 1     2.574818   2Y_전일비_irs
# 2     1.298608   1Y_전일비_crs
# 3     1.318478  10Y_전일비_crs
# 4     1.001715      전일비_ndf
# 5     1.704163     국고1년_전일비
# 6     1.501209    국고10년_전일비
# 7     1.342869   통안364일_전일비
# 8     1.415529  1Y_베이시스_전일비
# 9     1.386808  5Y_베이시스_전일비
# 10    1.002203     M1_스왑포인트

# %%
df_Target = df['종가_ex']
df_Data = df[['1Y_전일비_irs', '전일비_ndf', '국고1년_전일비', 'M1_스왑포인트']]

# %%
import statsmodels.api as sm
feature_add = sm.add_constant(df_Data, has_constant='add')

# sm OLS 적합
model = sm.OLS(df_Target, feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  종가_ex   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     102.4
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.37e-80
# Time:                        20:24:06   Log-Likelihood:                -12813.
# No. Observations:                2389   AIC:                         2.564e+04
# Df Residuals:                    2384   BIC:                         2.567e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1141.7826      1.125   1014.704      0.000    1139.576    1143.989
# ...

# %%
# 1) 원 변수 x4에 수정한 조정 주당배당금, 조정 종가 추가한 csv 가져오기
df = pd.read_excel("../데이터자료/join_data.xlsx")
df.drop('Unnamed: 0', axis= 1 , inplace=True)
#y = df[['총배당금']]
# 2) stepwise 변수 선택법 이전 변수 조정
X_train = df_Data
y_train = df_Target
# 3) stepwise 함수화하기
def stepwise_feature_selection(X_train, y_train, variables=X_train.columns.tolist()):
    import statsmodels.api as sm
    import matplotlib.pyplot as plt
    import warnings
    warnings.filterwarnings("ignore")
    ## 반응 변수
    y_t = y_train 

    selected_variables = [] ## 선택된 변수들
    sl_enter = 0.05
    sl_remove = 0.05
    
    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(variables) > 0:
        remainder = (set(variables) - set(selected_variables))
        pval = pd.Series(index=remainder) ## 변수의 p-value
        ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
        ## 선형 모형을 적합한다.
        for col in remainder: 
            X_t = X_train[selected_variables+[col]]
            X_t = sm.add_constant(X_t)
            model = sm.OLS(y_t,X_t).fit(disp=0)
            pval[col] = model.pvalues[col]
    
        min_pval = pval.min()
        if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
            selected_variables.append(pval.idxmin())
            ## 선택된 변수들에대해서
            ## 어떤 변수를 제거할지 고른다.
            while len(selected_variables) > 0:
                selected_X = X_train[selected_variables]
                selected_X = sm.add_constant(selected_X)
                selected_pval = sm.OLS(y_t,selected_X).fit(disp=0).pvalues[1:] ## 절편항의 p-value는 뺀다
                max_pval = selected_pval.max()
                if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                    remove_variable = selected_pval.idxmax()
                    selected_variables.remove(remove_variable)
                else:
                    break
            
            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y_t,sm.add_constant(X_train[selected_variables])).fit(disp=0).rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break

    fig = plt.figure(figsize=(100,30))
    fig.set_facecolor('white')
    
    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=50)
    plt.plot(steps,adjusted_r_squared, marker='o')
      
    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()

    return selected_variables
    
selected_variables = stepwise_feature_selection(X_train, y_train)
# Out:
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
