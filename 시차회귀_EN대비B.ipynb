# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../데이터자료/시차상관분석4Data.xlsx",index_col=0)

df = df.set_index("DateTime")
df
# Out:
#             Unnamed: 0   종가_ex  1Y_Mid_irs  2Y_Mid_irs  3Y_Mid_irs  \
# DateTime
# 2012-08-02           1  1131.7       2.820       2.690       2.690
# 2012-08-03           2  1134.8       2.790       2.660       2.660
# 2012-08-06           3  1129.0       2.810       2.680       2.680
# 2012-08-07           4  1128.8       2.820       2.680       2.680
# 2012-08-08           5  1128.3       2.830       2.700       2.700
# ...                ...     ...         ...         ...         ...
# 2022-07-25        2455  1313.7       3.165       3.235       3.205
# 2022-07-26        2456  1307.6       3.155       3.215       3.175
# 2022-07-27        2457  1313.3       3.145       3.165       3.115
# 2022-07-28        2458  1296.1       3.175       3.205       3.165
# 2022-07-29        2459  1299.1       3.105       3.065       3.025
#
#             5Y_Mid_irs  10Y_Mid_irs  1Y_Mid_crs  2Y_Mid_crs  3Y_Mid_crs  ...  \
# DateTime                                                                 ...
# 2012-08-02       2.720        2.860        2.08       1.845        1.85  ...
# 2012-08-03       2.690        2.840        2.07       1.830        1.83  ...
# 2012-08-06       2.710        2.850        2.07       1.805        1.80  ...
# 2012-08-07       2.720        2.870        2.09       1.820        1.80  ...
# 2012-08-08       2.740        2.900        2.10       1.820        1.80  ...
# ...                ...          ...         ...         ...         ...  ...
# 2022-07-25       3.125        2.965        2.55       2.730        2.71  ...
# 2022-07-26       3.095        2.935        2.56       2.700        2.68  ...
# 2022-07-27       3.035        2.875        2.57       2.690        2.67  ...
# 2022-07-28       3.085        2.945        2.61       2.730        2.71  ...
# 2022-07-29       2.945        2.825        2.50       2.560        2.56  ...
#
#             국고10년대비  통안1년대비  통안2년대비  전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  \
# DateTime
# 2012-08-02    -0.21   -0.03    0.02          2.0          8.0          9.0
# 2012-08-03    -0.03   -0.03    0.00          2.0          1.5          1.0
# 2012-08-06    -0.03   -0.01    0.02         -2.0         -4.5         -5.0
# 2012-08-07    -0.04   -0.01   -0.01          1.0          1.5          0.0
# 2012-08-08    -0.04   -0.06   -0.03          0.0         -2.0         -2.0
# ...             ...     ...     ...          ...          ...          ...
# 2022-07-25    -0.11    0.05    0.00         -4.0         -1.0          0.0
# 2022-07-26    -0.08    0.01   -0.05          2.0         -1.0          0.0
# 2022-07-27     0.01   -0.01   -0.02          2.0          4.0          5.0
# 2022-07-28     0.06    0.00    0.00          1.0          0.0         -1.0
# 2022-07-29     0.02    0.12    0.01         -4.0         -3.0         -1.0
#
#             전일비_5Y_베이시스  전일비_10Y_베이시스  전날 종가_ex  종가_NDF차이
# DateTime
# 2012-08-02          9.0           9.0    1126.5     -7.50
# 2012-08-03         -5.0         -13.0    1131.7     -6.30
# 2012-08-06         -6.0          -5.0    1134.8      6.30
# 2012-08-07         -8.0         -10.0    1129.0      0.00
# 2012-08-08         -4.0          -7.0    1128.8     -1.45
# ...                 ...           ...       ...       ...
# 2022-07-25         -2.0           0.0    1313.0      3.15
# 2022-07-26          1.0           1.0    1313.7      2.70
# 2022-07-27          5.0           5.0    1307.6     -2.90
# 2022-07-28         -2.0          -5.0    1313.3      7.30
# 2022-07-29          5.0           3.0    1296.1      0.35
#
# [2459 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '종가_ex', '1Y_Mid_irs', '2Y_Mid_irs', '3Y_Mid_irs',
#        '5Y_Mid_irs', '10Y_Mid_irs', '1Y_Mid_crs', '2Y_Mid_crs', '3Y_Mid_crs',
#        '5Y_Mid_crs', '10Y_Mid_crs', '국고1년', '국고3년', '국고5년', '국고10년', '통안364일',
#        '통안2년', 'Mid_ndf', '전일비_ndf', '1Y_베이시스', '2Y_베이시스', '3Y_베이시스',
#        '5Y_베이시스', '10Y_베이시스', 'M1_스왑포인트', '전일대비_종가_ex', '등락률_종가_ex',
#        '전일비_1Y_irs', '전일비_2Y_irs', '전일비_3Y_irs', '전일비_5Y_irs', '전일비_10Y_irs',
#        '전일비_1Y_crs', '전일비_2Y_crs', '전일비_3Y_crs', '전일비_5Y_crs', '전일비_10Y_crs',
#        '국고1년대비', '국고3년대비', '국고5년대비', '국고10년대비', '통안1년대비', '통안2년대비',
#        '전일비_1Y_베이시스', '전일비_2Y_베이시스', '전일비_3Y_베이시스', '전일비_5Y_베이시스',
#        '전일비_10Y_베이시스', '전날 종가_ex', '종가_NDF차이'],
#       dtype='object')

# %%
x = df[['전일비_1Y_베이시스', '전일비_2Y_베이시스', '전일비_3Y_베이시스', '전일비_5Y_베이시스','전일비_10Y_베이시스', 
            '국고1년대비', '국고3년대비', '국고5년대비', '국고10년대비', '통안1년대비', '통안2년대비',
            '종가_NDF차이', 'M1_스왑포인트', '전날 종가_ex']]
y = df['종가_ex']

x.feature = x.columns 

from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()

# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.
scaler.fit(x)
data_scaled = scaler.transform(x)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
x_scaled = pd.DataFrame(data = data_scaled, columns=x.feature)

x_scaled.index = y.index # 인덱스가 달라서 똑같이 설정

x_scaled
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_26596\1602819918.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.feature = x.columns
#             전일비_1Y_베이시스  전일비_2Y_베이시스  전일비_3Y_베이시스  전일비_5Y_베이시스  전일비_10Y_베이시스  \
# DateTime
# 2012-08-02     0.348741     1.544080     1.437744     1.627899      1.488363
# 2012-08-03     0.348741     0.286831     0.157058    -0.910410     -2.158344
# 2012-08-06    -0.350946    -0.873707    -0.803456    -1.091718     -0.832269
# 2012-08-07     0.173819     0.286831    -0.003027    -1.454333     -1.661066
# 2012-08-08    -0.001103    -0.390150    -0.323199    -0.729102     -1.163788
# ...                 ...          ...          ...          ...           ...
# 2022-07-25    -0.700790    -0.196727    -0.003027    -0.366487     -0.003472
# 2022-07-26     0.348741    -0.196727    -0.003027     0.177437      0.162288
# 2022-07-27     0.348741     0.770388     0.797401     0.902668      0.825326
# 2022-07-28     0.173819    -0.003304    -0.163113    -0.366487     -0.832269
# 2022-07-29    -0.700790    -0.583573    -0.163113     0.902668      0.493807
#
#               국고1년대비    국고3년대비    국고5년대비   국고10년대비    통안1년대비    통안2년대비  \
# DateTime
# 2012-08-02  1.898958 -0.488709 -1.584904 -5.377146 -0.325433  0.267777
# 2012-08-03  0.051587  0.004075  0.035699 -0.767092 -0.325433  0.014814
# 2012-08-06  0.051587 -0.160187  2.466603 -0.767092 -0.108742  0.267777
# 2012-08-07 -0.564203 -0.160187 -0.504502 -1.023207 -0.108742 -0.111668
# 2012-08-08 -0.564203 -0.324448  0.035699 -1.023207 -0.650470 -0.364632
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -1.179994  1.975212 -0.234402 -2.816005  0.541331  0.014814
# 2022-07-26  0.667378  0.825382 -1.314804 -2.047663  0.107949 -0.617595
# 2022-07-27  0.051587  0.661120 -1.584904  0.257364 -0.108742 -0.238150
# 2022-07-28  1.283168  1.153905  0.035699  1.537934 -0.000397  0.014814
# 2022-07-29  0.667378 -0.652971  0.305799  0.513478  1.299750  0.141295
#
#             종가_NDF차이  M1_스왑포인트  전날 종가_ex
# DateTime
# 2012-08-02 -0.514682  1.909409 -0.149841
# 2012-08-03 -0.511996  1.818881 -0.056232
# 2012-08-06 -0.483790  1.818881 -0.000426
# 2012-08-07 -0.497893  1.909409 -0.104837
# 2012-08-08 -0.501139  1.818881 -0.108437
# ...              ...       ...       ...
# 2022-07-25 -0.490842 -0.896960  3.207485
# 2022-07-26 -0.491849 -0.987488  3.220086
# 2022-07-27 -0.504385 -0.851696  3.110275
# 2022-07-28 -0.481552 -0.942224  3.212885
# 2022-07-29 -0.497110 -0.896960  2.903255
#
# [2459 rows x 14 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_train = x_scaled

def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_train.values,i)
                         for i in range(X_train.shape[1])]
    vif["Feature"] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor       Feature
# 0     3.107257   전일비_1Y_베이시스
# 1     5.877308   전일비_2Y_베이시스
# 2     2.400721   전일비_3Y_베이시스
# 3     4.756389   전일비_5Y_베이시스
# 4     3.229495  전일비_10Y_베이시스
# 5     1.007229        국고1년대비
# 6     1.003248        국고3년대비
# 7     1.005476        국고5년대비
# 8     1.007618       국고10년대비
# 9     1.003401        통안1년대비
# 10    1.000568        통안2년대비
# 11    1.262504      종가_NDF차이
# 12    1.444284      M1_스왑포인트
# 13    1.297333      전날 종가_ex

# %%
import statsmodels.api as sm

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.785e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:14:58   Log-Likelihood:                -7670.6
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2444   BIC:                         1.546e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스     -1.2581      0.195     -6.443      0.000      -1.641      -0.875
# 전일비_2Y_베이시스     -0.2627      0.269     -0.978      0.328      -0.789       0.264
# 전일비_3Y_베이시스     -0.1588      0.172     -0.925      0.355      -0.495       0.178
# 전일비_5Y_베이시스      0.0757      0.242      0.313      0.754      -0.398       0.549
# 전일비_10Y_베이시스     0.2991      0.199      1.502      0.133      -0.091       0.689
# 국고1년대비          -0.2181      0.111     -1.962      0.050      -0.436      -0.000
# 국고3년대비          -0.4127      0.111     -3.719      0.000      -0.630      -0.195
# 국고5년대비          -0.3749      0.111     -3.375      0.001      -0.593      -0.157
# 국고10년대비         -0.2903      0.111     -2.611      0.009      -0.508      -0.072
# 통안1년대비          -0.2474      0.111     -2.230      0.026      -0.465      -0.030
# 통안2년대비          -0.3701      0.111     -3.340      0.001      -0.587      -0.153
# 종가_NDF차이        -0.1740      0.124     -1.398      0.162      -0.418       0.070
# M1_스왑포인트        -0.2309      0.133     -1.734      0.083      -0.492       0.030
# 전날 종가_ex        55.3234      0.126    438.462      0.000      55.076      55.571
# ==============================================================================
# Omnibus:                       46.709   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.020
# Skew:                           0.010   Prob(JB):                     2.33e-21
# Kurtosis:                       3.963   Cond. No.                         5.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_5Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.923e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:14:58   Log-Likelihood:                -7670.7
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2445   BIC:                         1.545e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스     -1.2566      0.195     -6.438      0.000      -1.639      -0.874
# 전일비_2Y_베이시스     -0.2301      0.248     -0.930      0.353      -0.716       0.255
# 전일비_3Y_베이시스     -0.1500      0.169     -0.886      0.376      -0.482       0.182
# 전일비_10Y_베이시스     0.3297      0.173      1.901      0.057      -0.010       0.670
# 국고1년대비          -0.2180      0.111     -1.961      0.050      -0.436    1.72e-05
# 국고3년대비          -0.4127      0.111     -3.720      0.000      -0.630      -0.195
# 국고5년대비          -0.3755      0.111     -3.382      0.001      -0.593      -0.158
# 국고10년대비         -0.2906      0.111     -2.614      0.009      -0.509      -0.073
# 통안1년대비          -0.2474      0.111     -2.230      0.026      -0.465      -0.030
# 통안2년대비          -0.3698      0.111     -3.338      0.001      -0.587      -0.153
# 종가_NDF차이        -0.1741      0.124     -1.399      0.162      -0.418       0.070
# M1_스왑포인트        -0.2309      0.133     -1.735      0.083      -0.492       0.030
# 전날 종가_ex        55.3231      0.126    438.552      0.000      55.076      55.570
# ==============================================================================
# Omnibus:                       46.897   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.577
# Skew:                           0.009   Prob(JB):                     1.76e-21
# Kurtosis:                       3.966   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_2Y_베이시스', '전일비_3Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.272e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:14:59   Log-Likelihood:                -7671.9
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2447   BIC:                         1.544e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스     -1.4465      0.143    -10.134      0.000      -1.726      -1.167
# 전일비_10Y_베이시스     0.1772      0.143      1.243      0.214      -0.102       0.457
# 국고1년대비          -0.2188      0.111     -1.968      0.049      -0.437      -0.001
# 국고3년대비          -0.4106      0.111     -3.702      0.000      -0.628      -0.193
# 국고5년대비          -0.3746      0.111     -3.373      0.001      -0.592      -0.157
# 국고10년대비         -0.2856      0.111     -2.570      0.010      -0.503      -0.068
# 통안1년대비          -0.2456      0.111     -2.214      0.027      -0.463      -0.028
# 통안2년대비          -0.3695      0.111     -3.335      0.001      -0.587      -0.152
# 종가_NDF차이        -0.1726      0.124     -1.387      0.166      -0.417       0.071
# M1_스왑포인트        -0.2307      0.133     -1.733      0.083      -0.492       0.030
# 전날 종가_ex        55.3230      0.126    438.503      0.000      55.076      55.570
# ==============================================================================
# Omnibus:                       44.797   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.328
# Skew:                           0.019   Prob(JB):                     4.01e-20
# Kurtosis:                       3.933   Cond. No.                         2.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['전일비_10Y_베이시스'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.499e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:14:59   Log-Likelihood:                -7672.7
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2448   BIC:                         1.543e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스    -1.3352      0.111    -12.007      0.000      -1.553      -1.117
# 국고1년대비         -0.2198      0.111     -1.977      0.048      -0.438      -0.002
# 국고3년대비         -0.4113      0.111     -3.708      0.000      -0.629      -0.194
# 국고5년대비         -0.3738      0.111     -3.366      0.001      -0.592      -0.156
# 국고10년대비        -0.2826      0.111     -2.543      0.011      -0.500      -0.065
# 통안1년대비         -0.2442      0.111     -2.201      0.028      -0.462      -0.027
# 통안2년대비         -0.3686      0.111     -3.327      0.001      -0.586      -0.151
# 종가_NDF차이       -0.1735      0.124     -1.394      0.163      -0.418       0.071
# M1_스왑포인트       -0.2335      0.133     -1.754      0.080      -0.494       0.028
# 전날 종가_ex       55.3201      0.126    438.509      0.000      55.073      55.567
# ==============================================================================
# Omnibus:                       47.976   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.573
# Skew:                           0.018   Prob(JB):                     3.94e-22
# Kurtosis:                       3.980   Cond. No.                         1.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['종가_NDF차이'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.775e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:14:59   Log-Likelihood:                -7673.7
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2449   BIC:                         1.543e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스    -1.3335      0.111    -11.990      0.000      -1.552      -1.115
# 국고1년대비         -0.2248      0.111     -2.023      0.043      -0.443      -0.007
# 국고3년대비         -0.4145      0.111     -3.737      0.000      -0.632      -0.197
# 국고5년대비         -0.3710      0.111     -3.341      0.001      -0.589      -0.153
# 국고10년대비        -0.2887      0.111     -2.601      0.009      -0.506      -0.071
# 통안1년대비         -0.2457      0.111     -2.214      0.027      -0.463      -0.028
# 통안2년대비         -0.3689      0.111     -3.329      0.001      -0.586      -0.152
# M1_스왑포인트       -0.1524      0.120     -1.273      0.203      -0.387       0.082
# 전날 종가_ex       55.3745      0.120    461.460      0.000      55.139      55.610
# ==============================================================================
# Omnibus:                       48.093   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.103
# Skew:                           0.009   Prob(JB):                     3.02e-22
# Kurtosis:                       3.983   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_scaled.drop(['M1_스왑포인트'], axis=1, inplace=True)

feature_add = sm.add_constant(x_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  종가_ex   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 3.122e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:15:00   Log-Likelihood:                -7674.5
# No. Observations:                2459   AIC:                         1.537e+04
# Df Residuals:                    2450   BIC:                         1.542e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1134.8939      0.111   1.02e+04      0.000    1134.677    1135.111
# 전일비_1Y_베이시스    -1.3327      0.111    -11.982      0.000      -1.551      -1.115
# 국고1년대비         -0.2215      0.111     -1.994      0.046      -0.439      -0.004
# 국고3년대비         -0.4151      0.111     -3.741      0.000      -0.633      -0.198
# 국고5년대비         -0.3702      0.111     -3.333      0.001      -0.588      -0.152
# 국고10년대비        -0.2893      0.111     -2.606      0.009      -0.507      -0.072
# 통안1년대비         -0.2462      0.111     -2.218      0.027      -0.464      -0.029
# 통안2년대비         -0.3677      0.111     -3.318      0.001      -0.585      -0.150
# 전날 종가_ex       55.4321      0.111    498.834      0.000      55.214      55.650
# ==============================================================================
# Omnibus:                       48.054   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.028
# Skew:                           0.006   Prob(JB):                     3.14e-22
# Kurtosis:                       3.983   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np 
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=40)
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_pred = mlr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test, y_pred)))
# Out:
# MSE : 29.004403494571527, RMSE :  5.386, MAE: 5.386
# Variance score :  0.991

# %%
from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(mlr, x_scaled, y, scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (5.5285684451598325,
#  array([4.51402414, 6.76404703, 5.63855991, 5.64579496, 5.08041618]),
#  array([-20.37641398, -45.75233227, -31.79335787, -31.87500072,
#         -25.81062854]))

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=10)

from sklearn.model_selection import cross_val_score
neg_mse_scores = cross_val_score(ridge, x_scaled, y, scoring="neg_mean_squared_error", cv = 5)
rmse_scores = np.sqrt(-1 *neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_rmse,rmse_scores, neg_mse_scores
# Out:
# (5.553772938709055,
#  array([4.58082423, 6.74342023, 5.62799607, 5.65177825, 5.16484591]),
#  array([-20.98395062, -45.47371643, -31.67433971, -31.94259741,
#         -26.67563332]))
